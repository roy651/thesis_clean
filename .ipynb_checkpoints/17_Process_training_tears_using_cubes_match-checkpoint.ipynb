# %%
# RUN Main import block and TODO list

# TODO: see how uri calculated the ridges

# TODO: Perform Histogram equalization - start with it
# TODO: 
# take integral from the Highest peak+-0.005 divide by integral of the entire graph 
# This will be the peakness measure for the PSD ==> The desired ridge index
# TODO:
# take integral from the Highest peak+-0.005 divide by integral of the entire graph - it's the peakness measure for the PSD
# must select a peak above a min threshold in order to ignore noisy frequency
# must ignore peaks above a certain threshold in order to detect meaningful frequency
# run the PSD in moving windows every 200 px (deduced from the below PSD pointing to a freq of 1/0.02=50-> times 4= 200px)
# and medianf the result of the windows
# TODO:
# Another alternative: (with Yariv)
# Run PSD column by column - get the phase, freq, peakness and reconstruct an artificial ridge slice
# from this - reconstruct a "clean" artificial ridge image

# %matplotlib inline
import matplotlib.image as img
import matplotlib.pyplot as plt
import numpy as np
import urllib.request
import os
import shutil
import glob
from scipy import ndimage
from scipy import signal
#import cv2

from PIL import Image, ImageDraw, ImageFont

import mahotas as mh
from mahotas import polygon
# import pymorph as pm

import networkx as nx

from scipy import ndimage as nd
import skimage.transform as transform
import skimage.morphology as mp
import skimage.io as sio
import scipy.misc as sm
from skimage.filters import threshold_otsu, threshold_adaptive
from skimage.feature import hessian_matrix, hessian_matrix_eigvals
from skimage import exposure
from skimage import data, img_as_float
from sklearn.metrics import precision_recall_fscore_support

from bisect import bisect_left
import math
import warnings
import csv
import tensorflow as tf
from time import gmtime, strftime

# %%
# RUN Utility functions

# One time init
# with open('results.csv', 'w') as csvfile:
#     csvout = csv.writer(csvfile)
#     csvout.writerow(["File", "Model", "Gap", "Slice_size", "Count", "Precision", "Recall", "F-score", "True Count", "Error Rate"])

#BASIC CROP FRAME
X_START = 1000
X_END = 6000
Y_START = 800
Y_END = 4300
BG_2_OBJ_RATIO = 0.91
CUBE_SIZE = 250
EDGE_GAP = 50
ROOT_FOLDER = "/media/1KGB_ILAN/papyrus/"
# ROOT_FOLDER = "/Users/il239838/Downloads/private/Thesis/Papyrus/PX303/files/"
LEARNING_RATE = 0.001
BATCHES = 2000
BATCH_SIZE = 60
BREAK_VAL = 1000

# Simple crop by x/y ranges
def crop(image, ymin, ymax, xmin, xmax):
    return image[ymin:ymax, xmin:xmax]

# returns a logical matrix of values beyond a threshld
def thresholded(image, val): 
    return np.logical_and(*[image[...] > val  for t in enumerate([0, 0])])

def find_min_max_without_orphand_pixels(nonzero_dimension, crop_filter=20):
    sorted = np.sort(nonzero_dimension)
    prev=-1
    min_val = sorted[0]
    for i, x in enumerate(sorted[:100]):
        if prev >= 0 and x - prev > crop_filter:
            min_val = x
        prev = x
    prev=-1
    max_val = sorted[-1]
    for i, x in enumerate(sorted[-100:]):
        if prev >= 0 and x - prev > crop_filter:
            max_val = prev
            break
        prev = x
    
    return min_val, max_val

def calc_min_max_coordinates(image, crop_val=50):
    temp = thresholded(image, crop_val)
    temp = temp * 1
    temp = np.nonzero(temp)
    ymin, ymax = find_min_max_without_orphand_pixels(temp[0])
    xmin,xmax = find_min_max_without_orphand_pixels(temp[1])
    return ymin, ymax, xmin, xmax

def calc_min_max_coordinates_dynamic(image, cutoff=1):
    temp = exposure.equalize_adapthist(image, clip_limit=0.03)
    flat = np.sort(np.matrix.getA1(temp))
    sum_all = np.sum(flat)
    index = np.argmin(flat.cumsum() < (sum_all * cutoff))

    temp = thresholded(temp, flat[index])
    temp = temp * 1
    temp = np.nonzero(temp)
    ymin, ymax = find_min_max_without_orphand_pixels(temp[0])
    xmin,xmax = find_min_max_without_orphand_pixels(temp[1])
    return ymin, ymax, xmin, xmax

# initial static crop and a seondary dynamic crop based on signal2noise ratio
def crop_full_scan(image, x_start, x_end, y_start, y_end):
    temp = crop(image, y_start, y_end, x_start, x_end)
    ymin, ymax, xmin, xmax = calc_min_max_coordinates_dynamic(temp, cutoff=BG_2_OBJ_RATIO)
    temp = crop(image, y_start+ymin, y_start+ymax, x_start+xmin, x_start+xmax)
    return temp

def crop_thresholded(image):
    temp = crop(image, 0, image.shape[0]-1, 0, image.shape[1]-1)
    ymin, ymax, xmin, xmax = calc_min_max_coordinates(temp)
    temp = crop(image, ymin, ymax, xmin, xmax)
    return temp

def read_and_crop(image_name, x_start=X_START, x_end=X_END, y_start=Y_START, y_end=Y_END):
    #if "il239838" in os.getcwd():
    #    image = img.imread(ROOT_FOLDER + image_name)
    #else:
    #    f = urllib.request.urlopen("https://dl.dropboxusercontent.com/s/31b96942qdcn73k/" + image_name)
    #    image = img.imread(f, format='jpeg')
    image = img.imread(ROOT_FOLDER + image_name)
    
    # Smart-crop the image to get rid of all the noise and redundant area
    # return crop_full_scan(image)
    cropped = crop_full_scan(image, x_start, x_end, y_start, y_end)
    return exposure.equalize_adapthist(cropped, clip_limit=0.03)


# TODO: fix performance!!! http://scikit-image.org/docs/dev/user_guide/tutorial_parallelization.html
def combine_3_images_to_RGB(red, green, blue):
    new_image = np.empty((blue.shape[0],blue.shape[1],3))
    for x in range(0, blue.shape[0]):
        for y in range(0, blue.shape[1]):
            new_image[x,y,0] = red[x,y]
            new_image[x,y,1] = green[x,y]
            new_image[x,y,2] = blue[x,y]
    return new_image

def slice_image_left_edge(original, width=200, rotate=0):
    rot = ndimage.rotate(original, rotate)
    # Slice the left slice of the so-called "blue" image
    left_edge_orig = crop(rot, 1, 1400, 1, width)
    left_edge_orig = crop_thresholded(left_edge_orig)

    # Copy to a new array so we don't thrash the origin
    left_edge = np.empty_like (left_edge_orig)
    np.copyto(left_edge, left_edge_orig)

    # Zero down low level "noise" values
    low_values_indices = left_edge < 30  # Where values are low
    left_edge[low_values_indices] = 0  # All low values set to 0
    return left_edge

def get_best_angle_rotation(original, crop=True, width=200):
    min_var = 99999999999
    best_angle = -10
    for x in range(-5,5):
        if crop:            
            rot_edge = slice_image_left_edge(original, width, x)
        else:
            rot_edge = ndimage.rotate(original, x)
        left_var = np.var(rot_edge, axis=1)
        # left_var = np.apply_along_axis(lambda v: np.var(v[np.nonzero(v)]), 1, rot_edge)
        var_sum = np.sum(left_var)
        if (var_sum < min_var):
            min_var = var_sum
            best_angle = x
    print ("best_angle="+str(best_angle))
    return best_angle

#     import pdb; pdb.set_trace()
def calc_neighbors(slice_map, col, row):
    # import pdb; pdb.set_trace()
    if ((col-1, row) in slice_map and slice_map[(col-1, row)] != None):
        slice_map[(col, row)]["left"] = slice_map[(col-1, row)]
        slice_map[(col-1, row)]["right"] = slice_map[(col, row)]
    if ((col+1, row) in slice_map and slice_map[(col+1, row)] != None):
        slice_map[(col, row)]["right"] = slice_map[(col+1, row)]
        slice_map[(col+1, row)]["left"] = slice_map[(col, row)]
    if ((col, row-1) in slice_map and slice_map[(col, row-1)] != None):
        slice_map[(col, row)]["top"] = slice_map[(col, row-1)]
        slice_map[(col, row-1)]["bottom"] = slice_map[(col, row)]
    if ((col, row+1) in slice_map and slice_map[(col, row+1)] != None):
        slice_map[(col, row)]["bottom"] = slice_map[(col, row+1)]
        slice_map[(col, row+1)]["top"] = slice_map[(col, row)]
    


def VAL_create_cube(name, raw, x, y):
    cube = {}
    cube["cube"] = raw
    cube["file"] = name
    #     if name.find('P') == 0:
    #         cube["index"] = int(name[name.find('P')+1:name.find('P')+4]) * 1000 + int(name[name.find('Fg')+2:name.find('Fg')+5])
    #     else:
    # print("Found a ZERO index cube with the name:"+name)
    cube["index"] = 0
    cube["top_row"] = x
    cube["left_col"] = y
    cube["right_col"] = y + CUBE_SIZE
    return cube
    

ZERO_CUBE = VAL_create_cube("ZERO", np.zeros((CUBE_SIZE, CUBE_SIZE), dtype=np.int), -1, -2)

# slice an image to cubes with 250X250 pixel size
def VAL_slice_TEAR_to_static_slices(name, cropped_original):
    structure = {}
    # cropped_original = cropped_original / 256 # divide by 256 to "normalize" between 0 and 1

    x, y = cropped_original["cut"].shape
    # print (x,y)
    n = 0
    # see n offset to see offset in pixels on the x axis == rows. every n equals CUBE_SIZE
    while ((n + 1) * CUBE_SIZE < x):
        # mark the piece as narrow so the first would be counted as lastt too
        narrow = True if ((CUBE_SIZE + (4 * EDGE_GAP)) > y) else False
        # cut a cube of 250X250 at the FIRST column
        start_row_px = int(np.round(n * CUBE_SIZE, -1))
        end_row_px = int(np.round((n + 1) * CUBE_SIZE, -1))

        # crop a cube on the starting edge of the current row. 
        # start with EDGE_GAP and move inwards untill we have value
        fg_value = 0
        iteration = 1
        while fg_value <= 0.2 and iteration <= 5:
            cube = (crop(cropped_original["cut"], start_row_px, end_row_px, \
                         EDGE_GAP * iteration, CUBE_SIZE + (EDGE_GAP * iteration)))
            iteration += 1
            fg_value = np.median(cube)
            
        # keep only cubes for which half of the pixels have some "color"
        if np.median(cube) > 0.2: # aligned with the normalization 0.2 correlates to 50
            # keep the cube
            new_cube = VAL_create_cube(name, cube, start_row_px, EDGE_GAP)
            new_cube["col"] = 0 # marks that the cube is on the first col of the piece
            new_cube["row"] = n
            new_cube["last"] = narrow # marks that the cube is on the last col of the piece
            new_cube["orig"] = cropped_original
            new_cube["col_px_left"] = cropped_original["col_px"] + EDGE_GAP
            new_cube["col_px_right"] = cropped_original["col_px"] + CUBE_SIZE + EDGE_GAP
            new_cube["row_px_top"] = cropped_original["row_px"] + start_row_px
            new_cube["row_px_bottom"] = cropped_original["row_px"] + end_row_px
            structure[(0, n)] = new_cube

        # crop a cube on the starting edge of the current row. 
        # start with EDGE_GAP and move inwards untill we have value
        fg_value = 0
        iteration = 1
        while fg_value <= 0.2 and iteration <= 5:
            cube = (crop(cropped_original["cut"], start_row_px, end_row_px, \
                         y - CUBE_SIZE - (EDGE_GAP * iteration), y - (EDGE_GAP * iteration)))
            iteration += 1
            fg_value = np.median(cube)
            
        # keep only cubes for which half of the pixels have some "color"
        # aligned with the normalization 0.2 correlates to 50
        if np.median(cube) > 0.2:
            # keep the cube
            new_cube = VAL_create_cube(name, cube, start_row_px, y - CUBE_SIZE - EDGE_GAP)
            new_cube["col"] = 1 # marks that the cube is on the last col of the piece
            new_cube["row"] = n
            new_cube["last"] = not narrow # like col - marks that the cube is on the last col of the piece
            new_cube["orig"] = cropped_original
            new_cube["col_px_left"] = cropped_original["col_px"] + y - CUBE_SIZE - EDGE_GAP
            new_cube["col_px_right"] = cropped_original["col_px"] + y - EDGE_GAP
            new_cube["row_px_top"] = cropped_original["row_px"] + start_row_px
            new_cube["row_px_bottom"] = cropped_original["row_px"] + end_row_px
            structure[(1, n)] = new_cube

    #         m = 0
    #         # every 250 pixels on the y axis == cols
    #         while ((m + 1) * CUBE_SIZE < y):            
    #             if ((m == 0) or ((m + 2) * CUBE_SIZE >= y)): # Only keep the left and right edges of the piece for matching!!
    #                 # cut a cube of 250X250
    #                 cube = crop(cropped_original["cut"], n * CUBE_SIZE, (n + 1) * CUBE_SIZE, m * CUBE_SIZE, (m + 1) * CUBE_SIZE)
    #                 # keep only cubes for which half of the pixels have some "color"
    #                 # print(np.median(cube))
    #                 if np.median(cube) > 0.2: # aligned with the normalization 0.2 correlates to 50
    #                     # keep the cube
    #                     new_cube = VAL_create_cube(name, cube, n * CUBE_SIZE, m * CUBE_SIZE)
    #                     new_cube["col"] = m
    #                     new_cube["row"] = n
    #                     new_cube["orig"] = cropped_original
    #                     new_cube["col_px_left"] = cropped_original["col_px"] + m * CUBE_SIZE
    #                     new_cube["col_px_right"] = cropped_original["col_px"] + (m + 1) * CUBE_SIZE
    #                     new_cube["row_px_top"] = cropped_original["row_px"] + n * CUBE_SIZE
    #                     new_cube["row_px_bottom"] = cropped_original["row_px"] + (n + 1) * CUBE_SIZE
    #                     if ((m + 2) * CUBE_SIZE >= y):
    #                         new_cube["last"] = True
    #                     else:
    #                         new_cube["last"] = False
    #                     structure[(m, n)] = new_cube
    #             m += 1
        n += 0.2 # currently set to jump in 50 px offset
        n = np.round(n, 1)
        
    # this loop has to be performed only after we've established all the None cubes
    # import pdb; pdb.set_trace()
    for cube in structure.values():
        # set the reference to neighbor cubes
        if cube != None:
            calc_neighbors(structure, cube["col"], cube["row"])
            
    # return the data structure with all the cubes and the counters of the rows and columns
    return structure.values()

def pad_above(original, above, amount):
    res = np.insert(original["cube"], np.zeros(amount), above["cube"][-amount:], axis=0)
    res = np.delete(res, np.arange(CUBE_SIZE,CUBE_SIZE+amount), axis=0)
    cube = VAL_create_cube(original["file"], res, original["top_row"] - amount, original["left_col"])
    cube["col_px_left"] = original["col_px_left"]
    cube["col_px_right"] = original["col_px_right"]
    cube["row_px_top"] = original["row_px_top"] - amount
    cube["row_px_bottom"] = original["row_px_bottom"] - amount
    return cube

def pad_below(original, below, amount):
    res = np.insert(original["cube"], np.full(amount, CUBE_SIZE), below["cube"][:amount], axis=0)
    res = np.delete(res, np.arange(0, amount), axis=0)
    cube =  VAL_create_cube(original["file"], res, original["top_row"] + amount, original["left_col"])
    cube["col_px_left"] = original["col_px_left"]
    cube["col_px_right"] = original["col_px_right"]
    cube["row_px_top"] = original["row_px_top"] + amount
    cube["row_px_bottom"] = original["row_px_bottom"] + amount
    return cube
    
def pad_left(original, left, amount):
    res = np.insert(original["cube"], np.zeros(amount, dtype=int), left["cube"][:,-amount:], axis=1)
    res = np.delete(res, np.arange(CUBE_SIZE, CUBE_SIZE+amount), axis=1)
    cube = VAL_create_cube(original["file"], res, original["top_row"], original["left_col"] - amount)
    cube["col_px_left"] = original["col_px_left"] - amount
    cube["col_px_right"] = original["col_px_right"] - amount
    cube["row_px_top"] = original["row_px_top"]
    cube["row_px_bottom"] = original["row_px_bottom"]
    return cube

def pad_right(original, right, amount):
    res = np.insert(original["cube"], [CUBE_SIZE], right["cube"][:,:amount], axis=1)
    res = np.delete(res, np.arange(0, amount), axis=1)
    cube = VAL_create_cube(original["file"], res, original["top_row"], original["left_col"] + amount)
    cube["col_px_left"] = original["col_px_left"] + amount
    cube["col_px_right"] = original["col_px_right"] + amount
    cube["row_px_top"] = original["row_px_top"]
    cube["row_px_bottom"] = original["row_px_bottom"]
    return cube
    

# "Shave" the right edge of the cube with <gap> pixels and pad with zeros on the left
def shave_right(original, amount):
    return pad_left(original, ZERO_CUBE, amount)
    

# "Shave" the left edge of the cube with <gap> pixels and pad with zeros on the right    
def shave_left(original, amount):
    return pad_right(original, ZERO_CUBE, amount)
    

# concatenate cubes 
def concatenate_cubes(left, right, slice_size):
    con = np.concatenate((left["cube"][:,-slice_size:], right["cube"][:,:slice_size]), axis=1)
    x_delta = right["top_row"] - left["top_row"]
    y_delta = right["left_col"] - left["right_col"] 
    return con, x_delta, y_delta

# concatenate cubes 
def VAL_concatenate_cubes(left, right, slice_size):
    right_img = right["cube"]
    # next block is not relevant for training ...
    #     # if the left cube is matched to another left cube (or right cube to another right cube) then rotate the right
    #     # cube by 180 so we try to match it upside down, covering the option that the cube was pictured rotated
    #     if ((left["col"] == 0 and right["col"] == 0) or (left["col"] != 0 and right["col"] != 0)):
    #         right_img = np.rot90(right["cube"], 2);

    con = np.concatenate((left["cube"][:,-slice_size:], right_img[:,:slice_size]), axis=1)

    # next block calculates distance based on the distance between left's right-top corner and right's left-top corner    
    #     x_delta = right["top_row"] - left["top_row"]
    #     y_delta = right["left_col"] - left["right_col"] 

    # next block calculates the distance between the centers of cubes, accounting for test set's possibility of reverse slices (left instead of right and vice versa)
    x_delta = right["row_px_top"] - left["row_px_top"] # equivalent to distance between vertical centers
    y_delta = (right["col_px_left"] + (slice_size / 2)) - (left["col_px_right"] - (slice_size / 2)) # measuring the distance between horizontal centers of the slices

    return con, x_delta, y_delta, left["file"], right["file"]
    

# concatenate cubes while artificially creating a gap between them. Pad the other end of the cube with zeros
def concatenate_cubes_zero_pad_gaps(left_orig, right_orig, gap):
    left = left_orig if gap == 0 else shave_right(left_orig, gap)
    right = right_orig if gap == 0 else shave_left(right_orig, gap)
    return concatenate_cubes(left, right)    

# concatenate cubes while artificially creating a gap between them. Pad the other end of the cobe with the nearby
# continuation of the cubes
def concatenate_cubes_with_gap(left_orig, right_orig, gap, left_pad, right_pad, slice_size):
    # import pdb; pdb.set_trace()
    left = left_orig if gap == 0 else pad_left(left_orig, left_pad, gap)
    right = right_orig if gap == 0 else pad_right(right_orig, right_pad, gap)
    return concatenate_cubes(left, right, slice_size)        

# convert the data structure of cubes into a train set of 2 arrays of images and labels
# each image is a concatanation of 2 images from the original cubes set, covering all combinations of images
# effectively creating Nx(N-1) images
def VAL_build_train_set_for_euclidean_distance(cubes, slice_size, folder):
    # clean folder before starting
    for root, dirs, files in os.walk(folder):
        for f in files:
            os.unlink(os.path.join(root, f))

    #import pdb; pdb.set_trace()
    warnings.filterwarnings("ignore")

    train_imgs = []
    train_x_delta = []
    train_y_delta = []
    train_left_obj = []
    train_right_obj = []
    # iterate over all cubes   
    for curr in cubes:
        # iterate over the others (effectively n^2)
        for adj in cubes:
            if (adj["file"] != curr["file"]): # no need to test against self CURRENTLY checking from directions!!!
                #import pdb; pdb.set_trace()
                # append the adjacent image to the current image
                conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr, adj, slice_size)
                output = folder+x_file+"_"+str(curr["top_row"])+"_"+str(curr["left_col"])+"---"+y_file+"_"+str(adj["top_row"])+"_"+str(adj["left_col"])
                np.save(output, conc)
                train_imgs.append(output)
                train_x_delta.append(x_delta)
                train_y_delta.append(y_delta)
                train_left_obj.append(curr)
                train_right_obj.append(adj)

    warnings.filterwarnings("default")
    return train_imgs, train_x_delta, train_y_delta, train_left_obj, train_right_obj


# convert the data structure of cubes into a train set of 2 arrays of images and labels
# each image is a concatanation of 2 images from the original cubes set, covering all combinations of images
# effectively creating Nx(N-1) images
def ORIG_build_train_set(cubes, gap):
    # import pdb; pdb.set_trace()
    warnings.filterwarnings("ignore")

    train_imgs = []
    train_lbls = []
    train_x_delta = []
    train_y_delta = []
    # iterate over the rows and cols, essentially going over the grid of sliced cubes
    for row in range(0, rows):
        for col in range(0, cols):
            # if this cube exists (could have been removed previously due to lack of data)
            if (cubes[(col, row)] != None):
                # for each "current" image in the iteration
                curr = cubes[(col, row)]
                # iterate over all the cubes to find all the "other" (adjacent) cubes
                for adj_row in range(0, rows):
                    for adj_col in range(0, cols):
                        if (adj_row != row or adj_col != col):
                            if (cubes[(adj_col, adj_row)] != None):
                                adj = cubes[(adj_col, adj_row)]
                                # append the adjacent image to the current image
                                # pass the filling cubes on the right and left to pad against the gap
                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys())):
                                    if (gap == 0):
                                        conc, x_delta, y_delta = concatenate_cubes(curr, adj, slice_size)
                                    else:
                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr, adj, gap, curr["left"], adj["right"], slice_size)
                                    train_imgs.append(conc)
                                    train_x_delta.append(x_delta)
                                    train_y_delta.append(y_delta)
                                    # if the adj image is on the same row and on the right of the curr image - it will be marked as match    
                                    if (adj_row == row and adj_col == (col + 1)):
                                        # mark the image as matched
                                        train_lbls.append([0,1])
                                        # need to enrich the set with a few more tru positive samples - so we offset 
                                        # the matched images up ad down a few times and create more matches
                                        if ("top" in curr.keys() and "top"in adj.keys()):
                                            for i in range(5, 101, 5):
                                                curr1 = pad_above(curr, curr["top"],i)
                                                adj1 = pad_above(adj, adj["top"],i)
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys() and "top" in curr["left"].keys() and "top"in curr["right"].keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_above(curr["left"], curr["left"]["top"], i) # FIXIT?
                                                        adj1Right = pad_above(adj["right"], curr["right"]["top"], i) # FIXIT?
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                        if ("bottom" in curr.keys() and "bottom"in adj.keys()):
                                            for i in range(5, 101, 5):
                                                curr1 = pad_below(curr, curr["bottom"],i)
                                                adj1 = pad_below(adj, adj["bottom"],i)
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys() and "bottom" in curr["left"].keys() and "bottom"in curr["right"].keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_below(curr["left"], curr["left"]["bottom"], i) # FIXIT?
                                                        adj1Right = pad_below(adj["right"], curr["right"]["bottom"], i) # FIXIT?
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                        if ("left" in curr.keys()): # enough to check only the curr as the left of the adj is the curr
                                            for i in range(5, 101, 5):
                                                curr1 = pad_left(curr, curr["left"],i)
                                                adj1 = pad_left(adj, adj["left"],i) # essentially the curr
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_left(curr["left"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        adj1Right = pad_left(adj["right"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                        if ("right" in adj.keys()): # enough to check only the adj as the right of the curr is the adj
                                            for i in range(5, 101, 5):
                                                curr1 = pad_right(curr, curr["right"],i) # essentially the adj
                                                adj1 = pad_right(adj, adj["right"],i)
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_right(curr["left"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        adj1Right = pad_right(adj["right"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                    else:
                                        # mark the image as not matched
                                        train_lbls.append([1,0])
                                
    warnings.filterwarnings("default")
    return train_imgs, train_lbls, train_x_delta, train_y_delta

# %%
# RUN Utility functions 2
SAVE_PNG=False
def save_img(path, img):
    np.save(path, img)  
    if SAVE_PNG:
        plt.imsave(path+".png", img, cmap=plt.cm.gray)
                    
def VAL_add_tolerance_matches(slice_size, folder, train_imgs, train_lbls, train_x_delta, 
                              train_y_delta, is_enriched, curr, adj, tolerance_factor=0):
    # need to enhance the set with a few more true positive samples
    # allowing some up and down tolerance
    if ("top" in curr.keys()):
        for i in range(0, tolerance_factor * 10, 10):
            if i == 0:
                continue
            curr1 = pad_above(curr, curr["top"],i)
            adj1 = adj
            conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr1, adj1, slice_size)
            output = folder+"1_1="+x_file+"_"+str(curr1["top_row"])+"_"+str(curr1["left_col"])+"---"+y_file+"_"+str(adj1["top_row"])+"_"+str(adj1["left_col"])
            # print(">>> MATCH >>>"+output)
            save_img(output, conc)
            # print(">>> >>> >>> SAVED")
            train_imgs.append(output)
            train_x_delta.append(x_delta)
            train_y_delta.append(y_delta)
            # mark the image as matched
            train_lbls.append([0,1])
            is_enriched.append(True)
    if ("top" in adj.keys()):
        for i in range(0, tolerance_factor * 10, 10):
            if i == 0:
                continue
            curr1 = curr
            adj1 = pad_above(adj, adj["top"],i)
            conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr1, adj1, slice_size)
            output = folder+"1_1="+x_file+"_"+str(curr1["top_row"])+"_"+str(curr1["left_col"])+"---"+y_file+"_"+str(adj1["top_row"])+"_"+str(adj1["left_col"])
            # print(">>> MATCH >>>"+output)
            save_img(output, conc)
            # print(">>> >>> >>> SAVED")
            train_imgs.append(output)
            train_x_delta.append(x_delta)
            train_y_delta.append(y_delta)
            # mark the image as matched
            train_lbls.append([0,1])
            is_enriched.append(True)
    if ("bottom" in curr.keys()):
        for i in range(0, tolerance_factor * 10, 10):
            if i == 0:
                continue
            curr1 = pad_below(curr, curr["bottom"],i)
            adj1 = adj
            conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr1, adj1, slice_size)
            output = folder+"1_1="+x_file+"_"+str(curr1["top_row"])+"_"+str(curr1["left_col"])+"---"+y_file+"_"+str(adj1["top_row"])+"_"+str(adj1["left_col"])
            # print(">>> MATCH >>>"+output)
            save_img(output, conc)
            # print(">>> >>> >>> SAVED")
            train_imgs.append(output)
            train_x_delta.append(x_delta)
            train_y_delta.append(y_delta)
            # mark the image as matched
            train_lbls.append([0,1])
            is_enriched.append(True)
    if ("bottom"in adj.keys()):
        for i in range(0, tolerance_factor * 10, 10):
            if i == 0:
                continue
            curr1 = curr
            adj1 = pad_below(adj, adj["bottom"],i)
            conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr1, adj1, slice_size)
            output = folder+"1_1="+x_file+"_"+str(curr1["top_row"])+"_"+str(curr1["left_col"])+"---"+y_file+"_"+str(adj1["top_row"])+"_"+str(adj1["left_col"])
            # print(">>> MATCH >>>"+output)
            save_img(output, conc)
            # print(">>> >>> >>> SAVED")
            train_imgs.append(output)
            train_x_delta.append(x_delta)
            train_y_delta.append(y_delta)
            # mark the image as matched
            train_lbls.append([0,1])
            is_enriched.append(True)

                            
# IMPORTANT: enrich_factor determines how many "duplications" of TRUE values will we have in the train set
# This allows for a more balanced train set however, it reduces the strictness of the matches 
# i.e. (not sure why) when we have multiple nearby "duplicates" matches we get much more matches in the validation
# PARAMS: enrich_factor=1 means no enrich/duplicate, 20 means duplicate by 20, every 10 pixels
# PARAMS: tolerance_factor=0 means only match against exact horizon, each notch equals additional 10 pixels tolerance
def NEW_build_train_set_for_binary_labeling(cubes, adjs, slice_size, folder, enrich_factor=1, tolerance_factor=0): 
    # enrich_factor is split by 2 because it is dual-sided and 1 means actually no enrichment - i.e. 0.5
    enrich_factor = enrich_factor / 2 
    # clean folder before starting

    for root, dirs, files in os.walk(folder):
        for f in files:
            os.unlink(os.path.join(root, f))

    warnings.filterwarnings("ignore")

    train_imgs = []
    train_lbls = []
    train_x_delta = []
    train_y_delta = []
    is_enriched = []
    discard_c = 0
    skipped_c = 0
    curr_idx = 0

    # import pdb; pdb.set_trace()
    # iterate over the cubes
    for curr in cubes:
        curr_idx = curr_idx + 1
        if curr_idx % 100 == 0:
            print("*** CUBES="+str(curr_idx))
            print(" MATCHED="+str(sum(x[1] == 1 for x in train_lbls)))
            print(" NOT MATCHED="+str(sum(x[0] == 1 for x in train_lbls)))
            print(" DISCARDED="+str(discard_c))
            print(" SKIPPED="+str(skipped_c))
            
        # iterate over the others (effectively n^2)
        for adj in adjs:
            # Initial filter: what CAN be matched against what?
            # 1 - not of the same fragment (file==fragment)
            # 2 - they ARE of the same tear - don't want to confuse the learning with false data coming from different tears
            # 3 - no need to test against self and avoid checking from both directions
            if  adj["file"] != curr["file"] and \
                adj["tear"] == curr["tear"] and \
                curr["piece_col"] < adj["piece_col"]: 
                # last condition above - actually ignores pieces of the same col but different rows
                # the assumption is that they are either "not-match" and then will tilt the balance further to not-match
                # or they are "somewhat-matching" but in a way that might confuse the algorithm
                # import pdb; pdb.set_trace()
                
                # print(">>> >>>"+str(curr["cube"].shape)+" <<< <<<"+str(adj["cube"].shape))
                # append the adjacent image to the current image
                conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr, adj, slice_size)

                train_x_delta.append(x_delta)
                train_y_delta.append(y_delta)
                                
                # Condition for marking as match:
                # 1 - the adj piece is on the same row as the curr
                # 2 - the adj piece is just to the right of the curr
                # 3 - the curr cube is on the right edge of the piece
                # 4 - the adj cube is on the left edge of the piece
                # 5 - the cubes are in the same horizon
                if  curr["piece_row"] == adj["piece_row"] and \
                    curr["piece_col"] + 1 == adj["piece_col"] and \
                    (curr["col"] != 0 or curr["last"]) and \
                    (adj["col"] == 0 or not adj["last"]) and \
                    np.abs(x_delta) < 50: 

                    #print("TTT:", curr["col"], curr["last"], adj["col"], adj["last"], x_delta)
                    #print("TTT:", curr["left_col"], curr["top_row"], adj["left_col"], adj["top_row"], x_delta)
                    
                    # tag the image as matched (2nd digit) and not-enriched (1st digit)
                    output = folder+"0_1="+x_file+"_"+str(curr["top_row"])+"_"+str(curr["left_col"])+"---"+y_file+"_"+str(adj["top_row"])+"_"+str(adj["left_col"])
                    # print(">>> MATCH >>>"+output)
                    save_img(output, conc)
                    # print(">>> >>> >>> SAVED")
                    train_imgs.append(output)
                    train_lbls.append([0,1])
                    is_enriched.append(False)

                    # TOLERANCE
                    VAL_add_tolerance_matches(slice_size, folder, train_imgs, train_lbls, train_x_delta, 
                                              train_y_delta, is_enriched, curr, adj, tolerance_factor)
                    
                    # ENRICH/DUPLICATE
                    # need to enrich the set with a few more true positive samples - so we offset 
                    # the matched images up and down a few times and create more matches
                    if ("top" in curr.keys() and "top" in adj.keys()):
                        for i in range(0, 121, int(120/enrich_factor)):
                            if i == 0:
                                continue
                            curr1 = pad_above(curr, curr["top"],i)
                            adj1 = pad_above(adj, adj["top"],i)
                            conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr1, adj1, slice_size)
                            # tag the image as matched (2nd digit) and enriched (1st digit)
                            output = folder+"1_1="+x_file+"_"+str(curr1["top_row"])+"_"+str(curr1["left_col"])+"---"+y_file+"_"+str(adj1["top_row"])+"_"+str(adj1["left_col"])
                            # print(">>> MATCH >>>"+output)
                            save_img(output, conc)
                            # print(">>> >>> >>> SAVED")
                            train_imgs.append(output)
                            train_x_delta.append(x_delta)
                            train_y_delta.append(y_delta)
                            # mark the image as matched
                            train_lbls.append([0,1])
                            is_enriched.append(True)

                            # TOLERANCE
                            VAL_add_tolerance_matches(slice_size, folder, train_imgs, train_lbls, train_x_delta, 
                                                      train_y_delta, is_enriched, curr1, adj1, tolerance_factor)
                            
                    if ("bottom" in curr.keys() and "bottom"in adj.keys()):
                        for i in range(0, 121, int(120/enrich_factor)):
                            if i == 0:
                                continue
                            curr1 = pad_below(curr, curr["bottom"],i)
                            adj1 = pad_below(adj, adj["bottom"],i)
                            conc, x_delta, y_delta, x_file, y_file = VAL_concatenate_cubes(curr1, adj1, slice_size)
                            # tag the image as matched (2nd digit) and enriched (1st digit)
                            output = folder+"1_1="+x_file+"_"+str(curr1["top_row"])+"_"+str(curr1["left_col"])+"---"+y_file+"_"+str(adj1["top_row"])+"_"+str(adj1["left_col"])
                            # print(">>> MATCH >>>"+output)
                            save_img(output, conc)
                            # print(">>> >>> >>> SAVED")
                            train_imgs.append(output)
                            train_x_delta.append(x_delta)
                            train_y_delta.append(y_delta)
                            # mark the image as matched
                            train_lbls.append([0,1])
                            is_enriched.append(True)

                            # TOLERANCE
                            VAL_add_tolerance_matches(slice_size, folder, train_imgs, train_lbls, train_x_delta, 
                                                      train_y_delta, is_enriched, curr1, adj1, tolerance_factor)
 
                # adding a condition for marking as not-matched - we mark only the "key" cubes which are every 250px
                # and not overlap - hence we reduce the ratio in favour of not matched which is enormous
                
                # altering between the next 2 lines allows to control the number/ratio of non-match:match
                # elif int(curr["row"]) == curr["row"] and int(adj["row"]) == adj["row"]: # this condition will match curr key cubes with adj key cubes only
                elif int(adj["row"]) == adj["row"]: # this condition will allow curr cubes which are not just key
                    #print("NNN:", curr["col"], curr["last"], adj["col"], adj["last"], x_delta)
                    #print("NNN:", curr["left_col"], curr["top_row"], adj["left_col"], adj["top_row"], x_delta)
                    # tag the image as not-matched (2nd digit) and not-enriched (1st digit)
                    output = folder+"0_0="+x_file+"_"+str(curr["top_row"])+"_"+str(curr["left_col"])+"---"+y_file+"_"+str(adj["top_row"])+"_"+str(adj["left_col"])
                    # print("<<< nonmatch <<<"+output)
                    save_img(output, conc)
                    # print("<<< <<< <<< SAVED")
                    train_imgs.append(output)
                    train_lbls.append([1,0]) # not matched
                    is_enriched.append(False)
                
                # discard not matched which are not "key" cubes (every 250px)
                else:
                    #if x_delta == 0:
                    #    print("DDD:", curr["col"], curr["last"], adj["col"], adj["last"], x_delta)
                    #    print("DDD:", curr["left_col"], curr["top_row"], adj["left_col"], adj["top_row"], x_delta)
                    discard_c += 1
            else:
                skipped_c += 1
    print("*** MATCHED="+str(sum(x[1] == 1 for x in train_lbls)))
    print("*** NOT MATCHED="+str(sum(x[0] == 1 for x in train_lbls)))
    print("*** DISCARDED="+str(discard_c))
    print("*** SKIPPED="+str(skipped_c))
    warnings.filterwarnings("default")
    return train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched


def PARALLEL_build_train_set_for_binary_labeling(args): 
    print('args:', args)
    return NEW_build_train_set_for_binary_labeling(args[0], args[1], args[2], args[3], args[4], args[5])


def frame_to_n_by_m(orig, start_vector, end_vector, is_col):
    max_val = np.amax(end_vector)
    min_val = np.amin(start_vector)
    width = max_val - min_val
    if width < CUBE_SIZE:
        width = CUBE_SIZE
    if (is_col):
        result = np.zeros((start_vector.size, width))
    else:
        result = np.zeros((width, start_vector.size))
    
    for i in range(0, start_vector.size):
        if (is_col):
            row_vec = orig[i, start_vector[i]:end_vector[i]]
        else:
            row_vec = orig[start_vector[i]:end_vector[i],i]
        temp = np.lib.pad(row_vec, (start_vector[i]-min_val, max_val-end_vector[i]), 'constant', constant_values=(0.09, 0.09))
        if (is_col):
            if (result[i].size != width):
                import pdb; pdb.set_trace()
            result[i] = temp[0:width]
        else:
            result[:,i] = temp[0:width]
    return min_val, result

def rough_tear_line(orig, start_vector, cut_mean, is_col, chew_factor):
    end_vector = np.empty(start_vector.size).astype(int)
    if (is_col and np.absolute(cut_mean-orig.shape[1]) < 10):
        end_vector.fill(orig.shape[1])
    elif (not is_col and np.absolute(cut_mean-orig.shape[0]) < 10):
        end_vector.fill(orig.shape[0])
    else:
        deviation_vector = np.random.normal(0, chew_factor, start_vector.size).astype(int)
        end_vector[0] = cut_mean + deviation_vector[0]
        for i in range(1, end_vector.size):
            end_vector[i] = end_vector[i - 1] + deviation_vector[i]

        cut_max = start_vector + (CUBE_SIZE + EDGE_GAP)
        max_and_end = np.append([end_vector], [cut_max], axis=0)
        end_vector = np.amax(max_and_end, axis=0)
            
    start_px, cut_piece = frame_to_n_by_m(orig, start_vector, end_vector, is_col)    
    return start_px, cut_piece, end_vector

def rough_tear_image(image, cols, rows):
    pieces = []
    col_width = int(image.shape[1] / cols)
    row_height = int(image.shape[0] / rows)
    # print(col_width, row_height)
    next_col_start_vec = np.zeros((image.shape[0],), dtype=int)
    for col_idx in range(0, cols):
    #         import pdb; pdb.set_trace()
        start_col_px, cut_column, next_col_start_vec =  rough_tear_line(image, next_col_start_vec, col_width * (col_idx + 1), True, 3)
        next_row_start_vec = np.zeros((cut_column.shape[1],), dtype=int)
        for row_idx in range(0, rows):
            start_row_px, cut_piece, next_row_start_vec = rough_tear_line(cut_column, next_row_start_vec, row_height * (row_idx + 1), False, 1)

            ymin, ymax, xmin, xmax = calc_min_max_coordinates_dynamic(cut_piece, cutoff=BG_2_OBJ_RATIO)
            temp = crop(cut_piece, ymin, ymax, xmin, xmax)
            
            #import pdb; pdb.set_trace()
            piece = {}
            piece["orig"] = cut_piece
            piece["cut"] = temp
            piece["col"] = col_idx
            piece["row"] = row_idx
            piece["col_px"] = start_col_px + xmin
            piece["row_px"] = start_row_px + ymin
            pieces.append(piece)
            
    return pieces

# %%
# RUN Define model util functions

# initialize a shaped matrix of weights with random values
def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

# initialize a shaped matrix of bias with random values
def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

def max_pool_1x2(x):
  return tf.nn.max_pool(x, ksize=[1, 1, 2, 1],
                        strides=[1, 1, 2, 1], padding='SAME')

def max_pool_2x1(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 1, 1],
                        strides=[1, 2, 1, 1], padding='SAME')

def max_pool_1x1(x):
  return tf.nn.max_pool(x, ksize=[1, 1, 1, 1],
                        strides=[1, 1, 1, 1], padding='SAME')

def max_pool_5x5(x):
  return tf.nn.max_pool(x, ksize=[1, 5, 5, 1],
                        strides=[1, 5, 5, 1], padding='SAME')

def max_pool_5x2(x):
  return tf.nn.max_pool(x, ksize=[1, 5, 2, 1],
                        strides=[1, 5, 2, 1], padding='SAME')

# %%
# RUN Image utility functions (external source)
def branchedPoints(skel):
    branch1=np.array([[2, 1, 2], [1, 1, 1], [2, 2, 2]])
    branch2=np.array([[1, 2, 1], [2, 1, 2], [1, 2, 1]])
    branch3=np.array([[1, 2, 1], [2, 1, 2], [1, 2, 2]])
    branch4=np.array([[2, 1, 2], [1, 1, 2], [2, 1, 2]])
    branch5=np.array([[1, 2, 2], [2, 1, 2], [1, 2, 1]])
    branch6=np.array([[2, 2, 2], [1, 1, 1], [2, 1, 2]])
    branch7=np.array([[2, 2, 1], [2, 1, 2], [1, 2, 1]])
    branch8=np.array([[2, 1, 2], [2, 1, 1], [2, 1, 2]])
    branch9=np.array([[1, 2, 1], [2, 1, 2], [2, 2, 1]])
    br1=mh.morph.hitmiss(skel,branch1)
    br2=mh.morph.hitmiss(skel,branch2)
    br3=mh.morph.hitmiss(skel,branch3)
    br4=mh.morph.hitmiss(skel,branch4)
    br5=mh.morph.hitmiss(skel,branch5)
    br6=mh.morph.hitmiss(skel,branch6)
    br7=mh.morph.hitmiss(skel,branch7)
    br8=mh.morph.hitmiss(skel,branch8)
    br9=mh.morph.hitmiss(skel,branch9)
    return br1+br2+br3+br4+br5+br6+br7+br8+br9

def endPoints(skel):
    endpoint1=np.array([[0, 0, 0],
                        [0, 1, 0],
                        [2, 1, 2]])
    
    endpoint2=np.array([[0, 0, 0],
                        [0, 1, 2],
                        [0, 2, 1]])
    
    endpoint3=np.array([[0, 0, 2],
                        [0, 1, 1],
                        [0, 0, 2]])
    
    endpoint4=np.array([[0, 2, 1],
                        [0, 1, 2],
                        [0, 0, 0]])
    
    endpoint5=np.array([[2, 1, 2],
                        [0, 1, 0],
                        [0, 0, 0]])
    
    endpoint6=np.array([[1, 2, 0],
                        [2, 1, 0],
                        [0, 0, 0]])
    
    endpoint7=np.array([[2, 0, 0],
                        [1, 1, 0],
                        [2, 0, 0]])
    
    endpoint8=np.array([[0, 0, 0],
                        [2, 1, 0],
                        [1, 2, 0]])
    
    ep1=mh.morph.hitmiss(skel,endpoint1)
    ep2=mh.morph.hitmiss(skel,endpoint2)
    ep3=mh.morph.hitmiss(skel,endpoint3)
    ep4=mh.morph.hitmiss(skel,endpoint4)
    ep5=mh.morph.hitmiss(skel,endpoint5)
    ep6=mh.morph.hitmiss(skel,endpoint6)
    ep7=mh.morph.hitmiss(skel,endpoint7)
    ep8=mh.morph.hitmiss(skel,endpoint8)
    ep = ep1+ep2+ep3+ep4+ep5+ep6+ep7+ep8
    return ep

def pruning(skeleton, size):
    '''remove iteratively end points "size" 
       times from the skeleton
    '''
    for i in range(0, size):
        endpoints = endPoints(skeleton)
        endpoints = np.logical_not(endpoints)
        skeleton = np.logical_and(skeleton,endpoints)
    return skeleton

def plot_comparison(original, filtered, filter_name):

    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 4), sharex=True, sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    ax1.set_adjustable('box-forced')
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(filter_name)
    ax2.axis('off')
    ax2.set_adjustable('box-forced')

# %%
# RUN model_tf_deep - Define the model - 250, 125, 62, 25
def model_tf_deep(input_width, forced_bias=0): 
    global accuracy, correct_prediction, train_step, x, y_, y_conv, keep_prob, probability, probabilities #, W_fc, b_fc, cost, y_conv_temp
    
    # foundation of the model - the input layer of the image 250 x input_width*2
    x = tf.placeholder(tf.float32, [None, 250, input_width*2], "001")
    x_image = tf.reshape(x, [-1,250,input_width*2,1], "0011") # 1 is the number of color channels

    # the target digits of the model
    y_ = tf.placeholder(tf.float32, [None, 2], "002") # 1

    # zero convolutional layer: one input image and 32 output filters of 5x5
    W_conv0 = weight_variable([5, 5, 1, 32])
    b_conv0 = bias_variable([32])
    h_conv0 = tf.nn.relu(conv2d(x_image, W_conv0) + b_conv0, "0020")
    h_pool0 = max_pool_1x1(h_conv0) # size is maintained

    # first convolutional layer: one input image and 32 output filters of 5x5
    W_conv1 = weight_variable([5, 5, 32, 32])
#     W_conv1 = weight_variable([5, 5, 1, 32])
    b_conv1 = bias_variable([32])
    h_conv1 = tf.nn.relu(conv2d(h_pool0, W_conv1) + b_conv1, "0021")
#     h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1, "0021")
    if (input_width == 250):
        h_pool1 = max_pool_2x2(h_conv1) # size is reduced to 125x250
    elif (input_width == 125):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x250
    elif (input_width == 62):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x125
    elif (input_width == 25):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x50
    else:
        print("ERROR - unsupported slice width")
        return

    # second convolutional layer: 32 input (filtered) images and 32 output filters of 5x5
    W_conv2 = weight_variable([5, 5, 32, 32])
    b_conv2 = bias_variable([32])
    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2, "0022")
    if (input_width == 62):
        h_pool2 = max_pool_1x1(h_conv2) # size is reduced to 125x125
    elif (input_width == 25):
        h_pool2 = max_pool_1x1(h_conv2) # size is reduced to 125x50
    else:
        h_pool2 = max_pool_1x2(h_conv2) # size is reduced to 125x125


    # third convolutional layer: 32 input (filtered) images and 32 output filters of 5x5
    W_conv3 = weight_variable([5, 5, 32, 32])
    b_conv3 = bias_variable([32])
    h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3, "0023")
    if (input_width == 25):
        h_pool3 = max_pool_5x2(h_conv3) # size is reduced to 25x25
    else:
        h_pool3 = max_pool_5x5(h_conv3) # size is reduced to 25x25


    h_pool3_flat = tf.reshape(h_pool3, [-1, 25*25*32]) # shape as an array 

    # fourth layer - fully connected with input 25*25*128 and output 1024
    W_fc1 = weight_variable([25*25*32, 1024])
    b_fc1 = bias_variable([1024])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1, "0024")

    # a drop layer with probability 
    keep_prob = tf.placeholder(tf.float32, name="003")
    h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob, name="0031")

    #     # final layer - reduce to one "class" for the linear regression
    #     W_fc = weight_variable([1024, 1]) 
    #     b_fc = bias_variable([1])         
    #     y_conv_temp = tf.matmul(h_fc1_drop, W_fc, name="0032") + b_fc
    #     y_conv = tf.minimum(y_conv_temp, tf.constant(BREAK_VAL, tf.float32))

    #     #     # minimize loss function
    #     #     cross_entropy = tf.reduce_mean(
    #     #       tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
    #     # cost = tf.reduce_sum(tf.pow(y_conv - y_, 2))/(2*BATCHES*BATCH_SIZE) # Mean squared error
    #     cost = tf.reduce_mean(tf.square(y_conv_temp - y_), name="0033") # Mean squared error

    #     #     # define train step and rate
    #     #     train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
    #     train_step = tf.train.AdamOptimizer(LEARNING_RATE).minimize(cost) # Gradient descent

    #     # evaluate the prediction and the accuracy on the train test - needed only for printing during the training
    #     correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
    #     accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # final layer - softmax reduction 2 outputs
    W_fc2 = weight_variable([1024, 2])
    b_fc2 = bias_variable([2])
    c_fc2 = tf.constant([0, forced_bias], dtype=tf.float32)
    y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2 + c_fc2

    # minimize loss function
    cross_entropy = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
      # tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_, logits=y_conv))

    probability = tf.nn.softmax(y_conv,1)
    
    probabilities=tf.reduce_sum(probability,1)
    
    # define train step and rate
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)

    # evaluate the prediction and the accuracy on the train test - needed only for printing during the training
    correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# RUN model_tf_orig - Define the model - 250, 125, 62, 25
def model_tf_orig(input_width): 
    global accuracy, correct_prediction, train_step, x, y_, y_conv, keep_prob #, W_fc, b_fc, cost, y_conv_temp
    
    # foundation of the model - the input layer of the image 250 x input_width*2
    x = tf.placeholder(tf.float32, [None, 250, input_width*2], "001")
    x_image = tf.reshape(x, [-1,250,input_width*2,1], "0011") # 1 is the number of color channels

    # the target digits of the model
    y_ = tf.placeholder(tf.float32, [None, 2], "002") # 1

    # zero convolutional layer: one input image and 32 output filters of 5x5
#     W_conv0 = weight_variable([5, 5, 1, 32])
#     b_conv0 = bias_variable([32])
#     h_conv0 = tf.nn.relu(conv2d(x_image, W_conv0) + b_conv0, "0020")
#     h_pool0 = max_pool_1x1(h_conv0) # size is maintained

    # first convolutional layer: one input image and 32 output filters of 5x5
#     W_conv1 = weight_variable([5, 5, 32, 32])
    W_conv1 = weight_variable([5, 5, 1, 32])
    b_conv1 = bias_variable([32])
#     h_conv1 = tf.nn.relu(conv2d(h_pool0, W_conv1) + b_conv1, "0021")
    h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1, "0021")
    if (input_width == 250):
        h_pool1 = max_pool_2x2(h_conv1) # size is reduced to 125x250
    elif (input_width == 125):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x250
    elif (input_width == 62):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x125
    elif (input_width == 25):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x50
    else:
        print("ERROR - unsupported slice width")
        return

    # second convolutional layer: 32 input (filtered) images and 32 output filters of 5x5
    W_conv2 = weight_variable([5, 5, 32, 32])
    b_conv2 = bias_variable([32])
    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2, "0022")
    if (input_width == 62):
        h_pool2 = max_pool_1x1(h_conv2) # size is reduced to 125x125
    elif (input_width == 25):
        h_pool2 = max_pool_1x1(h_conv2) # size is reduced to 125x50
    else:
        h_pool2 = max_pool_1x2(h_conv2) # size is reduced to 125x125


    # third convolutional layer: 32 input (filtered) images and 32 output filters of 5x5
    W_conv3 = weight_variable([5, 5, 32, 32])
    b_conv3 = bias_variable([32])
    h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3, "0023")
    if (input_width == 25):
        h_pool3 = max_pool_5x2(h_conv3) # size is reduced to 25x25
    else:
        h_pool3 = max_pool_5x5(h_conv3) # size is reduced to 25x25


    h_pool3_flat = tf.reshape(h_pool3, [-1, 25*25*32]) # shape as an array 

    # fourth layer - fully connected with input 25*25*128 and output 1024
    W_fc1 = weight_variable([25*25*32, 1024])
    b_fc1 = bias_variable([1024])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1, "0024")

    # a drop layer with probability 
    keep_prob = tf.placeholder(tf.float32, name="003")
    h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob, name="0031")

    #     # final layer - reduce to one "class" for the linear regression
    #     W_fc = weight_variable([1024, 1]) 
    #     b_fc = bias_variable([1])         
    #     y_conv_temp = tf.matmul(h_fc1_drop, W_fc, name="0032") + b_fc
    #     y_conv = tf.minimum(y_conv_temp, tf.constant(BREAK_VAL, tf.float32))

    #     #     # minimize loss function
    #     #     cross_entropy = tf.reduce_mean(
    #     #       tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
    #     # cost = tf.reduce_sum(tf.pow(y_conv - y_, 2))/(2*BATCHES*BATCH_SIZE) # Mean squared error
    #     cost = tf.reduce_mean(tf.square(y_conv_temp - y_), name="0033") # Mean squared error

    #     #     # define train step and rate
    #     #     train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
    #     train_step = tf.train.AdamOptimizer(LEARNING_RATE).minimize(cost) # Gradient descent

    #     # evaluate the prediction and the accuracy on the train test - needed only for printing during the training
    #     correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
    #     accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # final layer - softmax reduction 2 outputs
    W_fc2 = weight_variable([1024, 2])
    b_fc2 = bias_variable([2])
    y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

    # minimize loss function
    cross_entropy = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))

    # define train step and rate
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)

    # evaluate the prediction and the accuracy on the train test - needed only for printing during the training
    correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# RUN model_tf_wide - Define the model - 250, 125, 62, 25
def model_tf_wide(input_width): 
    global accuracy, correct_prediction, train_step, x, y_, y_conv, keep_prob #, W_fc, b_fc, cost, y_conv_temp
    
    # foundation of the model - the input layer of the image 250 x input_width*2
    x = tf.placeholder(tf.float32, [None, 250, input_width*2], "001")
    x_image = tf.reshape(x, [-1,250,input_width*2,1], "0011") # 1 is the number of color channels

    # the target digits of the model
    y_ = tf.placeholder(tf.float32, [None, 2], "002") # 1

    # first convolutional layer: one input image and 32 output filters of 5x5
    W_conv1 = weight_variable([5, 5, 1, 64])
    b_conv1 = bias_variable([64])
    h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1, "0021")
    if (input_width == 250):
        h_pool1 = max_pool_2x2(h_conv1) # size is reduced to 125x250
    elif (input_width == 125):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x250
    elif (input_width == 62):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x125
    elif (input_width == 25):
        h_pool1 = max_pool_2x1(h_conv1) # size is reduced to 125x50
    else:
        print("ERROR - unsupported slice width")
        return

    # second convolutional layer: 32 input (filtered) images and 32 output filters of 5x5
    W_conv2 = weight_variable([5, 5, 64, 64])
    b_conv2 = bias_variable([64])
    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2, "0022")
    if (input_width == 62):
        h_pool2 = max_pool_1x1(h_conv2) # size is reduced to 125x125
    elif (input_width == 25):
        h_pool2 = max_pool_1x1(h_conv2) # size is reduced to 125x50
    else:
        h_pool2 = max_pool_1x2(h_conv2) # size is reduced to 125x125


    # third convolutional layer: 32 input (filtered) images and 32 output filters of 5x5
    W_conv3 = weight_variable([5, 5, 64, 64])
    b_conv3 = bias_variable([64])
    h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3, "0023")
    if (input_width == 25):
        h_pool3 = max_pool_5x2(h_conv3) # size is reduced to 25x25
    else:
        h_pool3 = max_pool_5x5(h_conv3) # size is reduced to 25x25


    h_pool3_flat = tf.reshape(h_pool3, [-1, 25*25*64]) # shape as an array 

    # fourth layer - fully connected with input 25*25*128 and output 1024
    W_fc1 = weight_variable([25*25*64, 2048])
    b_fc1 = bias_variable([2048])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1, "0024")

    # a drop layer with probability 
    keep_prob = tf.placeholder(tf.float32, name="003")
    h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob, name="0031")

    #     # final layer - reduce to one "class" for the linear regression
    #     W_fc = weight_variable([1024, 1]) 
    #     b_fc = bias_variable([1])         
    #     y_conv_temp = tf.matmul(h_fc1_drop, W_fc, name="0032") + b_fc
    #     y_conv = tf.minimum(y_conv_temp, tf.constant(BREAK_VAL, tf.float32))

    #     #     # minimize loss function
    #     #     cross_entropy = tf.reduce_mean(
    #     #       tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
    #     # cost = tf.reduce_sum(tf.pow(y_conv - y_, 2))/(2*BATCHES*BATCH_SIZE) # Mean squared error
    #     cost = tf.reduce_mean(tf.square(y_conv_temp - y_), name="0033") # Mean squared error

    #     #     # define train step and rate
    #     #     train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
    #     train_step = tf.train.AdamOptimizer(LEARNING_RATE).minimize(cost) # Gradient descent

    #     # evaluate the prediction and the accuracy on the train test - needed only for printing during the training
    #     correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
    #     accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # final layer - softmax reduction 2 outputs
    W_fc2 = weight_variable([2048, 2])
    b_fc2 = bias_variable([2])
    y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

    # minimize loss function
    cross_entropy = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))

    # define train step and rate
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)

    # evaluate the prediction and the accuracy on the train test - needed only for printing during the training
    correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# RUN train
def train(train_imgs, train_lbls, output_model, input_model=""):
    print("#####################################################################")
    print("TRAINING:")
    print("MODEL:"+output_model)
    print("#####################################################################")

    from random import randrange
    
    # TRAIN Prepare the session

    # create a saver object
    saver = tf.train.Saver()

    # start session and initialize variables
    sess = tf.InteractiveSession()
    if input_model != "":
        # Restore variables from disk.
        saver.restore(sess, input_model)
        print("Model restored.")
    else:
        sess.run(tf.initialize_all_variables())

    # TRAIN Train the model
    x_batch = []
    y_batch = []
    # run the train batches
    for i in range(BATCHES):
        x_batch = []
        y_batch = []
        for _ in range(BATCH_SIZE):
            random_index = randrange(0,len(train_imgs))
            image = np.load(train_imgs[random_index]+".npy")
            # print(train_imgs[random_index])
            x_batch.append(image)
            y_batch.append(train_lbls[random_index])

        # train
        # print("step %d"%(i))
        train_step.run(feed_dict={x: x_batch, y_: y_batch, keep_prob: 0.5})

        # print the accuracy thus far
        if (i+1)%50 == 0:
            train_accuracy = accuracy.eval(feed_dict={
                x:x_batch, y_: y_batch, keep_prob: 1.0})
            print("step %d, training accuracy %.2f"%(i, train_accuracy))


    print("Optimization Finished!")
    train_accuracy = accuracy.eval(feed_dict={
        x:x_batch, y_: y_batch, keep_prob: 1.0})
    print("step %d, training accuracy %g"%(i, train_accuracy))

    # Save the variables to disk.
    save_path = saver.save(sess, output_model)
    print("Model saved in file: %s" % save_path)

    # Close the Session when we're done. If un-commented - need to run next bock of restore...
    sess.close()   
    print("#####################################################################")
    print("TRAINING ENDED")
    print("#####################################################################")
    print(" ")
    print(" ")

# %%
# RUN pre_process - OLD?
def pre_process(folder):
    print("#####################################################################")
    print("PRE_PROCESS:"+folder)
    print("#####################################################################")
    result = []
    
    for root, dirs, files in os.walk(folder):
        for file_ in files:
            # Read the image
            # image = img.imread(os.path.join(root, file_))
            image = np.load(os.path.join(root, file_))
            # import pdb; pdb.set_trace()
            cubes = VAL_slice_to_static_slices(file_, image)
            print("File: %s >>> cubes: %d"%(file_, len(cubes)))
            result.extend(cubes)
    
    return result
    print("#####################################################################")
    print("PRE_PROCESS ENDED")
    print("#####################################################################")
    print(" ")
    print(" ")

# %%
# RUN pre_process_training - crop image, then tear it randomly to various tears, then per tear create cubes out of the edges, return cube set
def pre_process_training(img_name, x_start=X_START, x_end=X_END, y_start=Y_START, y_end=Y_END, max_cols=8, max_rows=4):
    print("#####################################################################")
    print("PRE_PROCESS:"+img_name)
    print("#####################################################################")
    short_name = img_name[:img_name.rfind('-D')]
    image = read_and_crop(img_name, x_start, x_end, y_start, y_end)
    result = []
    
    for root, dirs, files in os.walk(ROOT_FOLDER+"fragments/"):
        for f in files:
            os.unlink(os.path.join(root, f))

    
    for col_cut in range(3, max_cols): # 9 3...10
        for row_cut in range(2, max_rows): # 6 2...5
            print("PRE_PROCESS:::"+"TEAR_"+str(col_cut)+"X"+str(row_cut))
            pieces = rough_tear_image(image, col_cut, row_cut)
            
            for piece in pieces:
                # print("PRE_PROCESS:::"+"PIECE_"+str(piece["col"])+"X"+str(piece["row"]))
                fragment_name = short_name + "_TEAR_"+str(col_cut)+"X"+str(row_cut)+"_PIECE_"+str(piece["col"])+"X"+str(piece["row"])
                fragment_file_name = short_name + "_"+str(col_cut)+"X"+str(row_cut)+"_"+str(piece["col"])+"X"+str(piece["row"])
                # import pdb; pdb.set_trace()
                plt.imsave(os.path.join(ROOT_FOLDER+"fragments/",fragment_file_name+".jpg"), piece["cut"], cmap=plt.cm.gray)
                cubes = VAL_slice_TEAR_to_static_slices(fragment_name, piece)
                for cube in cubes:
                    cube["tear"] = str(col_cut)+"X"+str(row_cut)
                    cube["piece_col"] = piece["col"]
                    cube["piece_row"] = piece["row"]
                # print("File: %s >>> cubes: %d"%(file_, len(cubes)))
                result.extend(cubes)
    
    return result
    print("#####################################################################")
    print("PRE_PROCESS ENDED")
    print("#####################################################################")
    print(" ")
    print(" ")

# %%
def validate1(cubes, model, slice_size, folder, curr_cube):    
    # VALIDATE prepare the data sets
    test_imgs, test_x_delta, test_y_delta, test_x_file, test_y_file = VAL_build_train_set(cubes, slice_size, folder, curr_cube)
    print("loaded %d images"%(len(test_imgs)))

# %%
def validate2(folder, model, slice_size):
    test_imgs = []
    test_x_file = []
    test_y_file = []
    the_root = ""
    for root, dirs, files in os.walk(folder):
        the_root = root
        for file_ in files:
            test_imgs.append( os.path.join(root, file_) )
            test_x_file.append(file_[:file_.rfind('---P')])
            test_y_file.append(file_[file_.rfind('---P')+3:])
            
    print(len(test_imgs))
    
    # VALIDATE Prepare a test session 

    # Add ops to save and restore all the variables.
    saver = tf.train.Saver()

    # start session and initialize variables
    sess = tf.InteractiveSession()

    # Restore variables from disk.
    saver.restore(sess, model)
    print("Model restored.")

    # VALIDATE Validate the model

    # import pdb; pdb.set_trace()
    v1t = []
    count = 0
    length = len(test_imgs)
    batch = 100
    x_batch = []
    # change the ranges in the loop below - first number is the start point (multiplied by batch size)
    # second number is the end point (multiplied by batch size)
    # third number is the jump from batch to batch
    # use the length about to set the batch length
    for start in range(0, length, batch):
        for i in range(start, start+batch):
            if (i < length):
                image = np.load(test_imgs[i])
                x_batch.append(image)
                count += 1

        # print("Validating start at #%d end at %d"%(start*batch,(start+length)*batch))
        my_prediction=tf.argmax(y_conv,1)
        v1 = my_prediction.eval(feed_dict={x:x_batch, keep_prob: 1.0})
        v1t = np.concatenate((v1t, v1), axis=0)
        x_batch = []
        print(">>> step %d"%(start+batch))


    match_indexes = np.nonzero(v1t)[0]
    A = np.array(test_x_file)
    B = np.array(test_y_file)
    C = np.array(test_imgs)
    match_x_files = A[match_indexes]
    match_y_files = B[match_indexes]
    match_images = C[match_indexes]
    
    for matched_img in match_images:
        load_img = np.load(matched_img)
        plt.imsave(os.path.join("/Volumes/250GB/matched/",matched_img[matched_img.rfind('/')+1:]+".png"), load_img, cmap=plt.cm.gray)
    
    for root, dirs, files in os.walk(folder):
        for file_ in files:
            os.remove( os.path.join(root, file_) ) # delete it from the FS
                
    with open('matches.csv', 'a') as csvfile:
        csvout = csv.writer(csvfile)
        for match_index in match_indexes:
            print("MATCH %s === %s"%(test_x_file[match_index], test_y_file[match_index]))
            # print("MATCH %s === %s"%(A[match_index], B[match_index]))
            # csvout.writerow([A[match_index], B[match_index]])
            csvout.writerow([test_x_file[match_index], test_y_file[match_index]])
            # plt.imsave("match_"+match_index+".jpg", C[match_index])

    # Close the Session when we're done.
    sess.close()

# %%
def validate2_for_cross_validation(test_imgs, test_lbls, is_enriched, model, max_samples=0):
    print(len(test_imgs))
    
    # VALIDATE Prepare a test session 

    # Add ops to save and restore all the variables.
    saver = tf.train.Saver()

    # start session and initialize variables
    sess = tf.InteractiveSession()

    # Restore variables from disk.
    saver.restore(sess, model)
    print("Model restored.")

    # VALIDATE Validate the model

    count = 0
    se = 0
    st = 0
    v1t = []
    v2t = []
    v1tt = []
    v2tt = []
    length = len(test_imgs)
    if max_samples != 0:
        length = max_samples
    batch = 100
    x_batch = []
    y_batch = []
    # change the ranges in the loop below - first number is the start point (multiplied by batch size)
    # second number is the end point (multiplied by batch size)
    # third number is the jump from batch to batch
    # use the length about to set the batch length
    for start in range(0, length, batch):
        for i in range(start, start+batch):
            if (i < length):
                image = np.load(test_imgs[i]+".npy")
                x_batch.append(image)
                y_batch.append(train_lbls[i])                
                
        # print the accuracy thus far
    #         train_accuracy = accuracy.eval(feed_dict={
    #             x:x_batch, y_: y_batch, keep_prob: 1.0})
    #         print("step %d, training accuracy %g"%(i, train_accuracy))

        # print("Validating start at #%d end at %d"%(start*batch,(start+length)*batch))
    #         my_prediction=tf.argmax(y_conv,1)
    #         v1 = my_prediction.eval(feed_dict={x:x_batch, keep_prob: 1.0})
    #         v1t = np.concatenate((v1t, v1), axis=0)

        ######## printing the predictions and their normalized values
        # print("y_conv="+str(y_conv.eval(feed_dict={x:x_batch, y_: y_batch, keep_prob: 1.0})))
        # print("probability="+str(probability.eval(feed_dict={x:x_batch, y_: y_batch, keep_prob: 1.0})))
        # print("probabilities="+str(probabilities.eval(feed_dict={x:x_batch, y_: y_batch, keep_prob: 1.0})))
        
        my_prediction=tf.argmax(y_conv,1)
        my_target=tf.argmax(y_,1)
        v1 = my_prediction.eval(feed_dict={x:x_batch, y_: y_batch, keep_prob: 1.0})
        v2 = my_target.eval(feed_dict={x:x_batch, y_: y_batch, keep_prob: 1.0})
        v1t = np.concatenate((v1t, v1), axis=0)
        v2t = np.concatenate((v2t, v2), axis=0)

        c1 = np.sum(np.absolute(np.subtract(v2, v1)))
        c2 = np.sum(np.absolute(v2))
        se += c1
        st += c2

        x_batch = []
        y_batch = []
        print(">>> step %d"%(start+batch))
        
        count += ((i+1) - start)
        precision, recall, f_score, support = precision_recall_fscore_support(v2t, v1t, average='binary')
        print("step %d-%d, precision %f, recall %f, f_score %f"%(start, i, precision, recall, f_score))
        # print("Accumulated total true = %d"%(st));
        # print("Accumulated total error rate = %f"%(se/count));
        # v1tt = np.concatenate((v1tt, v1t), axis=0)
        # v2tt = np.concatenate((v2tt, v2t), axis=0)
        print("=== total %d match %d"%(count, len(np.nonzero(v1t)[0])))

    precision, recall, f_score, support = precision_recall_fscore_support(v2t, v1t, average='binary')
    print("TOTAL %d, precision %f, recall %f, f_score %f"%(count, precision, recall, f_score))
    print("TOTAL true = %d"%(st));
    print("TOTAL error rate = %f"%(se/count));
    
    match_indexes = np.nonzero(v1t)[0]
    C = np.array(test_imgs)
    match_images = C[match_indexes]
    
    # for matched_img in match_images:
    #    load_img = np.load(matched_img+".npy")
    #    plt.imsave(os.path.join(ROOT_FOLDER+"synt_matched/",matched_img[matched_img.rfind('/')+1:]+".png"), load_img, cmap=plt.cm.gray)

    with open(strftime("%Y%m%d_%H%M%S", gmtime())+'_synt_all.csv', 'a') as csvfile:
        csvout = csv.writer(csvfile)
        for idx, test_img in enumerate(test_imgs):
            # print("MATCH %s === %s"%(test_imgs[match_index], train_lbls[match_index]))
            match_class = 0
            if idx in match_indexes:
                match_class = 1
            csvout.writerow([test_img, train_lbls[idx], match_class, is_enriched[idx]])
            # plt.imsave("match_"+match_index+".jpg", C[match_index])

    with open(strftime("%Y%m%d_%H%M%S", gmtime())+'_synt_matches.csv', 'a') as csvfile:
        csvout = csv.writer(csvfile)
        for match_index in match_indexes:
            # print("MATCH %s === %s"%(test_imgs[match_index], train_lbls[match_index]))
            csvout.writerow([test_imgs[match_index], train_lbls[match_index], is_enriched[match_index]])
            # plt.imsave("match_"+match_index+".jpg", C[match_index])

    # Close the Session when we're done.
    sess.close()

# %%
def iter_validate(cubes, model, slice_size, folder):
    print("#####################################################################")
    print("VALIDATING")
    print("#####################################################################")
    cubes_len = len(cubes)
    batch_size = 100
    count = 0
    # iterate over the cubes
    for curr in cubes:
        count += 1
        if count < batch_size: ### TEMP LIMITATION
            print("CUBE:%s"%(curr["file"]+"_"+str(curr["top_row"])+"_"+str(curr["left_col"])))
            validate1(cubes, model, slice_size, folder, curr)
            validate2(folder, model, slice_size)
        
    print("#####################################################################")
    print("VALIDATION ENDED")
    print("#####################################################################")
    print(" ")
    print(" ")

# %%
def run_all(folder, model, slice_size):
    model_tf(slice_size)
    cubes_set = pre_process(folder)
    validate(cubes_set, model, slice_size)

# %%
# HELPER block
# image = read_and_crop("PX303/FG001/PX303-Fg001-V-C01-R01-D05032015-T112602-ML924__012.jpg")
## image = read_and_crop("PX303/FG004/PX303-Fg004-V-C01-R01-D08032015-T110900-ML924__012.jpg", 100, -1, 400, -1)
# image = read_and_crop("PX303/FG004/PX303-Fg004-V-C01-R02-D08032015-T105147-ML924__012.jpg")
# image = read_and_crop("PX303/FG004/PX303-Fg004-V-C02-R01-D08032015-T110025-ML924__012.jpg")
# image = read_and_crop("PX303/FG004/PX303-Fg004-V-C02-R02-D08032015-T105553-ML924__012.jpg")
# image = read_and_crop("PX303/FG006/PX303-Fg006-V-C01-R01-D08032015-T120605-ML924__012.jpg")
# image = read_and_crop("PX303/FG006/PX303-Fg006-V-C01-R02-D08032015-T115230-ML924__012.jpg")
# image = read_and_crop("PX303/FG006/PX303-Fg006-V-C02-R01-D08032015-T120158-ML924__012.jpg")
##image = read_and_crop("PX303/FG006/PX303-Fg006-V-C02-R02-D08032015-T115704-ML924__012.jpg", 0, 6200, 0, 4400)
##plt.imshow(image)

# %%
def load_train_from_disk(path):
    train_imgs = []
    train_lbls = []
    is_enriched = []
    for root, dirs, files in os.walk(path):
        for file_ in files:
            file_name = os.path.join(root, file_)
            file_name = file_name[:file_name.rfind(".")]
            train_imgs.append(file_name)
    #        train_lbls.append([1,0] if file_.startswith("0=") else [0,1])
    # return train_imgs, train_lbls
            enriched = file_[0] == '1'
            is_enriched.append(enriched)
            label = [0,1] if file_[2] == '1' else [1,0] 
            train_lbls.append(label)
    return train_imgs, train_lbls, is_enriched

# %%
##########################################
########################################## RUN ALL ABOVE !!! Then select the relevant code below
##########################################

# %%
# RUN1 - take 1st large pieces and train on it
cubes_set = pre_process_training("PX303-Fg001-V-C01-R01-D05032015-T112520-ML638__006.jpg", max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 2, 7)
tf.reset_default_graph()
model_tf_deep(250)
train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model1.ckpt")
# Out:
# #####################################################################
# PRE_PROCESS:PX303-Fg001-V-C01-R01-D05032015-T112520-ML638__006.jpg
# #####################################################################
# PRE_PROCESS:::TEAR_3X2
# /home/ilan/venv35/lib/python3.5/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# PRE_PROCESS:::TEAR_3X3
# PRE_PROCESS:::TEAR_4X2
# PRE_PROCESS:::TEAR_4X3
# PRE_PROCESS:::TEAR_5X2
# PRE_PROCESS:::TEAR_5X3
# PRE_PROCESS:::TEAR_6X2
# PRE_PROCESS:::TEAR_6X3
# PRE_PROCESS:::TEAR_7X2
# PRE_PROCESS:::TEAR_7X3
# *** CUBES=100
#  MATCHED=1149
#  NOT MATCHED=2241
#  DISCARDED=7680
#  SKIPPED=268505
# *** CUBES=200
#  MATCHED=1719
#  NOT MATCHED=2897
#  DISCARDED=9920
#  SKIPPED=546877
# *** CUBES=300
#  MATCHED=2678
#  NOT MATCHED=4442
#  DISCARDED=15238
#  SKIPPED=821235
# *** CUBES=400
#  MATCHED=3337
#  NOT MATCHED=6414
#  DISCARDED=23074
#  SKIPPED=1092690
# *** CUBES=500
#  MATCHED=4592
#  NOT MATCHED=8476
#  DISCARDED=31318
#  SKIPPED=1363617
# *** CUBES=600
#  MATCHED=5191
#  NOT MATCHED=9286
#  DISCARDED=34246
#  SKIPPED=1641145
# *** CUBES=700
#  MATCHED=6102
#  NOT MATCHED=12030
#  DISCARDED=43460
#  SKIPPED=1910409
# *** CUBES=800
#  MATCHED=6568
#  NOT MATCHED=12758
#  DISCARDED=45957
#  SKIPPED=2188445
# *** CUBES=900
#  MATCHED=7558
#  NOT MATCHED=17418
#  DISCARDED=63002
#  SKIPPED=2447985
# *** CUBES=1000
#  MATCHED=8916
#  NOT MATCHED=19919
#  DISCARDED=72256
#  SKIPPED=2717457
# *** CUBES=1100
#  MATCHED=9573
#  NOT MATCHED=20394
#  DISCARDED=74147
#  SKIPPED=2996357
# *** CUBES=1200
#  MATCHED=10490
#  NOT MATCHED=24623
#  DISCARDED=88341
#  SKIPPED=3259157
# *** CUBES=1300
#  MATCHED=11422
#  NOT MATCHED=26529
#  DISCARDED=94789
#  SKIPPED=3532025
# *** CUBES=1400
#  MATCHED=11914
#  NOT MATCHED=28922
#  DISCARDED=104285
#  SKIPPED=3801405
# *** CUBES=1500
#  MATCHED=13295
#  NOT MATCHED=33755
#  DISCARDED=123616
#  SKIPPED=4058465
# *** CUBES=1600
#  MATCHED=14776
#  NOT MATCHED=36644
#  DISCARDED=135168
#  SKIPPED=4325245
# *** CUBES=1700
#  MATCHED=15586
#  NOT MATCHED=37404
#  DISCARDED=138204
#  SKIPPED=4602705
# *** CUBES=1800
#  MATCHED=16223
#  NOT MATCHED=41760
#  DISCARDED=152461
#  SKIPPED=4865337
# *** CUBES=1900
#  MATCHED=17016
#  NOT MATCHED=45320
#  DISCARDED=164227
#  SKIPPED=5131241
# *** CUBES=2000
#  MATCHED=17842
#  NOT MATCHED=46601
#  DISCARDED=168333
#  SKIPPED=5407085
# *** CUBES=2100
#  MATCHED=18981
#  NOT MATCHED=51510
#  DISCARDED=187962
#  SKIPPED=5663785
# *** CUBES=2200
#  MATCHED=20514
#  NOT MATCHED=56892
#  DISCARDED=209494
#  SKIPPED=5918085
# *** CUBES=2300
#  MATCHED=22137
#  NOT MATCHED=60237
#  DISCARDED=222864
#  SKIPPED=6182585
# *** CUBES=2400
#  MATCHED=23482
#  NOT MATCHED=61664
#  DISCARDED=228564
#  SKIPPED=6456685
# *** CUBES=2500
#  MATCHED=24202
#  NOT MATCHED=65253
#  DISCARDED=240515
#  SKIPPED=6722385
# *** CUBES=2600
#  MATCHED=25220
#  NOT MATCHED=70707
#  DISCARDED=258685
#  SKIPPED=6979973
# *** CUBES=2700
#  MATCHED=26210
#  NOT MATCHED=73856
#  DISCARDED=269179
#  SKIPPED=7247545
# *** CUBES=2800
#  MATCHED=26825
#  NOT MATCHED=74709
#  DISCARDED=272018
#  SKIPPED=7525101
# *** MATCHED=26825
# *** NOT MATCHED=74709
# *** DISCARDED=272018
# *** SKIPPED=7564483
# #####################################################################
# TRAINING:
# MODEL:/media/1KGB_ILAN/papyrus/models/tear_model1.ckpt
# #####################################################################
# WARNING:tensorflow:From /home/ilan/venv35/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# /home/ilan/venv35/lib/python3.5/site-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# step 49, training accuracy 0.83
# step 99, training accuracy 0.78
# step 149, training accuracy 0.83
# step 199, training accuracy 0.77
# step 249, training accuracy 0.77
# step 299, training accuracy 0.78
# step 349, training accuracy 0.83
# step 399, training accuracy 0.90
# step 449, training accuracy 0.85
# step 499, training accuracy 0.85
# step 549, training accuracy 0.80
# step 599, training accuracy 0.78
# step 649, training accuracy 0.92
# step 699, training accuracy 0.85
# step 749, training accuracy 0.92
# step 799, training accuracy 0.92
# step 849, training accuracy 0.93
# step 899, training accuracy 0.90
# step 949, training accuracy 0.95
# step 999, training accuracy 0.93
# step 1049, training accuracy 0.93
# step 1099, training accuracy 0.90
# step 1149, training accuracy 0.95
# step 1199, training accuracy 0.90
# step 1249, training accuracy 0.95
# step 1299, training accuracy 0.87
# step 1349, training accuracy 0.95
# step 1399, training accuracy 0.92
# step 1449, training accuracy 0.95
# step 1499, training accuracy 0.97
# step 1549, training accuracy 0.98
# step 1599, training accuracy 0.97
# step 1649, training accuracy 0.93
# step 1699, training accuracy 0.95
# step 1749, training accuracy 0.93
# step 1799, training accuracy 0.95
# step 1849, training accuracy 0.97
# step 1899, training accuracy 0.97
# step 1949, training accuracy 0.97
# step 1999, training accuracy 0.97
# Optimization Finished!
# step 1999, training accuracy 0.966667
# Model saved in file: /media/1KGB_ILAN/papyrus/models/tear_model1.ckpt
# #####################################################################
# TRAINING ENDED
# #####################################################################

# %%
# RE-RUN1 - take 1st large pieces and train on it
train_imgs, train_lbls, is_enriched = \
    load_train_from_disk(ROOT_FOLDER + "train_concats3/")
tf.reset_default_graph()
model_tf_deep(250)
train(train_imgs, train_lbls, ROOT_FOLDER + "model_binary/tear_model1.ckpt")

# %%
# TEMP DEBUG
len_cubes = len(cubes_set)
print(len_cubes)
# bat_cubes = 1000
# BATCHES = 500 # smaller train batches
# for start in range(0, len_cubes, bat_cubes):
#     end = ((start+bat_cubes) if start+bat_cubes < len_cubes else (len_cubes - 1))
#     print("start:%s end:%s", start, end)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set[1:2], cubes_set, CUBE_SIZE, 
                                            ROOT_FOLDER + "train_concats2/", 1, 5)

# %%
# RUN2 - take 2nd large pieces and train on it
# train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
#    parallelize_build_train_set(cubes_set, ROOT_FOLDER + "train_concats2/", 1, 7, PARALLEL_build_train_set_for_binary_labeling)
cubes_set = pre_process_training("PX303-Fg004-V-C01-R01-D08032015-T110817-ML638__006.jpg", \
                                 100, -1, 400, -1, max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 2, 7)
tf.reset_default_graph()
model_tf_deep(250)
train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model2.ckpt", ROOT_FOLDER + "models/tear_model1.ckpt")

# cubes_set = pre_process_training("PX303-Fg004-V-C01-R01-D08032015-T110817-ML638__006.jpg", \
#                                  100, -1, 400, -1, max_cols=8, max_rows=5)
# tf.reset_default_graph()
# model_tf_deep(250)
# len_cubes = len(cubes_set)
# bat_cubes = 1000
# # COPY MANUALLY!!!
# #shutil.copy(ROOT_FOLDER + "models/tear_model1.ckpt", ROOT_FOLDER + "models/tear_model2.ckpt")
# for start_cubes in range(0, len_cubes, bat_cubes):
#     end_cubes = ((start+bat_cubes) if start+bat_cubes < len_cubes else (len_cubes - 1))
#     BATCHES = int((end_cubes - start_cubes) / 10) # smaller train batches
#     train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
#         NEW_build_train_set_for_binary_labeling(cubes_set[start_cubes:end_cubes], cubes_set, CUBE_SIZE, 
#                                                 ROOT_FOLDER + "train_concats2/", 1, 5)
#     train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model2.ckpt", ROOT_FOLDER + "models/tear_model2.ckpt")  
# BATCHES = 2000
# Out:
# #####################################################################
# TRAINING:
# MODEL:/media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# #####################################################################
# INFO:tensorflow:Restoring parameters from /media/1KGB_ILAN/papyrus/models/tear_model1.ckpt
# /home/ilan/venv35/lib/python3.5/site-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Model restored.
# step 49, training accuracy 0.82
# step 99, training accuracy 0.85
# step 149, training accuracy 0.77
# step 199, training accuracy 0.80
# step 249, training accuracy 0.77
# step 299, training accuracy 0.75
# step 349, training accuracy 0.87
# step 399, training accuracy 0.83
# step 449, training accuracy 0.85
# step 499, training accuracy 0.88
# step 549, training accuracy 0.83
# step 599, training accuracy 0.85
# step 649, training accuracy 0.88
# step 699, training accuracy 0.83
# step 749, training accuracy 0.83
# step 799, training accuracy 0.80
# step 849, training accuracy 0.92
# step 899, training accuracy 0.83
# step 949, training accuracy 0.88
# step 999, training accuracy 0.87
# step 1049, training accuracy 0.85
# step 1099, training accuracy 0.90
# step 1149, training accuracy 0.85
# step 1199, training accuracy 0.93
# step 1249, training accuracy 0.82
# step 1299, training accuracy 0.78
# step 1349, training accuracy 0.93
# step 1399, training accuracy 0.92
# step 1449, training accuracy 0.83
# step 1499, training accuracy 0.88
# step 1549, training accuracy 0.88
# step 1599, training accuracy 0.92
# step 1649, training accuracy 0.97
# step 1699, training accuracy 0.83
# step 1749, training accuracy 0.92
# step 1799, training accuracy 0.92
# step 1849, training accuracy 0.92
# step 1899, training accuracy 0.87
# step 1949, training accuracy 0.85
# step 1999, training accuracy 0.90
# Optimization Finished!
# step 1999, training accuracy 0.9
# Model saved in file: /media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# #####################################################################
# TRAINING ENDED
# #####################################################################

# %%
# MULTI PROCESS
import multiprocessing
from itertools import product, repeat

num_cores = 4# multiprocessing.cpu_count()
num_partitions = num_cores * 4

def chunkify(lst,n):
    return [lst[i::n] for i in range(n)]

def parallelize_build_train_set(cubes_set, folder, enrich_factor, tolerance_factor, func):
    adjs_list = chunkify(cubes_set, num_partitions)
    print('list:', adjs_list)
    # test block for running serialy    
    # results = []
    # for item in zip(np.arange(num_partitions), df_split):
    #    results.append(func(item))
    # df = pd.concat(results, ignore_index=True)

    # parallel block
    pool = multiprocessing.Pool(num_cores)
    # import pdb; pdb.set_trace()
    args = zip(repeat(cubes_set), adjs_list, repeat(CUBE_SIZE), \
               repeat(ROOT_FOLDER + folder), repeat(enrich_factor), repeat(tolerance_factor))

    results = pool.map(func, args)
    train_imgs = []
    train_lbls = []
    train_x_delta = []
    train_y_delta = []
    is_enriched = []
    
    for result in results:
        train_imgs.append(result[0])
        train_lbls.append(result[1])
        train_x_delta.append(result[2])
        train_y_delta.append(result[3])
        is_enriched.append(result[4])
    
    pool.close()
    pool.join()

    return train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched

# %%
# Parallel RUN2 - take 2nd large pieces and train on it
cubes_set = pre_process_training("PX303-Fg004-V-C01-R01-D08032015-T110817-ML638__006.jpg", 100, -1, 400, -1, max_cols=9, max_rows=6)

# %%
# RE-RUN2 - take 2nd large pieces and train on it
train_imgs, train_lbls, is_enriched = \
    load_train_from_disk(ROOT_FOLDER + "train_concats2/")
print(len(train_imgs))
tf.reset_default_graph()
model_tf_deep(250)
train(train_imgs, train_lbls, ROOT_FOLDER + "model_binary/tear_model2.ckpt", ROOT_FOLDER + "model_binary/tear_model1.ckpt")

# %%
# OPTIONAL RUN3 - take 3rd large pieces and train on it OR TEST in next block

cubes_set = pre_process_training("PX303-Fg006-V-C02-R02-D08032015-T115622-ML638__006.jpg", 0, 6200, 0, 4400, max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/")
tf.reset_default_graph()
model_tf_deep(250)    
train(train_imgs, train_lbls, ROOT_FOLDER + "model_binary/tear_model3.ckpt", ROOT_FOLDER + "model_binary/tear_model2.ckpt")
# train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model1.ckpt")

# %%
# TEST3 - take 1 piece and cross- validate on this (uncomment all for full test run)
cubes_set = pre_process_training("PX303-Fg006-V-C02-R02-D08032015-T115622-ML638__006.jpg", 0, 6200, 0, 4400, max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 1, 5)
tf.reset_default_graph()
model_tf_deep(250, 1)    
validate2_for_cross_validation(train_imgs, train_lbls, is_enriched, ROOT_FOLDER + "models/tear_model2.ckpt")
# Out:
# #####################################################################
# PRE_PROCESS:PX303-Fg006-V-C02-R02-D08032015-T115622-ML638__006.jpg
# #####################################################################
# PRE_PROCESS:::TEAR_3X2
# /home/ilan/venv35/lib/python3.5/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# PRE_PROCESS:::TEAR_3X3
# PRE_PROCESS:::TEAR_4X2
# PRE_PROCESS:::TEAR_4X3
# PRE_PROCESS:::TEAR_5X2
# PRE_PROCESS:::TEAR_5X3
# PRE_PROCESS:::TEAR_6X2
# PRE_PROCESS:::TEAR_6X3
# PRE_PROCESS:::TEAR_7X2
# PRE_PROCESS:::TEAR_7X3
# *** CUBES=100
#  MATCHED=824
#  NOT MATCHED=6128
#  DISCARDED=24506
#  SKIPPED=694089
# *** CUBES=200
#  MATCHED=1926
#  NOT MATCHED=10693
#  DISCARDED=42659
#  SKIPPED=1403397
# *** CUBES=300
#  MATCHED=3272
#  NOT MATCHED=13810
#  DISCARDED=54936
#  SKIPPED=2120013
# *** CUBES=400
#  MATCHED=3272
#  NOT MATCHED=13810
#  DISCARDED=54936
#  SKIPPED=2852113
# *** CUBES=500
#  MATCHED=3544
#  NOT MATCHED=16577
#  DISCARDED=65261
#  SKIPPED=3571101
# *** CUBES=600
#  MATCHED=4804
#  NOT MATCHED=22694
#  DISCARDED=88108
#  SKIPPED=4274141
# *** CUBES=700
#  MATCHED=5843
#  NOT MATCHED=25680
#  DISCARDED=100047
#  SKIPPED=4991241
# *** CUBES=800
#  MATCHED=6421
#  NOT MATCHED=26962
#  DISCARDED=105173
#  SKIPPED=5716891
# *** CUBES=900
#  MATCHED=6481
#  NOT MATCHED=27613
#  DISCARDED=107787
#  SKIPPED=6445722
# *** CUBES=1000
#  MATCHED=7492
#  NOT MATCHED=36901
#  DISCARDED=145132
#  SKIPPED=7131122
# *** CUBES=1100
#  MATCHED=8412
#  NOT MATCHED=44272
#  DISCARDED=174695
#  SKIPPED=7826224
# *** CUBES=1200
#  MATCHED=9615
#  NOT MATCHED=50050
#  DISCARDED=197798
#  SKIPPED=8529364
# *** CUBES=1300
#  MATCHED=10720
#  NOT MATCHED=53236
#  DISCARDED=210539
#  SKIPPED=9245464
# *** CUBES=1400
#  MATCHED=11277
#  NOT MATCHED=54539
#  DISCARDED=215759
#  SKIPPED=9971004
# *** CUBES=1500
#  MATCHED=11277
#  NOT MATCHED=54539
#  DISCARDED=215759
#  SKIPPED=10703104
# *** CUBES=1600
#  MATCHED=12123
#  NOT MATCHED=63336
#  DISCARDED=250353
#  SKIPPED=11391743
# *** CUBES=1700
#  MATCHED=13084
#  NOT MATCHED=70307
#  DISCARDED=277903
#  SKIPPED=12089249
# *** CUBES=1800
#  MATCHED=14196
#  NOT MATCHED=75544
#  DISCARDED=298682
#  SKIPPED=12795249
# *** CUBES=1900
#  MATCHED=15416
#  NOT MATCHED=78527
#  DISCARDED=310611
#  SKIPPED=13512349
# *** CUBES=2000
#  MATCHED=15705
#  NOT MATCHED=79211
#  DISCARDED=313356
#  SKIPPED=14240999
# *** CUBES=2100
#  MATCHED=15848
#  NOT MATCHED=82477
#  DISCARDED=326495
#  SKIPPED=14956683
# *** CUBES=2200
#  MATCHED=16852
#  NOT MATCHED=94562
#  DISCARDED=375142
#  SKIPPED=15627983
# *** CUBES=2300
#  MATCHED=17807
#  NOT MATCHED=104127
#  DISCARDED=413608
#  SKIPPED=16311985
# *** CUBES=2400
#  MATCHED=18851
#  NOT MATCHED=112125
#  DISCARDED=445674
#  SKIPPED=17003953
# *** CUBES=2500
#  MATCHED=20134
#  NOT MATCHED=118408
#  DISCARDED=470708
#  SKIPPED=17704653
# *** CUBES=2600
#  MATCHED=21032
#  NOT MATCHED=121814
#  DISCARDED=484318
#  SKIPPED=18419675
# *** CUBES=2700
#  MATCHED=22000
#  NOT MATCHED=123753
#  DISCARDED=492075
#  SKIPPED=19142015
# *** CUBES=2800
#  MATCHED=22000
#  NOT MATCHED=123753
#  DISCARDED=492075
#  SKIPPED=19874115
# *** CUBES=2900
#  MATCHED=22553
#  NOT MATCHED=133222
#  DISCARDED=528377
#  SKIPPED=20560395
# *** CUBES=3000
#  MATCHED=23587
#  NOT MATCHED=143827
#  DISCARDED=569350
#  SKIPPED=21240843
# *** CUBES=3100
#  MATCHED=24688
#  NOT MATCHED=152587
#  DISCARDED=603585
#  SKIPPED=21929863
# *** CUBES=3200
#  MATCHED=25844
#  NOT MATCHED=158771
#  DISCARDED=627517
#  SKIPPED=22631763
# *** CUBES=3300
#  MATCHED=26939
#  NOT MATCHED=162919
#  DISCARDED=643290
#  SKIPPED=23343863
# *** CUBES=3400
#  MATCHED=28033
#  NOT MATCHED=165523
#  DISCARDED=653072
#  SKIPPED=24063499
# *** CUBES=3500
#  MATCHED=28033
#  NOT MATCHED=165523
#  DISCARDED=653072
#  SKIPPED=24795599
# *** CUBES=3600
#  MATCHED=28535
#  NOT MATCHED=175481
#  DISCARDED=692844
#  SKIPPED=25477935
# *** CUBES=3700
#  MATCHED=29643
#  NOT MATCHED=189896
#  DISCARDED=750345
#  SKIPPED=26138043
# *** CUBES=3800
#  MATCHED=30741
#  NOT MATCHED=202180
#  DISCARDED=799187
#  SKIPPED=26808943
# *** CUBES=3900
#  MATCHED=31578
#  NOT MATCHED=212089
#  DISCARDED=838777
#  SKIPPED=27491487
# *** CUBES=4000
#  MATCHED=32745
#  NOT MATCHED=220276
#  DISCARDED=871351
#  SKIPPED=28182747
# *** CUBES=4100
#  MATCHED=34031
#  NOT MATCHED=226657
#  DISCARDED=896484
#  SKIPPED=28883247
# *** CUBES=4200
#  MATCHED=34922
#  NOT MATCHED=230295
#  DISCARDED=910799
#  SKIPPED=29597335
# *** CUBES=4300
#  MATCHED=35993
#  NOT MATCHED=232583
#  DISCARDED=919816
#  SKIPPED=30318059
# *** CUBES=4400
#  MATCHED=35993
#  NOT MATCHED=232583
#  DISCARDED=919816
#  SKIPPED=31050159
# *** CUBES=4500
#  MATCHED=36475
#  NOT MATCHED=243144
#  DISCARDED=960173
#  SKIPPED=31731299
# *** CUBES=4600
#  MATCHED=37571
#  NOT MATCHED=257108
#  DISCARDED=1013289
#  SKIPPED=32396239
# *** CUBES=4700
#  MATCHED=38871
#  NOT MATCHED=269389
#  DISCARDED=1059612
#  SKIPPED=33069639
# *** CUBES=4800
#  MATCHED=39569
#  NOT MATCHED=278608
#  DISCARDED=1094577
#  SKIPPED=33757493
# *** CUBES=4900
#  MATCHED=40647
#  NOT MATCHED=286204
#  DISCARDED=1123530
#  SKIPPED=34452966
# *** CUBES=5000
#  MATCHED=41975
#  NOT MATCHED=291999
#  DISCARDED=1145839
#  SKIPPED=35156866
# *** CUBES=5100
#  MATCHED=43043
#  NOT MATCHED=294984
#  DISCARDED=1157778
#  SKIPPED=35873966
# *** CUBES=5200
#  MATCHED=43587
#  NOT MATCHED=296116
#  DISCARDED=1162306
#  SKIPPED=36600366
# *** CUBES=5300
#  MATCHED=43690
#  NOT MATCHED=298323
#  DISCARDED=1170940
#  SKIPPED=37321618
# *** CUBES=5400
#  MATCHED=44628
#  NOT MATCHED=316713
#  DISCARDED=1242888
#  SKIPPED=37963318
# *** CUBES=5500
#  MATCHED=45574
#  NOT MATCHED=333124
#  DISCARDED=1307019
#  SKIPPED=38614810
# *** CUBES=5600
#  MATCHED=46715
#  NOT MATCHED=347891
#  DISCARDED=1364551
#  SKIPPED=39274534
# *** CUBES=5700
#  MATCHED=47739
#  NOT MATCHED=360376
#  DISCARDED=1412898
#  SKIPPED=39945734
# *** CUBES=5800
#  MATCHED=48552
#  NOT MATCHED=370748
#  DISCARDED=1453149
#  SKIPPED=40627154
# *** CUBES=5900
#  MATCHED=49781
#  NOT MATCHED=379278
#  DISCARDED=1486290
#  SKIPPED=41317502
# *** CUBES=6000
#  MATCHED=50946
#  NOT MATCHED=385662
#  DISCARDED=1511129
#  SKIPPED=42018302
# *** CUBES=6100
#  MATCHED=51772
#  NOT MATCHED=389585
#  DISCARDED=1526282
#  SKIPPED=42731268
# *** CUBES=6200
#  MATCHED=52946
#  NOT MATCHED=392162
#  DISCARDED=1536182
#  SKIPPED=43450813
# *** CUBES=6300
#  MATCHED=52946
#  NOT MATCHED=392162
#  DISCARDED=1536182
#  SKIPPED=44182913
# *** CUBES=6400
#  MATCHED=53385
#  NOT MATCHED=403418
#  DISCARDED=1579547
#  SKIPPED=44860357
# *** CUBES=6500
#  MATCHED=54406
#  NOT MATCHED=420105
#  DISCARDED=1644179
#  SKIPPED=45511057
# *** CUBES=6600
#  MATCHED=55476
#  NOT MATCHED=434686
#  DISCARDED=1701390
#  SKIPPED=46171279
# *** CUBES=6700
#  MATCHED=56288
#  NOT MATCHED=446574
#  DISCARDED=1747738
#  SKIPPED=46845079
# *** CUBES=6800
#  MATCHED=57256
#  NOT MATCHED=456689
#  DISCARDED=1787372
#  SKIPPED=47527358
# *** CUBES=6900
#  MATCHED=58464
#  NOT MATCHED=465014
#  DISCARDED=1820099
#  SKIPPED=48218314
# *** CUBES=7000
#  MATCHED=59671
#  NOT MATCHED=470997
#  DISCARDED=1843629
#  SKIPPED=48920814
# *** CUBES=7100
#  MATCHED=60571
#  NOT MATCHED=474762
#  DISCARDED=1858296
#  SKIPPED=49634414
# *** CUBES=7200
#  MATCHED=61571
#  NOT MATCHED=477027
#  DISCARDED=1867055
#  SKIPPED=50355418
# *** CUBES=7300
#  MATCHED=61571
#  NOT MATCHED=477027
#  DISCARDED=1867055
#  SKIPPED=51087518
# *** MATCHED=61571
# *** NOT MATCHED=477027
# *** DISCARDED=1867055
# *** SKIPPED=51248580
# 538598
# /home/ilan/venv35/lib/python3.5/site-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# INFO:tensorflow:Restoring parameters from /media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# Model restored.
# >>> step 100
# step 0-99, precision 0.500000, recall 1.000000, f_score 0.666667
# === total 100 match 34
# >>> step 200
# step 100-199, precision 0.311927, recall 1.000000, f_score 0.475524
# === total 200 match 109
# >>> step 300
# step 200-299, precision 0.298013, recall 1.000000, f_score 0.459184
# === total 300 match 151
# >>> step 400
# step 300-399, precision 0.238318, recall 1.000000, f_score 0.384906
# === total 400 match 214
# >>> step 500
# step 400-499, precision 0.215827, recall 1.000000, f_score 0.355030
# === total 500 match 278
# >>> step 600
# step 500-599, precision 0.219219, recall 1.000000, f_score 0.359606
# === total 600 match 333
# >>> step 700
# step 600-699, precision 0.223325, recall 1.000000, f_score 0.365112
# === total 700 match 403
# >>> step 800
# step 700-799, precision 0.205950, recall 1.000000, f_score 0.341556
# === total 800 match 437
# >>> step 900
# step 800-899, precision 0.190678, recall 1.000000, f_score 0.320285
# === total 900 match 472
# >>> step 1000
# step 900-999, precision 0.177515, recall 1.000000, f_score 0.301508
# === total 1000 match 507
# >>> step 1100
# step 1000-1099, precision 0.184015, recall 1.000000, f_score 0.310832
# === total 1100 match 538
# >>> step 1200
# step 1100-1199, precision 0.181818, recall 1.000000, f_score 0.307692
# === total 1200 match 616
# >>> step 1300
# step 1200-1299, precision 0.185612, recall 1.000000, f_score 0.313107
# === total 1300 match 695
# >>> step 1400
# step 1300-1399, precision 0.177442, recall 1.000000, f_score 0.301402
# === total 1400 match 727
# >>> step 1500
# step 1400-1499, precision 0.176316, recall 1.000000, f_score 0.299776
# === total 1500 match 760
# >>> step 1600
# step 1500-1599, precision 0.177184, recall 1.000000, f_score 0.301031
# === total 1600 match 824
# >>> step 1700
# step 1600-1699, precision 0.184389, recall 1.000000, f_score 0.311366
# === total 1700 match 884
# >>> step 1800
# step 1700-1799, precision 0.193966, recall 1.000000, f_score 0.324910
# === total 1800 match 928
# >>> step 1900
# step 1800-1899, precision 0.180723, recall 1.000000, f_score 0.306122
# === total 1900 match 996
# >>> step 2000
# step 1900-1999, precision 0.187850, recall 1.000000, f_score 0.316286
# === total 2000 match 1070
# >>> step 2100
# step 2000-2099, precision 0.183601, recall 1.000000, f_score 0.310241
# === total 2100 match 1122
# >>> step 2200
# step 2100-2199, precision 0.189582, recall 0.995516, f_score 0.318508
# === total 2200 match 1171
# >>> step 2300
# step 2200-2299, precision 0.198877, recall 0.995984, f_score 0.331551
# === total 2300 match 1247
# >>> step 2400
# step 2300-2399, precision 0.200302, recall 0.996241, f_score 0.333543
# === total 2400 match 1323
# >>> step 2500
# step 2400-2499, precision 0.191673, recall 0.996269, f_score 0.321493
# === total 2500 match 1393
# >>> step 2600
# step 2500-2599, precision 0.194751, recall 0.996466, f_score 0.325823
# === total 2600 match 1448
# >>> step 2700
# step 2600-2699, precision 0.191057, recall 0.996466, f_score 0.320637
# === total 2700 match 1476
# >>> step 2800
# step 2700-2799, precision 0.196066, recall 0.996667, f_score 0.327671
# === total 2800 match 1525
# >>> step 2900
# step 2800-2899, precision 0.188882, recall 0.996667, f_score 0.317578
# === total 2900 match 1583
# >>> step 3000
# step 2900-2999, precision 0.185369, recall 0.996667, f_score 0.312598
# === total 3000 match 1613
# >>> step 3100
# step 3000-3099, precision 0.187351, recall 0.990536, f_score 0.315103
# === total 3100 match 1676
# >>> step 3200
# step 3100-3199, precision 0.189576, recall 0.991018, f_score 0.318269
# === total 3200 match 1746
# >>> step 3300
# step 3200-3299, precision 0.185538, recall 0.991018, f_score 0.312559
# === total 3300 match 1784
# >>> step 3400
# step 3300-3399, precision 0.191524, recall 0.991667, f_score 0.321043
# === total 3400 match 1864
# >>> step 3500
# step 3400-3499, precision 0.193582, recall 0.992042, f_score 0.323950
# === total 3500 match 1932
# >>> step 3600
# step 3500-3599, precision 0.188537, recall 0.992063, f_score 0.316857
# === total 3600 match 1989
# >>> step 3700
# step 3600-3699, precision 0.189057, recall 0.992308, f_score 0.317604
# === total 3700 match 2047
# >>> step 3800
# step 3700-3799, precision 0.191197, recall 0.992629, f_score 0.320635
# === total 3800 match 2113
# >>> step 3900
# step 3800-3899, precision 0.189798, recall 0.992788, f_score 0.318673
# === total 3900 match 2176
# >>> step 4000
# step 3900-3999, precision 0.188899, recall 0.992941, f_score 0.317413
# === total 4000 match 2234
# >>> step 4100
# step 4000-4099, precision 0.192291, recall 0.993213, f_score 0.322202
# === total 4100 match 2283
# >>> step 4200
# step 4100-4199, precision 0.187848, recall 0.993213, f_score 0.315941
# === total 4200 match 2337
# >>> step 4300
# step 4200-4299, precision 0.186667, recall 0.993348, f_score 0.314276
# === total 4300 match 2400
# >>> step 4400
# step 4300-4399, precision 0.185924, recall 0.993478, f_score 0.313228
# === total 4400 match 2458
# >>> step 4500
# step 4400-4499, precision 0.185600, recall 0.993576, f_score 0.312774
# === total 4500 match 2500
# >>> step 4600
# step 4500-4599, precision 0.190458, recall 0.993927, f_score 0.319661
# === total 4600 match 2578
# >>> step 4700
# step 4600-4699, precision 0.186621, recall 0.993927, f_score 0.314240
# === total 4700 match 2631
# >>> step 4800
# step 4700-4799, precision 0.183826, recall 0.993927, f_score 0.310269
# === total 4800 match 2671
# >>> step 4900
# step 4800-4899, precision 0.185808, recall 0.994129, f_score 0.313097
# === total 4900 match 2734
# >>> step 5000
# step 4900-4999, precision 0.185411, recall 0.977273, f_score 0.311688
# === total 5000 match 2783
# >>> step 5100
# step 5000-5099, precision 0.188007, recall 0.977982, f_score 0.315385
# === total 5100 match 2835
# >>> step 5200
# step 5100-5199, precision 0.186364, recall 0.977982, f_score 0.313069
# === total 5200 match 2860
# >>> step 5300
# step 5200-5299, precision 0.188809, recall 0.978648, f_score 0.316547
# === total 5300 match 2913
# >>> step 5400
# step 5300-5399, precision 0.186188, recall 0.978648, f_score 0.312856
# === total 5400 match 2954
# >>> step 5500
# step 5400-5499, precision 0.190096, recall 0.979452, f_score 0.318397
# === total 5500 match 3009
# >>> step 5600
# step 5500-5599, precision 0.196896, recall 0.979100, f_score 0.327860
# === total 5600 match 3093
# >>> step 5700
# step 5600-5699, precision 0.195687, recall 0.979365, f_score 0.326196
# === total 5700 match 3153
# >>> step 5800
# step 5700-5799, precision 0.197021, recall 0.979938, f_score 0.328081
# === total 5800 match 3223
# >>> step 5900
# step 5800-5899, precision 0.194905, recall 0.979938, f_score 0.325141
# === total 5900 match 3258
# >>> step 6000
# step 5900-5999, precision 0.201385, recall 0.980938, f_score 0.334166
# === total 6000 match 3322
# >>> step 6100
# step 6000-6099, precision 0.206886, recall 0.981844, f_score 0.341760
# === total 6100 match 3398
# >>> step 6200
# step 6100-6199, precision 0.211782, recall 0.982667, f_score 0.348463
# === total 6200 match 3480
# >>> step 6300
# step 6200-6299, precision 0.210271, recall 0.982667, f_score 0.346416
# === total 6300 match 3505
# >>> step 6400
# step 6300-6399, precision 0.208900, recall 0.982667, f_score 0.344554
# === total 6400 match 3528
# >>> step 6500
# step 6400-6499, precision 0.206848, recall 0.982667, f_score 0.341757
# === total 6500 match 3563
# >>> step 6600
# step 6500-6599, precision 0.207422, recall 0.982940, f_score 0.342557
# === total 6600 match 3611
# >>> step 6700
# step 6600-6699, precision 0.212598, recall 0.983668, f_score 0.349632
# === total 6700 match 3683
# >>> step 6800
# step 6700-6799, precision 0.212325, recall 0.983791, f_score 0.349270
# === total 6800 match 3716
# >>> step 6900
# step 6800-6899, precision 0.215806, recall 0.984223, f_score 0.353994
# === total 6900 match 3758
# >>> step 7000
# step 6900-6999, precision 0.218201, recall 0.984615, f_score 0.357235
# === total 7000 match 3813
# >>> step 7100
# step 7000-7099, precision 0.224076, recall 0.985327, f_score 0.365119
# === total 7100 match 3896
# >>> step 7200
# step 7100-7199, precision 0.222363, recall 0.985426, f_score 0.362848
# === total 7200 match 3953
# >>> step 7300
# step 7200-7299, precision 0.220522, recall 0.985426, f_score 0.360394
# === total 7300 match 3986
# >>> step 7400
# step 7300-7399, precision 0.225265, recall 0.985961, f_score 0.366740
# === total 7400 match 4053
# >>> step 7500
# step 7400-7499, precision 0.224104, recall 0.985961, f_score 0.365200
# === total 7500 match 4074
# >>> step 7600
# step 7500-7599, precision 0.222249, recall 0.985961, f_score 0.362733
# === total 7600 match 4108
# >>> step 7700
# step 7600-7699, precision 0.224436, recall 0.973958, f_score 0.364807
# === total 7700 match 4166
# >>> step 7800
# step 7700-7799, precision 0.227946, recall 0.974849, f_score 0.369495
# === total 7800 match 4251
# >>> step 7900
# step 7800-7899, precision 0.226455, recall 0.974849, f_score 0.367533
# === total 7900 match 4279
# >>> step 8000
# step 7900-7999, precision 0.228472, recall 0.975296, f_score 0.370218
# === total 8000 match 4320
# >>> step 8100
# step 8000-8099, precision 0.227524, recall 0.975296, f_score 0.368972
# === total 8100 match 4338
# >>> step 8200
# step 8100-8199, precision 0.231677, recall 0.976099, f_score 0.374473
# === total 8200 match 4407
# >>> step 8300
# step 8200-8299, precision 0.234653, recall 0.976852, f_score 0.378407
# === total 8300 match 4496
# >>> step 8400
# step 8300-8399, precision 0.232123, recall 0.976852, f_score 0.375111
# === total 8400 match 4545
# >>> step 8500
# step 8400-8499, precision 0.236501, recall 0.977679, f_score 0.380870
# === total 8500 match 4630
# >>> step 8600
# step 8500-8599, precision 0.238651, recall 0.978261, f_score 0.383697
# === total 8600 match 4714
# >>> step 8700
# step 8600-8699, precision 0.241609, recall 0.978885, f_score 0.387561
# === total 8700 match 4797
# >>> step 8800
# step 8700-8799, precision 0.244618, recall 0.979475, f_score 0.391468
# === total 8800 match 4877
# >>> step 8900
# step 8800-8899, precision 0.242184, recall 0.979475, f_score 0.388346
# === total 8900 match 4926
# >>> step 9000
# step 8900-8999, precision 0.245400, recall 0.980032, f_score 0.392514
# === total 9000 match 5000
# >>> step 9100
# step 9000-9099, precision 0.244082, recall 0.980032, f_score 0.390827
# === total 9100 match 5027
# >>> step 9200
# step 9100-9199, precision 0.245152, recall 0.980222, f_score 0.392213
# === total 9200 match 5054
# >>> step 9300
# step 9200-9299, precision 0.247110, recall 0.980560, f_score 0.394741
# === total 9300 match 5103
# >>> step 9400
# step 9300-9399, precision 0.247485, recall 0.980828, f_score 0.395241
# === total 9400 match 5168
# >>> step 9500
# step 9400-9499, precision 0.248093, recall 0.981146, f_score 0.396043
# === total 9500 match 5244
# >>> step 9600
# step 9500-9599, precision 0.250379, recall 0.977827, f_score 0.398674
# === total 9600 match 5284
# >>> step 9700
# step 9600-9699, precision 0.250376, recall 0.977974, f_score 0.398683
# === total 9700 match 5320
# >>> step 9800
# step 9700-9799, precision 0.249112, recall 0.977974, f_score 0.397079
# === total 9800 match 5347
# >>> step 9900
# step 9800-9899, precision 0.252355, recall 0.978510, f_score 0.401234
# === total 9900 match 5413
# >>> step 10000
# step 9900-9999, precision 0.249909, recall 0.978510, f_score 0.398135
# === total 10000 match 5466
# >>> step 10100
# step 10000-10099, precision 0.252077, recall 0.976224, f_score 0.400689
# === total 10100 match 5538
# >>> step 10200
# step 10100-10199, precision 0.250673, recall 0.976224, f_score 0.398914
# === total 10200 match 5569
# >>> step 10300
# step 10200-10299, precision 0.253501, recall 0.976776, f_score 0.402533
# === total 10300 match 5641
# >>> step 10400
# step 10300-10399, precision 0.252024, recall 0.976808, f_score 0.400672
# === total 10400 match 5682
# >>> step 10500
# step 10400-10499, precision 0.254742, recall 0.977303, f_score 0.404141
# === total 10500 match 5747
# >>> step 10600
# step 10500-10599, precision 0.257831, recall 0.977807, f_score 0.408063
# === total 10600 match 5810
# >>> step 10700
# step 10600-10699, precision 0.258312, recall 0.978050, f_score 0.408686
# === total 10700 match 5865
# >>> step 10800
# step 10700-10799, precision 0.258778, recall 0.978302, f_score 0.409291
# === total 10800 match 5924
# >>> step 10900
# step 10800-10899, precision 0.260030, recall 0.978697, f_score 0.410890
# === total 10900 match 6007
# >>> step 11000
# step 10900-10999, precision 0.259738, recall 0.978763, f_score 0.410532
# === total 11000 match 6033
# >>> step 11100
# step 11000-11099, precision 0.259222, recall 0.978763, f_score 0.409888
# === total 11100 match 6045
# >>> step 11200
# step 11100-11199, precision 0.260252, recall 0.979103, f_score 0.411203
# === total 11200 match 6121
# >>> step 11300
# step 11200-11299, precision 0.260898, recall 0.979319, f_score 0.412028
# === total 11300 match 6171
# >>> step 11400
# step 11300-11399, precision 0.261660, recall 0.979530, f_score 0.412997
# === total 11400 match 6218
# >>> step 11500
# step 11400-11499, precision 0.262201, recall 0.979738, f_score 0.413689
# === total 11500 match 6270
# >>> step 11600
# step 11500-11599, precision 0.264377, recall 0.980140, f_score 0.416429
# === total 11600 match 6347
# >>> step 11700
# step 11600-11699, precision 0.265090, recall 0.980437, f_score 0.417340
# === total 11700 match 6428
# >>> step 11800
# step 11700-11799, precision 0.267376, recall 0.980780, f_score 0.420199
# === total 11800 match 6489
# >>> step 11900
# step 11800-11899, precision 0.268004, recall 0.981090, f_score 0.421002
# === total 11900 match 6582
# >>> step 12000
# step 11900-11999, precision 0.268720, recall 0.981257, f_score 0.421901
# === total 12000 match 6624
# >>> step 12100
# step 12000-12099, precision 0.267900, recall 0.981267, f_score 0.420891
# === total 12100 match 6648
# >>> step 12200
# step 12100-12199, precision 0.268679, recall 0.981441, f_score 0.421868
# === total 12200 match 6692
# >>> step 12300
# step 12200-12299, precision 0.269648, recall 0.981612, f_score 0.423077
# === total 12300 match 6731
# >>> step 12400
# step 12300-12399, precision 0.269729, recall 0.981779, f_score 0.423192
# === total 12400 match 6792
# >>> step 12500
# step 12400-12499, precision 0.271179, recall 0.982077, f_score 0.425003
# === total 12500 match 6870
# >>> step 12600
# step 12500-12599, precision 0.272937, recall 0.982347, f_score 0.427184
# === total 12600 match 6932
# >>> step 12700
# step 12600-12699, precision 0.272870, recall 0.982501, f_score 0.427117
# === total 12700 match 6996
# >>> step 12800
# step 12700-12799, precision 0.272908, recall 0.982662, f_score 0.427178
# === total 12800 match 7061
# >>> step 12900
# step 12800-12899, precision 0.273149, recall 0.982811, f_score 0.427488
# === total 12900 match 7117
# >>> step 13000
# step 12900-12999, precision 0.272740, recall 0.982906, f_score 0.426996
# === total 13000 match 7168
# >>> step 13100
# step 13000-13099, precision 0.273305, recall 0.983110, f_score 0.427707
# === total 13100 match 7241
# >>> step 13200
# step 13100-13199, precision 0.273350, recall 0.983251, f_score 0.427775
# === total 13200 match 7302
# >>> step 13300
# step 13200-13299, precision 0.273891, recall 0.982902, f_score 0.428404
# === total 13300 match 7346
# >>> step 13400
# step 13300-13399, precision 0.274560, recall 0.983043, f_score 0.429236
# === total 13400 match 7390
# >>> step 13500
# step 13400-13499, precision 0.275407, recall 0.983181, f_score 0.430284
# === total 13500 match 7429
# >>> step 13600
# step 13500-13599, precision 0.275324, recall 0.983317, f_score 0.430195
# === total 13600 match 7493
# >>> step 13700
# step 13600-13699, precision 0.277528, recall 0.983583, f_score 0.432907
# === total 13700 match 7556
# >>> step 13800
# step 13700-13799, precision 0.280026, recall 0.983841, f_score 0.435966
# === total 13800 match 7610
# >>> step 13900
# step 13800-13899, precision 0.282748, recall 0.983644, f_score 0.439237
# === total 13900 match 7657
# >>> step 14000
# step 13900-13999, precision 0.286231, recall 0.984014, f_score 0.443466
# === total 14000 match 7742
# >>> step 14100
# step 14000-14099, precision 0.288388, recall 0.984252, f_score 0.446075
# === total 14100 match 7802
# >>> step 14200
# step 14100-14199, precision 0.287871, recall 0.984252, f_score 0.445456
# === total 14200 match 7816
# >>> step 14300
# step 14200-14299, precision 0.287039, recall 0.984314, f_score 0.444466
# === total 14300 match 7870
# >>> step 14400
# step 14300-14399, precision 0.290172, recall 0.984629, f_score 0.448246
# === total 14400 match 7947
# >>> step 14500
# step 14400-14499, precision 0.291505, recall 0.984739, f_score 0.449845
# === total 14500 match 7969
# >>> step 14600
# step 14500-14599, precision 0.292941, recall 0.984956, f_score 0.451576
# === total 14600 match 8046
# >>> step 14700
# step 14600-14699, precision 0.294581, recall 0.985173, f_score 0.453546
# === total 14700 match 8120
# >>> step 14800
# step 14700-14799, precision 0.298673, recall 0.985536, f_score 0.458419
# === total 14800 match 8213
# >>> step 14900
# step 14800-14899, precision 0.298050, recall 0.985583, f_score 0.457690
# === total 14900 match 8257
# >>> step 15000
# step 14900-14999, precision 0.301869, recall 0.985915, f_score 0.462216
# === total 15000 match 8348
# >>> step 15100
# step 15000-15099, precision 0.303951, recall 0.985385, f_score 0.464593
# === total 15100 match 8429
# >>> step 15200
# step 15100-15199, precision 0.304528, recall 0.985086, f_score 0.465234
# === total 15200 match 8459
# >>> step 15300
# step 15200-15299, precision 0.307999, recall 0.985388, f_score 0.469308
# === total 15300 match 8539
# >>> step 15400
# step 15300-15399, precision 0.308087, recall 0.985464, f_score 0.469419
# === total 15400 match 8582
# >>> step 15500
# step 15400-15499, precision 0.310493, recall 0.985646, f_score 0.472227
# === total 15500 match 8625
# >>> step 15600
# step 15500-15599, precision 0.312019, recall 0.985854, f_score 0.474015
# === total 15600 match 8711
# >>> step 15700
# step 15600-15699, precision 0.314341, recall 0.986086, f_score 0.476716
# === total 15700 match 8793
# >>> step 15800
# step 15700-15799, precision 0.315885, recall 0.986234, f_score 0.478507
# === total 15800 match 8845
# >>> step 15900
# step 15800-15899, precision 0.317150, recall 0.985335, f_score 0.479850
# === total 15900 match 8898
# >>> step 16000
# step 15900-15999, precision 0.321361, recall 0.985675, f_score 0.484696
# === total 16000 match 8993
# >>> step 16100
# step 16000-16099, precision 0.322630, recall 0.985840, f_score 0.486158
# === total 16100 match 9063
# >>> step 16200
# step 16100-16199, precision 0.324271, recall 0.986000, f_score 0.488038
# === total 16200 match 9122
# >>> step 16300
# step 16200-16299, precision 0.324395, recall 0.986083, f_score 0.488189
# === total 16300 match 9174
# >>> step 16400
# step 16300-16399, precision 0.326181, recall 0.986239, f_score 0.490228
# === total 16400 match 9228
# >>> step 16500
# step 16400-16499, precision 0.327104, recall 0.986319, f_score 0.491279
# === total 16500 match 9257
# >>> step 16600
# step 16500-16599, precision 0.328541, recall 0.986469, f_score 0.492917
# === total 16600 match 9320
# >>> step 16700
# step 16600-16699, precision 0.329385, recall 0.985003, f_score 0.493683
# === total 16700 match 9372
# >>> step 16800
# step 16700-16799, precision 0.331748, recall 0.984934, f_score 0.496323
# === total 16800 match 9459
# >>> step 16900
# step 16800-16899, precision 0.333474, recall 0.984477, f_score 0.498193
# === total 16900 match 9509
# >>> step 17000
# step 16900-16999, precision 0.333857, recall 0.984558, f_score 0.498631
# === total 17000 match 9549
# >>> step 17100
# step 17000-17099, precision 0.337046, recall 0.984793, f_score 0.502210
# === total 17100 match 9607
# >>> step 17200
# step 17100-17199, precision 0.335642, recall 0.984536, f_score 0.500617
# === total 17200 match 9674
# >>> step 17300
# step 17200-17299, precision 0.334701, recall 0.984615, f_score 0.499579
# === total 17300 match 9752
# >>> step 17400
# step 17300-17399, precision 0.333197, recall 0.984615, f_score 0.497903
# === total 17400 match 9796
# >>> step 17500
# step 17400-17499, precision 0.332387, recall 0.984675, f_score 0.497005
# === total 17500 match 9859
# >>> step 17600
# step 17500-17599, precision 0.331345, recall 0.984675, f_score 0.495839
# === total 17600 match 9890
# >>> step 17700
# step 17600-17699, precision 0.330443, recall 0.984675, f_score 0.494828
# === total 17700 match 9917
# >>> step 17800
# step 17700-17799, precision 0.329920, recall 0.984717, f_score 0.494247
# === total 17800 match 9960
# >>> step 17900
# step 17800-17899, precision 0.329181, recall 0.984794, f_score 0.493427
# === total 17900 match 10034
# >>> step 18000
# step 17900-17999, precision 0.328004, recall 0.984794, f_score 0.492104
# === total 18000 match 10070
# >>> step 18100
# step 18000-18099, precision 0.326480, recall 0.984794, f_score 0.490387
# === total 18100 match 10117
# >>> step 18200
# step 18100-18199, precision 0.326629, recall 0.984911, f_score 0.490569
# === total 18200 match 10192
# >>> step 18300
# step 18200-18299, precision 0.326503, recall 0.984987, f_score 0.490436
# === total 18300 match 10248
# >>> step 18400
# step 18300-18399, precision 0.325444, recall 0.985026, f_score 0.489245
# === total 18400 match 10309
# >>> step 18500
# step 18400-18499, precision 0.324855, recall 0.985101, f_score 0.488589
# === total 18500 match 10380
# >>> step 18600
# step 18500-18599, precision 0.324493, recall 0.985174, f_score 0.488188
# === total 18600 match 10444
# >>> step 18700
# step 18600-18699, precision 0.323501, recall 0.985174, f_score 0.487065
# === total 18700 match 10476
# >>> step 18800
# step 18700-18799, precision 0.323703, recall 0.985247, f_score 0.487302
# === total 18800 match 10522
# >>> step 18900
# step 18800-18899, precision 0.322263, recall 0.985247, f_score 0.485669
# === total 18900 match 10569
# >>> step 19000
# step 18900-18999, precision 0.321594, recall 0.985247, f_score 0.484909
# === total 19000 match 10591
# >>> step 19100
# step 19000-19099, precision 0.320597, recall 0.985286, f_score 0.483780
# === total 19100 match 10652
# >>> step 19200
# step 19100-19199, precision 0.319757, recall 0.985286, f_score 0.482822
# === total 19200 match 10680
# >>> step 19300
# step 19200-19299, precision 0.318749, recall 0.985324, f_score 0.481677
# === total 19300 match 10742
# >>> step 19400
# step 19300-19399, precision 0.317184, recall 0.985324, f_score 0.479888
# === total 19400 match 10795
# >>> step 19500
# step 19400-19499, precision 0.316588, recall 0.985395, f_score 0.479215
# === total 19500 match 10869
# >>> step 19600
# step 19500-19599, precision 0.316079, recall 0.985433, f_score 0.478635
# === total 19600 match 10915
# >>> step 19700
# step 19600-19699, precision 0.315401, recall 0.985470, f_score 0.477861
# === total 19700 match 10967
# >>> step 19800
# step 19700-19799, precision 0.315799, recall 0.985540, f_score 0.478327
# === total 19800 match 11007
# >>> step 19900
# step 19800-19899, precision 0.314456, recall 0.985540, f_score 0.476785
# === total 19900 match 11054
# >>> step 20000
# step 19900-19999, precision 0.313633, recall 0.985540, f_score 0.475838
# === total 20000 match 11083
# >>> step 20100
# step 20000-20099, precision 0.313639, recall 0.985609, f_score 0.475853
# === total 20100 match 11137
# >>> step 20200
# step 20100-20199, precision 0.312834, recall 0.985678, f_score 0.474934
# === total 20200 match 11220
# >>> step 20300
# step 20200-20299, precision 0.311972, recall 0.985678, f_score 0.473940
# === total 20300 match 11251
# >>> step 20400
# step 20300-20399, precision 0.311329, recall 0.985730, f_score 0.473203
# === total 20400 match 11316
# >>> step 20500
# step 20400-20499, precision 0.311318, recall 0.985798, f_score 0.473199
# === total 20500 match 11371
# >>> step 20600
# step 20500-20599, precision 0.310581, recall 0.985798, f_score 0.472346
# === total 20600 match 11398
# >>> step 20700
# step 20600-20699, precision 0.310994, recall 0.985837, f_score 0.472829
# === total 20700 match 11415
# >>> step 20800
# step 20700-20799, precision 0.310233, recall 0.985837, f_score 0.471949
# === total 20800 match 11443
# >>> step 20900
# step 20800-20899, precision 0.310366, recall 0.985923, f_score 0.472112
# === total 20900 match 11509
# >>> step 21000
# step 20900-20999, precision 0.309801, recall 0.985923, f_score 0.471458
# === total 21000 match 11530
# >>> step 21100
# step 21000-21099, precision 0.310969, recall 0.986054, f_score 0.472825
# === total 21100 match 11596
# >>> step 21200
# step 21100-21199, precision 0.311313, recall 0.986122, f_score 0.473231
# === total 21200 match 11641
# >>> step 21300
# step 21200-21299, precision 0.311908, recall 0.986235, f_score 0.473930
# === total 21300 match 11715
# >>> step 21400
# step 21300-21399, precision 0.312431, recall 0.986018, f_score 0.474508
# === total 21400 match 11737
# >>> step 21500
# step 21400-21499, precision 0.311926, recall 0.986018, f_score 0.473926
# === total 21500 match 11756
# >>> step 21600
# step 21500-21599, precision 0.313485, recall 0.986144, f_score 0.475738
# === total 21600 match 11806
# >>> step 21700
# step 21600-21699, precision 0.314052, recall 0.986211, f_score 0.476398
# === total 21700 match 11842
# >>> step 21800
# step 21700-21799, precision 0.312915, recall 0.986211, f_score 0.475089
# === total 21800 match 11885
# >>> step 21900
# step 21800-21899, precision 0.313545, recall 0.986323, f_score 0.475828
# === total 21900 match 11960
# >>> step 22000
# step 21900-21999, precision 0.314821, recall 0.986434, f_score 0.477309
# === total 22000 match 12010
# >>> step 22100
# step 22000-22099, precision 0.313698, recall 0.986434, f_score 0.476017
# === total 22100 match 12053
# >>> step 22200
# step 22100-22199, precision 0.313825, recall 0.986469, f_score 0.476167
# === total 22200 match 12080
# >>> step 22300
# step 22200-22299, precision 0.313099, recall 0.986469, f_score 0.475331
# === total 22300 match 12108
# >>> step 22400
# step 22300-22399, precision 0.313165, recall 0.978592, f_score 0.474487
# === total 22400 match 12115
# >>> step 22500
# step 22400-22499, precision 0.313498, recall 0.978674, f_score 0.474878
# === total 22500 match 12150
# >>> step 22600
# step 22500-22599, precision 0.315070, recall 0.978880, f_score 0.476704
# === total 22600 match 12210
# >>> step 22700
# step 22600-22699, precision 0.314418, recall 0.978961, f_score 0.475967
# === total 22700 match 12283
# >>> step 22800
# step 22700-22799, precision 0.315644, recall 0.979140, f_score 0.477392
# === total 22800 match 12343
# >>> step 22900
# step 22800-22899, precision 0.316680, recall 0.979317, f_score 0.478597
# === total 22900 match 12410
# >>> step 23000
# step 22900-22999, precision 0.316860, recall 0.979384, f_score 0.478810
# === total 23000 match 12444
# >>> step 23100
# step 23000-23099, precision 0.317683, recall 0.977323, f_score 0.479502
# === total 23100 match 12481
# >>> step 23200
# step 23100-23199, precision 0.318087, recall 0.975000, f_score 0.479682
# === total 23200 match 12506
# >>> step 23300
# step 23200-23299, precision 0.319350, recall 0.975207, f_score 0.481142
# === total 23300 match 12563
# >>> step 23400
# step 23300-23399, precision 0.318286, recall 0.975207, f_score 0.479933
# === total 23400 match 12605
# >>> step 23500
# step 23400-23499, precision 0.317606, recall 0.975207, f_score 0.479159
# === total 23500 match 12632
# >>> step 23600
# step 23500-23599, precision 0.317029, recall 0.975207, f_score 0.478502
# === total 23600 match 12655
# >>> step 23700
# step 23600-23699, precision 0.317820, recall 0.975350, f_score 0.479420
# === total 23700 match 12699
# >>> step 23800
# step 23700-23799, precision 0.318670, recall 0.975516, f_score 0.480407
# === total 23800 match 12753
# >>> step 23900
# step 23800-23899, precision 0.319806, recall 0.975714, f_score 0.481721
# === total 23900 match 12814
# >>> step 24000
# step 23900-23999, precision 0.319209, recall 0.975714, f_score 0.481042
# === total 24000 match 12838
# >>> step 24100
# step 24000-24099, precision 0.319957, recall 0.975852, f_score 0.481908
# === total 24100 match 12883
# >>> step 24200
# step 24100-24199, precision 0.319703, recall 0.975887, f_score 0.481624
# === total 24200 match 12912
# >>> step 24300
# step 24200-24299, precision 0.319258, recall 0.975887, f_score 0.481119
# === total 24300 match 12930
# >>> step 24400
# step 24300-24399, precision 0.318494, recall 0.975887, f_score 0.480251
# === total 24400 match 12961
# >>> step 24500
# step 24400-24499, precision 0.318604, recall 0.976028, f_score 0.480393
# === total 24500 match 13035
# >>> step 24600
# step 24500-24599, precision 0.319328, recall 0.976179, f_score 0.481234
# === total 24600 match 13090
# >>> step 24700
# step 24600-24699, precision 0.318816, recall 0.976179, f_score 0.480653
# === total 24700 match 13111
# >>> step 24800
# step 24700-24799, precision 0.319301, recall 0.976301, f_score 0.481219
# === total 24800 match 13160
# >>> step 24900
# step 24800-24899, precision 0.319961, recall 0.976481, f_score 0.481989
# === total 24900 match 13236
# >>> step 25000
# step 24900-24999, precision 0.320889, recall 0.976680, f_score 0.483067
# === total 25000 match 13313
# >>> step 25100
# step 25000-25099, precision 0.320972, recall 0.976792, f_score 0.483174
# === total 25100 match 13375
# >>> step 25200
# step 25100-25199, precision 0.321519, recall 0.976970, f_score 0.483815
# === total 25200 match 13458
# >>> step 25300
# step 25200-25299, precision 0.320875, recall 0.976970, f_score 0.483086
# === total 25300 match 13485
# >>> step 25400
# step 25300-25399, precision 0.322035, recall 0.977145, f_score 0.484421
# === total 25400 match 13542
# >>> step 25500
# step 25400-25499, precision 0.322993, recall 0.977313, f_score 0.485525
# === total 25500 match 13604
# >>> step 25600
# step 25500-25599, precision 0.322049, recall 0.977318, f_score 0.484458
# === total 25600 match 13647
# >>> step 25700
# step 25600-25699, precision 0.321530, recall 0.977318, f_score 0.483871
# === total 25700 match 13669
# >>> step 25800
# step 25700-25799, precision 0.321882, recall 0.977409, f_score 0.484280
# === total 25800 match 13710
# >>> step 25900
# step 25800-25899, precision 0.321460, recall 0.977409, f_score 0.483802
# === total 25900 match 13728
# >>> step 26000
# step 25900-25999, precision 0.321833, recall 0.977498, f_score 0.484236
# === total 26000 match 13768
# >>> step 26100
# step 26000-26099, precision 0.321227, recall 0.977498, f_score 0.483549
# === total 26100 match 13794
# >>> step 26200
# step 26100-26199, precision 0.322155, recall 0.977676, f_score 0.484622
# === total 26200 match 13866
# >>> step 26300
# step 26200-26299, precision 0.322119, recall 0.977317, f_score 0.484537
# === total 26300 match 13911
# >>> step 26400
# step 26300-26399, precision 0.322195, recall 0.977426, f_score 0.484636
# === total 26400 match 13976
# >>> step 26500
# step 26400-26499, precision 0.322351, recall 0.977509, f_score 0.484822
# === total 26500 match 14022
# >>> step 26600
# step 26500-26599, precision 0.322551, recall 0.977591, f_score 0.485059
# === total 26600 match 14066
# >>> step 26700
# step 26600-26699, precision 0.322024, recall 0.977591, f_score 0.484463
# === total 26700 match 14089
# >>> step 26800
# step 26700-26799, precision 0.322327, recall 0.977697, f_score 0.484819
# === total 26800 match 14144
# >>> step 26900
# step 26800-26899, precision 0.323418, recall 0.977886, f_score 0.486075
# === total 26900 match 14220
# >>> step 27000
# step 26900-26999, precision 0.322818, recall 0.977915, f_score 0.485401
# === total 27000 match 14265
# >>> step 27100
# step 27000-27099, precision 0.322845, recall 0.977971, f_score 0.485438
# === total 27100 match 14301
# >>> step 27200
# step 27100-27199, precision 0.323605, recall 0.978105, f_score 0.486314
# === total 27200 match 14357
# >>> step 27300
# step 27200-27299, precision 0.323628, recall 0.978156, f_score 0.486345
# === total 27300 match 14390
# >>> step 27400
# step 27300-27399, precision 0.323956, recall 0.978293, f_score 0.486733
# === total 27400 match 14468
# >>> step 27500
# step 27400-27499, precision 0.323892, recall 0.978351, f_score 0.486668
# === total 27500 match 14511
# >>> step 27600
# step 27500-27599, precision 0.324237, recall 0.978428, f_score 0.487067
# === total 27600 match 14548
# >>> step 27700
# step 27600-27699, precision 0.323943, recall 0.978468, f_score 0.486740
# === total 27700 match 14589
# >>> step 27800
# step 27700-27799, precision 0.324175, recall 0.978543, f_score 0.487011
# === total 27800 match 14631
# >>> step 27900
# step 27800-27899, precision 0.324558, recall 0.978667, f_score 0.487458
# === total 27900 match 14700
# >>> step 28000
# step 27900-27999, precision 0.324447, recall 0.978771, f_score 0.487346
# === total 28000 match 14779
# >>> step 28100
# step 28000-28099, precision 0.324756, recall 0.978883, f_score 0.487709
# === total 28100 match 14845
# >>> step 28200
# step 28100-28199, precision 0.324960, recall 0.978956, f_score 0.487948
# === total 28200 match 14888
# >>> step 28300
# step 28200-28299, precision 0.325359, recall 0.979028, f_score 0.488406
# === total 28300 match 14922
# >>> step 28400
# step 28300-28399, precision 0.325134, recall 0.979066, f_score 0.488157
# === total 28400 match 14960
# >>> step 28500
# step 28400-28499, precision 0.325105, recall 0.979158, f_score 0.488136
# === total 28500 match 15029
# >>> step 28600
# step 28500-28599, precision 0.325276, recall 0.979266, f_score 0.488343
# === total 28600 match 15101
# >>> step 28700
# step 28600-28699, precision 0.325012, recall 0.979303, f_score 0.488049
# === total 28700 match 15141
# >>> step 28800
# step 28700-28799, precision 0.325147, recall 0.979373, f_score 0.488210
# === total 28800 match 15187
# >>> step 28900
# step 28800-28899, precision 0.325374, recall 0.979463, f_score 0.488477
# === total 28900 match 15244
# >>> step 29000
# step 28900-28999, precision 0.325677, recall 0.979532, f_score 0.488828
# === total 29000 match 15282
# >>> step 29100
# step 29000-29099, precision 0.325890, recall 0.979648, f_score 0.489082
# === total 29100 match 15361
# >>> step 29200
# step 29100-29199, precision 0.326576, recall 0.979790, f_score 0.489871
# === total 29200 match 15439
# >>> step 29300
# step 29200-29299, precision 0.328345, recall 0.979600, f_score 0.491835
# === total 29300 match 15502
# >>> step 29400
# step 29300-29399, precision 0.329001, recall 0.979127, f_score 0.492511
# === total 29400 match 15541
# >>> step 29500
# step 29400-29499, precision 0.329091, recall 0.978967, f_score 0.492592
# === total 29500 match 15558
# >>> step 29600
# step 29500-29599, precision 0.329361, recall 0.979052, f_score 0.492905
# === total 29600 match 15609
# >>> step 29700
# step 29600-29699, precision 0.330052, recall 0.979143, f_score 0.493690
# === total 29700 match 15646
# >>> step 29800
# step 29700-29799, precision 0.331659, recall 0.979159, f_score 0.495487
# === total 29800 match 15724
# >>> step 29900
# step 29800-29899, precision 0.331182, recall 0.979229, f_score 0.494963
# === total 29900 match 15801
# >>> step 30000
# step 29900-29999, precision 0.332892, recall 0.979429, f_score 0.496897
# === total 30000 match 15876
# >>> step 30100
# step 30000-30099, precision 0.334087, recall 0.979558, f_score 0.498244
# === total 30100 match 15921
# >>> step 30200
# step 30100-30199, precision 0.335002, recall 0.979685, f_score 0.499277
# === total 30200 match 15979
# >>> step 30300
# step 30200-30299, precision 0.335911, recall 0.979811, f_score 0.500302
# === total 30300 match 16037
# >>> step 30400
# step 30300-30399, precision 0.335719, recall 0.979307, f_score 0.500023
# === total 30400 match 16070
# >>> step 30500
# step 30400-30499, precision 0.335757, recall 0.977738, f_score 0.499861
# === total 30500 match 16089
# >>> step 30600
# step 30500-30599, precision 0.335463, recall 0.975122, f_score 0.499192
# === total 30600 match 16124
# >>> step 30700
# step 30600-30699, precision 0.336549, recall 0.975273, f_score 0.500414
# === total 30700 match 16173
# >>> step 30800
# step 30700-30799, precision 0.337276, recall 0.975414, f_score 0.501236
# === total 30800 match 16233
# >>> step 30900
# step 30800-30899, precision 0.338244, recall 0.975567, f_score 0.502325
# === total 30900 match 16290
# >>> step 31000
# step 30900-30999, precision 0.338342, recall 0.975597, f_score 0.502436
# === total 31000 match 16306
# >>> step 31100
# step 31000-31099, precision 0.340116, recall 0.975806, f_score 0.504418
# === total 31100 match 16365
# >>> step 31200
# step 31100-31199, precision 0.340716, recall 0.975712, f_score 0.505065
# === total 31200 match 16389
# >>> step 31300
# step 31200-31299, precision 0.341437, recall 0.975855, f_score 0.505875
# === total 31300 match 16454
# >>> step 31400
# step 31300-31399, precision 0.343262, recall 0.976072, f_score 0.507905
# === total 31400 match 16518
# >>> step 31500
# step 31400-31499, precision 0.344010, recall 0.976040, f_score 0.508720
# === total 31500 match 16578
# >>> step 31600
# step 31500-31599, precision 0.344983, recall 0.975838, f_score 0.509755
# === total 31600 match 16624
# >>> step 31700
# step 31600-31699, precision 0.344817, recall 0.975838, f_score 0.509574
# === total 31700 match 16632
# >>> step 31800
# step 31700-31799, precision 0.345323, recall 0.975981, f_score 0.510145
# === total 31800 match 16709
# >>> step 31900
# step 31800-31899, precision 0.345926, recall 0.976050, f_score 0.510813
# === total 31900 match 16729
# >>> step 32000
# step 31900-31999, precision 0.347167, recall 0.976258, f_score 0.512193
# === total 32000 match 16819
# >>> step 32100
# step 32000-32099, precision 0.348271, recall 0.976463, f_score 0.513422
# === total 32100 match 16915
# >>> step 32200
# step 32100-32199, precision 0.348859, recall 0.976622, f_score 0.514083
# === total 32200 match 17004
# >>> step 32300
# step 32200-32299, precision 0.349613, recall 0.975462, f_score 0.514740
# === total 32300 match 17056
# >>> step 32400
# step 32300-32399, precision 0.350423, recall 0.975297, f_score 0.515594
# === total 32400 match 17125
# >>> step 32500
# step 32400-32499, precision 0.350280, recall 0.975297, f_score 0.515439
# === total 32500 match 17132
# >>> step 32600
# step 32500-32599, precision 0.350942, recall 0.975369, f_score 0.516165
# === total 32600 match 17151
# >>> step 32700
# step 32600-32699, precision 0.351050, recall 0.975440, f_score 0.516292
# === total 32700 match 17197
# >>> step 32800
# step 32700-32799, precision 0.352301, recall 0.975164, f_score 0.517605
# === total 32800 match 17275
# >>> step 32900
# step 32800-32899, precision 0.352351, recall 0.975251, f_score 0.517671
# === total 32900 match 17335
# >>> step 33000
# step 32900-32999, precision 0.353134, recall 0.975226, f_score 0.518512
# === total 33000 match 17390
# >>> step 33100
# step 33000-33099, precision 0.353309, recall 0.975305, f_score 0.518712
# === total 33100 match 17438
# >>> step 33200
# step 33100-33199, precision 0.354537, recall 0.975491, f_score 0.520060
# === total 33200 match 17513
# >>> step 33300
# step 33200-33299, precision 0.354942, recall 0.975575, f_score 0.520508
# === total 33300 match 17555
# >>> step 33400
# step 33300-33399, precision 0.355473, recall 0.973524, f_score 0.520786
# === total 33400 match 17585
# >>> step 33500
# step 33400-33499, precision 0.355934, recall 0.973594, f_score 0.521291
# === total 33500 match 17610
# >>> step 33600
# step 33500-33599, precision 0.355125, recall 0.973619, f_score 0.520426
# === total 33600 match 17667
# >>> step 33700
# step 33600-33699, precision 0.354924, recall 0.973664, f_score 0.520217
# === total 33700 match 17708
# >>> step 33800
# step 33700-33799, precision 0.354750, recall 0.973680, f_score 0.520031
# === total 33800 match 17728
# >>> step 33900
# step 33800-33899, precision 0.354284, recall 0.973733, f_score 0.519538
# === total 33900 match 17788
# >>> step 34000
# step 33900-33999, precision 0.353849, recall 0.973753, f_score 0.519073
# === total 34000 match 17824
# >>> step 34100
# step 34000-34099, precision 0.353063, recall 0.973769, f_score 0.518230
# === total 34100 match 17875
# >>> step 34200
# step 34100-34199, precision 0.352353, recall 0.973769, f_score 0.517465
# === total 34200 match 17911
# >>> step 34300
# step 34200-34299, precision 0.352190, recall 0.972453, f_score 0.517103
# === total 34300 match 17942
# >>> step 34400
# step 34300-34399, precision 0.351863, recall 0.972525, f_score 0.516760
# === total 34400 match 18007
# >>> step 34500
# step 34400-34499, precision 0.351220, recall 0.972525, f_score 0.516066
# === total 34500 match 18040
# >>> step 34600
# step 34500-34599, precision 0.350753, recall 0.972525, f_score 0.515562
# === total 34600 match 18064
# >>> step 34700
# step 34600-34699, precision 0.350191, recall 0.972525, f_score 0.514954
# === total 34700 match 18093
# >>> step 34800
# step 34700-34799, precision 0.349572, recall 0.972525, f_score 0.514286
# === total 34800 match 18125
# >>> step 34900
# step 34800-34899, precision 0.349226, recall 0.972525, f_score 0.513910
# === total 34900 match 18143
# >>> step 35000
# step 34900-34999, precision 0.349298, recall 0.972563, f_score 0.513994
# === total 35000 match 18165
# >>> step 35100
# step 35000-35099, precision 0.349245, recall 0.972617, f_score 0.513944
# === total 35100 match 18205
# >>> step 35200
# step 35100-35199, precision 0.349017, recall 0.972676, f_score 0.513705
# === total 35200 match 18257
# >>> step 35300
# step 35200-35299, precision 0.348189, recall 0.972688, f_score 0.512810
# === total 35300 match 18309
# >>> step 35400
# step 35300-35399, precision 0.347639, recall 0.972688, f_score 0.512213
# === total 35400 match 18338
# >>> step 35500
# step 35400-35499, precision 0.347109, recall 0.972688, f_score 0.511637
# === total 35500 match 18366
# >>> step 35600
# step 35500-35599, precision 0.347278, recall 0.972759, f_score 0.511831
# === total 35600 match 18406
# >>> step 35700
# step 35600-35699, precision 0.346356, recall 0.972759, f_score 0.510829
# === total 35700 match 18455
# >>> step 35800
# step 35700-35799, precision 0.346489, recall 0.972829, f_score 0.510983
# === total 35800 match 18497
# >>> step 35900
# ...
# === total 525400 match 201482
# >>> step 525500
# step 525400-525499, precision 0.274604, recall 0.943234, f_score 0.425371
# === total 525500 match 201559
# >>> step 525600
# step 525500-525599, precision 0.274687, recall 0.943267, f_score 0.425473
# === total 525600 match 201622
# >>> step 525700
# step 525600-525699, precision 0.274686, recall 0.943267, f_score 0.425472
# === total 525700 match 201623
# >>> step 525800
# step 525700-525799, precision 0.274748, recall 0.943300, f_score 0.425550
# === total 525800 match 201701
# >>> step 525900
# step 525800-525899, precision 0.274732, recall 0.943300, f_score 0.425530
# === total 525900 match 201713
# >>> step 526000
# step 525900-525999, precision 0.274694, recall 0.943300, f_score 0.425484
# === total 526000 match 201741
# >>> step 526100
# step 526000-526099, precision 0.274730, recall 0.943301, f_score 0.425528
# === total 526100 match 201776
# >>> step 526200
# step 526100-526199, precision 0.274810, recall 0.943333, f_score 0.425628
# === total 526200 match 201841
# >>> step 526300
# step 526200-526299, precision 0.274791, recall 0.943333, f_score 0.425605
# === total 526300 match 201855
# >>> step 526400
# step 526300-526399, precision 0.274796, recall 0.943351, f_score 0.425612
# === total 526400 match 201917
# >>> step 526500
# step 526400-526499, precision 0.274870, recall 0.943264, f_score 0.425692
# === total 526500 match 201961
# >>> step 526600
# step 526500-526599, precision 0.274908, recall 0.943270, f_score 0.425738
# === total 526600 match 202013
# >>> step 526700
# step 526600-526699, precision 0.274994, recall 0.943306, f_score 0.425845
# === total 526700 match 202088
# >>> step 526800
# step 526700-526799, precision 0.275088, recall 0.943194, f_score 0.425946
# === total 526800 match 202139
# >>> step 526900
# step 526800-526899, precision 0.275078, recall 0.943195, f_score 0.425934
# === total 526900 match 202150
# >>> step 527000
# step 526900-526999, precision 0.275136, recall 0.943228, f_score 0.426007
# === total 527000 match 202231
# >>> step 527100
# step 527000-527099, precision 0.275102, recall 0.943228, f_score 0.425966
# === total 527100 match 202256
# >>> step 527200
# step 527100-527199, precision 0.275188, recall 0.943257, f_score 0.426072
# === total 527200 match 202302
# >>> step 527300
# step 527200-527299, precision 0.275156, recall 0.943257, f_score 0.426035
# === total 527300 match 202325
# >>> step 527400
# step 527300-527399, precision 0.275154, recall 0.943260, f_score 0.426033
# === total 527400 match 202341
# >>> step 527500
# step 527400-527499, precision 0.275158, recall 0.943274, f_score 0.426039
# === total 527500 match 202389
# >>> step 527600
# step 527500-527599, precision 0.275175, recall 0.943281, f_score 0.426060
# === total 527600 match 202402
# >>> step 527700
# step 527600-527699, precision 0.275235, recall 0.943312, f_score 0.426134
# === total 527700 match 202478
# >>> step 527800
# step 527700-527799, precision 0.275191, recall 0.943312, f_score 0.426082
# === total 527800 match 202510
# >>> step 527900
# step 527800-527899, precision 0.275245, recall 0.943345, f_score 0.426150
# === total 527900 match 202594
# >>> step 528000
# step 527900-527999, precision 0.275237, recall 0.943353, f_score 0.426141
# === total 528000 match 202633
# >>> step 528100
# step 528000-528099, precision 0.275266, recall 0.943371, f_score 0.426177
# === total 528100 match 202677
# >>> step 528200
# step 528100-528199, precision 0.275307, recall 0.943394, f_score 0.426229
# === total 528200 match 202734
# >>> step 528300
# step 528200-528299, precision 0.275295, recall 0.943403, f_score 0.426215
# === total 528300 match 202779
# >>> step 528400
# step 528300-528399, precision 0.275292, recall 0.943403, f_score 0.426212
# === total 528400 match 202781
# >>> step 528500
# step 528400-528499, precision 0.275389, recall 0.943436, f_score 0.426332
# === total 528500 match 202833
# >>> step 528600
# step 528500-528599, precision 0.275456, recall 0.943468, f_score 0.426416
# === total 528600 match 202907
# >>> step 528700
# step 528600-528699, precision 0.275436, recall 0.943468, f_score 0.426391
# === total 528700 match 202922
# >>> step 528800
# step 528700-528799, precision 0.275536, recall 0.943501, f_score 0.426514
# === total 528800 match 202972
# >>> step 528900
# step 528800-528899, precision 0.275597, recall 0.943533, f_score 0.426591
# === total 528900 match 203050
# >>> step 529000
# step 528900-528999, precision 0.275555, recall 0.943533, f_score 0.426541
# === total 529000 match 203081
# >>> step 529100
# step 529000-529099, precision 0.275632, recall 0.943565, f_score 0.426636
# === total 529100 match 203148
# >>> step 529200
# step 529100-529199, precision 0.275668, recall 0.943377, f_score 0.426660
# === total 529200 match 203190
# >>> step 529300
# step 529200-529299, precision 0.275700, recall 0.943396, f_score 0.426700
# === total 529300 match 203239
# >>> step 529400
# step 529300-529399, precision 0.275695, recall 0.943382, f_score 0.426693
# === total 529400 match 203250
# >>> step 529500
# step 529400-529499, precision 0.275767, recall 0.943294, f_score 0.426770
# === total 529500 match 203284
# >>> step 529600
# step 529500-529599, precision 0.275763, recall 0.943294, f_score 0.426765
# === total 529600 match 203287
# >>> step 529700
# step 529600-529699, precision 0.275763, recall 0.943294, f_score 0.426765
# === total 529700 match 203287
# >>> step 529800
# step 529700-529799, precision 0.275748, recall 0.943311, f_score 0.426749
# === total 529800 match 203363
# >>> step 529900
# step 529800-529899, precision 0.275822, recall 0.943343, f_score 0.426841
# === total 529900 match 203432
# >>> step 530000
# step 529900-529999, precision 0.275810, recall 0.943343, f_score 0.426826
# === total 530000 match 203441
# >>> step 530100
# step 530000-530099, precision 0.275814, recall 0.943243, f_score 0.426821
# === total 530100 match 203478
# >>> step 530200
# step 530100-530199, precision 0.275891, recall 0.943281, f_score 0.426917
# === total 530200 match 203566
# >>> step 530300
# step 530200-530299, precision 0.275932, recall 0.943310, f_score 0.426969
# === total 530300 match 203648
# >>> step 530400
# step 530300-530399, precision 0.275992, recall 0.943342, f_score 0.427045
# === total 530400 match 203723
# >>> step 530500
# step 530400-530499, precision 0.276052, recall 0.943374, f_score 0.427120
# === total 530500 match 203802
# >>> step 530600
# step 530500-530599, precision 0.276033, recall 0.943378, f_score 0.427097
# === total 530600 match 203831
# >>> step 530700
# step 530600-530699, precision 0.276103, recall 0.943406, f_score 0.427183
# === total 530700 match 203888
# >>> step 530800
# step 530700-530799, precision 0.276167, recall 0.943435, f_score 0.427263
# === total 530800 match 203949
# >>> step 530900
# step 530800-530899, precision 0.276131, recall 0.943435, f_score 0.427220
# === total 530900 match 203976
# >>> step 531000
# step 530900-530999, precision 0.276074, recall 0.943435, f_score 0.427152
# === total 531000 match 204018
# >>> step 531100
# step 531000-531099, precision 0.276099, recall 0.943335, f_score 0.427172
# === total 531100 match 204039
# >>> step 531200
# step 531100-531199, precision 0.276098, recall 0.943335, f_score 0.427170
# === total 531200 match 204040
# >>> step 531300
# step 531200-531299, precision 0.276152, recall 0.943339, f_score 0.427236
# === total 531300 match 204076
# >>> step 531400
# step 531300-531399, precision 0.276248, recall 0.943371, f_score 0.427354
# === total 531400 match 204128
# >>> step 531500
# step 531400-531499, precision 0.276203, recall 0.943379, f_score 0.427301
# === total 531500 match 204194
# >>> step 531600
# step 531500-531599, precision 0.276244, recall 0.943397, f_score 0.427351
# === total 531600 match 204229
# >>> step 531700
# step 531600-531699, precision 0.276195, recall 0.943397, f_score 0.427293
# === total 531700 match 204265
# >>> step 531800
# step 531700-531799, precision 0.276255, recall 0.943429, f_score 0.427368
# === total 531800 match 204344
# >>> step 531900
# step 531800-531899, precision 0.276234, recall 0.943429, f_score 0.427343
# === total 531900 match 204359
# >>> step 532000
# step 531900-531999, precision 0.276232, recall 0.943435, f_score 0.427341
# === total 532000 match 204386
# >>> step 532100
# step 532000-532099, precision 0.276325, recall 0.943460, f_score 0.427455
# === total 532100 match 204473
# >>> step 532200
# step 532100-532199, precision 0.276341, recall 0.943476, f_score 0.427475
# === total 532200 match 204523
# >>> step 532300
# step 532200-532299, precision 0.276349, recall 0.943481, f_score 0.427486
# === total 532300 match 204535
# >>> step 532400
# step 532300-532399, precision 0.276439, recall 0.943450, f_score 0.427591
# === total 532400 match 204591
# >>> step 532500
# step 532400-532499, precision 0.276468, recall 0.943466, f_score 0.427627
# === total 532500 match 204631
# >>> step 532600
# step 532500-532599, precision 0.276491, recall 0.943486, f_score 0.427657
# === total 532600 match 204690
# >>> step 532700
# step 532600-532699, precision 0.276439, recall 0.943487, f_score 0.427595
# === total 532700 match 204732
# >>> step 532800
# step 532700-532799, precision 0.276423, recall 0.943487, f_score 0.427575
# === total 532800 match 204744
# >>> step 532900
# step 532800-532899, precision 0.276439, recall 0.943508, f_score 0.427596
# === total 532900 match 204812
# >>> step 533000
# step 532900-532999, precision 0.276411, recall 0.943512, f_score 0.427563
# === total 533000 match 204851
# >>> step 533100
# step 533000-533099, precision 0.276428, recall 0.943537, f_score 0.427586
# === total 533100 match 204932
# >>> step 533200
# step 533100-533199, precision 0.276467, recall 0.943569, f_score 0.427636
# === total 533200 match 205026
# >>> step 533300
# step 533200-533299, precision 0.276480, recall 0.943589, f_score 0.427654
# === total 533300 match 205096
# >>> step 533400
# step 533300-533399, precision 0.276503, recall 0.943605, f_score 0.427682
# === total 533400 match 205141
# >>> step 533500
# step 533400-533499, precision 0.276497, recall 0.943605, f_score 0.427676
# === total 533500 match 205145
# >>> step 533600
# step 533500-533599, precision 0.276495, recall 0.943548, f_score 0.427668
# === total 533600 match 205168
# >>> step 533700
# step 533600-533699, precision 0.276480, recall 0.943507, f_score 0.427645
# === total 533700 match 205201
# >>> step 533800
# step 533700-533799, precision 0.276484, recall 0.943527, f_score 0.427652
# === total 533800 match 205278
# >>> step 533900
# step 533800-533899, precision 0.276518, recall 0.943548, f_score 0.427695
# === total 533900 match 205332
# >>> step 534000
# step 533900-533999, precision 0.276480, recall 0.943548, f_score 0.427650
# === total 534000 match 205360
# >>> step 534100
# step 534000-534099, precision 0.276533, recall 0.943580, f_score 0.427716
# === total 534100 match 205444
# >>> step 534200
# step 534100-534199, precision 0.276494, recall 0.943580, f_score 0.427669
# === total 534200 match 205473
# >>> step 534300
# step 534200-534299, precision 0.276541, recall 0.943571, f_score 0.427724
# === total 534300 match 205525
# >>> step 534400
# step 534300-534399, precision 0.276654, recall 0.943611, f_score 0.427864
# === total 534400 match 205596
# >>> step 534500
# step 534400-534499, precision 0.276674, recall 0.943628, f_score 0.427890
# === total 534500 match 205646
# >>> step 534600
# step 534500-534599, precision 0.276765, recall 0.943642, f_score 0.428001
# === total 534600 match 205694
# >>> step 534700
# step 534600-534699, precision 0.276791, recall 0.943656, f_score 0.428033
# === total 534700 match 205729
# >>> step 534800
# step 534700-534799, precision 0.276876, recall 0.943691, f_score 0.428137
# === total 534800 match 205800
# >>> step 534900
# step 534800-534899, precision 0.276911, recall 0.943691, f_score 0.428180
# === total 534900 match 205835
# >>> step 535000
# step 534900-534999, precision 0.277029, recall 0.943740, f_score 0.428326
# === total 535000 match 205935
# >>> step 535100
# step 535000-535099, precision 0.277156, recall 0.943787, f_score 0.428482
# === total 535100 match 206025
# >>> step 535200
# step 535100-535199, precision 0.277218, recall 0.943819, f_score 0.428560
# === total 535200 match 206105
# >>> step 535300
# step 535200-535299, precision 0.277303, recall 0.943735, f_score 0.428653
# === total 535300 match 206139
# >>> step 535400
# step 535300-535399, precision 0.277390, recall 0.943767, f_score 0.428760
# === total 535400 match 206197
# >>> step 535500
# step 535400-535499, precision 0.277393, recall 0.943769, f_score 0.428764
# === total 535500 match 206202
# >>> step 535600
# step 535500-535599, precision 0.277423, recall 0.943767, f_score 0.428799
# === total 535600 match 206234
# >>> step 535700
# step 535600-535699, precision 0.277489, recall 0.943792, f_score 0.428881
# === total 535700 match 206282
# >>> step 535800
# step 535700-535799, precision 0.277574, recall 0.943832, f_score 0.428986
# === total 535800 match 206374
# >>> step 535900
# step 535800-535899, precision 0.277636, recall 0.943828, f_score 0.429060
# === total 535900 match 206432
# >>> step 536000
# step 535900-535999, precision 0.277723, recall 0.943859, f_score 0.429167
# === total 536000 match 206490
# >>> step 536100
# step 536000-536099, precision 0.277693, recall 0.943859, f_score 0.429132
# === total 536100 match 206512
# >>> step 536200
# step 536100-536199, precision 0.277888, recall 0.943922, f_score 0.429371
# === total 536200 match 206612
# >>> step 536300
# step 536200-536299, precision 0.277893, recall 0.943888, f_score 0.429372
# === total 536300 match 206659
# >>> step 536400
# step 536300-536399, precision 0.278021, recall 0.943866, f_score 0.429524
# === total 536400 match 206718
# >>> step 536500
# step 536400-536499, precision 0.278092, recall 0.943897, f_score 0.429611
# === total 536500 match 206788
# >>> step 536600
# step 536500-536599, precision 0.278218, recall 0.943945, f_score 0.429767
# === total 536600 match 206881
# >>> step 536700
# step 536600-536699, precision 0.278246, recall 0.943961, f_score 0.429802
# === total 536700 match 206921
# >>> step 536800
# step 536700-536799, precision 0.278276, recall 0.943976, f_score 0.429839
# === total 536800 match 206960
# >>> step 536900
# step 536800-536899, precision 0.278316, recall 0.943993, f_score 0.429888
# === total 536900 match 206995
# >>> step 537000
# step 536900-536999, precision 0.278403, recall 0.944024, f_score 0.429996
# === total 537000 match 207052
# >>> step 537100
# step 537000-537099, precision 0.278457, recall 0.944054, f_score 0.430063
# === total 537100 match 207131
# >>> step 537200
# step 537100-537199, precision 0.278552, recall 0.944092, f_score 0.430181
# === total 537200 match 207207
# >>> step 537300
# step 537200-537299, precision 0.278687, recall 0.944136, f_score 0.430346
# === total 537300 match 207279
# >>> step 537400
# step 537300-537399, precision 0.278772, recall 0.944167, f_score 0.430450
# === total 537400 match 207338
# >>> step 537500
# step 537400-537499, precision 0.278866, recall 0.944198, f_score 0.430566
# === total 537500 match 207390
# >>> step 537600
# step 537500-537599, precision 0.278940, recall 0.944229, f_score 0.430657
# === total 537600 match 207457
# >>> step 537700
# step 537600-537699, precision 0.278940, recall 0.944243, f_score 0.430659
# === total 537700 match 207514
# >>> step 537800
# step 537700-537799, precision 0.278953, recall 0.944257, f_score 0.430676
# === total 537800 match 207558
# >>> step 537900
# step 537800-537899, precision 0.278932, recall 0.944270, f_score 0.430652
# === total 537900 match 207624
# >>> step 538000
# step 537900-537999, precision 0.279088, recall 0.944301, f_score 0.430841
# === total 538000 match 207691
# >>> step 538100
# step 538000-538099, precision 0.279133, recall 0.944320, f_score 0.430897
# === total 538100 match 207736
# >>> step 538200
# step 538100-538199, precision 0.279199, recall 0.944351, f_score 0.430978
# === total 538200 match 207809
# >>> step 538300
# step 538200-538299, precision 0.279217, recall 0.944365, f_score 0.431002
# === total 538300 match 207849
# >>> step 538400
# step 538300-538399, precision 0.279363, recall 0.944413, f_score 0.431181
# === total 538400 match 207930
# >>> step 538500
# step 538400-538499, precision 0.279438, recall 0.944440, f_score 0.431272
# === total 538500 match 207982
# >>> step 538600
# step 538500-538599, precision 0.279508, recall 0.944471, f_score 0.431359
# === total 538600 match 208051
# TOTAL 538600, precision 0.279508, recall 0.944471, f_score 0.431359
# TOTAL true = 61571
# TOTAL error rate = 0.284660

# %%
# RE-TEST3 - take 1 piece and cross- validate on this (uncomment all for full test run)
train_imgs, train_lbls, is_enriched = \
    load_train_from_disk(ROOT_FOLDER + "train_concats3/")
# tf.reset_default_graph()
# model_tf_deep(250, 1)    
# validate2_for_cross_validation(train_imgs, train_lbls, is_enriched, ROOT_FOLDER + "model_binary/tear_model3.ckpt")

# %%
#### STOP

# %%
len(train_imgs)

# %%
sum(x[1] == 1 for x in train_lbls)

# %%
#####################################################################
TRAINING:
MODEL:/Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model1.ckpt
#####################################################################
step 49, training accuracy 0.78
step 99, training accuracy 0.84
step 149, training accuracy 0.9
step 199, training accuracy 0.92
step 249, training accuracy 0.88
step 299, training accuracy 0.84
step 349, training accuracy 0.92
step 399, training accuracy 0.86
Optimization Finished!
step 399, training accuracy 0.86
Model saved in file: /Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model1.ckpt
#####################################################################
TRAINING ENDED
#####################################################################
deper network
#####################################################################
TRAINING:
MODEL:/Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model1.ckpt
#####################################################################
step 49, training accuracy 0.84
step 99, training accuracy 0.94
step 149, training accuracy 0.86
step 199, training accuracy 0.92
step 249, training accuracy 0.88
step 299, training accuracy 0.92
step 349, training accuracy 0.96
step 399, training accuracy 0.96
Optimization Finished!
step 399, training accuracy 0.96
Model saved in file: /Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model1.ckpt
#####################################################################
TRAINING ENDED
#####################################################################
deeper network on GCP
#####################################################################
TRAINING:
MODEL:/home/il239838/files/model_binary/tear_model1.ckpt
#####################################################################
WARNING:tensorflow:From /home/il239838/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
Instructions for updating:
Use `tf.global_variables_initializer` instead.
step 49, training accuracy 0.82
step 99, training accuracy 0.92
step 149, training accuracy 0.72
step 199, training accuracy 0.8
step 249, training accuracy 0.88
step 299, training accuracy 0.88
step 349, training accuracy 0.94
step 399, training accuracy 0.84
Optimization Finished!
step 399, training accuracy 0.84
Model saved in file: /home/il239838/files/model_binary/tear_model1.ckpt
#####################################################################
TRAINING ENDED
#####################################################################

# %%
#####################################################################
TRAINING:
MODEL:/Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model2.ckpt
#####################################################################
INFO:tensorflow:Restoring parameters from /Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model1.ckpt
Model restored.
step 49, training accuracy 0.76
step 99, training accuracy 0.82
step 149, training accuracy 0.96
step 199, training accuracy 0.86
step 249, training accuracy 0.76
step 299, training accuracy 0.82
step 349, training accuracy 0.86
step 399, training accuracy 0.88
Optimization Finished!
step 399, training accuracy 0.88
Model saved in file: /Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model2.ckpt
#####################################################################
TRAINING ENDED
#####################################################################
deeper network
#####################################################################
TRAINING:
MODEL:/Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model2.ckpt
#####################################################################
INFO:tensorflow:Restoring parameters from /Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model1.ckpt
Model restored.
step 49, training accuracy 0.88
step 99, training accuracy 0.88
step 149, training accuracy 0.88
step 199, training accuracy 0.88
step 249, training accuracy 0.92
step 299, training accuracy 0.92
step 349, training accuracy 0.86
step 399, training accuracy 0.94
Optimization Finished!
step 399, training accuracy 0.94
Model saved in file: /Users/il239838/Downloads/private/Thesis/Papyrus/model_binary_new_X6/tear_model2.ckpt
#####################################################################
TRAINING ENDED
#####################################################################
deeper network on GCP
#####################################################################
TRAINING:
MODEL:/home/il239838/files/model_binary/tear_model2.ckpt
#####################################################################
INFO:tensorflow:Restoring parameters from /home/il239838/files/model_binary/tear_model1.ckpt
Model restored.
step 49, training accuracy 0.88
step 99, training accuracy 0.96
step 149, training accuracy 0.84
step 199, training accuracy 0.84
step 249, training accuracy 0.84
step 299, training accuracy 0.92
step 349, training accuracy 0.98
step 399, training accuracy 0.9
Optimization Finished!
step 399, training accuracy 0.9
Model saved in file: /home/il239838/files/model_binary/tear_model2.ckpt
#####################################################################
TRAINING ENDED
#####################################################################

# %%
#####################################################################
>>> step 100
step 0-99, precision 0.695652, recall 0.640000, f_score 0.666667
>>> step 200
step 100-199, precision 0.512500, recall 0.732143, f_score 0.602941
>>> step 300
step 200-299, precision 0.350427, recall 0.732143, f_score 0.473988
>>> step 400
step 300-399, precision 0.408805, recall 0.677083, f_score 0.509804
>>> step 500
step 400-499, precision 0.366834, recall 0.651786, f_score 0.469453
>>> step 600
step 500-599, precision 0.349282, recall 0.651786, f_score 0.454829
>>> step 700
step 600-699, precision 0.376471, recall 0.662069, f_score 0.480000
>>> step 800
step 700-799, precision 0.383142, recall 0.595238, f_score 0.466200
>>> step 900
step 800-899, precision 0.394649, recall 0.617801, f_score 0.481633
>>> step 1000
step 900-999, precision 0.407821, recall 0.651786, f_score 0.501718
>>> step 1100
step 1000-1099, precision 0.404432, recall 0.651786, f_score 0.499145
>>> step 1200
step 1100-1199, precision 0.423559, recall 0.657588, f_score 0.515244
>>> step 1300
step 1200-1299, precision 0.408983, recall 0.662835, f_score 0.505848
>>> step 1400
step 1300-1399, precision 0.405640, recall 0.667857, f_score 0.504723
>>> step 1500
step 1400-1499, precision 0.415020, recall 0.670927, f_score 0.512821
>>> step 1600
step 1500-1599, precision 0.402852, recall 0.672619, f_score 0.503902
>>> step 1700
step 1600-1699, precision 0.401681, recall 0.647696, f_score 0.495851
>>> step 1800
step 1700-1799, precision 0.387987, recall 0.647696, f_score 0.485279
>>> step 1900
step 1800-1899, precision 0.385484, recall 0.647696, f_score 0.483316
>>> step 2000
step 1900-1999, precision 0.388802, recall 0.647668, f_score 0.485909
>>> step 2100
step 2000-2099, precision 0.379161, recall 0.650124, f_score 0.478976
>>> step 2200
step 2100-2199, precision 0.374286, recall 0.650124, f_score 0.475068
>>> step 2300
step 2200-2299, precision 0.381868, recall 0.651054, f_score 0.481385
>>> step 2400
step 2300-2399, precision 0.392622, recall 0.659292, f_score 0.492155
>>> step 2500
step 2400-2499, precision 0.393604, recall 0.665281, f_score 0.494590
>>> step 2600
step 2500-2599, precision 0.392601, recall 0.664646, f_score 0.493623
>>> step 2700
step 2600-2699, precision 0.389810, recall 0.664646, f_score 0.491412
>>> step 2800
step 2700-2799, precision 0.384884, recall 0.655446, f_score 0.484982
>>> step 2900
step 2800-2899, precision 0.390572, recall 0.664122, f_score 0.491873
>>> step 3000
step 2900-2999, precision 0.401064, recall 0.679279, f_score 0.504348
>>> step 3100
step 3000-3099, precision 0.418534, recall 0.695431, f_score 0.522568
>>> step 3200
step 3100-3199, precision 0.430129, recall 0.704545, f_score 0.534154
>>> step 3300
step 3200-3299, precision 0.446036, recall 0.716258, f_score 0.549735
>>> step 3400
step 3300-3399, precision 0.448563, recall 0.722388, f_score 0.553459
>>> step 3500
step 3400-3499, precision 0.455204, recall 0.719599, f_score 0.557650
>>> step 3600
step 3500-3599, precision 0.456560, recall 0.718271, f_score 0.558266
>>> step 3700
step 3600-3699, precision 0.457841, recall 0.724000, f_score 0.560950
>>> step 3800
step 3700-3799, precision 0.455285, recall 0.720721, f_score 0.558047
>>> step 3900
step 3800-3899, precision 0.459969, recall 0.724351, f_score 0.562650
>>> step 4000
step 3900-3999, precision 0.445289, recall 0.724351, f_score 0.551529
>>> step 4100
step 4000-4099, precision 0.442598, recall 0.724351, f_score 0.549461
>>> step 4200
step 4100-4199, precision 0.445596, recall 0.725301, f_score 0.552040
>>> step 4300
step 4200-4299, precision 0.429793, recall 0.724760, f_score 0.539597
>>> step 4400
step 4300-4399, precision 0.426450, recall 0.724760, f_score 0.536955
>>> step 4500
step 4400-4499, precision 0.427491, recall 0.727485, f_score 0.538528
>>> step 4600
step 4500-4599, precision 0.427310, recall 0.723820, f_score 0.537377
>>> step 4700
step 4600-4699, precision 0.422999, recall 0.723820, f_score 0.533956
>>> step 4800
step 4700-4799, precision 0.419893, recall 0.723820, f_score 0.531474
>>> step 4900
step 4800-4899, precision 0.423740, recall 0.723669, f_score 0.534504
>>> step 5000
step 4900-4999, precision 0.428387, recall 0.725683, f_score 0.538742
>>> step 5100
step 5000-5099, precision 0.417348, recall 0.725683, f_score 0.529928
>>> step 5200
step 5100-5199, precision 0.414482, recall 0.725683, f_score 0.527612
>>> step 5300
step 5200-5299, precision 0.412935, recall 0.725683, f_score 0.526358
>>> step 5400
step 5300-5399, precision 0.418093, recall 0.720759, f_score 0.529207
>>> step 5500
step 5400-5499, precision 0.409934, recall 0.720294, f_score 0.522502
>>> step 5600
step 5500-5599, precision 0.409280, recall 0.719665, f_score 0.521805
>>> step 5700
step 5600-5699, precision 0.411176, recall 0.716189, f_score 0.522422
>>> step 5800
step 5700-5799, precision 0.413056, recall 0.707921, f_score 0.521707
>>> step 5900
step 5800-5899, precision 0.408427, recall 0.701061, f_score 0.516152
>>> step 6000
step 5900-5999, precision 0.404113, recall 0.701061, f_score 0.512694
>>> step 6100
step 6000-6099, precision 0.399565, recall 0.700382, f_score 0.508839
>>> step 6200
step 6100-6199, precision 0.398913, recall 0.700382, f_score 0.508310
>>> step 6300
step 6200-6299, precision 0.402681, recall 0.704503, f_score 0.512453
>>> step 6400
step 6300-6399, precision 0.404178, recall 0.709441, f_score 0.514970
>>> step 6500
step 6400-6499, precision 0.402955, recall 0.713255, f_score 0.514974
>>> step 6600
step 6500-6599, precision 0.402532, recall 0.713645, f_score 0.514730
>>> step 6700
step 6600-6699, precision 0.413011, recall 0.712585, f_score 0.522933
>>> step 6800
step 6700-6799, precision 0.416506, recall 0.713813, f_score 0.526059
>>> step 6900
step 6800-6899, precision 0.421002, recall 0.712439, f_score 0.529253
>>> step 7000
step 6900-6999, precision 0.428773, recall 0.709176, f_score 0.534427
>>> step 7100
step 7000-7099, precision 0.430497, recall 0.704718, f_score 0.534488
>>> step 7200
step 7100-7199, precision 0.437929, recall 0.695273, f_score 0.537381
>>> step 7300
step 7200-7299, precision 0.440254, recall 0.693133, f_score 0.538483
>>> step 7400
step 7300-7399, precision 0.441348, recall 0.690577, f_score 0.538525
>>> step 7500
step 7400-7499, precision 0.439821, recall 0.688375, f_score 0.536719
>>> step 7600
step 7500-7599, precision 0.440693, recall 0.683196, f_score 0.535782
>>> step 7700
step 7600-7699, precision 0.440618, recall 0.676152, f_score 0.533547
>>> step 7800
step 7700-7799, precision 0.435618, recall 0.676152, f_score 0.529865
>>> step 7900
step 7800-7899, precision 0.431701, recall 0.674044, f_score 0.526316
>>> step 8000
step 7900-7999, precision 0.429482, recall 0.668651, f_score 0.523021
>>> step 8100
step 8000-8099, precision 0.428027, recall 0.667768, f_score 0.521672
>>> step 8200
step 8100-8199, precision 0.429717, recall 0.664057, f_score 0.521784
>>> step 8300
step 8200-8299, precision 0.428451, recall 0.664057, f_score 0.520849
>>> step 8400
step 8300-8399, precision 0.429589, recall 0.660438, f_score 0.520569
>>> step 8500
step 8400-8499, precision 0.428870, recall 0.660438, f_score 0.520041
>>> step 8600
step 8500-8599, precision 0.427618, recall 0.660438, f_score 0.519119
>>> step 8700
step 8600-8699, precision 0.424528, recall 0.655478, f_score 0.515310
>>> step 8800
step 8700-8799, precision 0.421074, recall 0.655478, f_score 0.512757
>>> step 8900
step 8800-8899, precision 0.420032, recall 0.650814, f_score 0.510555
>>> step 9000
step 8900-8999, precision 0.415667, recall 0.650814, f_score 0.507317
>>> step 9100
step 9000-9099, precision 0.414201, recall 0.646154, f_score 0.504808
>>> step 9200
step 9100-9199, precision 0.414510, recall 0.642944, f_score 0.504053
>>> step 9300
step 9200-9299, precision 0.413793, recall 0.639138, f_score 0.502352
>>> step 9400
step 9300-9399, precision 0.408101, recall 0.639138, f_score 0.498134
>>> step 9500
step 9400-9499, precision 0.407789, recall 0.639138, f_score 0.497902
>>> step 9600
step 9500-9599, precision 0.408248, recall 0.639218, f_score 0.498268
>>> step 9700
step 9600-9699, precision 0.406097, recall 0.639218, f_score 0.496663
>>> step 9800
step 9700-9799, precision 0.408482, recall 0.639487, f_score 0.498524
>>> step 9900
step 9800-9899, precision 0.407298, recall 0.639098, f_score 0.497524
>>> step 10000
step 9900-9999, precision 0.406250, recall 0.639098, f_score 0.496741
>>> step 10100
step 10000-10099, precision 0.407407, recall 0.636312, f_score 0.496758
>>> step 10200
step 10100-10199, precision 0.408892, recall 0.636415, f_score 0.497892
>>> step 10300
step 10200-10299, precision 0.407852, recall 0.636415, f_score 0.497120
>>> step 10400
step 10300-10399, precision 0.408796, recall 0.637079, f_score 0.498024
>>> step 10500
step 10400-10499, precision 0.406452, recall 0.637079, f_score 0.496280
>>> step 10600
step 10500-10599, precision 0.405540, recall 0.637989, f_score 0.495875
>>> step 10700
step 10600-10699, precision 0.403583, recall 0.636918, f_score 0.494087
>>> step 10800
step 10700-10799, precision 0.401748, recall 0.636918, f_score 0.492710
>>> step 10900
step 10800-10899, precision 0.402490, recall 0.636066, f_score 0.493011
>>> step 11000
step 10900-10999, precision 0.400619, recall 0.633496, f_score 0.490836
>>> step 11100
step 11000-11099, precision 0.396798, recall 0.633496, f_score 0.487958
>>> step 11200
step 11100-11199, precision 0.396944, recall 0.629510, f_score 0.486880
>>> step 11300
step 11200-11299, precision 0.397928, recall 0.628496, f_score 0.487316
>>> step 11400
step 11300-11399, precision 0.398474, recall 0.625521, f_score 0.486826
>>> step 11500
step 11400-11499, precision 0.397233, recall 0.620690, f_score 0.484435
>>> step 11600
step 11500-11599, precision 0.396189, recall 0.620690, f_score 0.483658
>>> step 11700
step 11600-11699, precision 0.397906, recall 0.620725, f_score 0.484945
>>> step 11800
step 11700-11799, precision 0.397856, recall 0.618999, f_score 0.484381
>>> step 11900
step 11800-11899, precision 0.396184, recall 0.618999, f_score 0.483139
>>> step 12000
step 11900-11999, precision 0.394779, recall 0.618999, f_score 0.482094
>>> step 12100
step 12000-12099, precision 0.397894, recall 0.619473, f_score 0.484554
>>> step 12200
step 12100-12199, precision 0.402704, recall 0.621242, f_score 0.488652
>>> step 12300
step 12200-12299, precision 0.408271, recall 0.618464, f_score 0.491852
>>> step 12400
step 12300-12399, precision 0.411149, recall 0.615207, f_score 0.492893
>>> step 12500
step 12400-12499, precision 0.414962, recall 0.612991, f_score 0.494902
>>> step 12600
step 12500-12599, precision 0.416262, recall 0.606275, f_score 0.493614
>>> step 12700
step 12600-12699, precision 0.419520, recall 0.603456, f_score 0.494951
>>> step 12800
step 12700-12799, precision 0.418013, recall 0.603456, f_score 0.493901
>>> step 12900
step 12800-12899, precision 0.417014, recall 0.600943, f_score 0.492362
>>> step 13000
step 12900-12999, precision 0.412596, recall 0.600943, f_score 0.489269
>>> step 13100
step 13000-13099, precision 0.410480, recall 0.599745, f_score 0.487383
>>> step 13200
step 13100-13199, precision 0.408577, recall 0.599745, f_score 0.486039
>>> step 13300
step 13200-13299, precision 0.407397, recall 0.599745, f_score 0.485203
>>> step 13400
step 13300-13399, precision 0.406178, recall 0.599409, f_score 0.484228
>>> step 13500
step 13400-13499, precision 0.401925, recall 0.599409, f_score 0.481193
>>> step 13600
step 13500-13599, precision 0.401584, recall 0.599409, f_score 0.480948
>>> step 13700
step 13600-13699, precision 0.400391, recall 0.600335, f_score 0.480389
>>> step 13800
step 13700-13799, precision 0.399224, recall 0.598753, f_score 0.479042
>>> step 13900
step 13800-13899, precision 0.395553, recall 0.598919, f_score 0.476442
>>> step 14000
step 13900-13999, precision 0.393915, recall 0.598432, f_score 0.475098
>>> step 14100
step 14000-14099, precision 0.393915, recall 0.598432, f_score 0.475098
>>> step 14200
step 14100-14199, precision 0.392741, recall 0.598432, f_score 0.474244
>>> step 14300
step 14200-14299, precision 0.393562, recall 0.597536, f_score 0.474560
>>> step 14400
step 14300-14399, precision 0.390675, recall 0.594374, f_score 0.471463
>>> step 14500
step 14400-14499, precision 0.389944, recall 0.592924, f_score 0.470474
>>> step 14600
step 14500-14599, precision 0.386943, recall 0.592924, f_score 0.468283
>>> step 14700
step 14600-14699, precision 0.386532, recall 0.592924, f_score 0.467983
>>> step 14800
step 14700-14799, precision 0.387326, recall 0.595152, f_score 0.469258
>>> step 14900
step 14800-14899, precision 0.386903, recall 0.595343, f_score 0.469007
>>> step 15000
step 14900-14999, precision 0.388658, recall 0.595694, f_score 0.470403
>>> step 15100
step 15000-15099, precision 0.387264, recall 0.595304, f_score 0.469260
>>> step 15200
step 15100-15199, precision 0.386923, recall 0.596679, f_score 0.469435
>>> step 15300
step 15200-15299, precision 0.387583, recall 0.597950, f_score 0.470315
>>> step 15400
step 15300-15399, precision 0.384228, recall 0.599214, f_score 0.468222
>>> step 15500
step 15400-15499, precision 0.383070, recall 0.599214, f_score 0.467361
>>> step 15600
step 15500-15599, precision 0.384500, recall 0.599143, f_score 0.468403
>>> step 15700
step 15600-15699, precision 0.386607, recall 0.601239, f_score 0.470606
>>> step 15800
step 15700-15799, precision 0.382607, recall 0.601239, f_score 0.467630
>>> step 15900
step 15800-15899, precision 0.382626, recall 0.603309, f_score 0.468269
>>> step 16000
step 15900-15999, precision 0.383248, recall 0.603296, f_score 0.468731
>>> step 16100
step 16000-16099, precision 0.382317, recall 0.603296, f_score 0.468034
>>> step 16200
step 16100-16199, precision 0.381946, recall 0.603296, f_score 0.467756
>>> step 16300
step 16200-16299, precision 0.379460, recall 0.603296, f_score 0.465887
>>> step 16400
step 16300-16399, precision 0.382472, recall 0.604669, f_score 0.468563
>>> step 16500
step 16400-16499, precision 0.385124, recall 0.605644, f_score 0.470843
>>> step 16600
step 16500-16599, precision 0.386226, recall 0.609174, f_score 0.472732
>>> step 16700
step 16600-16699, precision 0.385509, recall 0.609174, f_score 0.472195
>>> step 16800
step 16700-16799, precision 0.387558, recall 0.609641, f_score 0.473870
>>> step 16900
step 16800-16899, precision 0.389587, recall 0.611689, f_score 0.476004
>>> step 17000
step 16900-16999, precision 0.392534, recall 0.612858, f_score 0.478555
>>> step 17100
step 17000-17099, precision 0.393763, recall 0.611711, f_score 0.479115
>>> step 17200
step 17100-17199, precision 0.392442, recall 0.611711, f_score 0.478136
>>> step 17300
step 17200-17299, precision 0.394895, recall 0.614296, f_score 0.480746
>>> step 17400
step 17300-17399, precision 0.397101, recall 0.616644, f_score 0.483100
>>> step 17500
step 17400-17499, precision 0.401132, recall 0.617085, f_score 0.486208
>>> step 17600
step 17500-17599, precision 0.399220, recall 0.617085, f_score 0.484801
>>> step 17700
step 17600-17699, precision 0.400259, recall 0.617539, f_score 0.485707
>>> step 17800
step 17700-17799, precision 0.402402, recall 0.618734, f_score 0.487653
>>> step 17900
step 17800-17899, precision 0.403036, recall 0.617830, f_score 0.487836
>>> step 18000
step 17900-17999, precision 0.404838, recall 0.618076, f_score 0.489231
>>> step 18100
step 18000-18099, precision 0.407634, recall 0.618758, f_score 0.491482
>>> step 18200
step 18100-18199, precision 0.406473, recall 0.618682, f_score 0.490614
>>> step 18300
step 18200-18299, precision 0.407004, recall 0.619139, f_score 0.491144
>>> step 18400
step 18300-18399, precision 0.406982, recall 0.619472, f_score 0.491232
>>> step 18500
step 18400-18499, precision 0.405737, recall 0.619093, f_score 0.490206
>>> step 18600
step 18500-18599, precision 0.404076, recall 0.620025, f_score 0.489282
>>> step 18700
step 18600-18699, precision 0.401760, recall 0.620025, f_score 0.487581
>>> step 18800
step 18700-18799, precision 0.399308, recall 0.620025, f_score 0.485771
>>> step 18900
step 18800-18899, precision 0.398062, recall 0.620321, f_score 0.484938
>>> step 19000
step 18900-18999, precision 0.396462, recall 0.620321, f_score 0.483748
>>> step 19100
step 19000-19099, precision 0.396994, recall 0.620614, f_score 0.484234
>>> step 19200
step 19100-19199, precision 0.395224, recall 0.620431, f_score 0.482859
>>> step 19300
step 19200-19299, precision 0.393585, recall 0.620281, f_score 0.481589
>>> step 19400
step 19300-19399, precision 0.393508, recall 0.620281, f_score 0.481531
>>> step 19500
step 19400-19499, precision 0.393243, recall 0.621160, f_score 0.481597
>>> step 19600
step 19500-19599, precision 0.392549, recall 0.621160, f_score 0.481077
>>> step 19700
step 19600-19699, precision 0.392088, recall 0.621160, f_score 0.480730
>>> step 19800
step 19700-19799, precision 0.391704, recall 0.621160, f_score 0.480442
>>> step 19900
step 19800-19899, precision 0.391016, recall 0.621160, f_score 0.479923
>>> step 20000
step 19900-19999, precision 0.390358, recall 0.620519, f_score 0.479236
>>> step 20100
step 20000-20099, precision 0.390504, recall 0.620764, f_score 0.479419
>>> step 20200
step 20100-20199, precision 0.386887, recall 0.621114, f_score 0.476787
>>> step 20300
step 20200-20299, precision 0.384308, recall 0.621114, f_score 0.474824
>>> step 20400
step 20300-20399, precision 0.384161, recall 0.621114, f_score 0.474712
>>> step 20500
step 20400-20499, precision 0.383577, recall 0.621114, f_score 0.474266
>>> step 20600
step 20500-20599, precision 0.383660, recall 0.622861, f_score 0.474837
>>> step 20700
step 20600-20699, precision 0.383569, recall 0.624886, f_score 0.475355
>>> step 20800
step 20700-20799, precision 0.382785, recall 0.624886, f_score 0.474752
>>> step 20900
step 20800-20899, precision 0.384644, recall 0.627704, f_score 0.476995
>>> step 21000
step 20900-20999, precision 0.383092, recall 0.627704, f_score 0.475800
>>> step 21100
step 21000-21099, precision 0.383464, recall 0.626977, f_score 0.475878
>>> step 21200
step 21100-21199, precision 0.383045, recall 0.626977, f_score 0.475555
>>> step 21300
step 21200-21299, precision 0.383430, recall 0.626852, f_score 0.475816
>>> step 21400
step 21300-21399, precision 0.384685, recall 0.628119, f_score 0.477146
>>> step 21500
step 21400-21499, precision 0.383581, recall 0.628119, f_score 0.476296
>>> step 21600
step 21500-21599, precision 0.384506, recall 0.629446, f_score 0.477391
>>> step 21700
step 21600-21699, precision 0.382462, recall 0.629446, f_score 0.475813
>>> step 21800
step 21700-21799, precision 0.382716, recall 0.628439, f_score 0.475721
>>> step 21900
step 21800-21899, precision 0.380835, recall 0.628439, f_score 0.474265
>>> step 22000
step 21900-21999, precision 0.380235, recall 0.628439, f_score 0.473799
>>> step 22100
step 22000-22099, precision 0.380420, recall 0.629084, f_score 0.474126
>>> step 22200
step 22100-22199, precision 0.378838, recall 0.629758, f_score 0.473086
>>> step 22300
step 22200-22299, precision 0.378196, recall 0.628481, f_score 0.472225
>>> step 22400
step 22300-22399, precision 0.377388, recall 0.627647, f_score 0.471359
>>> step 22500
step 22400-22499, precision 0.377378, recall 0.626815, f_score 0.471117
>>> step 22600
step 22500-22599, precision 0.377937, recall 0.628183, f_score 0.471939
>>> step 22700
step 22600-22699, precision 0.376335, recall 0.628183, f_score 0.470688
>>> step 22800
step 22700-22799, precision 0.376016, recall 0.628183, f_score 0.470439
>>> step 22900
step 22800-22899, precision 0.375968, recall 0.629473, f_score 0.470762
>>> step 23000
step 22900-22999, precision 0.375210, recall 0.629473, f_score 0.470167
>>> step 23100
step 23000-23099, precision 0.374708, recall 0.630191, f_score 0.469973
>>> step 23200
step 23100-23199, precision 0.376144, recall 0.631564, f_score 0.471484
>>> step 23300
step 23200-23299, precision 0.376630, recall 0.632834, f_score 0.472219
>>> step 23400
step 23300-23399, precision 0.375021, recall 0.632834, f_score 0.470952
>>> step 23500
step 23400-23499, precision 0.374286, recall 0.633527, f_score 0.470564
>>> step 23600
step 23500-23599, precision 0.374068, recall 0.634763, f_score 0.470732
>>> step 23700
step 23600-23699, precision 0.373814, recall 0.635494, f_score 0.470731
>>> step 23800
step 23700-23799, precision 0.372496, recall 0.635494, f_score 0.469685
>>> step 23900
step 23800-23899, precision 0.372906, recall 0.635918, f_score 0.470127
>>> step 24000
step 23900-23999, precision 0.372976, recall 0.634865, f_score 0.469894
>>> step 24100
step 24000-24099, precision 0.373713, recall 0.634750, f_score 0.470448
>>> step 24200
step 24100-24199, precision 0.373123, recall 0.634750, f_score 0.469979
>>> step 24300
step 24200-24299, precision 0.374528, recall 0.635369, f_score 0.471263
>>> step 24400
step 24300-24399, precision 0.374765, recall 0.635397, f_score 0.471458
# Out:
#   File "<ipython-input-4-fea104041ec4>", line 2
#     step 100
#            ^
# SyntaxError: invalid syntax

# %%
print("test %.2f"%0.12)

# %%
for i in range(len(cubes_set)):
    if (cubes_set[i]["file"]) == "PX303-Fg001-V-C01-R01_TEAR_8X5_PIECE_2X4":
        plt.imshow(cubes_set[i]["cube"])

# %%
for i in range(len(cubes_set)):
    if (cubes_set[i]["file"]) == "PX303-Fg001-V-C01-R01_TEAR_8X5_PIECE_4X4":
        plt.imshow(cubes_set[i]["cube"])

# %%
# When trained on a ratio of 1:2 non-match:match - and tested on the same the results are excellend
*** MATCHED=19065
*** NOT MATCHED=8183
*** DISCARDED=1979027
TOTAL 27300, precision 0.815258, recall 0.979806, f_score 0.889990
TOTAL true = 19065
TOTAL error rate = 0.169158

# When trained on a ratio of 1:2 non-match:match - and tested on 6:1 (much more non-match) the results are poor
# coverage is still excellent but precision is bad - means a lot of false-positive
# this usually implies that we'll get a lot of trash in the validation set
# hence next attempt will be to train on 6:1 and see it the test is better
*** MATCHED=19065
*** NOT MATCHED=125210
*** DISCARDED=1862000
precision 0.237849, recall 0.973684, f_score 0.382309

# When trained on a ratio of 9:1 non-match:match - and tested on 6:1 the results are poor
# coverage is around 70% and precision is 35 - means a lot of false-positive
# this usually implies that we'll get a lot of trash in the validation set
# hence next attempt will be to train on 6:1 and see it the test is better
*** MATCHED=19065
*** NOT MATCHED=125210
*** DISCARDED=1862000
precision 0.355357, recall 0.737720, f_score 0.479663


# Test from 0ct-07
=== total 144000 match 62339
TOTAL 144000, precision 0.286081, recall 0.952518, f_score 0.440009
TOTAL true = 18723
TOTAL error rate = 0.315236

# %%
#debug

short_name = "PX303-Fg006-V-C02-R02"
# image = read_and_crop(img_name, x_start, x_end, y_start, y_end)

cubes_set = []
col_cut = 3
row_cut = 2
pieces = []
piece = {}
image = img.imread(ROOT_FOLDER + "test_fragments/PX303Fg006_3X2_1X1.jpg")
image = exposure.equalize_adapthist(image, clip_limit=0.03)
piece["cut"] = image[:,:,0]
piece["col"] = 1
piece["row"] = 1
piece["col_px"] = 0
piece["row_px"] = 0
pieces.append(piece)
piece = {}
image = img.imread(ROOT_FOLDER + "test_fragments/PX303Fg006_3X2_2X1.jpg")
image = exposure.equalize_adapthist(image, clip_limit=0.03)
piece["cut"] = image[:,:,0]
piece["col"] = 2
piece["row"] = 1
piece["col_px"] = 2300
piece["row_px"] = 0
pieces.append(piece)

for piece in pieces:
    # print("PRE_PROCESS:::"+"PIECE_"+str(piece["col"])+"X"+str(piece["row"]))
    fragment_name = short_name + "_TEAR_"+str(col_cut)+"X"+str(row_cut)+"_PIECE_"+str(piece["col"])+"X"+str(piece["row"])
    fragment_file_name = short_name + "_"+str(col_cut)+"X"+str(row_cut)+"_"+str(piece["col"])+"X"+str(piece["row"])
    cubes = VAL_slice_TEAR_to_static_slices(fragment_name, piece)
    # import pdb; pdb.set_trace()
    for cube in cubes:
        cube["tear"] = str(col_cut)+"X"+str(row_cut)
        cube["piece_col"] = piece["col"]
        cube["piece_row"] = piece["row"]
    # print("File: %s >>> cubes: %d"%(file_, len(cubes)))
    cubes_set.extend(cubes)
    
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 1, 7)
import pdb; pdb.set_trace()    
tf.reset_default_graph()
model_tf_deep(250, 1)    
validate2_for_cross_validation(train_imgs, train_lbls, is_enriched, ROOT_FOLDER + "model_binary/tear_model3.ckpt")

# %%
#TRAIN 3
cubes_set = pre_process_training("PX303-Fg006-V-C02-R02-D08032015-T115622-ML638__006.jpg", 0, 6200, 0, 4400, max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 2, 7)
tf.reset_default_graph()
model_tf_deep(250)    
train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model1.ckpt")
# Out:
# #####################################################################
# PRE_PROCESS:PX303-Fg006-V-C02-R02-D08032015-T115622-ML638__006.jpg
# #####################################################################
# PRE_PROCESS:::TEAR_3X2
# /home/ilan/venv35/lib/python3.5/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# PRE_PROCESS:::TEAR_3X3
# PRE_PROCESS:::TEAR_4X2
# PRE_PROCESS:::TEAR_4X3
# PRE_PROCESS:::TEAR_5X2
# PRE_PROCESS:::TEAR_5X3
# PRE_PROCESS:::TEAR_6X2
# PRE_PROCESS:::TEAR_6X3
# PRE_PROCESS:::TEAR_7X2
# PRE_PROCESS:::TEAR_7X3
# *** CUBES=100
#  MATCHED=1159
#  NOT MATCHED=6127
#  DISCARDED=24807
#  SKIPPED=699534
# *** CUBES=200
#  MATCHED=3038
#  NOT MATCHED=10723
#  DISCARDED=43324
#  SKIPPED=1414243
# *** CUBES=300
#  MATCHED=5127
#  NOT MATCHED=13906
#  DISCARDED=56053
#  SKIPPED=2136143
# *** CUBES=400
#  MATCHED=5127
#  NOT MATCHED=13906
#  DISCARDED=56053
#  SKIPPED=2874043
# *** CUBES=500
#  MATCHED=5564
#  NOT MATCHED=16542
#  DISCARDED=65636
#  SKIPPED=3599703
# *** CUBES=600
#  MATCHED=7561
#  NOT MATCHED=23122
#  DISCARDED=89561
#  SKIPPED=4307003
# *** CUBES=700
#  MATCHED=9160
#  NOT MATCHED=26506
#  DISCARDED=101504
#  SKIPPED=5029503
# *** CUBES=800
#  MATCHED=10316
#  NOT MATCHED=28264
#  DISCARDED=107702
#  SKIPPED=5759395
# *** CUBES=900
#  MATCHED=10316
#  NOT MATCHED=28264
#  DISCARDED=107702
#  SKIPPED=6497295
# *** CUBES=1000
#  MATCHED=11592
#  NOT MATCHED=36902
#  DISCARDED=141874
#  SKIPPED=7192331
# *** CUBES=1100
#  MATCHED=13212
#  NOT MATCHED=44638
#  DISCARDED=172318
#  SKIPPED=7891981
# *** CUBES=1200
#  MATCHED=15103
#  NOT MATCHED=50829
#  DISCARDED=196493
#  SKIPPED=8599434
# *** CUBES=1300
#  MATCHED=16298
#  NOT MATCHED=54018
#  DISCARDED=209053
#  SKIPPED=9321534
# *** CUBES=1400
#  MATCHED=16922
#  NOT MATCHED=55549
#  DISCARDED=215080
#  SKIPPED=10051850
# *** CUBES=1500
#  MATCHED=16922
#  NOT MATCHED=55549
#  DISCARDED=215080
#  SKIPPED=10789750
# *** CUBES=1600
#  MATCHED=18222
#  NOT MATCHED=63997
#  DISCARDED=248018
#  SKIPPED=11486196
# *** CUBES=1700
#  MATCHED=19679
#  NOT MATCHED=71359
#  DISCARDED=276741
#  SKIPPED=12187942
# *** CUBES=1800
#  MATCHED=21589
#  NOT MATCHED=76915
#  DISCARDED=298344
#  SKIPPED=12898592
# *** CUBES=1900
#  MATCHED=23507
#  NOT MATCHED=80098
#  DISCARDED=310474
#  SKIPPED=13621092
# *** CUBES=2000
#  MATCHED=24064
#  NOT MATCHED=81018
#  DISCARDED=313995
#  SKIPPED=14354526
# *** CUBES=2100
#  MATCHED=24220
#  NOT MATCHED=83142
#  DISCARDED=322421
#  SKIPPED=15081869
# *** CUBES=2200
#  MATCHED=25751
#  NOT MATCHED=95630
#  DISCARDED=371969
#  SKIPPED=15757669
# *** CUBES=2300
#  MATCHED=27245
#  NOT MATCHED=105925
#  DISCARDED=412977
#  SKIPPED=16444200
# *** CUBES=2400
#  MATCHED=29150
#  NOT MATCHED=114606
#  DISCARDED=447558
#  SKIPPED=17138756
# *** CUBES=2500
#  MATCHED=31007
#  NOT MATCHED=120990
#  DISCARDED=472897
#  SKIPPED=17844856
# *** CUBES=2600
#  MATCHED=32515
#  NOT MATCHED=125135
#  DISCARDED=489427
#  SKIPPED=18562016
# *** CUBES=2700
#  MATCHED=34481
#  NOT MATCHED=127936
#  DISCARDED=500624
#  SKIPPED=19285836
# *** CUBES=2800
#  MATCHED=34481
#  NOT MATCHED=127936
#  DISCARDED=500624
#  SKIPPED=20023736
# *** CUBES=2900
#  MATCHED=35026
#  NOT MATCHED=134015
#  DISCARDED=524784
#  SKIPPED=20731372
# *** CUBES=3000
#  MATCHED=36722
#  NOT MATCHED=145083
#  DISCARDED=568815
#  SKIPPED=21414086
# *** CUBES=3100
#  MATCHED=38429
#  NOT MATCHED=153966
#  DISCARDED=604347
#  SKIPPED=22107486
# *** CUBES=3200
#  MATCHED=40070
#  NOT MATCHED=160385
#  DISCARDED=630027
#  SKIPPED=22813211
# *** CUBES=3300
#  MATCHED=41886
#  NOT MATCHED=165168
#  DISCARDED=649162
#  SKIPPED=23527111
# *** CUBES=3400
#  MATCHED=43935
#  NOT MATCHED=168151
#  DISCARDED=661085
#  SKIPPED=24250011
# *** CUBES=3500
#  MATCHED=44144
#  NOT MATCHED=168449
#  DISCARDED=662279
#  SKIPPED=24986411
# *** CUBES=3600
#  MATCHED=44604
#  NOT MATCHED=174605
#  DISCARDED=686623
#  SKIPPED=25693791
# *** CUBES=3700
#  MATCHED=46402
#  NOT MATCHED=189929
#  DISCARDED=747223
#  SKIPPED=26355689
# *** CUBES=3800
#  MATCHED=47595
#  NOT MATCHED=202319
#  DISCARDED=796180
#  SKIPPED=27032189
# *** CUBES=3900
#  MATCHED=49388
#  NOT MATCHED=213113
#  DISCARDED=838758
#  SKIPPED=27716639
# *** CUBES=4000
#  MATCHED=51160
#  NOT MATCHED=222408
#  DISCARDED=875342
#  SKIPPED=28408583
# *** CUBES=4100
#  MATCHED=52611
#  NOT MATCHED=228796
#  DISCARDED=900493
#  SKIPPED=29114883
# *** CUBES=4200
#  MATCHED=54523
#  NOT MATCHED=233421
#  DISCARDED=918698
#  SKIPPED=29829873
# *** CUBES=4300
#  MATCHED=56599
#  NOT MATCHED=236603
#  DISCARDED=931228
#  SKIPPED=30551973
# *** CUBES=4400
#  MATCHED=56653
#  NOT MATCHED=236699
#  DISCARDED=931604
#  SKIPPED=31289399
# *** CUBES=4500
#  MATCHED=57063
#  NOT MATCHED=242623
#  DISCARDED=954208
#  SKIPPED=31998751
# *** CUBES=4600
#  MATCHED=58798
#  NOT MATCHED=257626
#  DISCARDED=1011464
#  SKIPPED=32664303
# *** CUBES=4700
#  MATCHED=60313
#  NOT MATCHED=269811
#  DISCARDED=1058206
#  SKIPPED=33343203
# *** CUBES=4800
#  MATCHED=61941
#  NOT MATCHED=280205
#  DISCARDED=1097706
#  SKIPPED=34031127
# *** CUBES=4900
#  MATCHED=63061
#  NOT MATCHED=288904
#  DISCARDED=1130517
#  SKIPPED=34727462
# *** CUBES=5000
#  MATCHED=64986
#  NOT MATCHED=295287
#  DISCARDED=1154446
#  SKIPPED=35434962
# *** CUBES=5100
#  MATCHED=66612
#  NOT MATCHED=299177
#  DISCARDED=1169026
#  SKIPPED=36154318
# *** CUBES=5200
#  MATCHED=68163
#  NOT MATCHED=301529
#  DISCARDED=1177851
#  SKIPPED=36880970
# *** CUBES=5300
#  MATCHED=68163
#  NOT MATCHED=301529
#  DISCARDED=1177851
#  SKIPPED=37618870
# *** CUBES=5400
#  MATCHED=69059
#  NOT MATCHED=315137
#  DISCARDED=1232137
#  SKIPPED=38288838
# *** CUBES=5500
#  MATCHED=70910
#  NOT MATCHED=332599
#  DISCARDED=1301710
#  SKIPPED=38939624
# *** CUBES=5600
#  MATCHED=72750
#  NOT MATCHED=348181
#  DISCARDED=1363648
#  SKIPPED=39599924
# *** CUBES=5700
#  MATCHED=74037
#  NOT MATCHED=361043
#  DISCARDED=1414407
#  SKIPPED=40274147
# *** CUBES=5800
#  MATCHED=75748
#  NOT MATCHED=372490
#  DISCARDED=1459451
#  SKIPPED=40955485
# *** CUBES=5900
#  MATCHED=77735
#  NOT MATCHED=382071
#  DISCARDED=1496987
#  SKIPPED=41646185
# *** CUBES=6000
#  MATCHED=79194
#  NOT MATCHED=388875
#  DISCARDED=1523575
#  SKIPPED=42350631
# *** CUBES=6100
#  MATCHED=81105
#  NOT MATCHED=394332
#  DISCARDED=1544797
#  SKIPPED=43061771
# *** CUBES=6200
#  MATCHED=82772
#  NOT MATCHED=397517
#  DISCARDED=1556941
#  SKIPPED=43784271
# *** CUBES=6300
#  MATCHED=83512
#  NOT MATCHED=398502
#  DISCARDED=1560698
#  SKIPPED=44517397
# *** CUBES=6400
#  MATCHED=83662
#  NOT MATCHED=401112
#  DISCARDED=1571041
#  SKIPPED=45242337
# *** CUBES=6500
#  MATCHED=85215
#  NOT MATCHED=418496
#  DISCARDED=1639976
#  SKIPPED=45893837
# *** CUBES=6600
#  MATCHED=86611
#  NOT MATCHED=433613
#  DISCARDED=1700016
#  SKIPPED=46556509
# *** CUBES=6700
#  MATCHED=88216
#  NOT MATCHED=446819
#  DISCARDED=1752440
#  SKIPPED=47228704
# *** CUBES=6800
#  MATCHED=89889
#  NOT MATCHED=458436
#  DISCARDED=1798525
#  SKIPPED=47908820
# *** CUBES=6900
#  MATCHED=91427
#  NOT MATCHED=467422
#  DISCARDED=1834460
#  SKIPPED=48601720
# *** CUBES=7000
#  MATCHED=93102
#  NOT MATCHED=474308
#  DISCARDED=1861997
#  SKIPPED=49305120
# *** CUBES=7100
#  MATCHED=94993
#  NOT MATCHED=479691
#  DISCARDED=1883528
#  SKIPPED=50016020
# *** CUBES=7200
#  MATCHED=96872
#  NOT MATCHED=482675
#  DISCARDED=1895458
#  SKIPPED=50738920
# *** CUBES=7300
#  MATCHED=97429
#  NOT MATCHED=483568
#  DISCARDED=1899040
#  SKIPPED=51472320
# *** MATCHED=97429
# *** NOT MATCHED=483568
# *** DISCARDED=1899040
# *** SKIPPED=52062640
# #####################################################################
# TRAINING:
# MODEL:/media/1KGB_ILAN/papyrus/models/tear_model1.ckpt
# #####################################################################
# step 49, training accuracy 0.77
# step 99, training accuracy 0.78
# step 149, training accuracy 0.85
# step 199, training accuracy 0.82
# step 249, training accuracy 0.82
# step 299, training accuracy 0.88
# step 349, training accuracy 0.90
# step 399, training accuracy 0.82
# step 449, training accuracy 0.88
# step 499, training accuracy 0.85
# step 549, training accuracy 0.83
# step 599, training accuracy 0.82
# step 649, training accuracy 0.83
# step 699, training accuracy 0.75
# step 749, training accuracy 0.85
# step 799, training accuracy 0.78
# step 849, training accuracy 0.87
# step 899, training accuracy 0.87
# step 949, training accuracy 0.83
# step 999, training accuracy 0.90
# step 1049, training accuracy 0.92
# step 1099, training accuracy 0.87
# step 1149, training accuracy 0.93
# step 1199, training accuracy 0.88
# step 1249, training accuracy 0.83
# step 1299, training accuracy 0.82
# step 1349, training accuracy 0.90
# step 1399, training accuracy 0.85
# step 1449, training accuracy 0.90
# step 1499, training accuracy 0.87
# step 1549, training accuracy 0.88
# step 1599, training accuracy 0.85
# step 1649, training accuracy 0.73
# step 1699, training accuracy 0.88
# step 1749, training accuracy 0.92
# step 1799, training accuracy 0.82
# step 1849, training accuracy 0.90
# step 1899, training accuracy 0.78
# step 1949, training accuracy 0.82
# step 1999, training accuracy 0.87
# Optimization Finished!
# step 1999, training accuracy 0.866667
# Model saved in file: /media/1KGB_ILAN/papyrus/models/tear_model1.ckpt
# #####################################################################
# TRAINING ENDED
# #####################################################################

# %%
#TRAIN 2
cubes_set = pre_process_training("PX303-Fg004-V-C01-R01-D08032015-T110817-ML638__006.jpg", \
                                 100, -1, 400, -1, max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 2, 7)
tf.reset_default_graph()
model_tf_deep(250)
train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model2.ckpt", ROOT_FOLDER + "models/tear_model1.ckpt")
# Out:
# #####################################################################
# PRE_PROCESS:PX303-Fg004-V-C01-R01-D08032015-T110817-ML638__006.jpg
# #####################################################################
# PRE_PROCESS:::TEAR_3X2
# /home/ilan/venv35/lib/python3.5/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# PRE_PROCESS:::TEAR_3X3
# PRE_PROCESS:::TEAR_4X2
# PRE_PROCESS:::TEAR_4X3
# PRE_PROCESS:::TEAR_5X2
# PRE_PROCESS:::TEAR_5X3
# PRE_PROCESS:::TEAR_6X2
# PRE_PROCESS:::TEAR_6X3
# PRE_PROCESS:::TEAR_7X2
# PRE_PROCESS:::TEAR_7X3
# *** CUBES=100
#  MATCHED=1621
#  NOT MATCHED=6816
#  DISCARDED=25879
#  SKIPPED=760914
# *** CUBES=200
#  MATCHED=3694
#  NOT MATCHED=12180
#  DISCARDED=46303
#  SKIPPED=1536736
# *** CUBES=300
#  MATCHED=6309
#  NOT MATCHED=15756
#  DISCARDED=60018
#  SKIPPED=2321036
# *** CUBES=400
#  MATCHED=6581
#  NOT MATCHED=16150
#  DISCARDED=61526
#  SKIPPED=3120822
# *** CUBES=500
#  MATCHED=6729
#  NOT MATCHED=17199
#  DISCARDED=65284
#  SKIPPED=3917707
# *** CUBES=600
#  MATCHED=8074
#  NOT MATCHED=24183
#  DISCARDED=90323
#  SKIPPED=4687307
# *** CUBES=700
#  MATCHED=10253
#  NOT MATCHED=28750
#  DISCARDED=106754
#  SKIPPED=5467912
# *** CUBES=800
#  MATCHED=12208
#  NOT MATCHED=31754
#  DISCARDED=117609
#  SKIPPED=6255668
# *** CUBES=900
#  MATCHED=12208
#  NOT MATCHED=31754
#  DISCARDED=117609
#  SKIPPED=7057368
# *** CUBES=1000
#  MATCHED=12815
#  NOT MATCHED=36850
#  DISCARDED=137288
#  SKIPPED=7834268
# *** CUBES=1100
#  MATCHED=14586
#  NOT MATCHED=47037
#  DISCARDED=176621
#  SKIPPED=8586368
# *** CUBES=1200
#  MATCHED=17280
#  NOT MATCHED=54843
#  DISCARDED=206610
#  SKIPPED=9350160
# *** CUBES=1300
#  MATCHED=19705
#  NOT MATCHED=60906
#  DISCARDED=229914
#  SKIPPED=10122392
# *** CUBES=1400
#  MATCHED=22104
#  NOT MATCHED=64487
#  DISCARDED=243834
#  SKIPPED=10906492
# *** CUBES=1500
#  MATCHED=23114
#  NOT MATCHED=65955
#  DISCARDED=249540
#  SKIPPED=11700976
# *** CUBES=1600
#  MATCHED=23114
#  NOT MATCHED=65955
#  DISCARDED=249540
#  SKIPPED=12502676
# *** CUBES=1700
#  MATCHED=24146
#  NOT MATCHED=74328
#  DISCARDED=280373
#  SKIPPED=13265117
# *** CUBES=1800
#  MATCHED=26297
#  NOT MATCHED=83830
#  DISCARDED=315215
#  SKIPPED=14022377
# *** CUBES=1900
#  MATCHED=28650
#  NOT MATCHED=91006
#  DISCARDED=340932
#  SKIPPED=14791077
# *** CUBES=2000
#  MATCHED=30995
#  NOT MATCHED=95416
#  DISCARDED=356789
#  SKIPPED=15572405
# *** CUBES=2100
#  MATCHED=32835
#  NOT MATCHED=98528
#  DISCARDED=368039
#  SKIPPED=16359663
# *** CUBES=2200
#  MATCHED=32835
#  NOT MATCHED=98528
#  DISCARDED=368039
#  SKIPPED=17161363
# *** CUBES=2300
#  MATCHED=33658
#  NOT MATCHED=104909
#  DISCARDED=392595
#  SKIPPED=17932090
# *** CUBES=2400
#  MATCHED=35746
#  NOT MATCHED=118492
#  DISCARDED=444821
#  SKIPPED=18667890
# *** CUBES=2500
#  MATCHED=37990
#  NOT MATCHED=129626
#  DISCARDED=487799
#  SKIPPED=19415382
# *** CUBES=2600
#  MATCHED=39955
#  NOT MATCHED=139054
#  DISCARDED=524330
#  SKIPPED=20171035
# *** CUBES=2700
#  MATCHED=42449
#  NOT MATCHED=146135
#  DISCARDED=551946
#  SKIPPED=20937935
# *** CUBES=2800
#  MATCHED=44909
#  NOT MATCHED=150834
#  DISCARDED=570249
#  SKIPPED=21716531
# *** CUBES=2900
#  MATCHED=47370
#  NOT MATCHED=154413
#  DISCARDED=584167
#  SKIPPED=22500631
# *** CUBES=3000
#  MATCHED=47424
#  NOT MATCHED=154557
#  DISCARDED=584725
#  SKIPPED=23301627
# *** CUBES=3100
#  MATCHED=47695
#  NOT MATCHED=157312
#  DISCARDED=594534
#  SKIPPED=24090747
# *** CUBES=3200
#  MATCHED=49433
#  NOT MATCHED=171095
#  DISCARDED=643568
#  SKIPPED=24829547
# *** CUBES=3300
#  MATCHED=51606
#  NOT MATCHED=182896
#  DISCARDED=685924
#  SKIPPED=25576987
# *** CUBES=3400
#  MATCHED=53621
#  NOT MATCHED=192826
#  DISCARDED=721809
#  SKIPPED=26332779
# *** CUBES=3500
#  MATCHED=55748
#  NOT MATCHED=199909
#  DISCARDED=746931
#  SKIPPED=27102179
# *** CUBES=3600
#  MATCHED=58052
#  NOT MATCHED=205097
#  DISCARDED=765354
#  SKIPPED=27880165
# *** CUBES=3700
#  MATCHED=60209
#  NOT MATCHED=208677
#  DISCARDED=778076
#  SKIPPED=28665465
# *** CUBES=3800
#  MATCHED=60317
#  NOT MATCHED=208856
#  DISCARDED=778713
#  SKIPPED=29466345
# *** CUBES=3900
#  MATCHED=60863
#  NOT MATCHED=214119
#  DISCARDED=798691
#  SKIPPED=30242780
# *** CUBES=4000
#  MATCHED=62934
#  NOT MATCHED=231101
#  DISCARDED=863120
#  SKIPPED=30962980
# *** CUBES=4100
#  MATCHED=64780
#  NOT MATCHED=246163
#  DISCARDED=920608
#  SKIPPED=31692046
# *** CUBES=4200
#  MATCHED=66789
#  NOT MATCHED=259418
#  DISCARDED=971422
#  SKIPPED=32429586
# *** CUBES=4300
#  MATCHED=69261
#  NOT MATCHED=269996
#  DISCARDED=1011942
#  SKIPPED=33180086
# *** CUBES=4400
#  MATCHED=71725
#  NOT MATCHED=278571
#  DISCARDED=1044671
#  SKIPPED=33940380
# *** CUBES=4500
#  MATCHED=74103
#  NOT MATCHED=285750
#  DISCARDED=1071994
#  SKIPPED=34707480
# *** CUBES=4600
#  MATCHED=76503
#  NOT MATCHED=289582
#  DISCARDED=1086666
#  SKIPPED=35490576
# *** CUBES=4700
#  MATCHED=78360
#  NOT MATCHED=292409
#  DISCARDED=1097508
#  SKIPPED=36278530
# *** CUBES=4800
#  MATCHED=78360
#  NOT MATCHED=292409
#  DISCARDED=1097508
#  SKIPPED=37080230
# *** CUBES=4900
#  MATCHED=79246
#  NOT MATCHED=300343
#  DISCARDED=1126286
#  SKIPPED=37845176
# *** CUBES=5000
#  MATCHED=81367
#  NOT MATCHED=317223
#  DISCARDED=1187507
#  SKIPPED=38568676
# *** CUBES=5100
#  MATCHED=82967
#  NOT MATCHED=331320
#  DISCARDED=1238826
#  SKIPPED=39304878
# *** CUBES=5200
#  MATCHED=84936
#  NOT MATCHED=343730
#  DISCARDED=1283941
#  SKIPPED=40048964
# *** CUBES=5300
#  MATCHED=87182
#  NOT MATCHED=354309
#  DISCARDED=1322262
#  SKIPPED=40801664
# *** CUBES=5400
#  MATCHED=89429
#  NOT MATCHED=361657
#  DISCARDED=1348803
#  SKIPPED=41569374
# *** CUBES=5500
#  MATCHED=91625
#  NOT MATCHED=367505
#  DISCARDED=1369989
#  SKIPPED=42343942
# *** CUBES=5600
#  MATCHED=93325
#  NOT MATCHED=371090
#  DISCARDED=1383128
#  SKIPPED=43128842
# *** CUBES=5700
#  MATCHED=93847
#  NOT MATCHED=372056
#  DISCARDED=1386676
#  SKIPPED=43926006
# *** CUBES=5800
#  MATCHED=93995
#  NOT MATCHED=373060
#  DISCARDED=1390476
#  SKIPPED=44722896
# *** CUBES=5900
#  MATCHED=96134
#  NOT MATCHED=393140
#  DISCARDED=1466507
#  SKIPPED=45428396
# *** CUBES=6000
#  MATCHED=98019
#  NOT MATCHED=411986
#  DISCARDED=1537898
#  SKIPPED=46139776
# *** CUBES=6100
#  MATCHED=99685
#  NOT MATCHED=428971
#  DISCARDED=1602338
#  SKIPPED=46859976
# *** CUBES=6200
#  MATCHED=101258
#  NOT MATCHED=443351
#  DISCARDED=1656927
#  SKIPPED=47592638
# *** CUBES=6300
#  MATCHED=103575
#  NOT MATCHED=455407
#  DISCARDED=1702959
#  SKIPPED=48336150
# *** CUBES=6400
#  MATCHED=105835
#  NOT MATCHED=465987
#  DISCARDED=1743586
#  SKIPPED=49086550
# *** CUBES=6500
#  MATCHED=108318
#  NOT MATCHED=473476
#  DISCARDED=1772280
#  SKIPPED=49851965
# *** CUBES=6600
#  MATCHED=110642
#  NOT MATCHED=479717
#  DISCARDED=1796219
#  SKIPPED=50623389
# *** CUBES=6700
#  MATCHED=113022
#  NOT MATCHED=483299
#  DISCARDED=1809937
#  SKIPPED=51407689
# *** CUBES=6800
#  MATCHED=114188
#  NOT MATCHED=485017
#  DISCARDED=1816523
#  SKIPPED=52201037
# *** CUBES=6900
#  MATCHED=114188
#  NOT MATCHED=485017
#  DISCARDED=1816523
#  SKIPPED=53002737
# *** CUBES=7000
#  MATCHED=115758
#  NOT MATCHED=500837
#  DISCARDED=1873481
#  SKIPPED=53731585
# *** CUBES=7100
#  MATCHED=117617
#  NOT MATCHED=520606
#  DISCARDED=1944641
#  SKIPPED=54442269
# *** CUBES=7200
#  MATCHED=119024
#  NOT MATCHED=537690
#  DISCARDED=2005976
#  SKIPPED=55165469
# *** CUBES=7300
#  MATCHED=120980
#  NOT MATCHED=552760
#  DISCARDED=2060203
#  SKIPPED=55897781
# *** CUBES=7400
#  MATCHED=122928
#  NOT MATCHED=565818
#  DISCARDED=2107149
#  SKIPPED=56639386
# *** CUBES=7500
#  MATCHED=125048
#  NOT MATCHED=576593
#  DISCARDED=2145676
#  SKIPPED=57391686
# *** CUBES=7600
#  MATCHED=127399
#  NOT MATCHED=584638
#  DISCARDED=2174765
#  SKIPPED=58156146
# *** CUBES=7700
#  MATCHED=129497
#  NOT MATCHED=591242
#  DISCARDED=2198813
#  SKIPPED=58927102
# *** CUBES=7800
#  MATCHED=131733
#  NOT MATCHED=594822
#  DISCARDED=2211934
#  SKIPPED=59712002
# *** CUBES=7900
#  MATCHED=132251
#  NOT MATCHED=596616
#  DISCARDED=2218516
#  SKIPPED=60505302
# *** CUBES=8000
#  MATCHED=132251
#  NOT MATCHED=596616
#  DISCARDED=2218516
#  SKIPPED=61307002
# *** MATCHED=132251
# *** NOT MATCHED=596616
# *** DISCARDED=2218516
# *** SKIPPED=61451308
# WARNING:tensorflow:From <ipython-input-6-6d6c00010ca0>:97: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# #####################################################################
# TRAINING:
# MODEL:/media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# #####################################################################
# INFO:tensorflow:Restoring parameters from /media/1KGB_ILAN/papyrus/models/tear_model1.ckpt
# Model restored.
# step 49, training accuracy 0.82
# step 99, training accuracy 0.75
# step 149, training accuracy 0.87
# step 199, training accuracy 0.80
# step 249, training accuracy 0.93
# step 299, training accuracy 0.82
# step 349, training accuracy 0.83
# step 399, training accuracy 0.90
# step 449, training accuracy 0.77
# step 499, training accuracy 0.88
# step 549, training accuracy 0.87
# step 599, training accuracy 0.88
# step 649, training accuracy 0.88
# step 699, training accuracy 0.85
# step 749, training accuracy 0.93
# step 799, training accuracy 0.93
# step 849, training accuracy 0.95
# step 899, training accuracy 0.92
# step 949, training accuracy 0.88
# step 999, training accuracy 0.93
# step 1049, training accuracy 0.95
# step 1099, training accuracy 0.82
# step 1149, training accuracy 0.90
# step 1199, training accuracy 0.93
# step 1249, training accuracy 0.92
# step 1299, training accuracy 0.88
# step 1349, training accuracy 0.92
# step 1399, training accuracy 0.83
# step 1449, training accuracy 0.92
# step 1499, training accuracy 0.95
# step 1549, training accuracy 0.83
# step 1599, training accuracy 0.88
# step 1649, training accuracy 0.93
# step 1699, training accuracy 0.92
# step 1749, training accuracy 0.90
# step 1799, training accuracy 0.88
# step 1849, training accuracy 0.88
# step 1899, training accuracy 0.85
# step 1949, training accuracy 0.95
# step 1999, training accuracy 0.97
# Optimization Finished!
# step 1999, training accuracy 0.966667
# Model saved in file: /media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# #####################################################################
# TRAINING ENDED
# #####################################################################

# %%
# validate 1
cubes_set = pre_process_training("PX303-Fg001-V-C01-R01-D05032015-T112520-ML638__006.jpg", max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
  NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 1, 5)
tf.reset_default_graph()
model_tf_deep(250, 1)    
validate2_for_cross_validation(train_imgs, train_lbls, is_enriched, ROOT_FOLDER + "models/tear_model2.ckpt")
# Out:
# #####################################################################
# PRE_PROCESS:PX303-Fg001-V-C01-R01-D05032015-T112520-ML638__006.jpg
# #####################################################################
# PRE_PROCESS:::TEAR_3X2
# /home/ilan/venv35/lib/python3.5/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# PRE_PROCESS:::TEAR_3X3
# PRE_PROCESS:::TEAR_4X2
# PRE_PROCESS:::TEAR_4X3
# PRE_PROCESS:::TEAR_5X2
# PRE_PROCESS:::TEAR_5X3
# PRE_PROCESS:::TEAR_6X2
# PRE_PROCESS:::TEAR_6X3
# PRE_PROCESS:::TEAR_7X2
# PRE_PROCESS:::TEAR_7X3
# *** CUBES=100
#  MATCHED=741
#  NOT MATCHED=1870
#  DISCARDED=7485
#  SKIPPED=267186
# *** CUBES=200
#  MATCHED=1040
#  NOT MATCHED=2596
#  DISCARDED=10056
#  SKIPPED=543262
# *** CUBES=300
#  MATCHED=1562
#  NOT MATCHED=3900
#  DISCARDED=14402
#  SKIPPED=816942
# *** CUBES=400
#  MATCHED=2104
#  NOT MATCHED=6353
#  DISCARDED=23677
#  SKIPPED=1084568
# *** CUBES=500
#  MATCHED=2938
#  NOT MATCHED=8375
#  DISCARDED=30961
#  SKIPPED=1354588
# *** CUBES=600
#  MATCHED=3216
#  NOT MATCHED=9452
#  DISCARDED=34564
#  SKIPPED=1629282
# *** CUBES=700
#  MATCHED=3804
#  NOT MATCHED=11907
#  DISCARDED=42745
#  SKIPPED=1897970
# *** CUBES=800
#  MATCHED=4132
#  NOT MATCHED=13119
#  DISCARDED=47219
#  SKIPPED=2171644
# *** CUBES=900
#  MATCHED=5075
#  NOT MATCHED=17420
#  DISCARDED=63619
#  SKIPPED=2430264
# *** CUBES=1000
#  MATCHED=5826
#  NOT MATCHED=19599
#  DISCARDED=71537
#  SKIPPED=2699504
# *** CUBES=1100
#  MATCHED=6175
#  NOT MATCHED=20634
#  DISCARDED=75045
#  SKIPPED=2974328
# *** CUBES=1200
#  MATCHED=6794
#  NOT MATCHED=24528
#  DISCARDED=88202
#  SKIPPED=3236598
# *** CUBES=1300
#  MATCHED=7413
#  NOT MATCHED=26166
#  DISCARDED=93661
#  SKIPPED=3508822
# *** CUBES=1400
#  MATCHED=7809
#  NOT MATCHED=29338
#  DISCARDED=106353
#  SKIPPED=3772322
# *** CUBES=1500
#  MATCHED=8620
#  NOT MATCHED=33814
#  DISCARDED=124250
#  SKIPPED=4029282
# *** CUBES=1600
#  MATCHED=9539
#  NOT MATCHED=36366
#  DISCARDED=134459
#  SKIPPED=4295842
# *** CUBES=1700
#  MATCHED=9993
#  NOT MATCHED=36924
#  DISCARDED=136683
#  SKIPPED=4572422
# *** CUBES=1800
#  MATCHED=10501
#  NOT MATCHED=41975
#  DISCARDED=153222
#  SKIPPED=4830164
# *** CUBES=1900
#  MATCHED=11087
#  NOT MATCHED=45151
#  DISCARDED=163600
#  SKIPPED=5095932
# *** CUBES=2000
#  MATCHED=11488
#  NOT MATCHED=46026
#  DISCARDED=166394
#  SKIPPED=5371610
# *** CUBES=2100
#  MATCHED=12345
#  NOT MATCHED=51953
#  DISCARDED=190094
#  SKIPPED=5621310
# *** CUBES=2200
#  MATCHED=13424
#  NOT MATCHED=57047
#  DISCARDED=210469
#  SKIPPED=5875150
# *** CUBES=2300
#  MATCHED=14398
#  NOT MATCHED=60068
#  DISCARDED=222542
#  SKIPPED=6139370
# *** CUBES=2400
#  MATCHED=15082
#  NOT MATCHED=61089
#  DISCARDED=226625
#  SKIPPED=6413610
# *** CUBES=2500
#  MATCHED=15635
#  NOT MATCHED=65718
#  DISCARDED=241913
#  SKIPPED=6673020
# *** CUBES=2600
#  MATCHED=16345
#  NOT MATCHED=70811
#  DISCARDED=258682
#  SKIPPED=6930468
# *** CUBES=2700
#  MATCHED=16964
#  NOT MATCHED=73601
#  DISCARDED=267791
#  SKIPPED=7197886
# *** MATCHED=17258
# *** NOT MATCHED=74109
# *** DISCARDED=269481
# *** SKIPPED=7461080
# 91367
# INFO:tensorflow:Restoring parameters from /media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# Model restored.
# >>> step 100
# step 0-99, precision 0.714286, recall 0.555556, f_score 0.625000
# === total 100 match 7
# >>> step 200
# step 100-199, precision 0.615385, recall 0.250000, f_score 0.355556
# === total 200 match 13
# >>> step 300
# step 200-299, precision 0.357143, recall 0.188679, f_score 0.246914
# === total 300 match 28
# >>> step 400
# step 300-399, precision 0.452381, recall 0.292308, f_score 0.355140
# === total 400 match 42
# >>> step 500
# step 400-499, precision 0.455696, recall 0.404494, f_score 0.428571
# === total 500 match 79
# >>> step 600
# step 500-599, precision 0.455696, recall 0.367347, f_score 0.406780
# === total 600 match 79
# >>> step 700
# step 600-699, precision 0.450000, recall 0.272727, f_score 0.339623
# === total 700 match 80
# >>> step 800
# step 700-799, precision 0.461538, recall 0.240000, f_score 0.315789
# === total 800 match 91
# >>> step 900
# step 800-899, precision 0.446809, recall 0.240000, f_score 0.312268
# === total 900 match 94
# >>> step 1000
# step 900-999, precision 0.495798, recall 0.305699, f_score 0.378205
# === total 1000 match 119
# >>> step 1100
# step 1000-1099, precision 0.552795, recall 0.399103, f_score 0.463542
# === total 1100 match 161
# >>> step 1200
# step 1100-1199, precision 0.553846, recall 0.420233, f_score 0.477876
# === total 1200 match 195
# >>> step 1300
# step 1200-1299, precision 0.555000, recall 0.414179, f_score 0.474359
# === total 1300 match 200
# >>> step 1400
# step 1300-1399, precision 0.570833, recall 0.450658, f_score 0.503676
# === total 1400 match 240
# >>> step 1500
# step 1400-1499, precision 0.561475, recall 0.420245, f_score 0.480702
# === total 1500 match 244
# >>> step 1600
# step 1500-1599, precision 0.586806, recall 0.449468, f_score 0.509036
# === total 1600 match 288
# >>> step 1700
# step 1600-1699, precision 0.583333, recall 0.442623, f_score 0.503329
# === total 1700 match 324
# >>> step 1800
# step 1700-1799, precision 0.599462, recall 0.480603, f_score 0.533493
# === total 1800 match 372
# >>> step 1900
# step 1800-1899, precision 0.602597, recall 0.490486, f_score 0.540793
# === total 1900 match 385
# >>> step 2000
# step 1900-1999, precision 0.603645, recall 0.521654, f_score 0.559662
# === total 2000 match 439
# >>> step 2100
# step 2000-2099, precision 0.598361, recall 0.544776, f_score 0.570312
# === total 2100 match 488
# >>> step 2200
# step 2100-2199, precision 0.580524, recall 0.550622, f_score 0.565178
# === total 2200 match 534
# >>> step 2300
# step 2200-2299, precision 0.583904, recall 0.552674, f_score 0.567860
# === total 2300 match 584
# >>> step 2400
# step 2300-2399, precision 0.581320, recall 0.564945, f_score 0.573016
# === total 2400 match 621
# >>> step 2500
# step 2400-2499, precision 0.594554, recall 0.580502, f_score 0.587444
# === total 2500 match 661
# >>> step 2600
# step 2500-2599, precision 0.600000, recall 0.606557, f_score 0.603261
# === total 2600 match 740
# >>> step 2700
# step 2600-2699, precision 0.595238, recall 0.613695, f_score 0.604326
# === total 2700 match 798
# >>> step 2800
# step 2700-2799, precision 0.600234, recall 0.626683, f_score 0.613174
# === total 2800 match 853
# >>> step 2900
# step 2800-2899, precision 0.621179, recall 0.645857, f_score 0.633278
# === total 2900 match 916
# >>> step 3000
# step 2900-2999, precision 0.632530, recall 0.665259, f_score 0.648482
# === total 3000 match 996
# >>> step 3100
# step 3000-3099, precision 0.632495, recall 0.667347, f_score 0.649454
# === total 3100 match 1034
# >>> step 3200
# step 3100-3199, precision 0.631021, recall 0.667006, f_score 0.648515
# === total 3200 match 1038
# >>> step 3300
# step 3200-3299, precision 0.629213, recall 0.669990, f_score 0.648962
# === total 3300 match 1068
# >>> step 3400
# step 3300-3399, precision 0.624434, recall 0.675808, f_score 0.649106
# === total 3400 match 1105
# >>> step 3500
# step 3400-3499, precision 0.616330, recall 0.675650, f_score 0.644628
# === total 3500 match 1139
# >>> step 3600
# step 3500-3599, precision 0.608658, recall 0.675962, f_score 0.640547
# === total 3600 match 1155
# >>> step 3700
# step 3600-3699, precision 0.609107, recall 0.675882, f_score 0.640759
# === total 3700 match 1164
# >>> step 3800
# step 3700-3799, precision 0.619323, recall 0.688073, f_score 0.651890
# === total 3800 match 1211
# >>> step 3900
# step 3800-3899, precision 0.620800, recall 0.694718, f_score 0.655682
# === total 3900 match 1250
# >>> step 4000
# step 3900-3999, precision 0.626750, recall 0.699046, f_score 0.660927
# === total 4000 match 1286
# >>> step 4100
# step 4000-4099, precision 0.631659, recall 0.705183, f_score 0.666399
# === total 4100 match 1314
# >>> step 4200
# step 4100-4199, precision 0.631659, recall 0.705183, f_score 0.666399
# === total 4200 match 1314
# >>> step 4300
# step 4200-4299, precision 0.629742, recall 0.691091, f_score 0.658992
# === total 4300 match 1318
# >>> step 4400
# step 4300-4399, precision 0.626888, recall 0.679214, f_score 0.652003
# === total 4400 match 1324
# >>> step 4500
# step 4400-4499, precision 0.625000, recall 0.666667, f_score 0.645161
# === total 4500 match 1328
# >>> step 4600
# step 4500-4599, precision 0.621541, recall 0.662679, f_score 0.641451
# === total 4600 match 1337
# >>> step 4700
# step 4600-4699, precision 0.621366, recall 0.664852, f_score 0.642374
# === total 4700 match 1376
# >>> step 4800
# step 4700-4799, precision 0.619355, recall 0.662069, f_score 0.640000
# === total 4800 match 1395
# >>> step 4900
# step 4800-4899, precision 0.620956, recall 0.660434, f_score 0.640087
# === total 4900 match 1422
# >>> step 5000
# step 4900-4999, precision 0.622629, recall 0.661151, f_score 0.641312
# === total 5000 match 1476
# >>> step 5100
# step 5000-5099, precision 0.616546, recall 0.658947, f_score 0.637042
# === total 5100 match 1523
# >>> step 5200
# step 5100-5199, precision 0.611039, recall 0.653472, f_score 0.631544
# === total 5200 match 1540
# >>> step 5300
# step 5200-5299, precision 0.611006, recall 0.647019, f_score 0.628497
# === total 5300 match 1581
# >>> step 5400
# step 5300-5399, precision 0.611453, recall 0.645644, f_score 0.628083
# === total 5400 match 1624
# >>> step 5500
# step 5400-5499, precision 0.610876, recall 0.647247, f_score 0.628536
# === total 5500 match 1655
# >>> step 5600
# step 5500-5599, precision 0.609771, recall 0.643539, f_score 0.626200
# === total 5600 match 1658
# >>> step 5700
# step 5600-5699, precision 0.607572, recall 0.643539, f_score 0.625039
# === total 5700 match 1664
# >>> step 5800
# step 5700-5799, precision 0.602854, recall 0.634941, f_score 0.618481
# === total 5800 match 1682
# >>> step 5900
# step 5800-5899, precision 0.602732, recall 0.628483, f_score 0.615338
# === total 5900 match 1684
# >>> step 6000
# step 5900-5999, precision 0.600237, recall 0.625000, f_score 0.612368
# === total 6000 match 1691
# >>> step 6100
# step 6000-6099, precision 0.596007, recall 0.621555, f_score 0.608513
# === total 6100 match 1703
# >>> step 6200
# step 6100-6199, precision 0.594312, recall 0.620230, f_score 0.606995
# === total 6200 match 1723
# >>> step 6300
# step 6200-6299, precision 0.593968, recall 0.620230, f_score 0.606815
# === total 6300 match 1724
# >>> step 6400
# step 6300-6399, precision 0.592250, recall 0.610614, f_score 0.601292
# === total 6400 match 1729
# >>> step 6500
# step 6400-6499, precision 0.590883, recall 0.604486, f_score 0.597607
# === total 6500 match 1733
# >>> step 6600
# step 6500-6599, precision 0.588506, recall 0.595349, f_score 0.591908
# === total 6600 match 1740
# >>> step 6700
# step 6600-6699, precision 0.586483, recall 0.589522, f_score 0.587999
# === total 6700 match 1746
# >>> step 6800
# step 6700-6799, precision 0.586148, recall 0.589522, f_score 0.587830
# === total 6800 match 1747
# >>> step 6900
# step 6800-6899, precision 0.587093, recall 0.590465, f_score 0.588774
# === total 6900 match 1751
# >>> step 7000
# step 6900-6999, precision 0.588600, recall 0.592951, f_score 0.590767
# === total 7000 match 1772
# >>> step 7100
# step 7000-7099, precision 0.592346, recall 0.595650, f_score 0.593993
# === total 7100 match 1803
# >>> step 7200
# step 7100-7199, precision 0.595512, recall 0.597802, f_score 0.596655
# === total 7200 match 1827
# >>> step 7300
# step 7200-7299, precision 0.592573, recall 0.599021, f_score 0.595779
# === total 7300 match 1858
# >>> step 7400
# step 7300-7399, precision 0.594450, recall 0.600216, f_score 0.597319
# === total 7400 match 1874
# >>> step 7500
# step 7400-7499, precision 0.595364, recall 0.598834, f_score 0.597094
# === total 7500 match 1898
# >>> step 7600
# step 7500-7599, precision 0.597302, recall 0.602618, f_score 0.599948
# === total 7600 match 1927
# >>> step 7700
# step 7600-7699, precision 0.597302, recall 0.602618, f_score 0.599948
# === total 7700 match 1927
# >>> step 7800
# step 7700-7799, precision 0.595420, recall 0.597549, f_score 0.596482
# === total 7800 match 1965
# >>> step 7900
# step 7800-7899, precision 0.594159, recall 0.595358, f_score 0.594758
# === total 7900 match 1986
# >>> step 8000
# step 7900-7999, precision 0.587885, recall 0.584403, f_score 0.586139
# === total 8000 match 2014
# >>> step 8100
# step 8000-8099, precision 0.589581, recall 0.585307, f_score 0.587436
# === total 8100 match 2054
# >>> step 8200
# step 8100-8199, precision 0.589632, recall 0.585659, f_score 0.587639
# === total 8200 match 2064
# >>> step 8300
# step 8200-8299, precision 0.585378, recall 0.585659, f_score 0.585518
# === total 8300 match 2079
# >>> step 8400
# step 8300-8399, precision 0.581384, recall 0.583613, f_score 0.582496
# === total 8400 match 2095
# >>> step 8500
# step 8400-8499, precision 0.579271, recall 0.577086, f_score 0.578177
# === total 8500 match 2113
# >>> step 8600
# step 8500-8599, precision 0.570833, recall 0.578602, f_score 0.574691
# === total 8600 match 2160
# >>> step 8700
# step 8600-8699, precision 0.567246, recall 0.577013, f_score 0.572088
# === total 8700 match 2186
# >>> step 8800
# step 8700-8799, precision 0.561459, recall 0.575450, f_score 0.568368
# === total 8800 match 2221
# >>> step 8900
# step 8800-8899, precision 0.560748, recall 0.577982, f_score 0.569234
# === total 8900 match 2247
# >>> step 9000
# step 8900-8999, precision 0.559545, recall 0.578281, f_score 0.568758
# === total 9000 match 2284
# >>> step 9100
# step 9000-9099, precision 0.558298, recall 0.582335, f_score 0.570063
# === total 9100 match 2350
# >>> step 9200
# step 9100-9199, precision 0.552654, recall 0.582335, f_score 0.567106
# === total 9200 match 2374
# >>> step 9300
# step 9200-9299, precision 0.552654, recall 0.579249, f_score 0.565639
# === total 9300 match 2374
# >>> step 9400
# step 9300-9399, precision 0.553549, recall 0.575546, f_score 0.564333
# === total 9400 match 2381
# >>> step 9500
# step 9400-9499, precision 0.553147, recall 0.568065, f_score 0.560507
# === total 9500 match 2399
# >>> step 9600
# step 9500-9599, precision 0.554267, recall 0.568394, f_score 0.561242
# === total 9600 match 2414
# >>> step 9700
# step 9600-9699, precision 0.552470, recall 0.568249, f_score 0.560248
# === total 9700 match 2449
# >>> step 9800
# step 9700-9799, precision 0.554666, recall 0.570899, f_score 0.562665
# === total 9800 match 2497
# >>> step 9900
# step 9800-9899, precision 0.551930, recall 0.571252, f_score 0.561425
# === total 9900 match 2513
# >>> step 10000
# step 9900-9999, precision 0.551479, recall 0.564165, f_score 0.557750
# === total 10000 match 2535
# >>> step 10100
# step 10000-10099, precision 0.550372, recall 0.556040, f_score 0.553191
# === total 10100 match 2551
# >>> step 10200
# step 10100-10199, precision 0.551777, recall 0.554779, f_score 0.553274
# === total 10200 match 2588
# >>> step 10300
# step 10200-10299, precision 0.552003, recall 0.552429, f_score 0.552216
# === total 10300 match 2596
# >>> step 10400
# step 10300-10399, precision 0.548289, recall 0.553976, f_score 0.551118
# === total 10400 match 2630
# >>> step 10500
# step 10400-10499, precision 0.547443, recall 0.559894, f_score 0.553598
# === total 10500 match 2698
# >>> step 10600
# step 10500-10599, precision 0.545323, recall 0.564353, f_score 0.554675
# === total 10600 match 2758
# >>> step 10700
# step 10600-10699, precision 0.543131, recall 0.568562, f_score 0.555556
# === total 10700 match 2817
# >>> step 10800
# step 10700-10799, precision 0.543914, recall 0.574088, f_score 0.558594
# === total 10800 match 2892
# >>> step 10900
# step 10800-10899, precision 0.542934, recall 0.579156, f_score 0.560461
# === total 10900 match 2958
# >>> step 11000
# step 10900-10999, precision 0.540640, recall 0.581512, f_score 0.560331
# === total 11000 match 3002
# >>> step 11100
# step 11000-11099, precision 0.543974, recall 0.588028, f_score 0.565144
# === total 11100 match 3070
# >>> step 11200
# step 11100-11199, precision 0.544759, recall 0.593544, f_score 0.568106
# === total 11200 match 3139
# >>> step 11300
# step 11200-11299, precision 0.546899, recall 0.599181, f_score 0.571848
# === total 11300 match 3209
# >>> step 11400
# step 11300-11399, precision 0.548080, recall 0.602296, f_score 0.573910
# === total 11400 match 3255
# >>> step 11500
# step 11400-11499, precision 0.552767, recall 0.603699, f_score 0.577111
# === total 11500 match 3307
# >>> step 11600
# step 11500-11599, precision 0.558284, recall 0.610285, f_score 0.583127
# === total 11600 match 3380
# >>> step 11700
# step 11600-11699, precision 0.558514, recall 0.613038, f_score 0.584507
# === total 11700 match 3418
# >>> step 11800
# step 11700-11799, precision 0.558350, recall 0.613038, f_score 0.584418
# === total 11800 match 3419
# >>> step 11900
# step 11800-11899, precision 0.557720, recall 0.613564, f_score 0.584311
# === total 11900 match 3439
# >>> step 12000
# step 11900-11999, precision 0.556671, recall 0.615873, f_score 0.584778
# === total 12000 match 3485
# >>> step 12100
# step 12000-12099, precision 0.554699, recall 0.614752, f_score 0.583183
# === total 12100 match 3501
# >>> step 12200
# step 12100-12199, precision 0.554046, recall 0.616499, f_score 0.583607
# === total 12200 match 3534
# >>> step 12300
# step 12200-12299, precision 0.551289, recall 0.617389, f_score 0.582470
# === total 12300 match 3568
# >>> step 12400
# step 12300-12399, precision 0.547732, recall 0.617509, f_score 0.580531
# === total 12400 match 3593
# >>> step 12500
# step 12400-12499, precision 0.547427, recall 0.617509, f_score 0.580360
# === total 12500 match 3595
# >>> step 12600
# step 12500-12599, precision 0.546534, recall 0.618824, f_score 0.580437
# === total 12600 match 3621
# >>> step 12700
# step 12600-12699, precision 0.547154, recall 0.618781, f_score 0.580768
# === total 12700 match 3637
# >>> step 12800
# step 12700-12799, precision 0.549073, recall 0.619311, f_score 0.582081
# === total 12800 match 3668
# >>> step 12900
# step 12800-12899, precision 0.549864, recall 0.620489, f_score 0.583046
# === total 12900 match 3690
# >>> step 13000
# step 12900-12999, precision 0.551103, recall 0.622796, f_score 0.584760
# === total 13000 match 3718
# >>> step 13100
# step 13000-13099, precision 0.550215, recall 0.622796, f_score 0.584260
# === total 13100 match 3724
# >>> step 13200
# step 13100-13199, precision 0.549772, recall 0.622796, f_score 0.584010
# === total 13200 match 3727
# >>> step 13300
# step 13200-13299, precision 0.549465, recall 0.621221, f_score 0.583144
# === total 13300 match 3740
# >>> step 13400
# step 13300-13399, precision 0.547764, recall 0.619760, f_score 0.581542
# === total 13400 match 3779
# >>> step 13500
# step 13400-13499, precision 0.547493, recall 0.617927, f_score 0.580582
# === total 13500 match 3790
# >>> step 13600
# step 13500-13599, precision 0.546785, recall 0.616382, f_score 0.579501
# === total 13600 match 3826
# >>> step 13700
# step 13600-13699, precision 0.545289, recall 0.615633, f_score 0.578330
# === total 13700 match 3842
# >>> step 13800
# step 13700-13799, precision 0.543887, recall 0.616574, f_score 0.577954
# === total 13800 match 3885
# >>> step 13900
# step 13800-13899, precision 0.542909, recall 0.616574, f_score 0.577401
# === total 13900 match 3892
# >>> step 14000
# step 13900-13999, precision 0.541050, recall 0.617579, f_score 0.576787
# === total 14000 match 3922
# >>> step 14100
# step 14000-14099, precision 0.537396, recall 0.618551, f_score 0.575125
# === total 14100 match 3971
# >>> step 14200
# step 14100-14199, precision 0.536311, recall 0.619487, f_score 0.574906
# === total 14200 match 4007
# >>> step 14300
# step 14200-14299, precision 0.535183, recall 0.619444, f_score 0.574239
# === total 14300 match 4036
# >>> step 14400
# step 14300-14399, precision 0.533202, recall 0.619444, f_score 0.573096
# === total 14400 match 4051
# >>> step 14500
# step 14400-14499, precision 0.532290, recall 0.619766, f_score 0.572707
# === total 14500 match 4088
# >>> step 14600
# step 14500-14599, precision 0.533542, recall 0.623344, f_score 0.574958
# === total 14600 match 4144
# >>> step 14700
# step 14600-14699, precision 0.534524, recall 0.626570, f_score 0.576898
# === total 14700 match 4200
# >>> step 14800
# step 14700-14799, precision 0.533130, recall 0.629055, f_score 0.577133
# === total 14800 match 4256
# >>> step 14900
# step 14800-14899, precision 0.531755, recall 0.629055, f_score 0.576327
# === total 14900 match 4267
# >>> step 15000
# step 14900-14999, precision 0.529234, recall 0.626759, f_score 0.573882
# === total 15000 match 4293
# >>> step 15100
# step 15000-15099, precision 0.528677, recall 0.623228, f_score 0.572072
# === total 15100 match 4324
# >>> step 15200
# step 15100-15199, precision 0.527185, recall 0.620913, f_score 0.570223
# === total 15200 match 4359
# >>> step 15300
# step 15200-15299, precision 0.525834, recall 0.618280, f_score 0.568322
# === total 15300 match 4374
# >>> step 15400
# step 15300-15399, precision 0.524761, recall 0.616987, f_score 0.567150
# === total 15400 match 4402
# >>> step 15500
# step 15400-15499, precision 0.523510, recall 0.617733, f_score 0.566732
# === total 15500 match 4445
# >>> step 15600
# step 15500-15599, precision 0.521961, recall 0.620190, f_score 0.566851
# === total 15600 match 4508
# >>> step 15700
# step 15600-15699, precision 0.519798, recall 0.621188, f_score 0.565988
# === total 15700 match 4546
# >>> step 15800
# step 15700-15799, precision 0.522294, recall 0.626103, f_score 0.569507
# === total 15800 match 4620
# >>> step 15900
# step 15800-15899, precision 0.524471, recall 0.630039, f_score 0.572428
# === total 15900 match 4679
# >>> step 16000
# step 15900-15999, precision 0.524514, recall 0.632679, f_score 0.573541
# === total 16000 match 4732
# >>> step 16100
# step 16000-16099, precision 0.523074, recall 0.633375, f_score 0.572964
# === total 16100 match 4789
# >>> step 16200
# step 16100-16199, precision 0.522643, recall 0.634274, f_score 0.573073
# === total 16200 match 4858
# >>> step 16300
# step 16200-16299, precision 0.521836, recall 0.635576, f_score 0.573118
# === total 16300 match 4923
# >>> step 16400
# step 16300-16399, precision 0.521721, recall 0.635667, f_score 0.573085
# === total 16400 match 4926
# >>> step 16500
# step 16400-16499, precision 0.521854, recall 0.636476, f_score 0.573493
# === total 16500 match 4942
# >>> step 16600
# step 16500-16599, precision 0.521221, recall 0.636476, f_score 0.573111
# === total 16600 match 4948
# >>> step 16700
# step 16600-16699, precision 0.522463, recall 0.638794, f_score 0.574801
# === total 16700 match 4986
# >>> step 16800
# step 16700-16799, precision 0.522173, recall 0.639589, f_score 0.574948
# === total 16800 match 5006
# >>> step 16900
# step 16800-16899, precision 0.522822, recall 0.640381, f_score 0.575661
# === total 16900 match 5017
# >>> step 17000
# step 16900-16999, precision 0.522768, recall 0.640438, f_score 0.575651
# === total 17000 match 5029
# >>> step 17100
# step 17000-17099, precision 0.522790, recall 0.641225, f_score 0.575983
# === total 17100 match 5046
# >>> step 17200
# step 17100-17199, precision 0.523462, recall 0.642702, f_score 0.576986
# === total 17200 match 5072
# >>> step 17300
# step 17200-17299, precision 0.522732, recall 0.642788, f_score 0.576577
# === total 17300 match 5081
# >>> step 17400
# step 17300-17399, precision 0.522526, recall 0.642788, f_score 0.576451
# === total 17400 match 5083
# >>> step 17500
# step 17400-17499, precision 0.523930, recall 0.645022, f_score 0.578204
# === total 17500 match 5119
# >>> step 17600
# step 17500-17599, precision 0.524995, recall 0.646467, f_score 0.579433
# === total 17600 match 5141
# >>> step 17700
# step 17600-17699, precision 0.525542, recall 0.647901, f_score 0.580342
# === total 17700 match 5168
# >>> step 17800
# step 17700-17799, precision 0.527105, recall 0.650071, f_score 0.582166
# === total 17800 match 5202
# >>> step 17900
# step 17800-17899, precision 0.526397, recall 0.650071, f_score 0.581733
# === total 17900 match 5209
# >>> step 18000
# step 17900-17999, precision 0.526296, recall 0.650071, f_score 0.581672
# === total 18000 match 5210
# >>> step 18100
# step 18000-18099, precision 0.526296, recall 0.650071, f_score 0.581672
# === total 18100 match 5210
# >>> step 18200
# step 18100-18199, precision 0.525086, recall 0.646698, f_score 0.579581
# === total 18200 match 5222
# >>> step 18300
# step 18200-18299, precision 0.524885, recall 0.646698, f_score 0.579459
# === total 18300 match 5224
# >>> step 18400
# step 18300-18399, precision 0.523837, recall 0.642273, f_score 0.577040
# === total 18400 match 5244
# >>> step 18500
# step 18400-18499, precision 0.523592, recall 0.639851, f_score 0.575913
# === total 18500 match 5256
# >>> step 18600
# step 18500-18599, precision 0.523285, recall 0.637416, f_score 0.574739
# === total 18600 match 5261
# >>> step 18700
# step 18600-18699, precision 0.522727, recall 0.637708, f_score 0.574521
# === total 18700 match 5280
# >>> step 18800
# step 18700-18799, precision 0.523062, recall 0.637999, f_score 0.574842
# === total 18800 match 5290
# >>> step 18900
# step 18800-18899, precision 0.522132, recall 0.633890, f_score 0.572609
# === total 18900 match 5309
# >>> step 19000
# step 18900-18999, precision 0.522783, recall 0.634935, f_score 0.573427
# === total 19000 match 5333
# >>> step 19100
# step 19000-19099, precision 0.522783, recall 0.634935, f_score 0.573427
# === total 19100 match 5333
# >>> step 19200
# step 19100-19199, precision 0.522761, recall 0.635518, f_score 0.573651
# === total 19200 match 5360
# >>> step 19300
# step 19200-19299, precision 0.519711, recall 0.632005, f_score 0.570384
# === total 19300 match 5403
# >>> step 19400
# step 19300-19399, precision 0.520485, recall 0.633356, f_score 0.571400
# === total 19400 match 5443
# >>> step 19500
# step 19400-19499, precision 0.517864, recall 0.630353, f_score 0.568598
# === total 19500 match 5486
# >>> step 19600
# step 19500-19599, precision 0.516164, recall 0.627235, f_score 0.566305
# === total 19600 match 5506
# >>> step 19700
# step 19600-19699, precision 0.515108, recall 0.624479, f_score 0.564545
# === total 19700 match 5527
# >>> step 19800
# step 19700-19799, precision 0.515108, recall 0.624479, f_score 0.564545
# === total 19800 match 5527
# >>> step 19900
# step 19800-19899, precision 0.514828, recall 0.624479, f_score 0.564377
# === total 19900 match 5530
# >>> step 20000
# step 19900-19999, precision 0.513577, recall 0.625219, f_score 0.563925
# === total 20000 match 5561
# >>> step 20100
# step 20000-20099, precision 0.514045, recall 0.626609, f_score 0.564773
# === total 20100 match 5589
# >>> step 20200
# step 20100-20199, precision 0.511863, recall 0.628069, f_score 0.564043
# === total 20200 match 5648
# >>> step 20300
# step 20200-20299, precision 0.511013, recall 0.628794, f_score 0.563818
# === total 20300 match 5675
# >>> step 20400
# step 20300-20399, precision 0.509288, recall 0.628868, f_score 0.562797
# === total 20400 match 5706
# >>> step 20500
# step 20400-20499, precision 0.508168, recall 0.630308, f_score 0.562686
# === total 20500 match 5754
# >>> step 20600
# step 20500-20599, precision 0.506126, recall 0.631024, f_score 0.561716
# === total 20600 match 5795
# >>> step 20700
# step 20600-20699, precision 0.506028, recall 0.630878, f_score 0.561598
# === total 20700 match 5806
# >>> step 20800
# step 20700-20799, precision 0.505135, recall 0.631365, f_score 0.561240
# === total 20800 match 5842
# >>> step 20900
# step 20800-20899, precision 0.505336, recall 0.633602, f_score 0.562247
# === total 20900 match 5903
# >>> step 21000
# step 20900-20999, precision 0.504106, recall 0.635403, f_score 0.562190
# === total 21000 match 5967
# >>> step 21100
# step 21000-21099, precision 0.503094, recall 0.635403, f_score 0.561561
# === total 21100 match 5979
# >>> step 21200
# step 21100-21199, precision 0.500749, recall 0.635403, f_score 0.560097
# === total 21200 match 6007
# >>> step 21300
# step 21200-21299, precision 0.500165, recall 0.636574, f_score 0.560185
# === total 21300 match 6048
# >>> step 21400
# step 21300-21399, precision 0.497945, recall 0.635810, f_score 0.558495
# === total 21400 match 6083
# >>> step 21500
# step 21400-21499, precision 0.498291, recall 0.637917, f_score 0.559525
# === total 21500 match 6145
# >>> step 21600
# step 21500-21599, precision 0.498784, recall 0.638647, f_score 0.560117
# === total 21600 match 6169
# >>> step 21700
# step 21600-21699, precision 0.498064, recall 0.638337, f_score 0.559543
# === total 21700 match 6198
# >>> step 21800
# step 21700-21799, precision 0.496885, recall 0.639729, f_score 0.559331
# === total 21800 match 6261
# >>> step 21900
# step 21800-21899, precision 0.497224, recall 0.641235, f_score 0.560121
# === total 21900 match 6305
# >>> step 22000
# step 21900-21999, precision 0.495037, recall 0.641355, f_score 0.558776
# === total 22000 match 6347
# >>> step 22100
# step 22000-22099, precision 0.494813, recall 0.639707, f_score 0.558008
# === total 22100 match 6362
# >>> step 22200
# step 22100-22199, precision 0.494531, recall 0.638749, f_score 0.557464
# === total 22200 match 6400
# >>> step 22300
# step 22200-22299, precision 0.493535, recall 0.634997, f_score 0.555400
# === total 22300 match 6419
# >>> step 22400
# step 22300-22399, precision 0.493327, recall 0.630629, f_score 0.553592
# === total 22400 match 6444
# >>> step 22500
# step 22400-22499, precision 0.494219, recall 0.631724, f_score 0.554575
# === total 22500 match 6487
# >>> step 22600
# step 22500-22599, precision 0.491190, recall 0.631724, f_score 0.552663
# === total 22600 match 6527
# >>> step 22700
# step 22600-22699, precision 0.490517, recall 0.631051, f_score 0.551979
# === total 22700 match 6538
# >>> step 22800
# step 22700-22799, precision 0.490250, recall 0.630857, f_score 0.551736
# === total 22800 match 6564
# >>> step 22900
# step 22800-22899, precision 0.488593, recall 0.631764, f_score 0.551031
# === total 22900 match 6619
# >>> step 23000
# step 22900-22999, precision 0.488876, recall 0.633054, f_score 0.551701
# === total 23000 match 6652
# >>> step 23100
# step 23000-23099, precision 0.487955, recall 0.632590, f_score 0.550938
# === total 23100 match 6683
# >>> step 23200
# step 23100-23199, precision 0.487550, recall 0.633230, f_score 0.550922
# === total 23200 match 6707
# >>> step 23300
# step 23200-23299, precision 0.487783, recall 0.634682, f_score 0.551620
# === total 23300 match 6753
# >>> step 23400
# step 23300-23399, precision 0.488980, recall 0.637060, f_score 0.553283
# === total 23400 match 6806
# >>> step 23500
# step 23400-23499, precision 0.487993, recall 0.638667, f_score 0.553255
# === total 23500 match 6871
# >>> step 23600
# step 23500-23599, precision 0.487567, recall 0.638667, f_score 0.552981
# === total 23600 match 6877
# >>> step 23700
# step 23600-23699, precision 0.487491, recall 0.639901, f_score 0.553394
# === total 23700 match 6915
# >>> step 23800
# step 23700-23799, precision 0.488235, recall 0.641833, f_score 0.554596
# === total 23800 match 6970
# >>> step 23900
# step 23800-23899, precision 0.487687, recall 0.642295, f_score 0.554414
# === total 23900 match 7025
# >>> step 24000
# step 23900-23999, precision 0.486818, recall 0.644096, f_score 0.554521
# === total 24000 match 7093
# >>> step 24100
# step 24000-24099, precision 0.487208, recall 0.646208, f_score 0.555556
# === total 24100 match 7153
# >>> step 24200
# step 24100-24199, precision 0.486040, recall 0.646168, f_score 0.554780
# === total 24200 match 7199
# >>> step 24300
# step 24200-24299, precision 0.486278, recall 0.647924, f_score 0.555582
# === total 24300 match 7251
# >>> step 24400
# step 24300-24399, precision 0.487379, recall 0.650875, f_score 0.557385
# === total 24400 match 7329
# >>> step 24500
# step 24400-24499, precision 0.488012, recall 0.654089, f_score 0.558976
# === total 24500 match 7424
# >>> step 24600
# step 24500-24599, precision 0.489087, recall 0.657306, f_score 0.560855
# === total 24600 match 7514
# >>> step 24700
# step 24600-24699, precision 0.489022, recall 0.657306, f_score 0.560812
# === total 24700 match 7515
# >>> step 24800
# step 24700-24799, precision 0.489350, recall 0.658537, f_score 0.561475
# === total 24800 match 7559
# >>> step 24900
# step 24800-24899, precision 0.488833, recall 0.659284, f_score 0.561406
# === total 24900 match 7612
# >>> step 25000
# step 24900-24999, precision 0.488342, recall 0.660035, f_score 0.561354
# === total 25000 match 7677
# >>> step 25100
# step 25000-25099, precision 0.487887, recall 0.660007, f_score 0.561043
# === total 25100 match 7719
# >>> step 25200
# step 25100-25199, precision 0.488731, recall 0.659541, f_score 0.561432
# === total 25200 match 7765
# >>> step 25300
# step 25200-25299, precision 0.488312, recall 0.659383, f_score 0.561098
# === total 25300 match 7786
# >>> step 25400
# step 25300-25399, precision 0.489408, recall 0.660182, f_score 0.562111
# === total 25400 match 7836
# >>> step 25500
# step 25400-25499, precision 0.489186, recall 0.656928, f_score 0.560782
# === total 25500 match 7860
# >>> step 25600
# step 25500-25599, precision 0.488641, recall 0.653096, f_score 0.559024
# === total 25600 match 7879
# >>> step 25700
# step 25600-25699, precision 0.488920, recall 0.649235, f_score 0.557787
# === total 25700 match 7897
# >>> step 25800
# step 25700-25799, precision 0.491323, recall 0.651275, f_score 0.560103
# === total 25800 match 7952
# >>> step 25900
# step 25800-25899, precision 0.493400, recall 0.654443, f_score 0.562624
# === total 25900 match 8030
# >>> step 26000
# step 25900-25999, precision 0.495424, recall 0.655110, f_score 0.564186
# === total 26000 match 8086
# >>> step 26100
# step 26000-26099, precision 0.494935, recall 0.655110, f_score 0.563868
# === total 26100 match 8094
# >>> step 26200
# step 26100-26199, precision 0.494935, recall 0.655110, f_score 0.563868
# === total 26200 match 8094
# >>> step 26300
# step 26200-26299, precision 0.495071, recall 0.655572, f_score 0.564128
# === total 26300 match 8116
# >>> step 26400
# step 26300-26399, precision 0.495326, recall 0.656077, f_score 0.564480
# === total 26400 match 8130
# >>> step 26500
# step 26400-26499, precision 0.495341, recall 0.656697, f_score 0.564719
# === total 26500 match 8156
# >>> step 26600
# step 26500-26599, precision 0.495161, recall 0.656595, f_score 0.564565
# === total 26600 match 8163
# >>> step 26700
# step 26600-26699, precision 0.494930, recall 0.657097, f_score 0.564599
# === total 26700 match 8185
# >>> step 26800
# step 26700-26799, precision 0.494520, recall 0.657652, f_score 0.564537
# === total 26800 match 8212
# >>> step 26900
# step 26800-26899, precision 0.494400, recall 0.657652, f_score 0.564459
# === total 26900 match 8214
# >>> step 27000
# step 26900-26999, precision 0.494279, recall 0.657652, f_score 0.564381
# === total 27000 match 8216
# >>> step 27100
# step 27000-27099, precision 0.494099, recall 0.657652, f_score 0.564263
# === total 27100 match 8219
# >>> step 27200
# step 27100-27199, precision 0.495525, recall 0.659636, f_score 0.565923
# === total 27200 match 8268
# >>> step 27300
# step 27200-27299, precision 0.496083, recall 0.660674, f_score 0.566669
# === total 27300 match 8297
# >>> step 27400
# step 27300-27399, precision 0.496334, recall 0.661381, f_score 0.567092
# === total 27400 match 8319
# >>> step 27500
# step 27400-27499, precision 0.497668, recall 0.662685, f_score 0.568443
# === total 27500 match 8361
# >>> step 27600
# step 27500-27599, precision 0.497550, recall 0.662214, f_score 0.568193
# === total 27600 match 8369
# >>> step 27700
# step 27600-27699, precision 0.497853, recall 0.662697, f_score 0.568567
# === total 27700 match 8382
# >>> step 27800
# step 27700-27799, precision 0.498393, recall 0.663340, f_score 0.569157
# === total 27800 match 8401
# >>> step 27900
# step 27800-27899, precision 0.498274, recall 0.663340, f_score 0.569079
# === total 27900 match 8403
# >>> step 28000
# step 27900-27999, precision 0.498215, recall 0.663340, f_score 0.569041
# === total 28000 match 8404
# >>> step 28100
# step 28000-28099, precision 0.497978, recall 0.663340, f_score 0.568886
# === total 28100 match 8408
# >>> step 28200
# step 28100-28199, precision 0.497564, recall 0.659994, f_score 0.567383
# === total 28200 match 8415
# >>> step 28300
# step 28200-28299, precision 0.497388, recall 0.658494, f_score 0.566714
# === total 28300 match 8424
# >>> step 28400
# step 28300-28399, precision 0.497034, recall 0.657771, f_score 0.566216
# === total 28400 match 8430
# >>> step 28500
# step 28400-28499, precision 0.496681, recall 0.654381, f_score 0.564728
# === total 28500 match 8436
# >>> step 28600
# step 28500-28599, precision 0.496445, recall 0.653462, f_score 0.564234
# === total 28600 match 8440
# >>> step 28700
# step 28600-28699, precision 0.496093, recall 0.651633, f_score 0.563323
# === total 28700 match 8446
# >>> step 28800
# step 28700-28799, precision 0.495389, recall 0.651430, f_score 0.562794
# === total 28800 match 8458
# >>> step 28900
# step 28800-28899, precision 0.495389, recall 0.651430, f_score 0.562794
# === total 28900 match 8458
# >>> step 29000
# step 28900-28999, precision 0.495155, recall 0.651430, f_score 0.562643
# === total 29000 match 8462
# >>> step 29100
# step 29000-29099, precision 0.495104, recall 0.650698, f_score 0.562337
# === total 29100 match 8477
# >>> step 29200
# step 29100-29199, precision 0.494708, recall 0.650433, f_score 0.561982
# === total 29200 match 8504
# >>> step 29300
# step 29200-29299, precision 0.494959, recall 0.650940, f_score 0.562334
# === total 29300 match 8530
# >>> step 29400
# step 29300-29399, precision 0.494790, recall 0.650654, f_score 0.562118
# === total 29400 match 8541
# >>> step 29500
# step 29400-29499, precision 0.494450, recall 0.650576, f_score 0.561869
# === total 29500 match 8559
# >>> step 29600
# step 29500-29599, precision 0.494104, recall 0.650576, f_score 0.561646
# === total 29600 match 8565
# >>> step 29700
# step 29600-29699, precision 0.494046, recall 0.650576, f_score 0.561608
# === total 29700 match 8566
# >>> step 29800
# step 29700-29799, precision 0.493938, recall 0.648752, f_score 0.560858
# === total 29800 match 8578
# >>> step 29900
# step 29800-29899, precision 0.493774, recall 0.646799, f_score 0.560021
# === total 29900 match 8593
# >>> step 30000
# step 29900-29999, precision 0.493849, recall 0.645969, f_score 0.559758
# === total 30000 match 8616
# >>> step 30100
# step 30000-30099, precision 0.493619, recall 0.643819, f_score 0.558802
# === total 30100 match 8620
# >>> step 30200
# step 30100-30199, precision 0.493333, recall 0.642943, f_score 0.558289
# === total 30200 match 8625
# >>> step 30300
# step 30200-30299, precision 0.493224, recall 0.641072, f_score 0.557512
# === total 30300 match 8633
# >>> step 30400
# step 30300-30399, precision 0.493109, recall 0.641072, f_score 0.557439
# === total 30400 match 8635
# >>> step 30500
# step 30400-30499, precision 0.492945, recall 0.640710, f_score 0.557197
# === total 30500 match 8646
# >>> step 30600
# step 30500-30599, precision 0.492951, recall 0.638241, f_score 0.556265
# === total 30600 match 8654
# >>> step 30700
# step 30600-30699, precision 0.492842, recall 0.636974, f_score 0.555715
# === total 30700 match 8662
# >>> step 30800
# step 30700-30799, precision 0.492682, recall 0.636161, f_score 0.555303
# === total 30800 match 8677
# >>> step 30900
# step 30800-30899, precision 0.492235, recall 0.635055, f_score 0.554598
# === total 30900 match 8693
# >>> step 31000
# step 30900-30999, precision 0.491965, recall 0.633836, f_score 0.553961
# === total 31000 match 8712
# >>> step 31100
# step 31000-31099, precision 0.490895, recall 0.633836, f_score 0.553282
# === total 31100 match 8731
# >>> step 31200
# step 31100-31199, precision 0.490557, recall 0.632527, f_score 0.552569
# === total 31200 match 8737
# >>> step 31300
# step 31200-31299, precision 0.490053, recall 0.630851, f_score 0.551609
# === total 31300 match 8746
# >>> step 31400
# step 31300-31399, precision 0.489381, recall 0.629184, f_score 0.550546
# === total 31400 match 8758
# >>> step 31500
# step 31400-31499, precision 0.488433, recall 0.628262, f_score 0.549593
# === total 31500 match 8775
# >>> step 31600
# step 31500-31599, precision 0.487378, recall 0.628262, f_score 0.548924
# === total 31600 match 8794
# >>> step 31700
# step 31600-31699, precision 0.487650, recall 0.628046, f_score 0.549015
# === total 31700 match 8826
# >>> step 31800
# step 31700-31799, precision 0.487648, recall 0.628252, f_score 0.549092
# === total 31800 match 8865
# >>> step 31900
# step 31800-31899, precision 0.488024, recall 0.627440, f_score 0.549020
# === total 31900 match 8893
# >>> step 32000
# step 31900-31999, precision 0.488075, recall 0.627917, f_score 0.549235
# === total 32000 match 8931
# >>> step 32100
# step 32000-32099, precision 0.487655, recall 0.627245, f_score 0.548712
# === total 32100 match 8951
# >>> step 32200
# step 32100-32199, precision 0.487111, recall 0.627245, f_score 0.548367
# === total 32200 match 8961
# >>> step 32300
# step 32200-32299, precision 0.487929, recall 0.629429, f_score 0.549719
# === total 32300 match 9030
# >>> step 32400
# step 32300-32399, precision 0.487730, recall 0.630620, f_score 0.550047
# === total 32400 match 9087
# >>> step 32500
# step 32400-32499, precision 0.487970, recall 0.631743, f_score 0.550626
# === total 32500 match 9144
# >>> step 32600
# step 32500-32599, precision 0.488240, recall 0.632440, f_score 0.551063
# === total 32600 match 9184
# >>> step 32700
# step 32600-32699, precision 0.486721, recall 0.632751, f_score 0.550211
# === total 32700 match 9225
# >>> step 32800
# step 32700-32799, precision 0.486725, recall 0.634440, f_score 0.550852
# === total 32800 match 9303
# >>> step 32900
# step 32800-32899, precision 0.485610, recall 0.634293, f_score 0.550082
# === total 32900 match 9347
# >>> step 33000
# step 32900-32999, precision 0.486147, recall 0.635288, f_score 0.550800
# === total 33000 match 9384
# >>> step 33100
# step 33000-33099, precision 0.487383, recall 0.635559, f_score 0.551695
# === total 33100 match 9432
# >>> step 33200
# step 33100-33199, precision 0.487818, recall 0.635564, f_score 0.551975
# === total 33200 match 9481
# >>> step 33300
# step 33200-33299, precision 0.487390, recall 0.635952, f_score 0.551847
# === total 33300 match 9516
# >>> step 33400
# step 33300-33399, precision 0.487531, recall 0.634010, f_score 0.551205
# === total 33400 match 9544
# >>> step 33500
# step 33400-33499, precision 0.487550, recall 0.631094, f_score 0.550112
# === total 33500 match 9558
# >>> step 33600
# step 33500-33599, precision 0.487155, recall 0.629300, f_score 0.549179
# === total 33600 match 9576
# >>> step 33700
# step 33600-33699, precision 0.487155, recall 0.629300, f_score 0.549179
# === total 33700 match 9576
# >>> step 33800
# step 33700-33799, precision 0.487158, recall 0.628672, f_score 0.548941
# === total 33800 match 9578
# >>> step 33900
# step 33800-33899, precision 0.487107, recall 0.628672, f_score 0.548909
# === total 33900 match 9579
# >>> step 34000
# step 33900-33999, precision 0.487375, recall 0.627907, f_score 0.548787
# === total 34000 match 9584
# >>> step 34100
# step 34000-34099, precision 0.487482, recall 0.626828, f_score 0.548442
# === total 34100 match 9586
# >>> step 34200
# step 34100-34199, precision 0.487431, recall 0.626660, f_score 0.548345
# === total 34200 match 9587
# >>> step 34300
# step 34200-34299, precision 0.487807, recall 0.626976, f_score 0.548705
# === total 34300 match 9596
# >>> step 34400
# step 34300-34399, precision 0.487807, recall 0.626221, f_score 0.548415
# === total 34400 match 9596
# >>> step 34500
# step 34400-34499, precision 0.487917, recall 0.625869, f_score 0.548349
# === total 34500 match 9600
# >>> step 34600
# step 34500-34599, precision 0.488132, recall 0.625784, f_score 0.548453
# === total 34600 match 9606
# >>> step 34700
# step 34600-34699, precision 0.488082, recall 0.625033, f_score 0.548133
# === total 34700 match 9607
# >>> step 34800
# step 34700-34799, precision 0.488031, recall 0.625033, f_score 0.548101
# === total 34800 match 9608
# >>> step 34900
# step 34800-34899, precision 0.488510, recall 0.625483, f_score 0.548575
# === total 34900 match 9617
# >>> step 35000
# step 34900-34999, precision 0.488565, recall 0.624336, f_score 0.548169
# === total 35000 match 9620
# >>> step 35100
# step 35000-35099, precision 0.489417, recall 0.625182, f_score 0.549031
# === total 35100 match 9638
# >>> step 35200
# step 35100-35199, precision 0.489842, recall 0.624967, f_score 0.549216
# === total 35200 match 9648
# >>> step 35300
# step 35200-35299, precision 0.490003, recall 0.624258, f_score 0.549042
# === total 35300 match 9653
# >>> step 35400
# step 35300-35399, precision 0.490005, recall 0.623484, f_score 0.548744
# === total 35400 match 9655
# >>> step 35500
# step 35400-35499, precision 0.490005, recall 0.623484, f_score 0.548744
# === total 35500 match 9655
# >>> step 35600
# step 35500-35599, precision 0.490005, recall 0.623484, f_score 0.548744
# === total 35600 match 9655
# >>> step 35700
# step 35600-35699, precision 0.490005, recall 0.623484, f_score 0.548744
# === total 35700 match 9655
# >>> step 35800
# step 35700-35799, precision 0.490226, recall 0.623192, f_score 0.548770
# === total 35800 match 9669
# >>> step 35900
# step 35800-35899, precision 0.490125, recall 0.623192, f_score 0.548706
# === total 35900 match 9671
# >>> step 36000
# step 35900-35999, precision 0.490133, recall 0.621268, f_score 0.547964
# === total 36000 match 9679
# >>> step 36100
# step 36000-36099, precision 0.490091, recall 0.620329, f_score 0.547572
# === total 36100 match 9688
# >>> step 36200
# step 36100-36199, precision 0.490196, recall 0.619135, f_score 0.547172
# === total 36200 match 9690
# >>> step 36300
# step 36200-36299, precision 0.490145, recall 0.617685, f_score 0.546574
# === total 36300 match 9691
# >>> step 36400
# step 36300-36399, precision 0.490097, recall 0.617093, f_score 0.546312
# === total 36400 match 9694
# >>> step 36500
# step 36400-36499, precision 0.490046, recall 0.617093, f_score 0.546280
# === total 36500 match 9695
# >>> step 36600
# step 36500-36599, precision 0.490313, recall 0.615444, f_score 0.545799
# === total 36600 match 9704
# >>> step 36700
# step 36600-36699, precision 0.490317, recall 0.613956, f_score 0.545215
# === total 36700 match 9708
# >>> step 36800
# step 36700-36799, precision 0.490267, recall 0.613956, f_score 0.545184
# === total 36800 match 9709
# >>> step 36900
# step 36800-36899, precision 0.490267, recall 0.613956, f_score 0.545184
# === total 36900 match 9709
# >>> step 37000
# step 36900-36999, precision 0.490065, recall 0.612140, f_score 0.544342
# === total 37000 match 9713
# >>> step 37100
# step 37000-37099, precision 0.489914, recall 0.609553, f_score 0.543224
# === total 37100 match 9716
# >>> step 37200
# step 37100-37199, precision 0.489813, recall 0.606911, f_score 0.542110
# === total 37200 match 9718
# >>> step 37300
# step 37200-37299, precision 0.489712, recall 0.604291, f_score 0.541001
# === total 37300 match 9720
# >>> step 37400
# step 37300-37399, precision 0.489928, recall 0.603800, f_score 0.540936
# === total 37400 match 9730
# >>> step 37500
# step 37400-37499, precision 0.489679, recall 0.601337, f_score 0.539794
# === total 37500 match 9737
# >>> step 37600
# step 37500-37599, precision 0.489679, recall 0.601337, f_score 0.539794
# === total 37600 match 9737
# >>> step 37700
# step 37600-37699, precision 0.489679, recall 0.601337, f_score 0.539794
# === total 37700 match 9737
# >>> step 37800
# step 37700-37799, precision 0.489528, recall 0.601337, f_score 0.539702
# === total 37800 match 9740
# >>> step 37900
# step 37800-37899, precision 0.489096, recall 0.601789, f_score 0.539622
# === total 37900 match 9767
# >>> step 38000
# step 37900-37999, precision 0.489879, recall 0.602540, f_score 0.540400
# === total 38000 match 9782
# >>> step 38100
# step 38000-38099, precision 0.488550, recall 0.602712, f_score 0.539659
# === total 38100 match 9825
# >>> step 38200
# step 38100-38199, precision 0.488505, recall 0.602283, f_score 0.539460
# === total 38200 match 9830
# >>> step 38300
# step 38200-38299, precision 0.488417, recall 0.602230, f_score 0.539385
# === total 38300 match 9842
# >>> step 38400
# step 38300-38399, precision 0.487546, recall 0.602553, f_score 0.538982
# === total 38400 match 9876
# >>> step 38500
# step 38400-38499, precision 0.487337, recall 0.603072, f_score 0.539062
# === total 38500 match 9911
# >>> step 38600
# step 38500-38599, precision 0.486478, recall 0.603517, f_score 0.538714
# === total 38600 match 9947
# >>> step 38700
# step 38600-38699, precision 0.486478, recall 0.603517, f_score 0.538714
# === total 38700 match 9947
# >>> step 38800
# step 38700-38799, precision 0.486568, recall 0.604257, f_score 0.539064
# === total 38800 match 9976
# >>> step 38900
# step 38800-38899, precision 0.486303, recall 0.604674, f_score 0.539067
# === total 38900 match 10002
# >>> step 39000
# step 38900-38999, precision 0.486917, recall 0.605843, f_score 0.539908
# === total 39000 match 10051
# >>> step 39100
# step 39000-39099, precision 0.486821, recall 0.606693, f_score 0.540187
# === total 39100 match 10092
# >>> step 39200
# step 39100-39199, precision 0.486259, recall 0.606984, f_score 0.539956
# === total 39200 match 10116
# >>> step 39300
# step 39200-39299, precision 0.486211, recall 0.606984, f_score 0.539926
# === total 39300 match 10117
# >>> step 39400
# step 39300-39399, precision 0.485779, recall 0.606984, f_score 0.539660
# === total 39400 match 10126
# >>> step 39500
# step 39400-39499, precision 0.486128, recall 0.608048, f_score 0.540295
# === total 39500 match 10164
# >>> step 39600
# step 39500-39599, precision 0.485602, recall 0.608048, f_score 0.539970
# === total 39600 match 10175
# >>> step 39700
# step 39600-39699, precision 0.486423, recall 0.609920, f_score 0.541216
# === total 39700 match 10238
# >>> step 39800
# step 39700-39799, precision 0.486692, recall 0.609747, f_score 0.541314
# === total 39800 match 10257
# >>> step 39900
# ...
# >>> step 77700
# step 77600-77699, precision 0.465242, recall 0.626737, f_score 0.534048
# === total 77700 match 20456
# >>> step 77800
# step 77700-77799, precision 0.465182, recall 0.626958, f_score 0.534088
# === total 77800 match 20478
# >>> step 77900
# step 77800-77899, precision 0.465159, recall 0.626958, f_score 0.534073
# === total 77900 match 20479
# >>> step 78000
# step 77900-77999, precision 0.465308, recall 0.627334, f_score 0.534308
# === total 78000 match 20509
# >>> step 78100
# step 78000-78099, precision 0.465458, recall 0.627315, f_score 0.534400
# === total 78100 match 20526
# >>> step 78200
# step 78100-78199, precision 0.465664, recall 0.627657, f_score 0.534660
# === total 78200 match 20547
# >>> step 78300
# step 78200-78299, precision 0.465588, recall 0.628096, f_score 0.534769
# === total 78300 match 20589
# >>> step 78400
# step 78300-78399, precision 0.465696, recall 0.627683, f_score 0.534690
# === total 78400 match 20595
# >>> step 78500
# step 78400-78499, precision 0.466026, recall 0.628121, f_score 0.535067
# === total 78500 match 20619
# >>> step 78600
# step 78500-78599, precision 0.466004, recall 0.628121, f_score 0.535052
# === total 78600 match 20620
# >>> step 78700
# step 78600-78699, precision 0.465959, recall 0.627752, f_score 0.534888
# === total 78700 match 20622
# >>> step 78800
# step 78700-78799, precision 0.466192, recall 0.627602, f_score 0.534987
# === total 78800 match 20631
# >>> step 78900
# step 78800-78899, precision 0.466412, recall 0.627811, f_score 0.535208
# === total 78900 match 20647
# >>> step 79000
# step 78900-78999, precision 0.466412, recall 0.627811, f_score 0.535208
# === total 79000 match 20647
# >>> step 79100
# step 79000-79099, precision 0.466428, recall 0.627401, f_score 0.535070
# === total 79100 match 20657
# >>> step 79200
# step 79100-79199, precision 0.466351, recall 0.626927, f_score 0.534846
# === total 79200 match 20669
# >>> step 79300
# step 79200-79299, precision 0.466193, recall 0.625828, f_score 0.534342
# === total 79300 match 20676
# >>> step 79400
# step 79300-79399, precision 0.466257, recall 0.625203, f_score 0.534157
# === total 79400 match 20686
# >>> step 79500
# step 79400-79499, precision 0.466167, recall 0.624879, f_score 0.533979
# === total 79500 match 20690
# >>> step 79600
# step 79500-79599, precision 0.466206, recall 0.624474, f_score 0.533857
# === total 79600 match 20699
# >>> step 79700
# step 79600-79699, precision 0.465958, recall 0.623748, f_score 0.533429
# === total 79700 match 20710
# >>> step 79800
# step 79700-79799, precision 0.465824, recall 0.623023, f_score 0.533076
# === total 79800 match 20716
# >>> step 79900
# step 79800-79899, precision 0.465759, recall 0.622364, f_score 0.532792
# === total 79900 match 20721
# >>> step 80000
# step 79900-79999, precision 0.465512, recall 0.621562, f_score 0.532337
# === total 80000 match 20732
# >>> step 80100
# step 80000-80099, precision 0.465565, recall 0.621262, f_score 0.532261
# === total 80100 match 20749
# >>> step 80200
# step 80100-80199, precision 0.465408, recall 0.620543, f_score 0.531894
# === total 80200 match 20756
# >>> step 80300
# step 80200-80299, precision 0.465296, recall 0.620304, f_score 0.531733
# === total 80300 match 20761
# >>> step 80400
# step 80300-80399, precision 0.465161, recall 0.620065, f_score 0.531558
# === total 80400 match 20767
# >>> step 80500
# step 80400-80499, precision 0.465139, recall 0.620065, f_score 0.531543
# === total 80500 match 20768
# >>> step 80600
# step 80500-80599, precision 0.465116, recall 0.620065, f_score 0.531529
# === total 80600 match 20769
# >>> step 80700
# step 80600-80699, precision 0.464928, recall 0.619964, f_score 0.531369
# === total 80700 match 20786
# >>> step 80800
# step 80700-80799, precision 0.464825, recall 0.620144, f_score 0.531367
# === total 80800 match 20810
# >>> step 80900
# step 80800-80899, precision 0.464601, recall 0.620064, f_score 0.531192
# === total 80900 match 20820
# >>> step 81000
# step 80900-80999, precision 0.464320, recall 0.620005, f_score 0.530986
# === total 81000 match 20852
# >>> step 81100
# step 81000-81099, precision 0.464053, recall 0.619886, f_score 0.530768
# === total 81100 match 20864
# >>> step 81200
# step 81100-81199, precision 0.463679, recall 0.619712, f_score 0.530459
# === total 81200 match 20883
# >>> step 81300
# step 81200-81299, precision 0.463245, recall 0.619508, f_score 0.530101
# === total 81300 match 20909
# >>> step 81400
# step 81300-81399, precision 0.462891, recall 0.619508, f_score 0.529869
# === total 81400 match 20925
# >>> step 81500
# step 81400-81499, precision 0.462825, recall 0.619508, f_score 0.529825
# === total 81500 match 20928
# >>> step 81600
# step 81500-81599, precision 0.462648, recall 0.619508, f_score 0.529709
# === total 81600 match 20936
# >>> step 81700
# step 81600-81699, precision 0.462626, recall 0.619508, f_score 0.529695
# === total 81700 match 20937
# >>> step 81800
# step 81700-81799, precision 0.462690, recall 0.619787, f_score 0.529839
# === total 81800 match 20973
# >>> step 81900
# step 81800-81899, precision 0.463172, recall 0.620210, f_score 0.530310
# === total 81900 match 21003
# >>> step 82000
# step 81900-81999, precision 0.463209, recall 0.620582, f_score 0.530470
# === total 82000 match 21038
# >>> step 82100
# step 82000-82099, precision 0.463302, recall 0.620920, f_score 0.530654
# === total 82100 match 21064
# >>> step 82200
# step 82100-82199, precision 0.463493, recall 0.621132, f_score 0.530857
# === total 82200 match 21092
# >>> step 82300
# step 82200-82299, precision 0.463405, recall 0.621132, f_score 0.530800
# === total 82300 match 21096
# >>> step 82400
# step 82300-82399, precision 0.463261, recall 0.621349, f_score 0.530784
# === total 82400 match 21122
# >>> step 82500
# step 82400-82499, precision 0.463394, recall 0.621464, f_score 0.530913
# === total 82500 match 21144
# >>> step 82600
# step 82500-82599, precision 0.463386, recall 0.621481, f_score 0.530914
# === total 82600 match 21153
# >>> step 82700
# step 82600-82699, precision 0.463320, recall 0.621481, f_score 0.530871
# === total 82700 match 21156
# >>> step 82800
# step 82700-82799, precision 0.463276, recall 0.621481, f_score 0.530842
# === total 82800 match 21158
# >>> step 82900
# step 82800-82899, precision 0.462817, recall 0.621481, f_score 0.530540
# === total 82900 match 21179
# >>> step 83000
# step 82900-82999, precision 0.463063, recall 0.621659, f_score 0.530767
# === total 83000 match 21198
# >>> step 83100
# step 83000-83099, precision 0.463071, recall 0.621546, f_score 0.530731
# === total 83100 match 21230
# >>> step 83200
# step 83100-83199, precision 0.463253, recall 0.621970, f_score 0.531005
# === total 83200 match 21267
# >>> step 83300
# step 83200-83299, precision 0.462992, recall 0.621970, f_score 0.530833
# === total 83300 match 21279
# >>> step 83400
# step 83300-83399, precision 0.463030, recall 0.621252, f_score 0.530597
# === total 83400 match 21301
# >>> step 83500
# step 83400-83499, precision 0.462943, recall 0.621252, f_score 0.530540
# === total 83500 match 21305
# >>> step 83600
# step 83500-83599, precision 0.462682, recall 0.620900, f_score 0.530240
# === total 83600 match 21317
# >>> step 83700
# step 83600-83699, precision 0.462570, recall 0.620512, f_score 0.530025
# === total 83700 match 21333
# >>> step 83800
# step 83700-83799, precision 0.462028, recall 0.620655, f_score 0.529721
# === total 83800 match 21371
# >>> step 83900
# step 83800-83899, precision 0.461920, recall 0.620655, f_score 0.529650
# === total 83900 match 21376
# >>> step 84000
# step 83900-83999, precision 0.461553, recall 0.620655, f_score 0.529409
# === total 84000 match 21393
# >>> step 84100
# step 84000-84099, precision 0.461194, recall 0.621131, f_score 0.529346
# === total 84100 match 21453
# >>> step 84200
# step 84100-84199, precision 0.461206, recall 0.621591, f_score 0.529520
# === total 84200 match 21498
# >>> step 84300
# step 84200-84299, precision 0.461099, recall 0.622018, f_score 0.529605
# === total 84300 match 21542
# >>> step 84400
# step 84300-84399, precision 0.460951, recall 0.622443, f_score 0.529661
# === total 84400 match 21588
# >>> step 84500
# step 84400-84499, precision 0.460685, recall 0.622656, f_score 0.529562
# === total 84500 match 21620
# >>> step 84600
# step 84500-84599, precision 0.461023, recall 0.623017, f_score 0.529916
# === total 84600 match 21641
# >>> step 84700
# step 84600-84699, precision 0.460619, recall 0.623159, f_score 0.529700
# === total 84700 match 21673
# >>> step 84800
# step 84700-84799, precision 0.460534, recall 0.623159, f_score 0.529644
# === total 84800 match 21677
# >>> step 84900
# step 84800-84899, precision 0.460428, recall 0.623159, f_score 0.529574
# === total 84900 match 21682
# >>> step 85000
# step 84900-84999, precision 0.460114, recall 0.623245, f_score 0.529398
# === total 85000 match 21712
# >>> step 85100
# step 85000-85099, precision 0.460123, recall 0.623030, f_score 0.529326
# === total 85100 match 21742
# >>> step 85200
# step 85100-85199, precision 0.459257, recall 0.623030, f_score 0.528753
# === total 85200 match 21783
# >>> step 85300
# step 85200-85299, precision 0.458859, recall 0.622706, f_score 0.528372
# === total 85300 match 21815
# >>> step 85400
# step 85300-85399, precision 0.458842, recall 0.623128, f_score 0.528513
# === total 85400 match 21855
# >>> step 85500
# step 85400-85499, precision 0.458347, recall 0.622556, f_score 0.527978
# === total 85500 match 21883
# >>> step 85600
# step 85500-85599, precision 0.458077, recall 0.622156, f_score 0.527655
# === total 85600 match 21909
# >>> step 85700
# step 85600-85699, precision 0.458014, recall 0.622156, f_score 0.527613
# === total 85700 match 21912
# >>> step 85800
# step 85700-85799, precision 0.457993, recall 0.622156, f_score 0.527600
# === total 85800 match 21913
# >>> step 85900
# step 85800-85899, precision 0.457596, recall 0.622156, f_score 0.527336
# === total 85900 match 21932
# >>> step 86000
# step 85900-85999, precision 0.457648, recall 0.621958, f_score 0.527299
# === total 86000 match 21947
# >>> step 86100
# step 86000-86099, precision 0.457628, recall 0.621408, f_score 0.527088
# === total 86100 match 21972
# >>> step 86200
# step 86100-86199, precision 0.457524, recall 0.621062, f_score 0.526895
# === total 86200 match 21977
# >>> step 86300
# step 86200-86299, precision 0.457466, recall 0.621075, f_score 0.526861
# === total 86300 match 22006
# >>> step 86400
# step 86300-86399, precision 0.457597, recall 0.620855, f_score 0.526869
# === total 86400 match 22015
# >>> step 86500
# step 86400-86499, precision 0.457429, recall 0.620475, f_score 0.526621
# === total 86500 match 22034
# >>> step 86600
# step 86500-86599, precision 0.457684, recall 0.620974, f_score 0.526969
# === total 86600 match 22072
# >>> step 86700
# step 86600-86699, precision 0.457394, recall 0.620974, f_score 0.526777
# === total 86700 match 22086
# >>> step 86800
# step 86700-86799, precision 0.457104, recall 0.620974, f_score 0.526585
# === total 86800 match 22100
# >>> step 86900
# step 86800-86899, precision 0.457005, recall 0.620349, f_score 0.526294
# === total 86900 match 22107
# >>> step 87000
# step 86900-86999, precision 0.456513, recall 0.619194, f_score 0.525552
# === total 87000 match 22133
# >>> step 87100
# step 87000-87099, precision 0.456096, recall 0.619097, f_score 0.525241
# === total 87100 match 22162
# >>> step 87200
# step 87100-87199, precision 0.455733, recall 0.618163, f_score 0.524664
# === total 87200 match 22195
# >>> step 87300
# step 87200-87299, precision 0.455679, recall 0.618216, f_score 0.524647
# === total 87300 match 22224
# >>> step 87400
# step 87300-87399, precision 0.455187, recall 0.617312, f_score 0.523996
# === total 87400 match 22248
# >>> step 87500
# step 87400-87499, precision 0.454696, recall 0.617312, f_score 0.523670
# === total 87500 match 22272
# >>> step 87600
# step 87500-87599, precision 0.454227, recall 0.617312, f_score 0.523359
# === total 87600 match 22295
# >>> step 87700
# step 87600-87699, precision 0.454041, recall 0.617638, f_score 0.523352
# === total 87700 match 22335
# >>> step 87800
# step 87700-87799, precision 0.454277, recall 0.618289, f_score 0.523743
# === total 87800 match 22385
# >>> step 87900
# step 87800-87899, precision 0.454310, recall 0.618822, f_score 0.523956
# === total 87900 match 22434
# >>> step 88000
# step 87900-87999, precision 0.454141, recall 0.619238, f_score 0.523993
# === total 88000 match 22482
# >>> step 88100
# step 88000-88099, precision 0.454077, recall 0.619639, f_score 0.524094
# === total 88100 match 22527
# >>> step 88200
# step 88100-88199, precision 0.453775, recall 0.619639, f_score 0.523892
# === total 88200 match 22542
# >>> step 88300
# step 88200-88299, precision 0.453413, recall 0.619639, f_score 0.523651
# === total 88300 match 22560
# >>> step 88400
# step 88300-88399, precision 0.453809, recall 0.620208, f_score 0.524119
# === total 88400 match 22602
# >>> step 88500
# step 88400-88499, precision 0.454100, recall 0.620450, f_score 0.524399
# === total 88500 match 22636
# >>> step 88600
# step 88500-88599, precision 0.453776, recall 0.620621, f_score 0.524244
# === total 88600 match 22683
# >>> step 88700
# step 88600-88699, precision 0.453769, recall 0.621032, f_score 0.524386
# === total 88700 match 22723
# >>> step 88800
# step 88700-88799, precision 0.453627, recall 0.621202, f_score 0.524351
# === total 88800 match 22761
# >>> step 88900
# step 88800-88899, precision 0.453780, recall 0.621388, f_score 0.524519
# === total 88900 match 22793
# >>> step 89000
# step 88900-88999, precision 0.453501, recall 0.621388, f_score 0.524333
# === total 89000 match 22807
# >>> step 89100
# step 89000-89099, precision 0.453125, recall 0.621466, f_score 0.524110
# === total 89100 match 22848
# >>> step 89200
# step 89100-89199, precision 0.452961, recall 0.621874, f_score 0.524145
# === total 89200 match 22896
# >>> step 89300
# step 89200-89299, precision 0.452798, recall 0.622282, f_score 0.524181
# === total 89300 match 22944
# >>> step 89400
# step 89300-89399, precision 0.452618, recall 0.622448, f_score 0.524119
# === total 89400 match 22973
# >>> step 89500
# step 89400-89499, precision 0.452284, recall 0.622448, f_score 0.523895
# === total 89500 match 22990
# >>> step 89600
# step 89500-89599, precision 0.452325, recall 0.621633, f_score 0.523633
# === total 89600 match 23010
# >>> step 89700
# step 89600-89699, precision 0.451972, recall 0.620595, f_score 0.523028
# === total 89700 match 23028
# >>> step 89800
# step 89700-89799, precision 0.451827, recall 0.619665, f_score 0.522601
# === total 89800 match 23042
# >>> step 89900
# step 89800-89899, precision 0.451709, recall 0.618782, f_score 0.522208
# === total 89900 match 23048
# >>> step 90000
# step 89900-89999, precision 0.451494, recall 0.618782, f_score 0.522064
# === total 90000 match 23059
# >>> step 90100
# step 90000-90099, precision 0.451894, recall 0.619460, f_score 0.522573
# === total 90100 match 23105
# >>> step 90200
# step 90100-90199, precision 0.451900, recall 0.620024, f_score 0.522777
# === total 90200 match 23160
# >>> step 90300
# step 90200-90299, precision 0.452009, recall 0.620537, f_score 0.523032
# === total 90300 match 23223
# >>> step 90400
# step 90300-90399, precision 0.452080, recall 0.620846, f_score 0.523190
# === total 90400 match 23268
# >>> step 90500
# step 90400-90499, precision 0.451545, recall 0.620891, f_score 0.522848
# === total 90500 match 23300
# >>> step 90600
# step 90500-90599, precision 0.451627, recall 0.621539, f_score 0.523132
# === total 90600 match 23360
# >>> step 90700
# step 90600-90699, precision 0.451623, recall 0.622140, f_score 0.523342
# === total 90700 match 23420
# >>> step 90800
# step 90700-90799, precision 0.451141, recall 0.621482, f_score 0.522786
# === total 90800 match 23445
# >>> step 90900
# step 90800-90899, precision 0.450944, recall 0.620130, f_score 0.522175
# === total 90900 match 23473
# >>> step 91000
# step 90900-90999, precision 0.451306, recall 0.620077, f_score 0.522398
# === total 91000 match 23514
# >>> step 91100
# step 91000-91099, precision 0.451491, recall 0.620201, f_score 0.522566
# === total 91100 match 23542
# >>> step 91200
# step 91100-91199, precision 0.452161, recall 0.621129, f_score 0.523345
# === total 91200 match 23600
# >>> step 91300
# step 91200-91299, precision 0.453105, recall 0.622316, f_score 0.524399
# === total 91300 match 23670
# >>> step 91400
# step 91300-91399, precision 0.453449, recall 0.622842, f_score 0.524815
# === total 91400 match 23705
# TOTAL 91400, precision 0.453449, recall 0.622842, f_score 0.524815
# TOTAL true = 17258
# TOTAL error rate = 0.212965

# %%
##############2_3_val_1
=== total 91300 match 12738 /// 1,5 => 1,5
TOTAL 91300, precision 0.475899, recall 0.349899, f_score 0.403286
TOTAL true = 17325
TOTAL error rate = 0.196484
=== total 91900 match 12457 /// 1,7 => 1,5
TOTAL 91900, precision 0.511760, recall 0.364765, f_score 0.425937
TOTAL true = 17477
TOTAL error rate = 0.186986
=== total 91000 match 20063 /// 2,7 => 1,5
TOTAL 91000, precision 0.516672, recall 0.600266, f_score 0.555341
TOTAL true = 17269
TOTAL error rate = 0.182418
=== total 91100 match 19002 /// 3,7 => 1,5
TOTAL 91100, precision 0.501474, recall 0.552022, f_score 0.525535
TOTAL true = 17262
TOTAL error rate = 0.188869
=== total 90800 match 15016 /// 4,7 => 1,5
TOTAL 90800, precision 0.472030, recall 0.416280, f_score 0.442406
TOTAL true = 17027
TOTAL error rate = 0.196773
=== total 91400 match 23705 /// 2,7 => 1,5
TOTAL 91400, precision 0.453449, recall 0.622842, f_score 0.524815
TOTAL true = 17258
TOTAL error rate = 0.212965

# %%
#############1_2_val_3
=== total 536900 match 120543 ## previously - not sure which params
TOTAL 536900, precision 0.348216, recall 0.684915, f_score 0.461700
TOTAL true = 61285
TOTAL error rate = 0.182302
=== total 538600 match 208051 /// 2,7 => 1,5
TOTAL 538600, precision 0.279508, recall 0.944471, f_score 0.431359
TOTAL true = 61571
TOTAL error rate = 0.284660

# %%
#############1_3_val_2
=== total 329000 match 111791 /// 2,7 => 1,5
TOTAL 329000, precision 0.344285, recall 0.757131, f_score 0.473334
TOTAL true = 50834
TOTAL error rate = 0.260331

# %%
#TRAIN 3
cubes_set = pre_process_training("PX303-Fg006-V-C02-R02-D08032015-T115622-ML638__006.jpg", 0, 6200, 0, 4400, max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
    NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 2, 7)
tf.reset_default_graph()
model_tf_deep(250)    
train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model2.ckpt", ROOT_FOLDER + "models/tear_model1.ckpt")
# Out:
# #####################################################################
# PRE_PROCESS:PX303-Fg006-V-C02-R02-D08032015-T115622-ML638__006.jpg
# #####################################################################
# PRE_PROCESS:::TEAR_3X2
# /home/ilan/venv35/lib/python3.5/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# PRE_PROCESS:::TEAR_3X3
# PRE_PROCESS:::TEAR_4X2
# PRE_PROCESS:::TEAR_4X3
# PRE_PROCESS:::TEAR_5X2
# PRE_PROCESS:::TEAR_5X3
# PRE_PROCESS:::TEAR_6X2
# PRE_PROCESS:::TEAR_6X3
# PRE_PROCESS:::TEAR_7X2
# PRE_PROCESS:::TEAR_7X3
# *** CUBES=100
#  MATCHED=1321
#  NOT MATCHED=6128
#  DISCARDED=24507
#  SKIPPED=697752
# *** CUBES=200
#  MATCHED=2998
#  NOT MATCHED=10874
#  DISCARDED=43395
#  SKIPPED=1409848
# *** CUBES=300
#  MATCHED=5196
#  NOT MATCHED=14054
#  DISCARDED=55922
#  SKIPPED=2129848
# *** CUBES=400
#  MATCHED=5250
#  NOT MATCHED=14182
#  DISCARDED=56424
#  SKIPPED=2865016
# *** CUBES=500
#  MATCHED=5666
#  NOT MATCHED=16686
#  DISCARDED=65452
#  SKIPPED=3589264
# *** CUBES=600
#  MATCHED=7717
#  NOT MATCHED=23267
#  DISCARDED=89176
#  SKIPPED=4294664
# *** CUBES=700
#  MATCHED=9328
#  NOT MATCHED=26453
#  DISCARDED=101117
#  SKIPPED=5015264
# *** CUBES=800
#  MATCHED=10415
#  NOT MATCHED=28107
#  DISCARDED=107318
#  SKIPPED=5743160
# *** CUBES=900
#  MATCHED=10415
#  NOT MATCHED=28107
#  DISCARDED=107318
#  SKIPPED=6478960
# *** CUBES=1000
#  MATCHED=11613
#  NOT MATCHED=37024
#  DISCARDED=142411
#  SKIPPED=7170696
# *** CUBES=1100
#  MATCHED=13287
#  NOT MATCHED=44481
#  DISCARDED=171933
#  SKIPPED=7869446
# *** CUBES=1200
#  MATCHED=15126
#  NOT MATCHED=50397
#  DISCARDED=195479
#  SKIPPED=8575705
# *** CUBES=1300
#  MATCHED=16706
#  NOT MATCHED=53583
#  DISCARDED=208027
#  SKIPPED=9295705
# *** CUBES=1400
#  MATCHED=17812
#  NOT MATCHED=54918
#  DISCARDED=213281
#  SKIPPED=10024869
# *** CUBES=1500
#  MATCHED=17812
#  NOT MATCHED=54918
#  DISCARDED=213281
#  SKIPPED=10760669
# *** CUBES=1600
#  MATCHED=19290
#  NOT MATCHED=64204
#  DISCARDED=248119
#  SKIPPED=11452269
# *** CUBES=1700
#  MATCHED=20636
#  NOT MATCHED=71342
#  DISCARDED=274755
#  SKIPPED=12154229
# *** CUBES=1800
#  MATCHED=22336
#  NOT MATCHED=76638
#  DISCARDED=294479
#  SKIPPED=12864929
# *** CUBES=1900
#  MATCHED=24337
#  NOT MATCHED=79820
#  DISCARDED=306406
#  SKIPPED=13585529
# *** CUBES=2000
#  MATCHED=24703
#  NOT MATCHED=80328
#  DISCARDED=308314
#  SKIPPED=14318897
# *** CUBES=2100
#  MATCHED=24973
#  NOT MATCHED=84135
#  DISCARDED=323854
#  SKIPPED=15035337
# *** CUBES=2200
#  MATCHED=26622
#  NOT MATCHED=96019
#  DISCARDED=372396
#  SKIPPED=15710637
# *** CUBES=2300
#  MATCHED=28065
#  NOT MATCHED=105417
#  DISCARDED=410356
#  SKIPPED=16399020
# *** CUBES=2400
#  MATCHED=29803
#  NOT MATCHED=113326
#  DISCARDED=442168
#  SKIPPED=17095026
# *** CUBES=2500
#  MATCHED=31758
#  NOT MATCHED=119610
#  DISCARDED=467302
#  SKIPPED=17799326
# *** CUBES=2600
#  MATCHED=33197
#  NOT MATCHED=122832
#  DISCARDED=479976
#  SKIPPED=18519169
# *** CUBES=2700
#  MATCHED=34593
#  NOT MATCHED=124674
#  DISCARDED=487240
#  SKIPPED=19245805
# *** CUBES=2800
#  MATCHED=34593
#  NOT MATCHED=124674
#  DISCARDED=487240
#  SKIPPED=19981605
# *** CUBES=2900
#  MATCHED=35552
#  NOT MATCHED=134744
#  DISCARDED=526089
#  SKIPPED=20668433
# *** CUBES=3000
#  MATCHED=37124
#  NOT MATCHED=145302
#  DISCARDED=566670
#  SKIPPED=21353022
# *** CUBES=3100
#  MATCHED=38905
#  NOT MATCHED=154150
#  DISCARDED=600455
#  SKIPPED=22046102
# *** CUBES=3200
#  MATCHED=40913
#  NOT MATCHED=160533
#  DISCARDED=624380
#  SKIPPED=22751502
# *** CUBES=3300
#  MATCHED=42533
#  NOT MATCHED=164614
#  DISCARDED=639681
#  SKIPPED=23467846
# *** CUBES=3400
#  MATCHED=44165
#  NOT MATCHED=167158
#  DISCARDED=649223
#  SKIPPED=24191486
# *** CUBES=3500
#  MATCHED=44165
#  NOT MATCHED=167158
#  DISCARDED=649223
#  SKIPPED=24927286
# *** CUBES=3600
#  MATCHED=44980
#  NOT MATCHED=177758
#  DISCARDED=691220
#  SKIPPED=25610454
# *** CUBES=3700
#  MATCHED=46790
#  NOT MATCHED=192565
#  DISCARDED=749862
#  SKIPPED=26272728
# *** CUBES=3800
#  MATCHED=48016
#  NOT MATCHED=205153
#  DISCARDED=799722
#  SKIPPED=26946028
# *** CUBES=3900
#  MATCHED=49162
#  NOT MATCHED=215433
#  DISCARDED=840266
#  SKIPPED=27630955
# *** CUBES=4000
#  MATCHED=50981
#  NOT MATCHED=224188
#  DISCARDED=874727
#  SKIPPED=28323463
# *** CUBES=4100
#  MATCHED=52805
#  NOT MATCHED=230572
#  DISCARDED=899867
#  SKIPPED=29027663
# *** CUBES=4200
#  MATCHED=54346
#  NOT MATCHED=234781
#  DISCARDED=916448
#  SKIPPED=29742607
# *** CUBES=4300
#  MATCHED=56339
#  NOT MATCHED=237645
#  DISCARDED=927721
#  SKIPPED=30464187
# *** CUBES=4400
#  MATCHED=56339
#  NOT MATCHED=237645
#  DISCARDED=927721
#  SKIPPED=31199987
# *** CUBES=4500
#  MATCHED=56884
#  NOT MATCHED=245544
#  DISCARDED=957861
#  SKIPPED=31897723
# *** CUBES=4600
#  MATCHED=58633
#  NOT MATCHED=260037
#  DISCARDED=1013235
#  SKIPPED=32563566
# *** CUBES=4700
#  MATCHED=60395
#  NOT MATCHED=272220
#  DISCARDED=1060067
#  SKIPPED=33240266
# *** CUBES=4800
#  MATCHED=61735
#  NOT MATCHED=282109
#  DISCARDED=1097814
#  SKIPPED=33928364
# *** CUBES=4900
#  MATCHED=63333
#  NOT MATCHED=290118
#  DISCARDED=1128479
#  SKIPPED=34625414
# *** CUBES=5000
#  MATCHED=65395
#  NOT MATCHED=296300
#  DISCARDED=1152403
#  SKIPPED=35331014
# *** CUBES=5100
#  MATCHED=67022
#  NOT MATCHED=299509
#  DISCARDED=1165183
#  SKIPPED=36050750
# *** CUBES=5200
#  MATCHED=68313
#  NOT MATCHED=301268
#  DISCARDED=1172217
#  SKIPPED=36777700
# *** CUBES=5300
#  MATCHED=68313
#  NOT MATCHED=301268
#  DISCARDED=1172217
#  SKIPPED=37513500
# *** CUBES=5400
#  MATCHED=69548
#  NOT MATCHED=318093
#  DISCARDED=1238514
#  SKIPPED=38166126
# *** CUBES=5500
#  MATCHED=71184
#  NOT MATCHED=335207
#  DISCARDED=1305918
#  SKIPPED=38817337
# *** CUBES=5600
#  MATCHED=73103
#  NOT MATCHED=350581
#  DISCARDED=1366402
#  SKIPPED=39477197
# *** CUBES=5700
#  MATCHED=74545
#  NOT MATCHED=363170
#  DISCARDED=1415653
#  SKIPPED=40151097
# *** CUBES=5800
#  MATCHED=76101
#  NOT MATCHED=374136
#  DISCARDED=1458584
#  SKIPPED=40832935
# *** CUBES=5900
#  MATCHED=78215
#  NOT MATCHED=383493
#  DISCARDED=1495232
#  SKIPPED=41522641
# *** CUBES=6000
#  MATCHED=79646
#  NOT MATCHED=389882
#  DISCARDED=1520183
#  SKIPPED=42227041
# *** CUBES=6100
#  MATCHED=81409
#  NOT MATCHED=394697
#  DISCARDED=1538951
#  SKIPPED=42939183
# *** CUBES=6200
#  MATCHED=83384
#  NOT MATCHED=397878
#  DISCARDED=1551285
#  SKIPPED=43659383
# *** CUBES=6300
#  MATCHED=83600
#  NOT MATCHED=398165
#  DISCARDED=1552394
#  SKIPPED=44393779
# *** CUBES=6400
#  MATCHED=83982
#  NOT MATCHED=404427
#  DISCARDED=1576389
#  SKIPPED=45099304
# *** CUBES=6500
#  MATCHED=85648
#  NOT MATCHED=422154
#  DISCARDED=1644291
#  SKIPPED=45749390
# *** CUBES=6600
#  MATCHED=87115
#  NOT MATCHED=437440
#  DISCARDED=1702329
#  SKIPPED=46411790
# *** CUBES=6700
#  MATCHED=88442
#  NOT MATCHED=450403
#  DISCARDED=1751601
#  SKIPPED=47085290
# *** CUBES=6800
#  MATCHED=90065
#  NOT MATCHED=461832
#  DISCARDED=1794916
#  SKIPPED=47766270
# *** CUBES=6900
#  MATCHED=92142
#  NOT MATCHED=471211
#  DISCARDED=1830041
#  SKIPPED=48457470
# *** CUBES=7000
#  MATCHED=93755
#  NOT MATCHED=477813
#  DISCARDED=1854915
#  SKIPPED=49161720
# *** CUBES=7100
#  MATCHED=95408
#  NOT MATCHED=482887
#  DISCARDED=1873813
#  SKIPPED=49873470
# *** CUBES=7200
#  MATCHED=97355
#  NOT MATCHED=486068
#  DISCARDED=1885142
#  SKIPPED=50594670
# *** CUBES=7300
#  MATCHED=97646
#  NOT MATCHED=486482
#  DISCARDED=1886614
#  SKIPPED=51328572
# *** MATCHED=97646
# *** NOT MATCHED=486482
# *** DISCARDED=1886614
# *** SKIPPED=51762694
# #####################################################################
# TRAINING:
# MODEL:/media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# #####################################################################
# INFO:tensorflow:Restoring parameters from /media/1KGB_ILAN/papyrus/models/tear_model1.ckpt
# /home/ilan/venv35/lib/python3.5/site-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Model restored.
# step 49, training accuracy 0.78
# step 99, training accuracy 0.80
# step 149, training accuracy 0.80
# step 199, training accuracy 0.78
# step 249, training accuracy 0.82
# step 299, training accuracy 0.88
# step 349, training accuracy 0.85
# step 399, training accuracy 0.88
# step 449, training accuracy 0.85
# step 499, training accuracy 0.88
# step 549, training accuracy 0.87
# step 599, training accuracy 0.87
# step 649, training accuracy 0.85
# step 699, training accuracy 0.87
# step 749, training accuracy 0.82
# step 799, training accuracy 0.90
# step 849, training accuracy 0.82
# step 899, training accuracy 0.88
# step 949, training accuracy 0.87
# step 999, training accuracy 0.85
# step 1049, training accuracy 0.93
# step 1099, training accuracy 0.88
# step 1149, training accuracy 0.92
# step 1199, training accuracy 0.92
# step 1249, training accuracy 0.93
# step 1299, training accuracy 0.92
# step 1349, training accuracy 0.95
# step 1399, training accuracy 0.88
# step 1449, training accuracy 0.95
# step 1499, training accuracy 0.93
# step 1549, training accuracy 0.88
# step 1599, training accuracy 0.97
# step 1649, training accuracy 0.93
# step 1699, training accuracy 0.83
# step 1749, training accuracy 0.87
# step 1799, training accuracy 0.92
# step 1849, training accuracy 0.87
# step 1899, training accuracy 0.95
# step 1949, training accuracy 0.92
# step 1999, training accuracy 0.90
# Optimization Finished!
# step 1999, training accuracy 0.9
# Model saved in file: /media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# #####################################################################
# TRAINING ENDED
# #####################################################################

# %%
# validate 2
cubes_set = pre_process_training("PX303-Fg004-V-C01-R01-D08032015-T110817-ML638__006.jpg", max_cols=8, max_rows=4)
train_imgs, train_lbls, train_x_delta, train_y_delta, is_enriched = \
  NEW_build_train_set_for_binary_labeling(cubes_set, cubes_set, CUBE_SIZE, ROOT_FOLDER + "train_concats3/", 1, 5)
tf.reset_default_graph()
model_tf_deep(250, 1)    
validate2_for_cross_validation(train_imgs, train_lbls, is_enriched, ROOT_FOLDER + "models/tear_model2.ckpt")
# Out:
# #####################################################################
# PRE_PROCESS:PX303-Fg004-V-C01-R01-D08032015-T110817-ML638__006.jpg
# #####################################################################
# PRE_PROCESS:::TEAR_3X2
# /home/ilan/venv35/lib/python3.5/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# PRE_PROCESS:::TEAR_3X3
# PRE_PROCESS:::TEAR_4X2
# PRE_PROCESS:::TEAR_4X3
# PRE_PROCESS:::TEAR_5X2
# PRE_PROCESS:::TEAR_5X3
# PRE_PROCESS:::TEAR_6X2
# PRE_PROCESS:::TEAR_6X3
# PRE_PROCESS:::TEAR_7X2
# PRE_PROCESS:::TEAR_7X3
# /home/ilan/venv35/lib/python3.5/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ilan/venv35/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# *** CUBES=100
#  MATCHED=743
#  NOT MATCHED=5038
#  DISCARDED=17962
#  SKIPPED=522027
# *** CUBES=200
#  MATCHED=2247
#  NOT MATCHED=7882
#  DISCARDED=27991
#  SKIPPED=1059650
# *** CUBES=300
#  MATCHED=2505
#  NOT MATCHED=8367
#  DISCARDED=29684
#  SKIPPED=1608054
# *** CUBES=400
#  MATCHED=3016
#  NOT MATCHED=11059
#  DISCARDED=40149
#  SKIPPED=2145454
# *** CUBES=500
#  MATCHED=3920
#  NOT MATCHED=14312
#  DISCARDED=52768
#  SKIPPED=2680102
# *** CUBES=600
#  MATCHED=4707
#  NOT MATCHED=15495
#  DISCARDED=57350
#  SKIPPED=3224878
# *** CUBES=700
#  MATCHED=5005
#  NOT MATCHED=18010
#  DISCARDED=66689
#  SKIPPED=3763598
# *** CUBES=800
#  MATCHED=6110
#  NOT MATCHED=24698
#  DISCARDED=91604
#  SKIPPED=4282514
# *** CUBES=900
#  MATCHED=7312
#  NOT MATCHED=29122
#  DISCARDED=108414
#  SKIPPED=4811794
# *** CUBES=1000
#  MATCHED=8773
#  NOT MATCHED=31544
#  DISCARDED=117359
#  SKIPPED=5350926
# *** CUBES=1100
#  MATCHED=8773
#  NOT MATCHED=31544
#  DISCARDED=117359
#  SKIPPED=5901526
# *** CUBES=1200
#  MATCHED=9378
#  NOT MATCHED=37077
#  DISCARDED=137725
#  SKIPPED=6426170
# *** CUBES=1300
#  MATCHED=10413
#  NOT MATCHED=42328
#  DISCARDED=157407
#  SKIPPED=6951750
# *** CUBES=1400
#  MATCHED=11697
#  NOT MATCHED=45032
#  DISCARDED=167557
#  SKIPPED=7489396
# *** CUBES=1500
#  MATCHED=12042
#  NOT MATCHED=45625
#  DISCARDED=169789
#  SKIPPED=8037146
# *** CUBES=1600
#  MATCHED=12910
#  NOT MATCHED=51225
#  DISCARDED=191396
#  SKIPPED=8560479
# *** CUBES=1700
#  MATCHED=14029
#  NOT MATCHED=59628
#  DISCARDED=223788
#  SKIPPED=9070201
# *** CUBES=1800
#  MATCHED=15042
#  NOT MATCHED=65911
#  DISCARDED=247941
#  SKIPPED=9590288
# *** CUBES=1900
#  MATCHED=16435
#  NOT MATCHED=70008
#  DISCARDED=263799
#  SKIPPED=10120836
# *** CUBES=2000
#  MATCHED=17655
#  NOT MATCHED=72103
#  DISCARDED=272180
#  SKIPPED=10660876
# *** CUBES=2100
#  MATCHED=17655
#  NOT MATCHED=72103
#  DISCARDED=272180
#  SKIPPED=11211476
# *** CUBES=2200
#  MATCHED=18691
#  NOT MATCHED=80183
#  DISCARDED=302844
#  SKIPPED=11723252
# *** CUBES=2300
#  MATCHED=19225
#  NOT MATCHED=87585
#  DISCARDED=330504
#  SKIPPED=12238736
# *** CUBES=2400
#  MATCHED=20476
#  NOT MATCHED=92695
#  DISCARDED=349621
#  SKIPPED=12765006
# *** CUBES=2500
#  MATCHED=21742
#  NOT MATCHED=95484
#  DISCARDED=360072
#  SKIPPED=13302268
# *** CUBES=2600
#  MATCHED=22165
#  NOT MATCHED=96220
#  DISCARDED=362839
#  SKIPPED=13849334
# *** CUBES=2700
#  MATCHED=22948
#  NOT MATCHED=102589
#  DISCARDED=387160
#  SKIPPED=14369189
# *** CUBES=2800
#  MATCHED=24131
#  NOT MATCHED=113369
#  DISCARDED=428203
#  SKIPPED=14867879
# *** CUBES=2900
#  MATCHED=24960
#  NOT MATCHED=122256
#  DISCARDED=461962
#  SKIPPED=15375764
# *** CUBES=3000
#  MATCHED=26365
#  NOT MATCHED=128696
#  DISCARDED=487033
#  SKIPPED=15894756
# *** CUBES=3100
#  MATCHED=27730
#  NOT MATCHED=133144
#  DISCARDED=504640
#  SKIPPED=16423208
# *** CUBES=3200
#  MATCHED=29150
#  NOT MATCHED=135526
#  DISCARDED=514158
#  SKIPPED=16961808
# *** CUBES=3300
#  MATCHED=29218
#  NOT MATCHED=135621
#  DISCARDED=514539
#  SKIPPED=17511928
# *** CUBES=3400
#  MATCHED=30155
#  NOT MATCHED=144118
#  DISCARDED=545793
#  SKIPPED=18022704
# *** CUBES=3500
#  MATCHED=31104
#  NOT MATCHED=153875
#  DISCARDED=582035
#  SKIPPED=18527228
# *** CUBES=3600
#  MATCHED=31862
#  NOT MATCHED=161623
#  DISCARDED=611201
#  SKIPPED=19040848
# *** CUBES=3700
#  MATCHED=33138
#  NOT MATCHED=166925
#  DISCARDED=631269
#  SKIPPED=19565978
# *** CUBES=3800
#  MATCHED=34330
#  NOT MATCHED=170156
#  DISCARDED=643449
#  SKIPPED=20101071
# *** CUBES=3900
#  MATCHED=35021
#  NOT MATCHED=171298
#  DISCARDED=647728
#  SKIPPED=20646199
# *** CUBES=4000
#  MATCHED=35572
#  NOT MATCHED=176535
#  DISCARDED=667836
#  SKIPPED=21171415
# *** CUBES=4100
#  MATCHED=36826
#  NOT MATCHED=189996
#  DISCARDED=719437
#  SKIPPED=21656867
# *** CUBES=4200
#  MATCHED=37723
#  NOT MATCHED=201485
#  DISCARDED=762879
#  SKIPPED=22152467
# *** CUBES=4300
#  MATCHED=38763
#  NOT MATCHED=210918
#  DISCARDED=798986
#  SKIPPED=22657451
# *** CUBES=4400
#  MATCHED=40073
#  NOT MATCHED=218157
#  DISCARDED=826937
#  SKIPPED=23172771
# *** CUBES=4500
#  MATCHED=41425
#  NOT MATCHED=223137
#  DISCARDED=845861
#  SKIPPED=23699371
# *** CUBES=4600
#  MATCHED=42890
#  NOT MATCHED=226057
#  DISCARDED=856692
#  SKIPPED=24236119
# *** CUBES=4700
#  MATCHED=43306
#  NOT MATCHED=226881
#  DISCARDED=859744
#  SKIPPED=24782815
# *** CUBES=4800
#  MATCHED=43828
#  NOT MATCHED=233129
#  DISCARDED=882848
#  SKIPPED=25304021
# *** CUBES=4900
#  MATCHED=44698
#  NOT MATCHED=245944
#  DISCARDED=930407
#  SKIPPED=25794177
# *** CUBES=5000
#  MATCHED=45951
#  NOT MATCHED=256690
#  DISCARDED=970620
#  SKIPPED=26293717
# *** CUBES=5100
#  MATCHED=46884
#  NOT MATCHED=265215
#  DISCARDED=1002476
#  SKIPPED=26803851
# *** CUBES=5200
#  MATCHED=47959
#  NOT MATCHED=271604
#  DISCARDED=1026242
#  SKIPPED=27324213
# *** CUBES=5300
#  MATCHED=49171
#  NOT MATCHED=275928
#  DISCARDED=1042332
#  SKIPPED=27854303
# *** CUBES=5400
#  MATCHED=50834
#  NOT MATCHED=278088
#  DISCARDED=1050601
#  SKIPPED=28394347
# *** CUBES=5500
#  MATCHED=50834
#  NOT MATCHED=278088
#  DISCARDED=1050601
#  SKIPPED=28944947
# *** MATCHED=50834
# *** NOT MATCHED=278088
# *** DISCARDED=1050601
# *** SKIPPED=28983489
# 328922
# INFO:tensorflow:Restoring parameters from /media/1KGB_ILAN/papyrus/models/tear_model2.ckpt
# /home/ilan/venv35/lib/python3.5/site-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Model restored.
# >>> step 100
# step 0-99, precision 0.678571, recall 0.452381, f_score 0.542857
# === total 100 match 28
# >>> step 200
# step 100-199, precision 0.462500, recall 0.616667, f_score 0.528571
# === total 200 match 80
# >>> step 300
# step 200-299, precision 0.362745, recall 0.616667, f_score 0.456790
# === total 300 match 102
# >>> step 400
# step 300-399, precision 0.291339, recall 0.616667, f_score 0.395722
# === total 400 match 127
# >>> step 500
# step 400-499, precision 0.228395, recall 0.616667, f_score 0.333333
# === total 500 match 162
# >>> step 600
# step 500-599, precision 0.300518, recall 0.666667, f_score 0.414286
# === total 600 match 193
# >>> step 700
# step 600-699, precision 0.316038, recall 0.697917, f_score 0.435065
# === total 700 match 212
# >>> step 800
# step 700-799, precision 0.273469, recall 0.697917, f_score 0.392962
# === total 800 match 245
# >>> step 900
# step 800-899, precision 0.306338, recall 0.713115, f_score 0.428571
# === total 900 match 284
# >>> step 1000
# step 900-999, precision 0.328076, recall 0.742857, f_score 0.455142
# === total 1000 match 317
# >>> step 1100
# step 1000-1099, precision 0.366477, recall 0.777108, f_score 0.498069
# === total 1100 match 352
# >>> step 1200
# step 1100-1199, precision 0.385013, recall 0.792553, f_score 0.518261
# === total 1200 match 387
# >>> step 1300
# step 1200-1299, precision 0.404358, recall 0.810680, f_score 0.539580
# === total 1300 match 413
# >>> step 1400
# step 1300-1399, precision 0.379545, recall 0.810680, f_score 0.517028
# === total 1400 match 440
# >>> step 1500
# step 1400-1499, precision 0.386752, recall 0.822727, f_score 0.526163
# === total 1500 match 468
# >>> step 1600
# step 1500-1599, precision 0.363454, recall 0.822727, f_score 0.504178
# === total 1600 match 498
# >>> step 1700
# step 1600-1699, precision 0.384473, recall 0.818898, f_score 0.523270
# === total 1700 match 541
# >>> step 1800
# step 1700-1799, precision 0.385009, recall 0.830882, f_score 0.526193
# === total 1800 match 587
# >>> step 1900
# step 1800-1899, precision 0.366883, recall 0.830882, f_score 0.509009
# === total 1900 match 616
# >>> step 2000
# step 1900-1999, precision 0.391176, recall 0.841772, f_score 0.534137
# === total 2000 match 680
# >>> step 2100
# step 2000-2099, precision 0.379944, recall 0.843260, f_score 0.523856
# === total 2100 match 708
# >>> step 2200
# step 2100-2199, precision 0.378667, recall 0.830409, f_score 0.520147
# === total 2200 match 750
# >>> step 2300
# step 2200-2299, precision 0.375959, recall 0.835227, f_score 0.518519
# === total 2300 match 782
# >>> step 2400
# step 2300-2399, precision 0.359413, recall 0.835227, f_score 0.502564
# === total 2400 match 818
# >>> step 2500
# step 2400-2499, precision 0.357311, recall 0.837017, f_score 0.500826
# === total 2500 match 848
# >>> step 2600
# step 2500-2599, precision 0.362069, recall 0.833333, f_score 0.504808
# === total 2600 match 870
# >>> step 2700
# step 2600-2699, precision 0.367503, recall 0.836228, f_score 0.510606
# === total 2700 match 917
# >>> step 2800
# step 2700-2799, precision 0.362786, recall 0.811628, f_score 0.501437
# === total 2800 match 962
# >>> step 2900
# step 2800-2899, precision 0.353239, recall 0.811628, f_score 0.492243
# === total 2900 match 988
# >>> step 3000
# step 2900-2999, precision 0.351325, recall 0.792035, f_score 0.486744
# === total 3000 match 1019
# >>> step 3100
# step 3000-3099, precision 0.358365, recall 0.783784, f_score 0.491846
# === total 3100 match 1052
# >>> step 3200
# step 3100-3199, precision 0.356227, recall 0.785859, f_score 0.490233
# === total 3200 match 1092
# >>> step 3300
# step 3200-3299, precision 0.359111, recall 0.787524, f_score 0.493284
# === total 3300 match 1125
# >>> step 3400
# step 3300-3399, precision 0.356201, recall 0.787938, f_score 0.490612
# === total 3400 match 1137
# >>> step 3500
# step 3400-3499, precision 0.348537, recall 0.787938, f_score 0.483294
# === total 3500 match 1162
# >>> step 3600
# step 3500-3599, precision 0.342061, recall 0.787938, f_score 0.477032
# === total 3600 match 1184
# >>> step 3700
# step 3600-3699, precision 0.345802, recall 0.759124, f_score 0.475157
# === total 3700 match 1203
# >>> step 3800
# step 3700-3799, precision 0.337388, recall 0.759124, f_score 0.467153
# === total 3800 match 1233
# >>> step 3900
# step 3800-3899, precision 0.325509, recall 0.759124, f_score 0.455641
# === total 3900 match 1278
# >>> step 4000
# step 3900-3999, precision 0.318355, recall 0.760000, f_score 0.448739
# === total 4000 match 1313
# >>> step 4100
# step 4000-4099, precision 0.311475, recall 0.760000, f_score 0.441860
# === total 4100 match 1342
# >>> step 4200
# step 4100-4199, precision 0.316252, recall 0.765957, f_score 0.447668
# === total 4200 match 1366
# >>> step 4300
# step 4200-4299, precision 0.311464, recall 0.765957, f_score 0.442850
# === total 4300 match 1387
# >>> step 4400
# step 4300-4399, precision 0.307912, recall 0.722408, f_score 0.431784
# === total 4400 match 1403
# >>> step 4500
# step 4400-4499, precision 0.302733, recall 0.722408, f_score 0.426667
# === total 4500 match 1427
# >>> step 4600
# step 4500-4599, precision 0.295890, recall 0.722408, f_score 0.419825
# === total 4600 match 1460
# >>> step 4700
# step 4600-4699, precision 0.289933, recall 0.722408, f_score 0.413793
# === total 4700 match 1490
# >>> step 4800
# step 4700-4799, precision 0.298371, recall 0.733974, f_score 0.424270
# === total 4800 match 1535
# >>> step 4900
# step 4800-4899, precision 0.291878, recall 0.734824, f_score 0.417802
# === total 4900 match 1576
# >>> step 5000
# step 4900-4999, precision 0.298017, recall 0.742284, f_score 0.425287
# === total 5000 match 1614
# >>> step 5100
# step 5000-5099, precision 0.291339, recall 0.742284, f_score 0.418443
# === total 5100 match 1651
# >>> step 5200
# step 5100-5199, precision 0.295775, recall 0.747774, f_score 0.423886
# === total 5200 match 1704
# >>> step 5300
# step 5200-5299, precision 0.290155, recall 0.747774, f_score 0.418084
# === total 5300 match 1737
# >>> step 5400
# step 5300-5399, precision 0.285552, recall 0.747774, f_score 0.413284
# === total 5400 match 1765
# >>> step 5500
# step 5400-5499, precision 0.293532, recall 0.754261, f_score 0.422602
# === total 5500 match 1809
# >>> step 5600
# step 5500-5599, precision 0.288587, recall 0.754261, f_score 0.417453
# === total 5600 match 1840
# >>> step 5700
# step 5600-5699, precision 0.294243, recall 0.756164, f_score 0.423638
# === total 5700 match 1876
# >>> step 5800
# step 5700-5799, precision 0.294397, recall 0.749664, f_score 0.422770
# === total 5800 match 1892
# >>> step 5900
# step 5800-5899, precision 0.288004, recall 0.749664, f_score 0.416137
# === total 5900 match 1934
# >>> step 6000
# step 5900-5999, precision 0.288101, recall 0.747700, f_score 0.415936
# === total 6000 match 1975
# >>> step 6100
# step 6000-6099, precision 0.286794, recall 0.715723, f_score 0.409500
# === total 6100 match 1984
# >>> step 6200
# step 6100-6199, precision 0.281849, recall 0.713574, f_score 0.404090
# === total 6200 match 2033
# >>> step 6300
# step 6200-6299, precision 0.294033, recall 0.713789, f_score 0.416498
# === total 6300 match 2095
# >>> step 6400
# step 6300-6399, precision 0.302607, recall 0.724638, f_score 0.426929
# === total 6400 match 2148
# >>> step 6500
# step 6400-6499, precision 0.304348, recall 0.712755, f_score 0.426555
# === total 6500 match 2185
# >>> step 6600
# step 6500-6599, precision 0.304407, recall 0.712766, f_score 0.426616
# === total 6600 match 2201
# >>> step 6700
# step 6600-6699, precision 0.311111, recall 0.717949, f_score 0.434109
# === total 6700 match 2250
# >>> step 6800
# step 6700-6799, precision 0.314060, recall 0.722782, f_score 0.437863
# === total 6800 match 2283
# >>> step 6900
# step 6800-6899, precision 0.316674, recall 0.727723, f_score 0.441309
# === total 6900 match 2321
# >>> step 7000
# step 6900-6999, precision 0.327910, recall 0.740113, f_score 0.454467
# === total 7000 match 2397
# >>> step 7100
# step 7000-7099, precision 0.334957, recall 0.743913, f_score 0.461926
# === total 7100 match 2463
# >>> step 7200
# step 7100-7199, precision 0.345426, recall 0.754522, f_score 0.473898
# === total 7200 match 2536
# >>> step 7300
# step 7200-7299, precision 0.352352, recall 0.759136, f_score 0.481306
# === total 7300 match 2594
# >>> step 7400
# step 7300-7399, precision 0.358888, recall 0.767068, f_score 0.488991
# === total 7400 match 2661
# >>> step 7500
# step 7400-7499, precision 0.359808, recall 0.769352, f_score 0.490310
# === total 7500 match 2707
# >>> step 7600
# step 7500-7599, precision 0.361733, recall 0.771339, f_score 0.492500
# === total 7600 match 2723
# >>> step 7700
# step 7600-7699, precision 0.369340, recall 0.780120, f_score 0.501331
# === total 7700 match 2805
# >>> step 7800
# step 7700-7799, precision 0.369983, recall 0.781135, f_score 0.502132
# === total 7800 match 2865
# >>> step 7900
# step 7800-7899, precision 0.373175, recall 0.786686, f_score 0.506218
# === total 7900 match 2945
# >>> step 8000
# step 7900-7999, precision 0.375374, recall 0.790470, f_score 0.509025
# === total 8000 match 3005
# >>> step 8100
# step 8000-8099, precision 0.377049, recall 0.793651, f_score 0.511225
# === total 8100 match 3050
# >>> step 8200
# step 8100-8199, precision 0.382324, recall 0.795822, f_score 0.516510
# === total 8200 match 3089
# >>> step 8300
# step 8200-8299, precision 0.384097, recall 0.798135, f_score 0.518615
# === total 8300 match 3119
# >>> step 8400
# step 8300-8399, precision 0.392329, recall 0.804124, f_score 0.527361
# === total 8400 match 3181
# >>> step 8500
# step 8400-8499, precision 0.393468, recall 0.806246, f_score 0.528846
# === total 8500 match 3215
# >>> step 8600
# step 8500-8599, precision 0.397859, recall 0.803086, f_score 0.532106
# === total 8600 match 3270
# >>> step 8700
# step 8600-8699, precision 0.398182, recall 0.802688, f_score 0.532307
# === total 8700 match 3300
# >>> step 8800
# step 8700-8799, precision 0.401666, recall 0.795522, f_score 0.533808
# === total 8800 match 3361
# >>> step 8900
# step 8800-8899, precision 0.403297, recall 0.787809, f_score 0.533489
# === total 8900 match 3397
# >>> step 9000
# step 8900-8999, precision 0.404330, recall 0.779470, f_score 0.532460
# === total 9000 match 3418
# >>> step 9100
# step 9000-9099, precision 0.403985, recall 0.781128, f_score 0.532547
# === total 9100 match 3463
# >>> step 9200
# step 9100-9199, precision 0.404249, recall 0.766467, f_score 0.529323
# === total 9200 match 3483
# >>> step 9300
# step 9200-9299, precision 0.403743, recall 0.761905, f_score 0.527798
# === total 9300 match 3527
# >>> step 9400
# step 9300-9399, precision 0.405134, recall 0.764211, f_score 0.529540
# === total 9400 match 3584
# >>> step 9500
# step 9400-9499, precision 0.406017, recall 0.753972, f_score 0.527808
# === total 9500 match 3623
# >>> step 9600
# step 9500-9599, precision 0.409177, recall 0.755010, f_score 0.530727
# === total 9600 match 3683
# >>> step 9700
# step 9600-9699, precision 0.411203, recall 0.758942, f_score 0.533402
# === total 9700 match 3767
# >>> step 9800
# step 9700-9799, precision 0.413330, recall 0.745722, f_score 0.531864
# === total 9800 match 3796
# >>> step 9900
# step 9800-9899, precision 0.414286, recall 0.745676, f_score 0.532643
# === total 9900 match 3850
# >>> step 10000
# step 9900-9999, precision 0.416859, recall 0.746673, f_score 0.535021
# === total 10000 match 3903
# >>> step 10100
# step 10000-10099, precision 0.418973, recall 0.747307, f_score 0.536924
# === total 10100 match 3974
# >>> step 10200
# step 10100-10199, precision 0.421013, recall 0.748344, f_score 0.538865
# === total 10200 match 4026
# >>> step 10300
# step 10200-10299, precision 0.424095, recall 0.753886, f_score 0.542826
# === total 10300 match 4117
# >>> step 10400
# step 10300-10399, precision 0.426104, recall 0.755423, f_score 0.544869
# === total 10400 match 4168
# >>> step 10500
# step 10400-10499, precision 0.425323, recall 0.745073, f_score 0.541521
# === total 10500 match 4178
# >>> step 10600
# step 10500-10599, precision 0.426876, recall 0.743282, f_score 0.542301
# === total 10600 match 4212
# >>> step 10700
# step 10600-10699, precision 0.428337, recall 0.746220, f_score 0.544262
# === total 10700 match 4263
# >>> step 10800
# step 10700-10799, precision 0.429067, recall 0.746083, f_score 0.544814
# === total 10800 match 4328
# >>> step 10900
# step 10800-10899, precision 0.429720, recall 0.746906, f_score 0.545561
# === total 10900 match 4354
# >>> step 11000
# step 10900-10999, precision 0.428376, recall 0.747913, f_score 0.544744
# === total 11000 match 4391
# >>> step 11100
# step 11000-11099, precision 0.426048, recall 0.747913, f_score 0.542857
# === total 11100 match 4415
# >>> step 11200
# step 11100-11199, precision 0.426418, recall 0.749308, f_score 0.543525
# === total 11200 match 4444
# >>> step 11300
# step 11200-11299, precision 0.427517, recall 0.750294, f_score 0.544677
# === total 11300 match 4470
# >>> step 11400
# step 11300-11399, precision 0.425328, recall 0.750294, f_score 0.542898
# === total 11400 match 4493
# >>> step 11500
# step 11400-11499, precision 0.424983, recall 0.752047, f_score 0.543074
# === total 11500 match 4539
# >>> step 11600
# step 11500-11599, precision 0.426413, recall 0.753775, f_score 0.544692
# === total 11600 match 4566
# >>> step 11700
# step 11600-11699, precision 0.423721, recall 0.753775, f_score 0.542491
# === total 11700 match 4595
# >>> step 11800
# step 11700-11799, precision 0.420791, recall 0.753775, f_score 0.540083
# === total 11800 match 4627
# >>> step 11900
# step 11800-11899, precision 0.422541, recall 0.755845, f_score 0.542056
# === total 11900 match 4667
# >>> step 12000
# step 11900-11999, precision 0.424139, recall 0.757495, f_score 0.543795
# === total 12000 match 4706
# >>> step 12100
# step 12000-12099, precision 0.421631, recall 0.757495, f_score 0.541729
# === total 12100 match 4734
# >>> step 12200
# step 12100-12199, precision 0.419504, recall 0.757495, f_score 0.539970
# === total 12200 match 4758
# >>> step 12300
# step 12200-12299, precision 0.417050, recall 0.757495, f_score 0.537933
# === total 12300 match 4786
# >>> step 12400
# step 12300-12399, precision 0.414100, recall 0.757564, f_score 0.535490
# === total 12400 match 4837
# >>> step 12500
# step 12400-12499, precision 0.413172, recall 0.758828, f_score 0.535028
# === total 12500 match 4889
# >>> step 12600
# step 12500-12599, precision 0.413919, recall 0.760595, f_score 0.536093
# === total 12600 match 4943
# >>> step 12700
# step 12600-12699, precision 0.413144, recall 0.762010, f_score 0.535793
# === total 12700 match 4991
# >>> step 12800
# step 12700-12799, precision 0.410704, recall 0.756204, f_score 0.532306
# === total 12800 match 5045
# >>> step 12900
# step 12800-12899, precision 0.410889, recall 0.758496, f_score 0.533028
# === total 12900 match 5106
# >>> step 13000
# step 12900-12999, precision 0.409038, recall 0.758906, f_score 0.531569
# === total 13000 match 5156
# >>> step 13100
# step 13000-13099, precision 0.408112, recall 0.760115, f_score 0.531082
# === total 13100 match 5202
# >>> step 13200
# step 13100-13199, precision 0.406304, recall 0.752388, f_score 0.527661
# === total 13200 match 5235
# >>> step 13300
# step 13200-13299, precision 0.405830, recall 0.753603, f_score 0.527559
# === total 13300 match 5283
# >>> step 13400
# step 13300-13399, precision 0.403614, recall 0.753603, f_score 0.525683
# === total 13400 match 5312
# >>> step 13500
# step 13400-13499, precision 0.400673, recall 0.753603, f_score 0.523182
# === total 13500 match 5351
# >>> step 13600
# step 13500-13599, precision 0.399144, recall 0.751577, f_score 0.521390
# === total 13600 match 5374
# >>> step 13700
# step 13600-13699, precision 0.400699, recall 0.753809, f_score 0.523254
# === total 13700 match 5433
# >>> step 13800
# step 13700-13799, precision 0.402439, recall 0.756674, f_score 0.525428
# === total 13800 match 5494
# >>> step 13900
# step 13800-13899, precision 0.404878, recall 0.758119, f_score 0.527853
# === total 13900 match 5535
# >>> step 14000
# step 13900-13999, precision 0.406613, recall 0.760870, f_score 0.529994
# === total 14000 match 5595
# >>> step 14100
# step 14000-14099, precision 0.406183, recall 0.753958, f_score 0.527945
# === total 14100 match 5628
# >>> step 14200
# step 14100-14199, precision 0.408066, recall 0.755215, f_score 0.529842
# === total 14200 match 5678
# >>> step 14300
# step 14200-14299, precision 0.406026, recall 0.753331, f_score 0.527658
# === total 14300 match 5709
# >>> step 14400
# step 14300-14399, precision 0.403692, recall 0.753331, f_score 0.525683
# === total 14400 match 5742
# >>> step 14500
# step 14400-14499, precision 0.402809, recall 0.752511, f_score 0.524735
# === total 14500 match 5767
# >>> step 14600
# step 14500-14599, precision 0.401243, recall 0.751617, f_score 0.523188
# === total 14600 match 5792
# >>> step 14700
# step 14600-14699, precision 0.399658, recall 0.752737, f_score 0.522108
# === total 14700 match 5850
# >>> step 14800
# step 14700-14799, precision 0.396137, recall 0.752737, f_score 0.519094
# === total 14800 match 5902
# >>> step 14900
# step 14800-14899, precision 0.395634, recall 0.754161, f_score 0.519000
# === total 14900 match 5955
# >>> step 15000
# step 14900-14999, precision 0.397164, recall 0.754436, f_score 0.520380
# === total 15000 match 5995
# >>> step 15100
# step 15000-15099, precision 0.394532, recall 0.754436, f_score 0.518116
# === total 15100 match 6035
# >>> step 15200
# step 15100-15199, precision 0.393034, recall 0.754436, f_score 0.516822
# === total 15200 match 6058
# >>> step 15300
# step 15200-15299, precision 0.393214, recall 0.755829, f_score 0.517305
# === total 15300 match 6101
# >>> step 15400
# step 15300-15399, precision 0.393456, recall 0.756258, f_score 0.517614
# === total 15400 match 6143
# >>> step 15500
# step 15400-15499, precision 0.391798, recall 0.756258, f_score 0.516177
# === total 15500 match 6169
# >>> step 15600
# step 15500-15599, precision 0.388398, recall 0.756258, f_score 0.513218
# === total 15600 match 6223
# >>> step 15700
# step 15600-15699, precision 0.387169, recall 0.756706, f_score 0.512247
# === total 15700 match 6266
# >>> step 15800
# step 15700-15799, precision 0.385202, recall 0.756706, f_score 0.510522
# === total 15800 match 6298
# >>> step 15900
# step 15800-15899, precision 0.386690, recall 0.758663, f_score 0.512274
# === total 15900 match 6341
# >>> step 16000
# step 15900-15999, precision 0.388287, recall 0.757427, f_score 0.513390
# === total 16000 match 6369
# >>> step 16100
# step 16000-16099, precision 0.388048, recall 0.758463, f_score 0.513419
# === total 16100 match 6409
# >>> step 16200
# step 16100-16199, precision 0.390138, recall 0.759891, f_score 0.515574
# === total 16200 match 6449
# >>> step 16300
# step 16200-16299, precision 0.387494, recall 0.759891, f_score 0.513260
# === total 16300 match 6493
# >>> step 16400
# step 16300-16399, precision 0.387996, recall 0.761190, f_score 0.513996
# === total 16400 match 6531
# >>> step 16500
# step 16400-16499, precision 0.388694, recall 0.762175, f_score 0.514834
# === total 16500 match 6563
# >>> step 16600
# step 16500-16599, precision 0.391041, recall 0.764271, f_score 0.517369
# === total 16600 match 6608
# >>> step 16700
# step 16600-16699, precision 0.392198, recall 0.765447, f_score 0.518651
# === total 16700 match 6665
# >>> step 16800
# step 16700-16799, precision 0.395007, recall 0.768208, f_score 0.521739
# === total 16800 match 6729
# >>> step 16900
# step 16800-16899, precision 0.394562, recall 0.769009, f_score 0.521535
# === total 16900 match 6767
# >>> step 17000
# step 16900-16999, precision 0.396342, recall 0.770259, f_score 0.523377
# === total 17000 match 6835
# >>> step 17100
# step 17000-17099, precision 0.395186, recall 0.770259, f_score 0.522368
# === total 17100 match 6855
# >>> step 17200
# step 17100-17199, precision 0.395703, recall 0.771146, f_score 0.523024
# === total 17200 match 6889
# >>> step 17300
# step 17200-17299, precision 0.399799, recall 0.775153, f_score 0.527520
# === total 17300 match 6976
# >>> step 17400
# step 17300-17399, precision 0.401476, recall 0.777564, f_score 0.529538
# === total 17400 match 7044
# >>> step 17500
# step 17400-17499, precision 0.405580, recall 0.780837, f_score 0.533862
# === total 17500 match 7133
# >>> step 17600
# step 17500-17599, precision 0.407849, recall 0.783640, f_score 0.536483
# === total 17600 match 7211
# >>> step 17700
# step 17600-17699, precision 0.407172, recall 0.783640, f_score 0.535897
# === total 17700 match 7223
# >>> step 17800
# step 17700-17799, precision 0.406599, recall 0.780546, f_score 0.534677
# === total 17800 match 7243
# >>> step 17900
# step 17800-17899, precision 0.407321, recall 0.780405, f_score 0.535267
# === total 17900 match 7294
# >>> step 18000
# step 17900-17999, precision 0.408466, recall 0.782121, f_score 0.536660
# === total 18000 match 7347
# >>> step 18100
# step 18000-18099, precision 0.409894, recall 0.784369, f_score 0.538421
# === total 18100 match 7419
# >>> step 18200
# step 18100-18199, precision 0.411481, recall 0.786244, f_score 0.540232
# === total 18200 match 7473
# >>> step 18300
# step 18200-18299, precision 0.411288, recall 0.786440, f_score 0.540112
# === total 18300 match 7530
# >>> step 18400
# step 18300-18399, precision 0.413698, recall 0.788722, f_score 0.542727
# === total 18400 match 7607
# >>> step 18500
# step 18400-18499, precision 0.412773, recall 0.789092, f_score 0.542018
# === total 18500 match 7641
# >>> step 18600
# step 18500-18599, precision 0.415253, recall 0.791071, f_score 0.544621
# === total 18600 match 7723
# >>> step 18700
# step 18600-18699, precision 0.417918, recall 0.793179, f_score 0.547411
# === total 18700 match 7791
# >>> step 18800
# step 18700-18799, precision 0.420251, recall 0.795963, f_score 0.550075
# === total 18800 match 7881
# >>> step 18900
# step 18800-18899, precision 0.422686, recall 0.798529, f_score 0.552772
# === total 18900 match 7961
# >>> step 19000
# step 18900-18999, precision 0.423101, recall 0.799291, f_score 0.553310
# === total 19000 match 7991
# >>> step 19100
# step 19000-19099, precision 0.423269, recall 0.799906, f_score 0.553601
# === total 19100 match 8028
# >>> step 19200
# step 19100-19199, precision 0.424276, recall 0.798457, f_score 0.554113
# === total 19200 match 8049
# >>> step 19300
# step 19200-19299, precision 0.424344, recall 0.793654, f_score 0.553010
# === total 19300 match 8076
# >>> step 19400
# step 19300-19399, precision 0.423861, recall 0.786975, f_score 0.550971
# === total 19400 match 8097
# >>> step 19500
# step 19400-19499, precision 0.424250, recall 0.784983, f_score 0.550810
# === total 19500 match 8132
# >>> step 19600
# step 19500-19599, precision 0.424856, recall 0.781539, f_score 0.550469
# === total 19600 match 8151
# >>> step 19700
# step 19600-19699, precision 0.424283, recall 0.775588, f_score 0.548507
# === total 19700 match 8162
# >>> step 19800
# step 19700-19799, precision 0.425238, recall 0.772012, f_score 0.548405
# === total 19800 match 8186
# >>> step 19900
# step 19800-19899, precision 0.425768, recall 0.764500, f_score 0.546935
# === total 19900 match 8204
# >>> step 20000
# step 19900-19999, precision 0.425850, recall 0.759359, f_score 0.545681
# === total 20000 match 8240
# >>> step 20100
# step 20000-20099, precision 0.426114, recall 0.752835, f_score 0.544203
# === total 20100 match 8256
# >>> step 20200
# step 20100-20199, precision 0.425805, recall 0.747397, f_score 0.542524
# === total 20200 match 8262
# >>> step 20300
# step 20200-20299, precision 0.426368, recall 0.747202, f_score 0.542929
# === total 20300 match 8298
# >>> step 20400
# step 20300-20399, precision 0.427167, recall 0.748372, f_score 0.543886
# === total 20400 match 8341
# >>> step 20500
# step 20400-20499, precision 0.426848, recall 0.748325, f_score 0.543615
# === total 20500 match 8373
# >>> step 20600
# step 20500-20599, precision 0.424920, recall 0.748325, f_score 0.542049
# === total 20600 match 8411
# >>> step 20700
# step 20600-20699, precision 0.424633, recall 0.747397, f_score 0.541572
# === total 20700 match 8452
# >>> step 20800
# step 20700-20799, precision 0.422683, recall 0.747397, f_score 0.539983
# === total 20800 match 8491
# >>> step 20900
# step 20800-20899, precision 0.421195, recall 0.747397, f_score 0.538768
# === total 20900 match 8521
# >>> step 21000
# step 20900-20999, precision 0.418786, recall 0.747397, f_score 0.536793
# === total 21000 match 8570
# >>> step 21100
# step 21000-21099, precision 0.417763, recall 0.747397, f_score 0.535952
# === total 21100 match 8591
# >>> step 21200
# step 21100-21199, precision 0.416502, recall 0.747397, f_score 0.534913
# === total 21200 match 8617
# >>> step 21300
# step 21200-21299, precision 0.415057, recall 0.747397, f_score 0.533720
# === total 21300 match 8647
# >>> step 21400
# step 21300-21399, precision 0.413765, recall 0.747397, f_score 0.532651
# === total 21400 match 8674
# >>> step 21500
# step 21400-21499, precision 0.413343, recall 0.748133, f_score 0.532487
# === total 21500 match 8724
# >>> step 21600
# step 21500-21599, precision 0.413415, recall 0.749070, f_score 0.532784
# === total 21600 match 8766
# >>> step 21700
# step 21600-21699, precision 0.414176, recall 0.750821, f_score 0.533859
# === total 21700 match 8832
# >>> step 21800
# step 21700-21799, precision 0.413463, recall 0.749898, f_score 0.533033
# === total 21800 match 8869
# >>> step 21900
# step 21800-21899, precision 0.413219, recall 0.750357, f_score 0.532947
# === total 21900 match 8896
# >>> step 22000
# step 21900-21999, precision 0.413878, recall 0.751473, f_score 0.533776
# === total 22000 match 8935
# >>> step 22100
# step 22000-22099, precision 0.412631, recall 0.751473, f_score 0.532738
# === total 22100 match 8962
# >>> step 22200
# step 22100-22199, precision 0.413283, recall 0.752177, f_score 0.533458
# === total 22200 match 8989
# >>> step 22300
# step 22200-22299, precision 0.412000, recall 0.752177, f_score 0.532388
# === total 22300 match 9017
# >>> step 22400
# step 22300-22399, precision 0.409954, recall 0.752177, f_score 0.530676
# === total 22400 match 9062
# >>> step 22500
# step 22400-22499, precision 0.408421, recall 0.752177, f_score 0.529391
# === total 22500 match 9096
# >>> step 22600
# step 22500-22599, precision 0.408996, recall 0.753276, f_score 0.530146
# === total 22600 match 9137
# >>> step 22700
# step 22600-22699, precision 0.407613, recall 0.753276, f_score 0.528983
# === total 22700 match 9168
# >>> step 22800
# step 22700-22799, precision 0.406107, recall 0.753276, f_score 0.527713
# === total 22800 match 9202
# >>> step 22900
# step 22800-22899, precision 0.406899, recall 0.754562, f_score 0.528697
# === total 22900 match 9248
# >>> step 23000
# step 22900-22999, precision 0.406515, recall 0.755445, f_score 0.528589
# === total 23000 match 9301
# >>> step 23100
# step 23000-23099, precision 0.404472, recall 0.755445, f_score 0.526858
# === total 23100 match 9348
# >>> step 23200
# step 23100-23199, precision 0.404613, recall 0.756708, f_score 0.527285
# === total 23200 match 9409
# >>> step 23300
# step 23200-23299, precision 0.405900, recall 0.757947, f_score 0.528679
# === total 23300 match 9458
# >>> step 23400
# step 23300-23399, precision 0.404361, recall 0.757947, f_score 0.527371
# === total 23400 match 9494
# >>> step 23500
# step 23400-23499, precision 0.404425, recall 0.758804, f_score 0.527633
# === total 23500 match 9537
# >>> step 23600
# step 23500-23599, precision 0.402610, recall 0.758804, f_score 0.526086
# === total 23600 match 9580
# >>> step 23700
# step 23600-23699, precision 0.401729, recall 0.758804, f_score 0.525334
# === total 23700 match 9601
# >>> step 23800
# step 23700-23799, precision 0.400373, recall 0.758946, f_score 0.524207
# === total 23800 match 9641
# >>> step 23900
# step 23800-23899, precision 0.400765, recall 0.759655, f_score 0.524712
# === total 23900 match 9669
# >>> step 24000
# step 23900-23999, precision 0.398786, recall 0.759655, f_score 0.523013
# === total 24000 match 9717
# >>> step 24100
# step 24000-24099, precision 0.397232, recall 0.759655, f_score 0.521675
# === total 24100 match 9755
# >>> step 24200
# step 24100-24199, precision 0.396014, recall 0.759655, f_score 0.520623
# === total 24200 match 9785
# >>> step 24300
# step 24200-24299, precision 0.395640, recall 0.759484, f_score 0.520260
# === total 24300 match 9817
# >>> step 24400
# step 24300-24399, precision 0.395653, recall 0.758567, f_score 0.520056
# === total 24400 match 9847
# >>> step 24500
# step 24400-24499, precision 0.394532, recall 0.758567, f_score 0.519086
# === total 24500 match 9875
# >>> step 24600
# step 24500-24599, precision 0.394965, recall 0.759783, f_score 0.519746
# === total 24600 match 9930
# >>> step 24700
# step 24600-24699, precision 0.394329, recall 0.759783, f_score 0.519195
# === total 24700 match 9946
# >>> step 24800
# step 24700-24799, precision 0.392907, recall 0.759783, f_score 0.517961
# === total 24800 match 9982
# >>> step 24900
# step 24800-24899, precision 0.393580, recall 0.760987, f_score 0.518825
# === total 24900 match 10031
# >>> step 25000
# step 24900-24999, precision 0.394257, recall 0.762543, f_score 0.519775
# === total 25000 match 10100
# >>> step 25100
# step 25000-25099, precision 0.394848, recall 0.764079, f_score 0.520646
# === total 25100 match 10171
# >>> step 25200
# step 25100-25199, precision 0.393417, recall 0.764079, f_score 0.519400
# === total 25200 match 10208
# >>> step 25300
# step 25200-25299, precision 0.391996, recall 0.764079, f_score 0.518160
# === total 25300 match 10245
# >>> step 25400
# step 25300-25399, precision 0.391843, recall 0.765229, f_score 0.518291
# === total 25400 match 10323
# >>> step 25500
# step 25400-25499, precision 0.390835, recall 0.763763, f_score 0.517072
# === total 25500 match 10365
# >>> step 25600
# step 25500-25599, precision 0.389295, recall 0.763763, f_score 0.515722
# === total 25600 match 10406
# >>> step 25700
# step 25600-25699, precision 0.387767, recall 0.763763, f_score 0.514380
# === total 25700 match 10447
# >>> step 25800
# step 25700-25799, precision 0.387339, recall 0.764562, f_score 0.514185
# === total 25800 match 10505
# >>> step 25900
# step 25800-25899, precision 0.386549, recall 0.760829, f_score 0.512643
# === total 25900 match 10542
# >>> step 26000
# step 25900-25999, precision 0.385197, recall 0.760829, f_score 0.511453
# === total 26000 match 10579
# >>> step 26100
# step 26000-26099, precision 0.383349, recall 0.760829, f_score 0.509821
# === total 26100 match 10630
# >>> step 26200
# step 26100-26199, precision 0.381626, recall 0.760829, f_score 0.508295
# === total 26200 match 10678
# >>> step 26300
# step 26200-26299, precision 0.381028, recall 0.758089, f_score 0.507153
# === total 26300 match 10700
# >>> step 26400
# step 26300-26399, precision 0.379291, recall 0.758089, f_score 0.505612
# === total 26400 match 10749
# >>> step 26500
# step 26400-26499, precision 0.378356, recall 0.756152, f_score 0.504350
# === total 26500 match 10802
# >>> step 26600
# step 26500-26599, precision 0.378736, recall 0.757542, f_score 0.504997
# === total 26600 match 10873
# >>> step 26700
# step 26600-26699, precision 0.379380, recall 0.758829, f_score 0.505855
# === total 26700 match 10931
# >>> step 26800
# step 26700-26799, precision 0.378529, recall 0.756644, f_score 0.504613
# === total 26800 match 10982
# >>> step 26900
# step 26800-26899, precision 0.377905, recall 0.755810, f_score 0.503873
# === total 26900 match 11016
# >>> step 27000
# step 26900-26999, precision 0.377524, recall 0.755664, f_score 0.503502
# === total 27000 match 11043
# >>> step 27100
# step 27000-27099, precision 0.378201, recall 0.756810, f_score 0.504358
# === total 27100 match 11092
# >>> step 27200
# step 27100-27199, precision 0.377143, recall 0.756664, f_score 0.503385
# === total 27200 match 11139
# >>> step 27300
# step 27200-27299, precision 0.377615, recall 0.757396, f_score 0.503967
# === total 27300 match 11186
# >>> step 27400
# step 27300-27399, precision 0.376102, recall 0.757396, f_score 0.502618
# === total 27400 match 11231
# >>> step 27500
# step 27400-27499, precision 0.376106, recall 0.758522, f_score 0.502869
# === total 27500 match 11300
# >>> step 27600
# step 27500-27599, precision 0.374614, recall 0.758522, f_score 0.501534
# === total 27600 match 11345
# >>> step 27700
# step 27600-27699, precision 0.373528, recall 0.758522, f_score 0.500559
# === total 27700 match 11378
# >>> step 27800
# step 27700-27799, precision 0.374508, recall 0.759979, f_score 0.501757
# === total 27800 match 11439
# >>> step 27900
# step 27800-27899, precision 0.373706, recall 0.759505, f_score 0.500933
# === total 27900 match 11493
# >>> step 28000
# step 27900-27999, precision 0.371861, recall 0.759505, f_score 0.499273
# === total 28000 match 11550
# >>> step 28100
# step 28000-28099, precision 0.372003, recall 0.760268, f_score 0.499566
# === total 28100 match 11594
# >>> step 28200
# step 28100-28199, precision 0.371945, recall 0.760252, f_score 0.499511
# === total 28200 match 11663
# >>> step 28300
# step 28200-28299, precision 0.371290, recall 0.760615, f_score 0.498997
# === total 28300 match 11724
# >>> step 28400
# step 28300-28399, precision 0.370043, recall 0.759101, f_score 0.497545
# === total 28400 match 11777
# >>> step 28500
# step 28400-28499, precision 0.368137, recall 0.759101, f_score 0.495819
# === total 28500 match 11838
# >>> step 28600
# step 28500-28599, precision 0.368483, recall 0.759812, f_score 0.496285
# === total 28600 match 11873
# >>> step 28700
# step 28600-28699, precision 0.366815, recall 0.759812, f_score 0.494770
# === total 28700 match 11927
# >>> step 28800
# step 28700-28799, precision 0.366848, recall 0.760561, f_score 0.494958
# === total 28800 match 11975
# >>> step 28900
# step 28800-28899, precision 0.365505, recall 0.760561, f_score 0.493734
# === total 28900 match 12019
# >>> step 29000
# step 28900-28999, precision 0.364950, recall 0.758502, f_score 0.492794
# === total 29000 match 12040
# >>> step 29100
# step 29000-29099, precision 0.363651, recall 0.758502, f_score 0.491609
# === total 29100 match 12083
# >>> step 29200
# step 29100-29199, precision 0.362662, recall 0.758668, f_score 0.490739
# === total 29200 match 12127
# >>> step 29300
# step 29200-29299, precision 0.363823, recall 0.760034, f_score 0.492087
# === total 29300 match 12179
# >>> step 29400
# step 29300-29399, precision 0.364335, recall 0.761141, f_score 0.492787
# === total 29400 match 12236
# >>> step 29500
# step 29400-29499, precision 0.363296, recall 0.761141, f_score 0.491836
# === total 29500 match 12271
# >>> step 29600
# step 29500-29599, precision 0.361469, recall 0.761141, f_score 0.490159
# === total 29600 match 12333
# >>> step 29700
# step 29600-29699, precision 0.361820, recall 0.762519, f_score 0.490768
# === total 29700 match 12415
# >>> step 29800
# step 29700-29799, precision 0.362637, recall 0.763553, f_score 0.491734
# === total 29800 match 12467
# >>> step 29900
# step 29800-29899, precision 0.361478, recall 0.763553, f_score 0.490666
# === total 29900 match 12507
# >>> step 30000
# step 29900-29999, precision 0.361906, recall 0.762888, f_score 0.490923
# === total 30000 match 12553
# >>> step 30100
# step 30000-30099, precision 0.362197, recall 0.764067, f_score 0.491435
# === total 30100 match 12634
# >>> step 30200
# step 30100-30199, precision 0.362303, recall 0.764774, f_score 0.491679
# === total 30200 match 12680
# >>> step 30300
# step 30200-30299, precision 0.362794, recall 0.764443, f_score 0.492062
# === total 30300 match 12729
# >>> step 30400
# step 30300-30399, precision 0.362651, recall 0.764443, f_score 0.491931
# === total 30400 match 12734
# >>> step 30500
# step 30400-30499, precision 0.362673, recall 0.764482, f_score 0.491959
# === total 30500 match 12736
# >>> step 30600
# step 30500-30599, precision 0.364433, recall 0.765692, f_score 0.493827
# === total 30600 match 12787
# >>> step 30700
# step 30600-30699, precision 0.364239, recall 0.765612, f_score 0.493633
# === total 30700 match 12824
# >>> step 30800
# step 30700-30799, precision 0.363778, recall 0.765957, f_score 0.493281
# === total 30800 match 12865
# >>> step 30900
# step 30800-30899, precision 0.364184, recall 0.767253, f_score 0.493923
# === total 30900 match 12944
# >>> step 31000
# step 30900-30999, precision 0.365662, recall 0.768908, f_score 0.495625
# === total 31000 match 13012
# >>> step 31100
# step 31000-31099, precision 0.365809, recall 0.769578, f_score 0.495899
# === total 31100 match 13056
# >>> step 31200
# step 31100-31199, precision 0.367154, recall 0.770707, f_score 0.497369
# === total 31200 match 13128
# >>> step 31300
# step 31200-31299, precision 0.368777, recall 0.771760, f_score 0.499076
# === total 31300 match 13176
# >>> step 31400
# step 31300-31399, precision 0.369223, recall 0.771899, f_score 0.499513
# === total 31400 match 13198
# >>> step 31500
# step 31400-31499, precision 0.369069, recall 0.771722, f_score 0.499336
# === total 31500 match 13236
# >>> step 31600
# step 31500-31599, precision 0.370331, recall 0.772784, f_score 0.500713
# === total 31600 match 13280
# >>> step 31700
# step 31600-31699, precision 0.371576, recall 0.773992, f_score 0.502104
# === total 31700 match 13327
# >>> step 31800
# step 31700-31799, precision 0.371617, recall 0.774626, f_score 0.502274
# === total 31800 match 13374
# >>> step 31900
# step 31800-31899, precision 0.370685, recall 0.774696, f_score 0.501437
# === total 31900 match 13413
# >>> step 32000
# step 31900-31999, precision 0.371113, recall 0.775675, f_score 0.502033
# === total 32000 match 13473
# >>> step 32100
# step 32000-32099, precision 0.371859, recall 0.776543, f_score 0.502898
# === total 32100 match 13532
# >>> step 32200
# step 32100-32199, precision 0.372122, recall 0.776085, f_score 0.503042
# === total 32200 match 13552
# >>> step 32300
# step 32200-32299, precision 0.372967, recall 0.776977, f_score 0.504002
# === total 32300 match 13591
# >>> step 32400
# step 32300-32399, precision 0.373956, recall 0.778134, f_score 0.505147
# === total 32400 match 13646
# >>> step 32500
# step 32400-32499, precision 0.373217, recall 0.778134, f_score 0.504473
# === total 32500 match 13673
# >>> step 32600
# step 32500-32599, precision 0.374035, recall 0.779278, f_score 0.505461
# === total 32600 match 13734
# >>> step 32700
# step 32600-32699, precision 0.375191, recall 0.780344, f_score 0.506740
# === total 32700 match 13777
# >>> step 32800
# step 32700-32799, precision 0.375713, recall 0.781381, f_score 0.507435
# === total 32800 match 13851
# >>> step 32900
# step 32800-32899, precision 0.375718, recall 0.781297, f_score 0.507422
# === total 32900 match 13920
# >>> step 33000
# step 32900-32999, precision 0.375503, recall 0.781297, f_score 0.507225
# === total 33000 match 13928
# >>> step 33100
# step 33000-33099, precision 0.375752, recall 0.780822, f_score 0.507353
# === total 33100 match 13956
# >>> step 33200
# step 33100-33199, precision 0.375725, recall 0.780822, f_score 0.507328
# === total 33200 match 13957
# >>> step 33300
# step 33200-33299, precision 0.375699, recall 0.780822, f_score 0.507304
# === total 33300 match 13958
# >>> step 33400
# step 33300-33399, precision 0.376046, recall 0.781097, f_score 0.507679
# === total 33400 match 13977
# >>> step 33500
# step 33400-33499, precision 0.375633, recall 0.781074, f_score 0.507297
# === total 33500 match 14019
# >>> step 33600
# step 33500-33599, precision 0.375579, recall 0.781074, f_score 0.507248
# === total 33600 match 14021
# >>> step 33700
# step 33600-33699, precision 0.375045, recall 0.781074, f_score 0.506760
# === total 33700 match 14041
# >>> step 33800
# step 33700-33799, precision 0.375524, recall 0.779811, f_score 0.506931
# === total 33800 match 14071
# >>> step 33900
# step 33800-33899, precision 0.374911, recall 0.779811, f_score 0.506373
# === total 33900 match 14094
# >>> step 34000
# step 33900-33999, precision 0.374805, recall 0.779811, f_score 0.506276
# === total 34000 match 14098
# >>> step 34100
# step 34000-34099, precision 0.374779, recall 0.778955, f_score 0.506071
# === total 34100 match 14123
# >>> step 34200
# step 34100-34199, precision 0.374346, recall 0.778300, f_score 0.505539
# === total 34200 match 14142
# >>> step 34300
# step 34200-34299, precision 0.375441, recall 0.779111, f_score 0.506707
# === total 34300 match 14186
# >>> step 34400
# step 34300-34399, precision 0.376257, recall 0.779656, f_score 0.507566
# === total 34400 match 14219
# >>> step 34500
# step 34400-34499, precision 0.376125, recall 0.779656, f_score 0.507446
# === total 34500 match 14224
# >>> step 34600
# step 34500-34599, precision 0.375755, recall 0.779656, f_score 0.507109
# === total 34600 match 14238
# >>> step 34700
# step 34600-34699, precision 0.375465, recall 0.776713, f_score 0.506221
# === total 34700 match 14249
# >>> step 34800
# step 34700-34799, precision 0.374886, recall 0.776713, f_score 0.505695
# === total 34800 match 14271
# >>> step 34900
# step 34800-34899, precision 0.375035, recall 0.776893, f_score 0.505868
# === total 34900 match 14308
# >>> step 35000
# step 34900-34999, precision 0.374738, recall 0.777119, f_score 0.505647
# === total 35000 match 14338
# >>> step 35100
# step 35000-35099, precision 0.374817, recall 0.777296, f_score 0.505756
# === total 35100 match 14359
# >>> step 35200
# step 35100-35199, precision 0.374783, recall 0.774504, f_score 0.505132
# === total 35200 match 14379
# >>> step 35300
# step 35200-35299, precision 0.375338, recall 0.774914, f_score 0.505723
# === total 35300 match 14419
# >>> step 35400
# step 35300-35399, precision 0.376306, recall 0.775749, f_score 0.506780
# === total 35400 match 14451
# >>> step 35500
# step 35400-35499, precision 0.376226, recall 0.774932, f_score 0.506533
# === total 35500 match 14478
# >>> step 35600
# step 35500-35599, precision 0.376575, recall 0.775305, f_score 0.506929
# === total 35600 match 14523
# >>> step 35700
# step 35600-35699, precision 0.377438, recall 0.776084, f_score 0.507876
# === total 35700 match 14564
# >>> step 35800
# step 35700-35799, precision 0.378600, recall 0.777357, f_score 0.509201
# === total 35800 match 14654
# >>> step 35900
# step 35800-35899, precision 0.379430, recall 0.778289, f_score 0.510152
# === total 35900 match 14701
# >>> step 36000
# step 35900-35999, precision 0.379780, recall 0.778999, f_score 0.510621
# === total 36000 match 14748
# >>> step 36100
# step 36000-36099, precision 0.380062, recall 0.778471, f_score 0.510762
# === total 36100 match 14766
# >>> step 36200
# step 36100-36199, precision 0.380821, recall 0.779205, f_score 0.511605
# === total 36200 match 14818
# >>> step 36300
# step 36200-36299, precision 0.381215, recall 0.779339, f_score 0.511990
# === total 36300 match 14842
# >>> step 36400
# step 36300-36399, precision 0.381835, recall 0.778950, f_score 0.512464
# === total 36400 match 14886
# >>> step 36500
# step 36400-36499, precision 0.383366, recall 0.780136, f_score 0.514099
# === total 36500 match 14957
# >>> step 36600
# step 36500-36599, precision 0.384759, recall 0.781111, f_score 0.515562
# === total 36600 match 15025
# >>> step 36700
# step 36600-36699, precision 0.385472, recall 0.780986, f_score 0.516175
# === total 36700 match 15088
# >>> step 36800
# step 36700-36799, precision 0.386743, recall 0.782214, f_score 0.517583
# === total 36800 match 15147
# >>> step 36900
# step 36800-36899, precision 0.387224, recall 0.782435, f_score 0.518062
# === total 36900 match 15185
# >>> step 37000
# step 36900-36999, precision 0.388049, recall 0.782891, f_score 0.518899
# === total 37000 match 15212
# ...
# === total 315800 match 106021
# >>> step 315900
# step 315800-315899, precision 0.335574, recall 0.750496, f_score 0.463777
# === total 315900 match 106048
# >>> step 316000
# step 315900-315999, precision 0.335568, recall 0.750459, f_score 0.463764
# === total 316000 match 106065
# >>> step 316100
# step 316000-316099, precision 0.335524, recall 0.750459, f_score 0.463721
# === total 316100 match 106079
# >>> step 316200
# step 316100-316199, precision 0.335510, recall 0.750501, f_score 0.463716
# === total 316200 match 106134
# >>> step 316300
# step 316200-316299, precision 0.335534, recall 0.750474, f_score 0.463735
# === total 316300 match 106156
# >>> step 316400
# step 316300-316399, precision 0.335481, recall 0.750474, f_score 0.463683
# === total 316400 match 106173
# >>> step 316500
# step 316400-316499, precision 0.335474, recall 0.750474, f_score 0.463677
# === total 316500 match 106175
# >>> step 316600
# step 316500-316599, precision 0.335459, recall 0.750474, f_score 0.463662
# === total 316600 match 106180
# >>> step 316700
# step 316600-316699, precision 0.335437, recall 0.750474, f_score 0.463641
# === total 316700 match 106187
# >>> step 316800
# step 316700-316799, precision 0.335451, recall 0.750563, f_score 0.463672
# === total 316800 match 106233
# >>> step 316900
# step 316800-316899, precision 0.335472, recall 0.750653, f_score 0.463709
# === total 316900 match 106277
# >>> step 317000
# step 316900-316999, precision 0.335522, recall 0.750700, f_score 0.463766
# === total 317000 match 106306
# >>> step 317100
# step 317000-317099, precision 0.335515, recall 0.750768, f_score 0.463772
# === total 317100 match 106356
# >>> step 317200
# step 317100-317199, precision 0.335492, recall 0.750773, f_score 0.463751
# === total 317200 match 106402
# >>> step 317300
# step 317200-317299, precision 0.335432, recall 0.750631, f_score 0.463667
# === total 317300 match 106421
# >>> step 317400
# step 317300-317399, precision 0.335437, recall 0.750720, f_score 0.463689
# === total 317400 match 106470
# >>> step 317500
# step 317400-317499, precision 0.335437, recall 0.750720, f_score 0.463689
# === total 317500 match 106470
# >>> step 317600
# step 317500-317599, precision 0.335437, recall 0.750720, f_score 0.463689
# === total 317600 match 106470
# >>> step 317700
# step 317600-317699, precision 0.335521, recall 0.750814, f_score 0.463787
# === total 317700 match 106497
# >>> step 317800
# step 317700-317799, precision 0.335511, recall 0.750819, f_score 0.463778
# === total 317800 match 106521
# >>> step 317900
# step 317800-317899, precision 0.335583, recall 0.750914, f_score 0.463865
# === total 317900 match 106552
# >>> step 318000
# step 317900-317999, precision 0.335554, recall 0.750914, f_score 0.463837
# === total 318000 match 106561
# >>> step 318100
# step 318000-318099, precision 0.335654, recall 0.751007, f_score 0.463950
# === total 318100 match 106601
# >>> step 318200
# step 318100-318199, precision 0.335725, recall 0.751102, f_score 0.464036
# === total 318200 match 106632
# >>> step 318300
# step 318200-318299, precision 0.335715, recall 0.751028, f_score 0.464012
# === total 318300 match 106665
# >>> step 318400
# step 318300-318399, precision 0.335832, recall 0.751121, f_score 0.464143
# === total 318400 match 106717
# >>> step 318500
# step 318400-318499, precision 0.335791, recall 0.751121, f_score 0.464103
# === total 318500 match 106730
# >>> step 318600
# step 318500-318599, precision 0.335872, recall 0.751173, f_score 0.464190
# === total 318600 match 106752
# >>> step 318700
# step 318600-318699, precision 0.335961, recall 0.751288, f_score 0.464297
# === total 318700 match 106807
# >>> step 318800
# step 318700-318799, precision 0.336004, recall 0.751334, f_score 0.464348
# === total 318800 match 106820
# >>> step 318900
# step 318800-318899, precision 0.335913, recall 0.751334, f_score 0.464261
# === total 318900 match 106849
# >>> step 319000
# step 318900-318999, precision 0.335938, recall 0.751366, f_score 0.464290
# === total 319000 match 106859
# >>> step 319100
# step 319000-319099, precision 0.335928, recall 0.751386, f_score 0.464285
# === total 319100 match 106892
# >>> step 319200
# step 319100-319199, precision 0.336094, recall 0.751599, f_score 0.464484
# === total 319200 match 106970
# >>> step 319300
# step 319200-319299, precision 0.336174, recall 0.751719, f_score 0.464583
# === total 319300 match 107013
# >>> step 319400
# step 319300-319399, precision 0.336269, recall 0.751749, f_score 0.464680
# === total 319400 match 107063
# >>> step 319500
# step 319400-319499, precision 0.336494, recall 0.751992, f_score 0.464941
# === total 319500 match 107140
# >>> step 319600
# step 319500-319599, precision 0.336515, recall 0.751860, f_score 0.464935
# === total 319600 match 107193
# >>> step 319700
# step 319600-319699, precision 0.336616, recall 0.751953, f_score 0.465049
# === total 319700 match 107241
# >>> step 319800
# step 319700-319799, precision 0.336594, recall 0.751953, f_score 0.465029
# === total 319800 match 107248
# >>> step 319900
# step 319800-319899, precision 0.336543, recall 0.751953, f_score 0.464981
# === total 319900 match 107264
# >>> step 320000
# step 319900-319999, precision 0.336467, recall 0.751858, f_score 0.464890
# === total 320000 match 107315
# >>> step 320100
# step 320000-320099, precision 0.336339, recall 0.751780, f_score 0.464752
# === total 320100 match 107365
# >>> step 320200
# step 320100-320199, precision 0.336306, recall 0.751665, f_score 0.464699
# === total 320200 match 107408
# >>> step 320300
# step 320200-320299, precision 0.336234, recall 0.751633, f_score 0.464624
# === total 320300 match 107449
# >>> step 320400
# step 320300-320399, precision 0.336254, recall 0.751632, f_score 0.464643
# === total 320400 match 107496
# >>> step 320500
# step 320400-320499, precision 0.336358, recall 0.751756, f_score 0.464766
# === total 320500 match 107552
# >>> step 320600
# step 320500-320599, precision 0.336280, recall 0.751787, f_score 0.464697
# === total 320600 match 107595
# >>> step 320700
# step 320600-320699, precision 0.336411, recall 0.751952, f_score 0.464854
# === total 320700 match 107648
# >>> step 320800
# step 320700-320799, precision 0.336447, recall 0.752045, f_score 0.464906
# === total 320800 match 107690
# >>> step 320900
# step 320800-320899, precision 0.336443, recall 0.752054, f_score 0.464904
# === total 320900 match 107733
# >>> step 321000
# step 320900-320999, precision 0.336626, recall 0.752275, f_score 0.465121
# === total 321000 match 107802
# >>> step 321100
# step 321000-321099, precision 0.336601, recall 0.752280, f_score 0.465098
# === total 321100 match 107822
# >>> step 321200
# step 321100-321199, precision 0.336585, recall 0.752280, f_score 0.465083
# === total 321200 match 107827
# >>> step 321300
# step 321200-321299, precision 0.336488, recall 0.752306, f_score 0.464995
# === total 321300 match 107873
# >>> step 321400
# step 321300-321399, precision 0.336453, recall 0.752352, f_score 0.464970
# === total 321400 match 107920
# >>> step 321500
# step 321400-321499, precision 0.336636, recall 0.752582, f_score 0.465189
# === total 321500 match 107995
# >>> step 321600
# step 321500-321599, precision 0.336643, recall 0.752700, f_score 0.465219
# === total 321600 match 108061
# >>> step 321700
# step 321600-321699, precision 0.336746, recall 0.752889, f_score 0.465353
# === total 321700 match 108138
# >>> step 321800
# step 321700-321799, precision 0.336937, recall 0.753093, f_score 0.465574
# === total 321800 match 108213
# >>> step 321900
# step 321800-321899, precision 0.337068, recall 0.753271, f_score 0.465733
# === total 321900 match 108275
# >>> step 322000
# step 321900-321999, precision 0.337133, recall 0.753424, f_score 0.465824
# === total 322000 match 108352
# >>> step 322100
# step 322000-322099, precision 0.337033, recall 0.753424, f_score 0.465729
# === total 322100 match 108384
# >>> step 322200
# step 322100-322199, precision 0.336993, recall 0.753424, f_score 0.465691
# === total 322200 match 108397
# >>> step 322300
# step 322200-322299, precision 0.337044, recall 0.753392, f_score 0.465734
# === total 322300 match 108416
# >>> step 322400
# step 322300-322399, precision 0.337068, recall 0.753277, f_score 0.465735
# === total 322400 match 108432
# >>> step 322500
# step 322400-322499, precision 0.337129, recall 0.753307, f_score 0.465798
# === total 322500 match 108457
# >>> step 322600
# step 322500-322599, precision 0.337089, recall 0.753307, f_score 0.465760
# === total 322600 match 108470
# >>> step 322700
# step 322600-322699, precision 0.337195, recall 0.753356, f_score 0.465870
# === total 322700 match 108510
# >>> step 322800
# step 322700-322799, precision 0.337261, recall 0.753267, f_score 0.465917
# === total 322800 match 108536
# >>> step 322900
# step 322800-322899, precision 0.337242, recall 0.753189, f_score 0.465884
# === total 322900 match 108560
# >>> step 323000
# step 322900-322999, precision 0.337302, recall 0.753135, f_score 0.465930
# === total 323000 match 108609
# >>> step 323100
# step 323000-323099, precision 0.337320, recall 0.753140, f_score 0.465948
# === total 323100 match 108624
# >>> step 323200
# step 323100-323199, precision 0.337370, recall 0.753231, f_score 0.466014
# === total 323200 match 108661
# >>> step 323300
# step 323200-323299, precision 0.337397, recall 0.752874, f_score 0.465971
# === total 323300 match 108697
# >>> step 323400
# step 323300-323399, precision 0.337415, recall 0.752858, f_score 0.465985
# === total 323400 match 108709
# >>> step 323500
# step 323400-323499, precision 0.337346, recall 0.752858, f_score 0.465920
# === total 323500 match 108731
# >>> step 323600
# step 323500-323599, precision 0.337346, recall 0.752827, f_score 0.465913
# === total 323600 match 108740
# >>> step 323700
# step 323600-323699, precision 0.337323, recall 0.752888, f_score 0.465903
# === total 323700 match 108783
# >>> step 323800
# step 323700-323799, precision 0.337403, recall 0.752798, f_score 0.465963
# === total 323800 match 108849
# >>> step 323900
# step 323800-323899, precision 0.337445, recall 0.752843, f_score 0.466011
# === total 323900 match 108889
# >>> step 324000
# step 323900-323999, precision 0.337509, recall 0.752994, f_score 0.466101
# === total 324000 match 108966
# >>> step 324100
# step 324000-324099, precision 0.337680, recall 0.753109, f_score 0.466286
# === total 324100 match 109041
# >>> step 324200
# step 324100-324199, precision 0.337706, recall 0.752958, f_score 0.466282
# === total 324200 match 109089
# >>> step 324300
# step 324200-324299, precision 0.337786, recall 0.752967, f_score 0.466360
# === total 324300 match 109140
# >>> step 324400
# step 324300-324399, precision 0.337771, recall 0.752967, f_score 0.466345
# === total 324400 match 109145
# >>> step 324500
# step 324400-324499, precision 0.337743, recall 0.752967, f_score 0.466319
# === total 324500 match 109154
# >>> step 324600
# step 324500-324599, precision 0.337805, recall 0.753098, f_score 0.466403
# === total 324600 match 109211
# >>> step 324700
# step 324600-324699, precision 0.337992, recall 0.753212, f_score 0.466603
# === total 324700 match 109263
# >>> step 324800
# step 324700-324799, precision 0.338091, recall 0.753292, f_score 0.466713
# === total 324800 match 109305
# >>> step 324900
# step 324800-324899, precision 0.338284, recall 0.753284, f_score 0.466895
# === total 324900 match 109355
# >>> step 325000
# step 324900-324999, precision 0.338397, recall 0.753352, f_score 0.467016
# === total 325000 match 109404
# >>> step 325100
# step 325000-325099, precision 0.338493, recall 0.753412, f_score 0.467118
# === total 325100 match 109444
# >>> step 325200
# step 325100-325199, precision 0.338490, recall 0.753502, f_score 0.467133
# === total 325200 match 109498
# >>> step 325300
# step 325200-325299, precision 0.338809, recall 0.753802, f_score 0.467495
# === total 325300 match 109572
# >>> step 325400
# step 325300-325399, precision 0.338994, recall 0.754012, f_score 0.467712
# === total 325400 match 109636
# >>> step 325500
# step 325400-325499, precision 0.339270, recall 0.754210, f_score 0.468012
# === total 325500 match 109709
# >>> step 325600
# step 325500-325599, precision 0.339484, recall 0.754468, f_score 0.468266
# === total 325600 match 109793
# >>> step 325700
# step 325600-325699, precision 0.339404, recall 0.754468, f_score 0.468189
# === total 325700 match 109819
# >>> step 325800
# step 325700-325799, precision 0.339443, recall 0.754602, f_score 0.468252
# === total 325800 match 109886
# >>> step 325900
# step 325800-325899, precision 0.339482, recall 0.754676, f_score 0.468303
# === total 325900 match 109944
# >>> step 326000
# step 325900-325999, precision 0.339564, recall 0.754784, f_score 0.468402
# === total 326000 match 110000
# >>> step 326100
# step 326000-326099, precision 0.339677, recall 0.754982, f_score 0.468548
# === total 326100 match 110081
# >>> step 326200
# step 326100-326199, precision 0.339804, recall 0.755150, f_score 0.468701
# === total 326200 match 110140
# >>> step 326300
# step 326200-326299, precision 0.339830, recall 0.755284, f_score 0.468751
# === total 326300 match 110211
# >>> step 326400
# step 326300-326399, precision 0.340046, recall 0.755540, f_score 0.469006
# === total 326400 match 110294
# >>> step 326500
# step 326400-326499, precision 0.339950, recall 0.755540, f_score 0.468915
# === total 326500 match 110325
# >>> step 326600
# step 326500-326599, precision 0.339952, recall 0.755633, f_score 0.468935
# === total 326600 match 110389
# >>> step 326700
# step 326600-326699, precision 0.340252, recall 0.755943, f_score 0.469280
# === total 326700 match 110477
# >>> step 326800
# step 326700-326799, precision 0.340380, recall 0.756134, f_score 0.469438
# === total 326800 match 110550
# >>> step 326900
# step 326800-326899, precision 0.340663, recall 0.756442, f_score 0.469767
# === total 326900 match 110643
# >>> step 327000
# step 326900-326999, precision 0.340857, recall 0.756636, f_score 0.469988
# === total 327000 match 110724
# >>> step 327100
# step 327000-327099, precision 0.340777, recall 0.756636, f_score 0.469912
# === total 327100 match 110750
# >>> step 327200
# step 327100-327199, precision 0.340962, recall 0.756841, f_score 0.470128
# === total 327200 match 110813
# >>> step 327300
# step 327200-327299, precision 0.341105, recall 0.756849, f_score 0.470266
# === total 327300 match 110872
# >>> step 327400
# step 327300-327399, precision 0.341160, recall 0.756679, f_score 0.470285
# === total 327400 match 110907
# >>> step 327500
# step 327400-327499, precision 0.341351, recall 0.756693, f_score 0.470469
# === total 327500 match 110962
# >>> step 327600
# step 327500-327599, precision 0.341566, recall 0.756614, f_score 0.470658
# === total 327600 match 111018
# >>> step 327700
# step 327600-327699, precision 0.341829, recall 0.756646, f_score 0.470914
# === total 327700 match 111079
# >>> step 327800
# step 327700-327799, precision 0.341837, recall 0.756163, f_score 0.470827
# === total 327800 match 111094
# >>> step 327900
# step 327800-327899, precision 0.341940, recall 0.756057, f_score 0.470905
# === total 327900 match 111151
# >>> step 328000
# step 327900-327999, precision 0.342203, recall 0.755919, f_score 0.471127
# === total 328000 match 111209
# >>> step 328100
# step 328000-328099, precision 0.342187, recall 0.755769, f_score 0.471083
# === total 328100 match 111214
# >>> step 328200
# step 328100-328199, precision 0.342333, recall 0.755884, f_score 0.471244
# === total 328200 match 111263
# >>> step 328300
# step 328200-328299, precision 0.342594, recall 0.756066, f_score 0.471526
# === total 328300 match 111333
# >>> step 328400
# step 328300-328399, precision 0.342928, recall 0.756220, f_score 0.471873
# === total 328400 match 111417
# >>> step 328500
# step 328400-328499, precision 0.343173, recall 0.756436, f_score 0.472147
# === total 328500 match 111486
# >>> step 328600
# step 328500-328599, precision 0.343544, recall 0.756732, f_score 0.472556
# === total 328600 match 111581
# >>> step 328700
# step 328600-328699, precision 0.343933, recall 0.757087, f_score 0.472993
# === total 328700 match 111670
# >>> step 328800
# step 328700-328799, precision 0.344117, recall 0.757143, f_score 0.473177
# === total 328800 match 111744
# >>> step 328900
# step 328800-328899, precision 0.344291, recall 0.757131, f_score 0.473340
# === total 328900 match 111789
# >>> step 329000
# step 328900-328999, precision 0.344285, recall 0.757131, f_score 0.473334
# === total 329000 match 111791
# TOTAL 329000, precision 0.344285, recall 0.757131, f_score 0.473334
# TOTAL true = 50834
# TOTAL error rate = 0.260331

# %%
tf.reset_default_graph()
model_tf_deep(250)    
train(train_imgs, train_lbls, ROOT_FOLDER + "models/tear_model3.ckpt", ROOT_FOLDER + "models/tear_model2.ckpt")
