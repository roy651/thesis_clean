# %%
# RUN Main import block and TODO list

# TODO: see how uri calculated the ridges

# TODO: Perform Histogram equalization - start with it
# TODO: 
# take integral from the Highest peak+-0.005 divide by integral of the entire graph 
# This will be the peakness measure for the PSD ==> The desired ridge index
# TODO:
# take integral from the Highest peak+-0.005 divide by integral of the entire graph - it's the peakness measure for the PSD
# must select a peak above a min threshold in order to ignore noisy frequency
# must ignore peaks above a certain threshold in order to detect meaningful frequency
# run the PSD in moving windows every 200 px (deduced from the below PSD pointing to a freq of 1/0.02=50-> times 4= 200px)
# and medianf the result of the windows
# TODO:
# Another alternative: (with Yariv)
# Run PSD column by column - get the phase, freq, peakness and reconstruct an artificial ridge slice
# from this - reconstruct a "clean" artificial ridge image

# %matplotlib inline
import matplotlib.image as img
import matplotlib.pyplot as plt
import numpy as np
import urllib.request
import os
import glob
from scipy import ndimage
from scipy import signal
# import cv2

from PIL import Image, ImageDraw, ImageFont

import mahotas as mh
from mahotas import polygon
# import pymorph as pm

import networkx as nx

from scipy import ndimage as nd
import skimage.transform as transform
import skimage.morphology as mp
import skimage.io as sio
import scipy.misc as sm
from skimage.filters import threshold_otsu, threshold_adaptive
from skimage.feature import hessian_matrix, hessian_matrix_eigvals
from skimage import exposure
from skimage import data, img_as_float
from sklearn.metrics import precision_recall_fscore_support

from bisect import bisect_left
import math
import warnings
import csv
import tensorflow as tf

# %%
# RUN Utility functions

# One time init
# with open('results.csv', 'w') as csvfile:
#     csvout = csv.writer(csvfile)
#     csvout.writerow(["File", "Model", "Gap", "Slice_size", "Count", "Precision", "Recall", "F-score", "True Count", "Error Rate"])

#BASIC CROP FRAME
X_START = 1000
X_END = 5000
Y_START = 800
Y_END = 4300
BG_2_OBJ_RATIO = 0.94
CUBE_SIZE = 250

# Simple crop by x/y ranges
def crop(image, ymin, ymax, xmin, xmax):
    return image[ymin:ymax, xmin:xmax]

# returns a logical matrix of values beyond a threshld
def thresholded(image, val): 
    return np.logical_and(*[image[...] > val  for t in enumerate([0, 0])])

def find_min_max_without_orphand_pixels(nonzero_dimension, crop_filter=20):
    sorted = np.sort(nonzero_dimension)
    prev=-1
    min_val = sorted[0]
    for i, x in enumerate(sorted[:100]):
        if prev >= 0 and x - prev > crop_filter:
            min_val = x
        prev = x
    prev=-1
    max_val = sorted[-1]
    for i, x in enumerate(sorted[-100:]):
        if prev >= 0 and x - prev > crop_filter:
            max_val = prev
            break
        prev = x
    
    return min_val, max_val

def calc_min_max_coordinates(image, crop_val=50):
    temp = thresholded(image, crop_val)
    temp = temp * 1
    temp = np.nonzero(temp)
    ymin, ymax = find_min_max_without_orphand_pixels(temp[0])
    xmin,xmax = find_min_max_without_orphand_pixels(temp[1])
    return ymin, ymax, xmin, xmax

def calc_min_max_coordinates_dynamic(image, cutoff=1):
    temp = exposure.equalize_adapthist(image, clip_limit=0.03)
    flat = np.sort(np.matrix.getA1(temp))
    sum_all = np.sum(flat)
    index = np.argmin(flat.cumsum() < (sum_all * cutoff))

    temp = thresholded(temp, flat[index])
    temp = temp * 1
    temp = np.nonzero(temp)
    ymin, ymax = find_min_max_without_orphand_pixels(temp[0])
    xmin,xmax = find_min_max_without_orphand_pixels(temp[1])
    return ymin, ymax, xmin, xmax

# initial static crop and a seondary dynamic crop based on signal2noise ratio
def crop_full_scan(image, cutoff):
    temp = crop(image, Y_START, Y_END, X_START, X_END)
    ymin, ymax, xmin, xmax = calc_min_max_coordinates_dynamic(temp, cutoff)
    temp = crop(image, Y_START+ymin, Y_START+ymax, X_START+xmin, X_START+xmax)
    return temp, X_START+xmin, Y_START+ymin, X_START+xmax, Y_START+ymax

def crop_thresholded(image):
    temp = crop(image, 0, image.shape[0]-1, 0, image.shape[1]-1)
    ymin, ymax, xmin, xmax = calc_min_max_coordinates(temp)
    temp = crop(image, ymin, ymax, xmin, xmax)
    return temp

def read_full_path_and_crop(image_name, cutoff=BG_2_OBJ_RATIO):
    image = img.imread(image_name)

    # Smart-crop the image to get rid of all the noise and redundant area
    # return crop_full_scan(image)
    cropped, x_min, y_min, x_max, y_max = crop_full_scan(image, cutoff)
    return exposure.equalize_adapthist(cropped, clip_limit=0.03), x_min, y_min, x_max, y_max

def read_and_crop(image_name):
    if "il239838" in os.getcwd():
        image = img.imread("/Users/il239838/Downloads/private/Thesis/Papyrus/" + image_name)
    else:
        f = urllib.request.urlopen("https://dl.dropboxusercontent.com/s/31b96942qdcn73k/" + image_name)
        image = img.imread(f, format='jpeg')

    # Smart-crop the image to get rid of all the noise and redundant area
    # return crop_full_scan(image)
    cropped = crop_full_scan(image)
    return exposure.equalize_adapthist(cropped, clip_limit=0.03)

# TODO: fix performance!!! http://scikit-image.org/docs/dev/user_guide/tutorial_parallelization.html
def combine_3_images_to_RGB(red, green, blue):
    new_image = np.empty((blue.shape[0],blue.shape[1],3))
    for x in range(0, blue.shape[0]):
        for y in range(0, blue.shape[1]):
            new_image[x,y,0] = red[x,y]
            new_image[x,y,1] = green[x,y]
            new_image[x,y,2] = blue[x,y]
    return new_image

def slice_image_left_edge_no_adapt(original, width=200, rotate=0):
    rot = ndimage.rotate(original, rotate)
    # Slice the left slice of the so-called "blue" image
    left_edge_orig = crop(rot, 0, 1400, 0, width)
    
    return left_edge_orig

def slice_image_left_edge(original, width=200, rotate=0):
    rot = ndimage.rotate(original, rotate)
    # Slice the left slice of the so-called "blue" image
    left_edge_orig = crop(rot, 0, 1400, 0, width)
    left_edge_orig = crop_thresholded(left_edge_orig)

    # Copy to a new array so we don't thrash the origin
    left_edge = np.empty_like (left_edge_orig)
    np.copyto(left_edge, left_edge_orig)

    # Zero down low level "noise" values
    low_values_indices = left_edge < 30  # Where values are low
    left_edge[low_values_indices] = 0  # All low values set to 0
    return left_edge

def get_best_angle_rotation(original, crop=True, width=200):
    min_var = 99999999999
    best_angle = -10
    for x in range(-5,5):
        if crop:            
            rot_edge = slice_image_left_edge(original, width, x)
        else:
            rot_edge = ndimage.rotate(original, x)
        left_var = np.var(rot_edge, axis=1)
        # left_var = np.apply_along_axis(lambda v: np.var(v[np.nonzero(v)]), 1, rot_edge)
        var_sum = np.sum(left_var)
        if (var_sum < min_var):
            min_var = var_sum
            best_angle = x
    print ("best_angle="+str(best_angle))
    return best_angle

def get_best_orientation(original, crop=True, width=200):
    min_var = 99999999999
    best_angle = 0
    #import pdb; pdb.set_trace()
    for x in [0, 90]:
        if crop:            
            rot_edge = slice_image_left_edge_no_adapt(original, width, x)
        else:
            rot_edge = ndimage.rotate(original, x)
        left_var = np.var(rot_edge, axis=1)
        # USE NEXT BLOCK if having issues with variance including zero values
        # low_values_indices = rot_edge < 0.12
        # rot_edge[low_values_indices] = 0
        # left_var = np.apply_along_axis(lambda v: np.var(v[np.nonzero(v)]), 1, rot_edge)
        var_sum = np.sum(left_var)
        if (var_sum < min_var):
            min_var = var_sum
            best_angle = x
    print ("best_angle="+str(best_angle))
    return best_angle

def get_manual_orientation(original, crop=True, width=200):
    rot1 = ndimage.rotate(original, 90)
    plot_comparison(original, rot1, "Rotated")
    input_var = input("Enter 1 to rotate and 0 to keep as-is: ")
    print ("you entered " + input_var) 
    
    return input_var


#     import pdb; pdb.set_trace()
def calc_neighbors(slice_map, col, row):
    # import pdb; pdb.set_trace()
    if ((col-1, row) in slice_map and slice_map[(col-1, row)] != None):
        slice_map[(col, row)]["left"] = slice_map[(col-1, row)]
        slice_map[(col-1, row)]["right"] = slice_map[(col, row)]
    if ((col+1, row) in slice_map and slice_map[(col+1, row)] != None):
        slice_map[(col, row)]["right"] = slice_map[(col+1, row)]
        slice_map[(col+1, row)]["left"] = slice_map[(col, row)]
    if ((col, row-1) in slice_map and slice_map[(col, row-1)] != None):
        slice_map[(col, row)]["top"] = slice_map[(col, row-1)]
        slice_map[(col, row-1)]["bottom"] = slice_map[(col, row)]
    if ((col, row+1) in slice_map and slice_map[(col, row+1)] != None):
        slice_map[(col, row)]["bottom"] = slice_map[(col, row+1)]
        slice_map[(col, row+1)]["top"] = slice_map[(col, row)]
    


def create_cube(raw, x, y):
    cube = {}
    cube["cube"] = raw
    cube["top_row"] = x
    cube["left_col"] = y
    cube["right_col"] = y + CUBE_SIZE
    return cube
    

ZERO_CUBE = create_cube(np.zeros((CUBE_SIZE, CUBE_SIZE), dtype=np.int), -1, -2)

# slice an image to cubes with 250X250 pixel size
def slice_to_static_slices(cropped_original):
    structure = {}
    # cropped_original = cropped_original / 256 # divide by 256 to "normalize" between 0 and 1
    x, y = cropped_original.shape
    print (x,y)
    n = 0
    # every 250 pixels on the x axis == rows
    while ((n + 1) * CUBE_SIZE < x):
        m = 0
        # every 250 pixels on the y axis == cols
        while ((m + 1) * CUBE_SIZE < y):
            # cut a cube of 250X250
            cube = (crop(cropped_original, n * CUBE_SIZE, (n + 1) * CUBE_SIZE, m * CUBE_SIZE, (m + 1) * CUBE_SIZE))
            # keep only cubes for which half of the pixels have some "color"
            # import pdb; pdb.set_trace()
            # print(np.median(cube))
            if np.median(cube) > 0.2: # aligned with the normalization 0.2 correlates to 50
                # keep the cube
                structure[(m, n)] = create_cube(cube, n * CUBE_SIZE, m * CUBE_SIZE)
                structure[(m, n)]["col"] = m
                structure[(m, n)]["row"] = n
            else:
                structure[(m, n)] = None
            m += 1
        n += 1
    
    # this loop has to be performed only after we've established all the None cubes
    for cube in structure.values():
        # set the reference to neighbor cubes
        if cube != None:
            calc_neighbors(structure, cube["col"], cube["row"])
        
    # return the data structure with all the cubes and the counters of the rows and columns
    return structure, m, n

def pad_above(original, above, amount):
    res = np.insert(original["cube"], np.zeros(amount), above["cube"][-amount:], axis=0)
    res = np.delete(res, np.arange(CUBE_SIZE,CUBE_SIZE+amount), axis=0)
    return create_cube(res, original["top_row"] - amount, original["left_col"])
  

def pad_below(original, below, amount):
    res = np.insert(original["cube"], np.full(amount, CUBE_SIZE), below["cube"][:amount], axis=0)
    res = np.delete(res, np.arange(0, amount), axis=0)
    return create_cube(res, original["top_row"] + amount, original["left_col"])

def pad_left(original, left, amount):
    res = np.insert(original["cube"], np.zeros(amount, dtype=int), left["cube"][:,-amount:], axis=1)
    res = np.delete(res, np.arange(CUBE_SIZE, CUBE_SIZE+amount), axis=1)
    return create_cube(res, original["top_row"], original["left_col"] - amount)

def pad_right(original, right, amount):
    res = np.insert(original["cube"], [CUBE_SIZE], right["cube"][:,:amount], axis=1)
    res = np.delete(res, np.arange(0, amount), axis=1)
    return create_cube(res, original["top_row"], original["left_col"] + amount)
    

# "Shave" the right edge of the cube with <gap> pixels and pad with zeros on the left
def shave_right(original, amount):
    return pad_left(original, ZERO_CUBE, amount)
    

# "Shave" the left edge of the cube with <gap> pixels and pad with zeros on the right    
def shave_left(original, amount):
    return pad_right(original, ZERO_CUBE, amount)
    

# concatenate cubes 
def concatenate_cubes(left, right, slice_size):
    con = np.concatenate((left["cube"][:,-slice_size:], right["cube"][:,:slice_size]), axis=1)
    x_delta = right["top_row"] - left["top_row"]
    y_delta = right["left_col"] - left["right_col"] 
    return con, x_delta, y_delta
    

# concatenate cubes while artificially creating a gap between them. Pad the other end of the cube with zeros
def concatenate_cubes_zero_pad_gaps(left_orig, right_orig, gap):
    left = left_orig if gap == 0 else shave_right(left_orig, gap)
    right = right_orig if gap == 0 else shave_left(right_orig, gap)
    return concatenate_cubes(left, right)    

# concatenate cubes while artificially creating a gap between them. Pad the other end of the cobe with the nearby
# continuation of the cubes
def concatenate_cubes_with_gap(left_orig, right_orig, gap, left_pad, right_pad, slice_size):
    # import pdb; pdb.set_trace()
    left = left_orig if gap == 0 else pad_left(left_orig, left_pad, gap)
    right = right_orig if gap == 0 else pad_right(right_orig, right_pad, gap)
    return concatenate_cubes(left, right, slice_size)        

# convert the data structure of cubes into a train set of 2 arrays of images and labels
# each image is a concatanation of 2 images from the original cubes set, covering all combinations of images
# effectively creating Nx(N-1) images
def build_train_set(rows, cols, cubes, gap, slice_size):
    # import pdb; pdb.set_trace()
    warnings.filterwarnings("ignore")

    train_imgs = []
    train_lbls = []
    train_x_delta = []
    train_y_delta = []
    # iterate over the rows and cols, essentially going over the grid of sliced cubes
    for row in range(0, rows):
        for col in range(0, cols):
            # if this cube exists (could have been removed previously due to lack of data)
            if (cubes[(col, row)] != None):
                # for each "current" image in the iteration
                curr = cubes[(col, row)]
                # iterate over all the cubes to find all the "other" (adjacent) cubes
                for adj_row in range(0, rows):
                    for adj_col in range(0, cols):
                        if (adj_row != row or adj_col != col):
                            if (cubes[(adj_col, adj_row)] != None):
                                adj = cubes[(adj_col, adj_row)]
                                # append the adjacent image to the current image
                                # pass the filling cubes on the right and left to pad against the gap
                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys())):
                                    if (gap == 0):
                                        conc, x_delta, y_delta = concatenate_cubes(curr, adj, slice_size)
                                    else:
                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr, adj, gap, curr["left"], adj["right"], slice_size)
                                    train_imgs.append(conc)
                                    train_x_delta.append(x_delta)
                                    train_y_delta.append(y_delta)
                                    # if the adj image is on the same row and on the right of the curr image - it will be marked as match    
                                    if (adj_row == row and adj_col == (col + 1)):
                                        # mark the image as matched
                                        train_lbls.append([0,1])
                                        # need to enrich the set with a few more tru positive samples - so we offset 
                                        # the matched images up ad down a few times and create more matches
                                        if ("top" in curr.keys() and "top"in adj.keys()):
                                            for i in range(5, 101, 5):
                                                curr1 = pad_above(curr, curr["top"],i)
                                                adj1 = pad_above(adj, adj["top"],i)
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys() and "top" in curr["left"].keys() and "top"in curr["right"].keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_above(curr["left"], curr["left"]["top"], i) # FIXIT?
                                                        adj1Right = pad_above(adj["right"], curr["right"]["top"], i) # FIXIT?
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                        if ("bottom" in curr.keys() and "bottom"in adj.keys()):
                                            for i in range(5, 101, 5):
                                                curr1 = pad_below(curr, curr["bottom"],i)
                                                adj1 = pad_below(adj, adj["bottom"],i)
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys() and "bottom" in curr["left"].keys() and "bottom"in curr["right"].keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_below(curr["left"], curr["left"]["bottom"], i) # FIXIT?
                                                        adj1Right = pad_below(adj["right"], curr["right"]["bottom"], i) # FIXIT?
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                        if ("left" in curr.keys()): # enough to check only the curr as the left of the adj is the curr
                                            for i in range(5, 101, 5):
                                                curr1 = pad_left(curr, curr["left"],i)
                                                adj1 = pad_left(adj, adj["left"],i) # essentially the curr
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_left(curr["left"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        adj1Right = pad_left(adj["right"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                        if ("right" in adj.keys()): # enough to check only the adj as the right of the curr is the adj
                                            for i in range(5, 101, 5):
                                                curr1 = pad_right(curr, curr["right"],i) # essentially the adj
                                                adj1 = pad_right(adj, adj["right"],i)
                                                if (gap == 0 or ("left" in curr.keys() and "right" in adj.keys())):
                                                    if (gap == 0):
                                                        conc, x_delta, y_delta = concatenate_cubes(curr1, adj1, slice_size)
                                                    else:
                                                        curr1Left = pad_right(curr["left"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        adj1Right = pad_right(adj["right"], ZERO_CUBE, i) # FIXIT? + assuming the gap will not be more than 150
                                                        conc, x_delta, y_delta = concatenate_cubes_with_gap(curr1, adj1, gap, curr1Left, adj1Right, slice_size)
                                                    train_imgs.append(conc)
                                                    train_x_delta.append(x_delta)
                                                    train_y_delta.append(y_delta)
                                                    # mark the image as matched
                                                    train_lbls.append([0,1])
                                    else:
                                        # mark the image as not matched
                                        train_lbls.append([1,0])
                                
    warnings.filterwarnings("default")
    return train_imgs, train_lbls, train_x_delta, train_y_delta

# %%
# RUN Image utility functions (external source)
def branchedPoints(skel):
    branch1=np.array([[2, 1, 2], [1, 1, 1], [2, 2, 2]])
    branch2=np.array([[1, 2, 1], [2, 1, 2], [1, 2, 1]])
    branch3=np.array([[1, 2, 1], [2, 1, 2], [1, 2, 2]])
    branch4=np.array([[2, 1, 2], [1, 1, 2], [2, 1, 2]])
    branch5=np.array([[1, 2, 2], [2, 1, 2], [1, 2, 1]])
    branch6=np.array([[2, 2, 2], [1, 1, 1], [2, 1, 2]])
    branch7=np.array([[2, 2, 1], [2, 1, 2], [1, 2, 1]])
    branch8=np.array([[2, 1, 2], [2, 1, 1], [2, 1, 2]])
    branch9=np.array([[1, 2, 1], [2, 1, 2], [2, 2, 1]])
    br1=mh.morph.hitmiss(skel,branch1)
    br2=mh.morph.hitmiss(skel,branch2)
    br3=mh.morph.hitmiss(skel,branch3)
    br4=mh.morph.hitmiss(skel,branch4)
    br5=mh.morph.hitmiss(skel,branch5)
    br6=mh.morph.hitmiss(skel,branch6)
    br7=mh.morph.hitmiss(skel,branch7)
    br8=mh.morph.hitmiss(skel,branch8)
    br9=mh.morph.hitmiss(skel,branch9)
    return br1+br2+br3+br4+br5+br6+br7+br8+br9

def endPoints(skel):
    endpoint1=np.array([[0, 0, 0],
                        [0, 1, 0],
                        [2, 1, 2]])
    
    endpoint2=np.array([[0, 0, 0],
                        [0, 1, 2],
                        [0, 2, 1]])
    
    endpoint3=np.array([[0, 0, 2],
                        [0, 1, 1],
                        [0, 0, 2]])
    
    endpoint4=np.array([[0, 2, 1],
                        [0, 1, 2],
                        [0, 0, 0]])
    
    endpoint5=np.array([[2, 1, 2],
                        [0, 1, 0],
                        [0, 0, 0]])
    
    endpoint6=np.array([[1, 2, 0],
                        [2, 1, 0],
                        [0, 0, 0]])
    
    endpoint7=np.array([[2, 0, 0],
                        [1, 1, 0],
                        [2, 0, 0]])
    
    endpoint8=np.array([[0, 0, 0],
                        [2, 1, 0],
                        [1, 2, 0]])
    
    ep1=mh.morph.hitmiss(skel,endpoint1)
    ep2=mh.morph.hitmiss(skel,endpoint2)
    ep3=mh.morph.hitmiss(skel,endpoint3)
    ep4=mh.morph.hitmiss(skel,endpoint4)
    ep5=mh.morph.hitmiss(skel,endpoint5)
    ep6=mh.morph.hitmiss(skel,endpoint6)
    ep7=mh.morph.hitmiss(skel,endpoint7)
    ep8=mh.morph.hitmiss(skel,endpoint8)
    ep = ep1+ep2+ep3+ep4+ep5+ep6+ep7+ep8
    return ep

def pruning(skeleton, size):
    '''remove iteratively end points "size" 
       times from the skeleton
    '''
    for i in range(0, size):
        endpoints = endPoints(skeleton)
        endpoints = np.logical_not(endpoints)
        skeleton = np.logical_and(skeleton,endpoints)
    return skeleton

def plot_comparison(original, filtered, filter_name):

    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 4), sharex=True, sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    ax1.set_adjustable('box-forced')
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(filter_name)
    ax2.axis('off')
    ax2.set_adjustable('box-forced')

# %%
# Pre-process the validation set
def folder_walker(path, full_path, filter_text=""):
    result = []
    for root, dirs, files in os.walk(path):
        for file_ in files:
            if "-V-" in file_ and not file_.startswith("."):
                if (filter_text == "" or filter_text in file_):
                    # print(os.path.join(root, file_))
                    if full_path:
                        result.append( os.path.join(root, file_) )
                    else:
                        result.append(file_)
    return result

input_files = folder_walker("/Volumes/250GB/PAPYRI", True, "ML638 _018")
no_rotate = folder_walker("/Volumes/250GB/no_rotate", False)
extra_crop = folder_walker("/Volumes/250GB/crop_more", False)
#input_files = folder_walker("/Volumes/250GB/P589-Fg011-V")

# %%
# RUN
def read_and_select(files):
    count = 0
    for file_ in files:
        image = img.imread(file_)
        output = "/Volumes/250gb/selected"+file_[file_.rfind('/'):]
        count += 1
        img.imsave(output, image, cmap=plt.cm.gray)
        print(output)
    print(count)

images_crop_data = []
def read_and_write_cropped(files):
    count = 0
    rot = False
    for file_ in files:
        image, x_min, y_min, x_max, y_max = read_full_path_and_crop(file_)
        output_np = "/Volumes/250gb/cropped2"+file_[file_.rfind('/'):]
        output_img = "/Volumes/250gb/cropped_bw2"+file_[file_.rfind('/'):]
        count += 1
        print(output_img)
        if file_[file_.rfind('/')+1:file_.rfind('-D')] in extra_crop:
            print("extra crop")
            image, x_min, y_min, x_max, y_max = read_full_path_and_crop(file_, 0.98)
            #import pdb; pdb.set_trace()

        if file_[file_.rfind('/')+1:file_.rfind('-D')] not in no_rotate:
            image = np.rot90(image)
            rot = True        
        else:
            print("no rotate")
            rot = False        
            
        images_crop_data.append({
                "file": file_,
                "x_start": x_min,
                "y_start": y_min,
                "x_end": x_max,
                "y_end": y_max,
                "rotate": rot
            })

        np.save(output_np, image)
        # cv2.imwrite(output, image)
        plt.imsave(output_img, image, cmap=plt.cm.gray)
        
    print(count)
        
read_and_write_cropped(input_files)
# Out:
# /Volumes/250gb/cropped_bw2/P589-Fg001-V-C01-R01-D12022013-T111114-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg002-V-C01-R01-D12022013-T112400-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg003-V-C01-R01-D12022013-T114238-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg004-V-C01-R01-D12022013-T115122-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg005-V-C01-R01-D12022013-T115957-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg006-V-C01-R01-D12022013-T121224-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P589-Fg007-V-C01-R01-D12022013-T122152-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg008-V-C01-R01-D12022013-T123020-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg009-V-C01-R01-D12022013-T123842-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg010-V-C01-R01-D12022013-T124806-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg011-V-C01-R01-D12022013-T125637-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P589-Fg012-V-C01-R01-D12022013-T130509-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg001-V-C01-R01-D19012014-T115843-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P596-Fg002-V-C01-R01-D19012014-T120813-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg003-V-C01-R01-D19012014-T121734-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg004-V-C01-R01-D19012014-T122811-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg005-V-C01-R01-D19012014-T131036-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg006-V-C01-R01-D19012014-T132029-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg007-V-C01-R01-D19012014-T133024-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg008-V-C01-R01-D19012014-T133839-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg009-V-C01-R01-D19012014-T134823-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg010-V-C01-R01-D19012014-T140114-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg011-V-C01-R01-D19012014-T140951-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg012-V-C01-R01-D19012014-T142045-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg013-V-C01-R01-D19012014-T142905-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg014-V-C01-R01-D19012014-T143732-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg015-V-C01-R01-D19012014-T144520-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg016-V-C01-R01-D10122014-T093231-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg017-V-C01-R01-D19012014-T150317-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg018-V-C01-R01-D19012014-T151220-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg019-V-C01-R01-D19012014-T152047-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg020-V-C01-R01-D19012014-T152939-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg021-V-C01-R01-D19012014-T153758-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg022-V-C01-R01-D20012014-T094822-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg023-V-C01-R01-D20012014-T095634-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg024-V-C01-R01-D20012014-T100441-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg025-V-C01-R01-D20012014-T101436-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg026-V-C01-R01-D20012014-T102256-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg027-V-C01-R01-D20012014-T103313-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg028-V-C01-R01-D20012014-T104311-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg029-V-C01-R01-D20012014-T105249-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg030-V-C01-R01-D20012014-T110102-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg031-V-C01-R01-D20012014-T110945-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg032-V-C01-R01-D20012014-T113938-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg033-V-C01-R01-D20012014-T112940-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg034-V-C01-R01-D20012014-T114914-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg035-V-C01-R01-D20012014-T115735-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg036-V-C01-R01-D20012014-T120635-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg037-V-C01-R01-D20012014-T121453-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg038-V-C01-R01-D20012014-T122525-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg039-V-C01-R01-D20012014-T131936-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg040-V-C01-R01-D20012014-T134235-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg041-V-C01-R01-D20012014-T133814-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg042-V-C01-R01-D20012014-T135659-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg043-V-C01-R01-D20012014-T140533-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg044-V-C01-R01-D20012014-T141552-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg045-V-C01-R01-D20012014-T142357-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg046-V-C01-R01-D20012014-T143202-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg047-V-C01-R01-D20012014-T144042-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg048-V-C01-R01-D20012014-T144916-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg049-V-C01-R01-D20012014-T150129-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg050-V-C01-R01-D20012014-T151021-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg051-V-C01-R01-D20012014-T152838-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg052-V-C01-R01-D22012014-T093945-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg053-V-C01-R01-D22012014-T094804-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg054-V-C01-R01-D22012014-T095736-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg055-V-C01-R01-D22012014-T100617-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg056-V-C01-R01-D22012014-T101455-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg057-V-C01-R01-D22012014-T102326-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg058-V-C01-R01-D22012014-T103334-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg059-V-C01-R01-D22012014-T104211-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg060-V-C01-R01-D22012014-T105053-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg061-V-C01-R01-D22012014-T105919-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg062-V-C01-R01-D22012014-T110734-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg063-V-C01-R01-D22012014-T111621-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg064-V-C01-R01-D22012014-T112529-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg065-V-C01-R01-D22012014-T113545-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg066-V-C01-R01-D22012014-T115010-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg067-V-C01-R01-D22012014-T120037-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg068-V-C01-R01-D22012014-T121857-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg069-V-C01-R01-D22012014-T122730-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg070-V-C01-R01-D22012014-T123605-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg071-V-C01-R01-D22012014-T124942-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg072-V-C01-R01-D22012014-T125806-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg073-V-C01-R01-D22012014-T130619-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P596-Fg074-V-C01-R01-D22012014-T131454-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg075-V-C01-R01-D22012014-T132331-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg076-V-C01-R01-D22012014-T133230-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg077-V-C01-R01-D22012014-T134039-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg078-V-C01-R01-D22012014-T134935-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg079-V-C01-R01-D22012014-T135758-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P596-Fg080-V-C01-R01-D22012014-T140626-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg081-V-C01-R01-D22012014-T141443-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P596-Fg082-V-C01-R01-D22012014-T142235-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg083-V-C01-R01-D22012014-T143021-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg084-V-C01-R01-D22012014-T143755-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P596-Fg085-V-C01-R01-D22012014-T144539-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg001-V-C01-R01-D30112014-T101313-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg002-V-C01-R01-D30112014-T102248-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg003-V-C01-R01-D30112014-T103141-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg004-V-C01-R01-D30112014-T110303-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg005-V-C01-R01-D30112014-T111131-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg006-V-C01-R01-D30112014-T111958-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg007-V-C01-R01-D30112014-T112820-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg008-V-C01-R01-D30112014-T113634-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg009-V-C01-R01-D30112014-T115017-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg010-V-C01-R01-D30112014-T123526-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg011-V-C01-R01-D30112014-T124252-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg012-V-C01-R01-D30112014-T125059-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg013-V-C01-R01-D30112014-T131041-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg014-V-C01-R01-D30112014-T131849-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg015-V-C01-R01-D30112014-T132658-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg016-V-C01-R01-D30112014-T133502-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg017-V-C01-R01-D30112014-T135628-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg018-V-C01-R01-D30112014-T140441-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg019-V-C01-R01-D30112014-T141320-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg020-V-C01-R01-D30112014-T142106-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg021-V-C01-R01-D30112014-T142912-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg022-V-C01-R01-D30112014-T143735-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg023-V-C01-R01-D30112014-T144639-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg024-V-C01-R01-D30112014-T145447-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg025-V-C01-R01-D30112014-T150611-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg026-V-C01-R01-D30112014-T151604-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg027-V-C01-R01-D30112014-T152802-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg028-V-C01-R01-D30112014-T153541-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg029-V-C01-R01-D30112014-T154333-ML638 _018.jpg
# extra crop
# no rotate
# /Volumes/250gb/cropped_bw2/P597-Fg030-V-C01-R01-D30112014-T155128-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg031-V-C01-R01-D01122014-T091456-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg032-V-C01-R01-D01122014-T092254-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg033-V-C01-R01-D01122014-T093105-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg034-V-C01-R01-D01122014-T093849-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg035-V-C01-R01-D01122014-T094646-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg036-V-C01-R01-D01122014-T095519-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg037-V-C01-R01-D01122014-T100405-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg038-V-C01-R01-D01122014-T101213-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg039-V-C01-R01-D01122014-T102051-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg040-V-C01-R01-D01122014-T103014-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg041-V-C01-R01-D01122014-T103817-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg042-V-C01-R01-D01122014-T104633-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg043-V-C01-R01-D01122014-T105546-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg044-V-C01-R01-D01122014-T110411-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg045-V-C01-R01-D01122014-T112210-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg046-V-C01-R01-D01122014-T113002-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg047-V-C01-R01-D01122014-T113803-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg048-V-C01-R01-D01122014-T122955-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg049-V-C01-R01-D01122014-T123857-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg050-V-C01-R01-D01122014-T124640-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg051-V-C01-R01-D01122014-T125556-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg052-V-C01-R01-D01122014-T130337-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg053-V-C01-R01-D01122014-T131604-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg054-V-C01-R01-D01122014-T132416-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg055-V-C01-R01-D01122014-T133333-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg056-V-C01-R01-D01122014-T134220-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg057-V-C01-R01-D01122014-T135348-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg058-V-C01-R01-D01122014-T140215-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg059-V-C01-R01-D01122014-T141104-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg060-V-C01-R01-D01122014-T141941-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg061-V-C01-R01-D01122014-T142927-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg062-V-C01-R01-D01122014-T143757-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg063-V-C01-R01-D01122014-T144548-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg064-V-C01-R01-D01122014-T145337-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg065-V-C01-R01-D01122014-T150736-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg066-V-C01-R01-D01122014-T151624-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg067-V-C01-R01-D02122014-T091144-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg068-V-C01-R01-D02122014-T091939-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg069-V-C01-R01-D02122014-T092736-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P597-Fg070-V-C01-R01-D02122014-T094251-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg071-V-C01-R01-D02122014-T095737-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P597-Fg072-V-C01-R01-D02122014-T100826-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P598-Fg001-V-C01-R01-D07012014-T105717-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg002-V-C01-R01-D07012014-T110515-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P598-Fg003-V-C01-R01-D07012014-T111412-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg004-V-C01-R01-D07012014-T112202-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg005-V-C01-R01-D07012014-T113520-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg006-V-C01-R01-D07012014-T114255-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg007-V-C01-R01-D07012014-T115107-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg008-V-C01-R01-D07012014-T123911-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg009-V-C01-R01-D07012014-T125232-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg010-V-C01-R01-D07012014-T130049-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg011-V-C01-R01-D07012014-T130850-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg012-V-C01-R01-D07012014-T131627-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg013-V-C01-R01-D07012014-T132450-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg014-V-C01-R01-D07012014-T133248-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg015-V-C01-R01-D07012014-T134050-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg016-V-C01-R01-D07012014-T134836-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg017-V-C01-R01-D07012014-T135638-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg018-V-C01-R01-D07012014-T140420-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P598-Fg019-V-C01-R01-D07012014-T141237-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg020-V-C01-R01-D07012014-T142020-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg021-V-C01-R01-D07012014-T142813-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg022-V-C01-R01-D07012014-T143617-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg023-V-C01-R01-D07012014-T144346-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg024-V-C01-R01-D07012014-T145134-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg025-V-C01-R01-D07012014-T145914-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg026-V-C01-R01-D07012014-T150637-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P598-Fg027-V-C01-R01-D08012014-T090319-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P598-Fg028-V-C01-R01-D08012014-T091113-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P598-Fg029-V-C01-R01-D08012014-T091929-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg030-V-C01-R01-D08012014-T092728-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg031-V-C01-R01-D08012014-T093535-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg032-V-C01-R01-D08012014-T094343-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg033-V-C01-R01-D08012014-T095124-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg034-V-C01-R01-D08012014-T113919-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P598-Fg035-V-C01-R01-D08012014-T114742-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P598-Fg036-V-C01-R01-D08012014-T120043-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P590-Fg001-V-C01-R01-D13022013-T135831-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg002-V-C01-R01-D13022013-T140623-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg003-V-C01-R01-D13022013-T141451-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg004-V-C01-R01-D13022013-T142314-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg005-V-C01-R01-D13022013-T143033-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg006-V-C01-R01-D13022013-T143816-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg007-V-C01-R01-D13022013-T144900-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg008-V-C01-R01-D13022013-T145640-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg009-V-C01-R01-D13022013-T150516-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg010-V-C01-R01-D13022013-T151327-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg011-V-C01-R01-D13022013-T152126-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg012-V-C01-R01-D13022013-T152920-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg013-V-C01-R01-D13022013-T154000-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg014-V-C01-R01-D14022013-T110256-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg015-V-C01-R01-D14022013-T111212-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg016-V-C01-R01-D14022013-T124908-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg017-V-C01-R01-D14022013-T112939-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg018-V-C01-R01-D14022013-T113955-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg019-V-C01-R01-D14022013-T115307-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg020-V-C01-R01-D14022013-T120138-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg021-V-C01-R01-D14022013-T121136-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P590-Fg022-V-C01-R01-D14022013-T122020-ML638 _018.jpg
# extra crop
# no rotate
# /Volumes/250gb/cropped_bw2/P590-Fg023-V-C01-R01-D14022013-T123034-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg024-V-C01-R01-D14022013-T123931-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg025-V-C01-R01-D14022013-T125734-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg026-V-C01-R01-D14022013-T141513-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg027-V-C01-R01-D14022013-T142337-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg028-V-C01-R01-D14022013-T143331-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg029-V-C01-R01-D14022013-T144300-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg030-V-C01-R01-D14022013-T145646-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg031-V-C01-R01-D14022013-T150510-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg032-V-C01-R01-D14022013-T151728-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg033-V-C01-R01-D14022013-T152702-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg034-V-C01-R01-D14022013-T153515-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P590-Fg035-V-C01-R01-D14022013-T154354-ML638 _018.jpg
# /Volumes/250gb/cropped_bw2/P593-Fg001-V-C01-R01-D30122013-T143528-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg002-V-C01-R01-D30122013-T144349-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg003-V-C01-R01-D30122013-T145210-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg004-V-C01-R01-D30122013-T150045-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg005-V-C01-R01-D30122013-T151255-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg006-V-C01-R01-D30122013-T152201-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P593-Fg007-V-C01-R01-D30122013-T153034-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P593-Fg008-V-C01-R01-D30122013-T153909-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P593-Fg009-V-C01-R01-D30122013-T154732-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P593-Fg010-V-C01-R01-D31122013-T084652-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg011-V-C01-R01-D31122013-T085542-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg012-V-C01-R01-D31122013-T090434-ML638 _018.jpg
# extra crop
# /Volumes/250gb/cropped_bw2/P593-Fg013-V-C01-R01-D31122013-T091310-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg014-V-C01-R01-D31122013-T092131-ML638 _018.jpg
# extra crop
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg015-V-C01-R01-D31122013-T092919-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg016-V-C01-R01-D31122013-T093806-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg017-V-C01-R01-D31122013-T094553-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg018-V-C01-R01-D31122013-T095423-ML638 _018.jpg
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg019-V-C01-R01-D31122013-T100354-ML638 _018.jpg
# extra crop
# no rotate
# /Volumes/250gb/cropped_bw2/P593-Fg020-V-C01-R01-D31122013-T101137-ML638 _018.jpg
# extra crop
# 260

# %%
with open('crops.csv', 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerow(["file", 
                        "x_start", 
                        "y_start",
                        "x_end",
                        "y_end",
                        "rotate"])
    for image_crop_data in images_crop_data:
        csvwriter.writerow([image_crop_data["file"], 
                            image_crop_data["x_start"], 
                            image_crop_data["y_start"], 
                            image_crop_data["x_end"], 
                            image_crop_data["y_end"], 
                            image_crop_data["rotate"]])
